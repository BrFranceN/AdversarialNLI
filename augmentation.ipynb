# %%
import torch
import numpy as np 
import pandas as pd
from typing import Dict
import torch
from datasets import load_dataset, Dataset
from transformers import DataCollatorWithPadding
from datasets import load_metric,load_from_disk
from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    EvalPrediction,
    Trainer,
    TrainingArguments,
    set_seed,
)

from tqdm import tqdm
from datetime import datetime
import re
import random

import nltk
from nltk.corpus import wordnet as wn
nltk.download('wordnet')

import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package wordnet to /home/bitfra/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
## MODEL PARAMETERS
# we will use with Distil-BERT
language_model_name = "distilbert-base-uncased"

### Training Argurments

# this GPU should be enough for this task to handle 32 samples per batch
batch_size = 32

# optim
learning_rate = 1e-4
weight_decay = 0.001 # we could use e.g. 0.01 in case of very low and very high amount of data for regularization

# training
epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
set_seed(42)
# load our dataset
adversarial_set = load_dataset("iperbole/adversarial_fever_nli")
nli_dataset = load_dataset("tommasobonomo/sem_augmented_fever_nli",trust_remote_code=True)

# %% [markdown]
# # Metric def and save the dataset

# %%
#SAVE DATASET

# nli_dataset.save_to_disk('nli_data')

# copy_dataset = load_from_disk('nli_data')

# print(copy_dataset)

# %%
# METRIC DEFINITION

# Metrics
def compute_metrics(eval_pred):
   load_accuracy = load_metric("accuracy")
   load_f1 = load_metric("f1")

   logits, labels = eval_pred
   predictions = np.argmax(logits, axis=-1)
   accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
   f1 = load_f1.compute(predictions=predictions, references=labels,accuracy="weigthed")["f1"]
   return {"accuracy": accuracy, "f1": f1}

# %% [markdown]
# # Utilities

# %%
def get_synonyms(word, pos):
    synonyms = set()
    for syn in wn.synsets(word, pos=pos):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)



def get_synset_by_offset(offset):
    # Estrai l'offset numerico dalla stringa e convertilo in un intero
    offset_num = int(''.join(filter(str.isdigit, offset)))
    pos = offset[-1]  # Prendi l'ultima lettera come parte del discorso
    return wn.synset_from_pos_and_offset(pos, offset_num)



def get_related_words(synset):
    # Ottenere sinonimi
    synonyms = synset.lemma_names()

    # Ottenere iperonimi (categorie generali)
    hypernyms = synset.hypernyms()
    hypernym_words = set()
    for hypernym in hypernyms:
        hypernym_words.update(hypernym.lemma_names())

    # Ottenere iponimi (sottocategorie)
    hyponyms = synset.hyponyms()
    hyponym_words = set()
    for hyponym in hyponyms:
        hyponym_words.update(hyponym.lemma_names())


    # Ottenere antonimi
    antonym_words = set()
    for lemma in synset.lemmas():
        for antonym in lemma.antonyms():
            antonym_words.add(antonym.name())

    return {
        'synonyms': list(synonyms),
        'hypernyms': list(hypernym_words),
        'hyponyms': list(hyponym_words),
        'antonyms': list(antonym_words)
    }



# extract the text from span information
def get_text_from_span(tokens, span):
    # return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1 ))
    result = ' '
    i = span[0]
    while span[0] <= i <= span[1]:
        try:

            result.join(tokens[i]['rawText'])
            i+=1
        except:
            print(f"tokens -> {tokens}")
            print(f"i -> {i}")
    return result


    # return ' '.join(tokens[i]['rawText'] while span[0] <= i <= span[1]: i+1)

# %% [markdown]
# # Idea0 (isnot)

# %%
# filtered_dataset = nli_dataset['train'].filter(lambda example: ' is not ' in example['premise'].lower() or ' is not ' in example['hypothesis'].lower())
filtered_dataset_isnot = nli_dataset['train'].filter(lambda example: ' is not ' in example['hypothesis'].lower())




# Define the set of words to check for
# keywords = {'marry', 'remarries', 'wed', 'marrying', 'marries', 'married'}

# Filter the dataset
# filtered_dataset_married = nli_dataset['train'].filter(lambda example: any(word in example['hypothesis'] for word in keywords))

# %%
print(len(filtered_dataset_married))
# Out:
# 330

# %%
# IDEA change is not when is a contradiction 
def opposite_isnot(filtered_dataset):

    new_samples = []


    for elem in filtered_dataset:

        new_sample = {}
        text_prem = elem['premise']
        text_hp = elem['hypothesis']
        label = elem['label']


        if label == 'CONTRADICTION':
            new_sample['premise'] = text_prem
            new_sample['hypothesis'] = text_hp.replace(" is not ", " is ")
            new_sample['label'] = 'ENTAILMENT'
            new_samples.append(new_sample)

    return new_samples
        

# print(len(filtered_dataset_isnot))
new_samples = opposite_isnot(filtered_dataset_isnot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 25
#      21     return new_samples
#      24 # print(len(filtered_dataset_isnot))
# ---> 25 new_samples = opposite_isnot(filtered_dataset_isnot)
#
# NameError: name 'filtered_dataset_isnot' is not defined

# %%
# TO CONCATENATE NEW SAMPLES
new_samples = {
    'premise': ["New premise 1", "New premise 2"],
    'hypothesis': ["New hypothesis 1", "New hypothesis 2"],
    'label': [0, 1],  # Example labels: 0 for ENTAILMENT, 1 for CONTRADICTION, etc.
    # Add other fields if needed, e.g., 'srl' and 'wsd'
}

# Convert new samples to a Dataset
new_dataset = Dataset.from_dict(new_samples)


# Add new samples to the existing training dataset
prova = concatenate_datasets([filtered_dataset_isnot, new_dataset])
print(prova[-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 14
#      10 new_dataset = Dataset.from_dict(new_samples)
#      13 # Add new samples to the existing training dataset
# ---> 14 prova = concatenate_datasets([filtered_dataset_isnot, new_dataset])
#      15 print(prova[-1])
#
# File ~/miniconda3/envs/nlp_env/lib/python3.11/site-packages/datasets/combine.py:213, in concatenate_datasets(dsets, info, split, axis)
#     209         raise ValueError(
#     210             f"Unable to interleave a {dataset_type.__name__} (at position 0) with a {other_type.__name__} (at position {i}). Expected a list of Dataset objects or a list of IterableDataset objects."
#     211         )
#     212 if dataset_type is Dataset:
# --> 213     return _concatenate_map_style_datasets(dsets, info=info, split=split, axis=axis)
#     214 else:
#     215     return _concatenate_iterable_datasets(dsets, info=info, split=split, axis=axis)
#
# File ~/miniconda3/envs/nlp_env/lib/python3.11/site-packages/datasets/arrow_dataset.py:6243, in _concatenate_map_style_datasets(dsets, info, split, axis)
#    6241 # Perform checks (and a potentional cast if axis=0)
#    6242 if axis == 0:
# -> 6243     _check_if_features_can_be_aligned([dset.features for dset in dsets])
#    6244 else:
#    6245     if not all(dset.num_rows == dsets[0].num_rows for dset in dsets):
#
# File ~/miniconda3/envs/nlp_env/lib/python3.11/site-packages/datasets/features/features.py:2211, in _check_if_features_can_be_aligned(features_list)
#    2209     _check_if_features_can_be_aligned([name2feature[k], v])
#    2210 elif not (isinstance(v, Value) and v.dtype == "null") and name2feature[k] != v:
# -> 2211     raise ValueError(
#    2212         f'The features can\'t be aligned because the key {k} of features {features} has unexpected type - {v} (expected either {name2feature[k]} or Value("null").'
#    2213     )
#
# ValueError: The features can't be aligned because the key label of features {'premise': Value(dtype='string', id=None), 'hypothesis': Value(dtype='string', id=None), 'label': Value(dtype='int64', id=None)} has unexpected type - Value(dtype='int64', id=None) (expected either Value(dtype='string', id=None) or Value("null").

# %%
print(len(new_samples))
# Out:
# 782

# %% [markdown]
# #  Extract info from dataset

# %%
def extract_info(filtered_dataset):

    most_frequent_verbs = {}
    most_frequent_pbframe = {}
    nb_data = set()
    new_samples = []
    info_elements = []
    possible_locations = []
    marriage_role = set()
    marriages_info = []
    verbs= set()
    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')
    for index,elem in tqdm(enumerate(filtered_dataset)):

        new_sample = {}

        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']
        subject_added = False
        marriage_added = False

        # print()
        # print(f"srl {srl['annotations']}")
        # print(f"srl {srl['tokens']}")


        # matches = re.findall(pattern_birth, premise)


        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']


        # find the born event in srl annotations


        for annotation_pre in annotations_pre:

            #reference verb of annotation
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']


            if (frame_name_pb in most_frequent_pbframe):
                most_frequent_pbframe[frame_name_pb] +=1
            else:
                most_frequent_pbframe[frame_name_pb] = 0


            if (verb in most_frequent_verbs):
                most_frequent_verbs[verb] +=1
            else:
                most_frequent_verbs[verb] = 1

           

    return most_frequent_verbs,most_frequent_pbframe


most_frequent_verbs,most_frequent_pbframe = extract_info(nli_dataset['train'])
# Out:
# 51086it [00:48, 1042.59it/s]

# %%
# Ordina il dizionario in base ai valori in ordine decrescente
most_frequent_pbframe_sorted = dict(sorted(most_frequent_pbframe.items(), key=lambda item: item[1], reverse=True))

# Stampa il dizionario ordinato
for chiave, valore in most_frequent_pbframe_sorted.items():
    print(f"{chiave}: {valore}")
# Out:
# be.01: 54298
# bear.02: 10215
# star.01: 7927
# know.01: 7891
# be.03: 7287
# direct.01: 6440
# include.01: 6279
# win.01: 6193
# have.01: 5611
# write.01: 5550
# release.01: 5171
# become.01: 3568
# receive.01: 3395
# produce.01: 3296
# appear.01: 2953
# have.03: 2527
# begin.01: 2455
# base.02: 2296
# play.02: 2014
# earn.01: 1864
# follow.01: 1740
# nominate.01: 1719
# create.01: 1672
# serve.01: 1596
# feature.01: 1525
# sell.01: 1380
# premiere.01: 1326
# found.01: 1198
# play.01: 1197
# work.01: 1141
# portray.01: 1138
# default.01: 0
# wedge.01: 0
# contradict.01: 0
# capitalize.02: 0
# pass.04: 0
# inhale.01: 0
# absorb.01: 0
# cure.01: 0
# interrupt.01: 0
# trip.01: 0
# conform.01: 0
# route.01: 0
# inflate.01: 0
# blow.04: 0
# outnumber.01: 0
# frustrate.01: 0
# swear.01: 0
# takeover.01: 0
# unload.01: 0
# shoot.06: 0
# penetrate.01: 0
# circumscribe.01: 0
# wreck.01: 0
# propagate.01: 0
# cater.01: 0
# exaggerate.01: 0
# carve.01: 0
# carve.02: 0
# outrage.01: 0
# band.01: 0
# tumble.01: 0
# look.07: 0
# reopen.01: 0
# analysis.01: 0
# deliberate.01: 0
# graze.01: 0
# crouch.01: 0
# subjugate.01: 0
# torment.01: 0
# clean.01: 0
# distribution.01: 0
# spew.01: 0
# brand.01: 0
# spare.01: 0
# tip.03: 0
# seal.01: 0
# hurry.01: 0
# recuperate.01: 0
# mature.01: 0
# intrigue.01: 0
# curtail.01: 0
# alienate.01: 0
# patent.01: 0
# pack.01: 0
# rob.01: 0
# burgeon.01: 0
# eclipse.01: 0
# indict.01: 0
# tailor.01: 0
# breach.01: 0
# knead.01: 0
# scoop.02: 0
# untie.01: 0
# blink.01: 0
# muse.01: 0
# bomb.01: 0
# tilt.01: 0
# charge.02: 0
# unfold.02: 0
# inflame.01: 0
# carry.02: 0
# disgust.01: 0
# startle.01: 0
# nurse.01: 0
# estrange.01: 0
# worry.02: 0
# cool.01: 0
# cook.01: 0
# vote.03: 0
# jump.01: 0
# stem.02: 0
# cry.03: 0
# mediate.01: 0

# %% [markdown]
# # Scheme to follow to extract info from srl

# %%
# print(type(nli_dataset["train"]))
# print(type(nli_dataset["train"][0]))
# print(nli_dataset["train"])

#TODO UNDERSTAND BEFORE GO AHEAD!
#THIS IS THE SCHEME THAT YOU HAVE TO FOLLOW TO IMPLEMENT THE VARIOUS IDEA THAT YOU HAVE.    

verbatlasFrame_pre = set()
probankFrame_pre = set()
verbatlasRoles_pre = set()
probankRoles_pre = set()


verbatlasFrame_hp = set()
probankFrame_hp = set()
verbatlasRoles_hp = set()
probankRoles_hp = set()


verbatlasLocations_pre = set()
probankLocations_pre = set()
verbatlasLocations_hp = set()
probankLocations_hp = set()

count = 0


# FOR EACH ELEMENT
for elem in nli_dataset["train"]:
    srl_hp = elem['srl']['hypothesis']
    srl_pre = elem['srl']['premise']

    tokens_pre = srl_pre['tokens']
    annotations_pre = srl_pre['annotations']    
    
    tokens_hp = srl_hp['tokens']
    annotations_hp = srl_hp['annotations']


    ## If you want to find a particular element
    # if elem['id'] == '15454': 
    #     count = 1
    #     print("trovato")
    #     trovato_tokens = tokens
    #     trovato_annotations = annotations

#EXTRACT INFO FROM PREMISE
    for annotation in annotations_hp:
        token_index = annotation['tokenIndex']
        verb = tokens_hp[token_index]['rawText']
        print(f"Verb: {verb}\n")

        print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame_hp.add(frame_name)
        print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'Location'):
                verbatlasLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()

        print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame_hp.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'ARGM-LOC'):
                probankLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()


## EXTRACT INFO FROM HYPOTHEIS
    for annotation in annotations_hp:
        token_index = annotation['tokenIndex']
        verb = tokens_hp[token_index]['rawText']
        print(f"Verb: {verb}\n")

        print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame_hp.add(frame_name)
        print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'Location'):
                verbatlasLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()

        print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame_hp.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'ARGM-LOC'):
                probankLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()



    
    # if count==1:break
    # else:count+=1

    # break
# Out:
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Roman Atwood is
#   Attribute: a content creator .
#
# PropBank:
#   ARG1: Roman Atwood is
#   ARG2: a content creator .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Roman Atwood is
#   Attribute: a content creator .
#
# PropBank:
#   ARG1: Roman Atwood is
#   ARG2: a content creator .
#
# Verb: play
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Agent: The Boston Celtics play
#   Theme: their home games at
#   Location: at TD Garden .
#
# PropBank:
#   ARG0: The Boston Celtics play
#   ARG1: their home games at
#   ARGM-LOC: at TD Garden .
#
# Verb: play
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Agent: The Boston Celtics play
#   Theme: their home games at
#   Location: at TD Garden .
#
# PropBank:
#   ARG0: The Boston Celtics play
#   ARG1: their home games at
#   ARGM-LOC: at TD Garden .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a movie called The Hunger Games .
#
# PropBank:
#   ARG1: a movie called The Hunger Games .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a movie called
#   Attribute: The Hunger Games .
#
# PropBank:
#   ARG1: a movie called
#   ARG2: The Hunger Games .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a movie called The Hunger Games .
#
# PropBank:
#   ARG1: a movie called The Hunger Games .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a movie called
#   Attribute: The Hunger Games .
#
# PropBank:
#   ARG1: a movie called
#   ARG2: The Hunger Games .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Ryan Seacrest is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Ryan Seacrest is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Ryan Seacrest is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Ryan Seacrest is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Stranger than Fiction is
#   Attribute: a film .
#
# PropBank:
#   ARG1: Stranger than Fiction is
#   ARG2: a film .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Stranger than Fiction is
#   Attribute: a film .
#
# PropBank:
#   ARG1: Stranger than Fiction is
#   ARG2: a film .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: John Wick : Chapter 2 was
#   Attribute: theatrically released
#   Location: in the Oregon .
#
# PropBank:
#   ARG1: John Wick : Chapter 2 was
#   ARGM-MNR: theatrically released
#   ARGM-LOC: in the Oregon .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: John Wick : Chapter 2 was
#   Attribute: theatrically released
#   Location: in the Oregon .
#
# PropBank:
#   ARG1: John Wick : Chapter 2 was
#   ARGM-MNR: theatrically released
#   ARGM-LOC: in the Oregon .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Afghanistan is
#   Attribute: the source of the Kushan dynasty .
#
# PropBank:
#   ARG1: Afghanistan is
#   ARG2: the source of the Kushan dynasty .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Afghanistan is
#   Attribute: the source of the Kushan dynasty .
#
# PropBank:
#   ARG1: Afghanistan is
#   ARG2: the source of the Kushan dynasty .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Tupac Shakur was
#   Location: Lesane Parish Crooks .
#
# PropBank:
#   ARG1: Tupac Shakur was
#   ARGM-LOC: Lesane Parish Crooks .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Tupac Shakur was
#   Location: Lesane Parish Crooks .
#
# PropBank:
#   ARG1: Tupac Shakur was
#   ARGM-LOC: Lesane Parish Crooks .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Whoopi Goldberg co
#   Attribute: co -
#   Product: an American dance tournament .
#
# PropBank:
#   ARG0: Whoopi Goldberg co
#   ARGM-MNR: co -
#   ARG1: an American dance tournament .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Whoopi Goldberg co
#   Attribute: co -
#   Product: an American dance tournament .
#
# PropBank:
#   ARG0: Whoopi Goldberg co
#   ARGM-MNR: co -
#   ARG1: an American dance tournament .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Grace Jones is
#   Attribute: a dancer .
#
# PropBank:
#   ARG1: Grace Jones is
#   ARG2: a dancer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Grace Jones is
#   Attribute: a dancer .
#
# PropBank:
#   ARG1: Grace Jones is
#   ARG2: a dancer .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Lisbon has
#   Attribute: a population larger than 1 .
#
# PropBank:
#   ARG0: Lisbon has
#   ARG1: a population larger than 1 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Lisbon has
#   Attribute: a population larger than 1 .
#
# PropBank:
#   ARG0: Lisbon has
#   ARG1: a population larger than 1 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Newfoundland and Labrador is
#   Attribute: the most linguistically homogeneous of Canada .
#
# PropBank:
#   ARG1: Newfoundland and Labrador is
#   ARG2: the most linguistically homogeneous of Canada .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Newfoundland and Labrador is
#   Attribute: the most linguistically homogeneous of Canada .
#
# PropBank:
#   ARG1: Newfoundland and Labrador is
#   ARG2: the most linguistically homogeneous of Canada .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Sophie Turner was
#   Time: in the 1990s .
#
# PropBank:
#   ARG1: Sophie Turner was
#   ARGM-TMP: in the 1990s .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Sophie Turner was
#   Time: in the 1990s .
#
# PropBank:
#   ARG1: Sophie Turner was
#   ARGM-TMP: in the 1990s .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: The Smurfs ( film ) was
#
# PropBank:
#   ARG1: The Smurfs ( film ) was
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: The Smurfs ( film ) was
#
# PropBank:
#   ARG1: The Smurfs ( film ) was
#
# Verb: led
#
# VerbAtlas:
#  Frame: MOVE-SOMETHING
#   Agent: Jimmy Carter led
#   Theme: the international boycott of the 2010 Olympics .
#
# PropBank:
#   ARG0: Jimmy Carter led
#   ARG1: the international boycott of the 2010 Olympics .
#
# Verb: led
#
# VerbAtlas:
#  Frame: MOVE-SOMETHING
#   Agent: Jimmy Carter led
#   Theme: the international boycott of the 2010 Olympics .
#
# PropBank:
#   ARG0: Jimmy Carter led
#   ARG1: the international boycott of the 2010 Olympics .
#
# Verb: came
#
# VerbAtlas:
#  Frame: HAPPEN_OCCUR
#   Theme: Hacksaw Ridge came
#   Location: in America on
#   Time: on November 4 , 2016 .
#
# PropBank:
#   ARG1: Hacksaw Ridge came
#   ARGM-LOC: in America on
#   ARGM-TMP: on November 4 , 2016 .
#
# Verb: came
#
# VerbAtlas:
#  Frame: HAPPEN_OCCUR
#   Theme: Hacksaw Ridge came
#   Location: in America on
#   Time: on November 4 , 2016 .
#
# PropBank:
#   ARG1: Hacksaw Ridge came
#   ARGM-LOC: in America on
#   ARGM-TMP: on November 4 , 2016 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Uzbekistan is
#   Attribute: a part of the Commonwealth of Independent States ( CIS ) .
#
# PropBank:
#   ARG1: Uzbekistan is
#   ARG2: a part of the Commonwealth of Independent States ( CIS ) .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Uzbekistan is
#   Attribute: a part of the Commonwealth of Independent States ( CIS ) .
#
# PropBank:
#   ARG1: Uzbekistan is
#   ARG2: a part of the Commonwealth of Independent States ( CIS ) .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Paul Wesley is
#   Attribute: a professional alias .
#
# PropBank:
#   ARG1: Paul Wesley is
#   ARG2: a professional alias .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Paul Wesley is
#   Attribute: a professional alias .
#
# PropBank:
#   ARG1: Paul Wesley is
#   ARG2: a professional alias .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Brian Wilson was
#   Attribute: part of the Beach Boys .
#
# PropBank:
#   ARG1: Brian Wilson was
#   ARG2: part of the Beach Boys .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Brian Wilson was
#   Attribute: part of the Beach Boys .
#
# PropBank:
#   ARG1: Brian Wilson was
#   ARG2: part of the Beach Boys .
#
# Verb: argued
#
# VerbAtlas:
#  Frame: SPEAK
#   Topic: The Existence of God has
#   Attribute: through the Five Ways .
#
# PropBank:
#   ARG1: The Existence of God has
#   ARGM-MNR: through the Five Ways .
#
# Verb: argued
#
# VerbAtlas:
#  Frame: SPEAK
#   Topic: The Existence of God has
#   Attribute: through the Five Ways .
#
# PropBank:
#   ARG1: The Existence of God has
#   ARGM-MNR: through the Five Ways .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Richard Harris was
#   Time: on October 25 , 2002 .
#
# PropBank:
#   ARG1: Richard Harris was
#   ARGM-TMP: on October 25 , 2002 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Richard Harris was
#   Time: on October 25 , 2002 .
#
# PropBank:
#   ARG1: Richard Harris was
#   ARGM-TMP: on October 25 , 2002 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Fosters is
#   Attribute: a television series .
#
# PropBank:
#   ARG1: The Fosters is
#   ARG2: a television series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Fosters is
#   Attribute: a television series .
#
# PropBank:
#   ARG1: The Fosters is
#   ARG2: a television series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Filmfare is
#   Attribute: about cheese .
#
# PropBank:
#   ARG1: Filmfare is
#   ARG2: about cheese .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Filmfare is
#   Attribute: about cheese .
#
# PropBank:
#   ARG1: Filmfare is
#   ARG2: about cheese .
#
# Verb: lacks
#
# VerbAtlas:
#  Frame: MISS_OMIT_LACK
#   Agent: Buckingham Palace lacks
#   Theme: brightly colored scagliola .
#
# PropBank:
#   ARG0: Buckingham Palace lacks
#   ARG1: brightly colored scagliola .
#
# Verb: colored
#
# VerbAtlas:
#  Frame: COLOR
#   Attribute: brightly colored
#   Patient: scagliola .
#
# PropBank:
#   ARGM-MNR: brightly colored
#   ARG1: scagliola .
#
# Verb: lacks
#
# VerbAtlas:
#  Frame: MISS_OMIT_LACK
#   Agent: Buckingham Palace lacks
#   Theme: brightly colored scagliola .
#
# PropBank:
#   ARG0: Buckingham Palace lacks
#   ARG1: brightly colored scagliola .
#
# Verb: colored
#
# VerbAtlas:
#  Frame: COLOR
#   Attribute: brightly colored
#   Patient: scagliola .
#
# PropBank:
#   ARGM-MNR: brightly colored
#   ARG1: scagliola .
#
# Verb: valued
#
# VerbAtlas:
#  Frame: CALCULATE_ESTIMATE
#   Theme: Liverpool F.C. was
#   Time: at one point .
#
# PropBank:
#   ARG1: Liverpool F.C. was
#   ARG2: at $ 1.55 billion at
#   ARGM-TMP: at one point .
#
# Verb: valued
#
# VerbAtlas:
#  Frame: CALCULATE_ESTIMATE
#   Theme: Liverpool F.C. was
#   Time: at one point .
#
# PropBank:
#   ARG1: Liverpool F.C. was
#   ARG2: at $ 1.55 billion at
#   ARGM-TMP: at one point .
#
# Verb: makes
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Land Rover makes
#   Product: cars .
#
# PropBank:
#   ARG0: Land Rover makes
#   ARG1: cars .
#
# Verb: makes
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Land Rover makes
#   Product: cars .
#
# PropBank:
#   ARG0: Land Rover makes
#   ARG1: cars .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Agent: Martin Scorsese worked
#   Theme: on commission .
#
# PropBank:
#   ARG0: Martin Scorsese worked
#   ARG1: on commission .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Agent: Martin Scorsese worked
#   Theme: on commission .
#
# PropBank:
#   ARG0: Martin Scorsese worked
#   ARG1: on commission .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Peter Davison has
#   Attribute: in a BBC show .
#
# PropBank:
#   ARG1: Peter Davison has
#   ARG2: in a BBC show .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Peter Davison has
#   Attribute: in a BBC show .
#
# PropBank:
#   ARG1: Peter Davison has
#   ARG2: in a BBC show .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: 21 Jump Street was
#   Time: June 16 , 2012 .
#
# PropBank:
#   ARG1: 21 Jump Street was
#   ARGM-TMP: June 16 , 2012 .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: 21 Jump Street was
#   Time: June 16 , 2012 .
#
# PropBank:
#   ARG1: 21 Jump Street was
#   ARGM-TMP: June 16 , 2012 .
#
# Verb: featured
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Attribute: T. J. Miller was
#   Cause: in Deadpool 2 .
#
# PropBank:
#   ARG1: T. J. Miller was
#   ARG2: in Deadpool 2 .
#
# Verb: featured
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Attribute: T. J. Miller was
#   Cause: in Deadpool 2 .
#
# PropBank:
#   ARG1: T. J. Miller was
#   ARG2: in Deadpool 2 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Chris Terrio was
#   Location: in Kansas .
#
# PropBank:
#   ARG1: Chris Terrio was
#   ARGM-LOC: in Kansas .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Chris Terrio was
#   Location: in Kansas .
#
# PropBank:
#   ARG1: Chris Terrio was
#   ARGM-LOC: in Kansas .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: named
#
# VerbAtlas:
#  Frame: NAME
#   Theme: Mariah Carey was
#   Time: on the 27th .
#
# PropBank:
#   ARG1: Mariah Carey was
#   ARGM-TMP: on the 27th .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: named
#
# VerbAtlas:
#  Frame: NAME
#   Theme: Mariah Carey was
#   Time: on the 27th .
#
# PropBank:
#   ARG1: Mariah Carey was
#   ARGM-TMP: on the 27th .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Giancarlo Stanton was
#   Attribute: in the 2017 MLB draft .
#
# PropBank:
#   ARG1: Giancarlo Stanton was
#   ARG2: in the 2017 MLB draft .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Giancarlo Stanton was
#   Attribute: in the 2017 MLB draft .
#
# PropBank:
#   ARG1: Giancarlo Stanton was
#   ARG2: in the 2017 MLB draft .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Sean Connery never
#   Negation: never won
#   Patient: an Academy Award .
#
# PropBank:
#   ARG0: Sean Connery never
#   ARGM-NEG: never won
#   ARG1: an Academy Award .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Sean Connery never
#   Negation: never won
#   Patient: an Academy Award .
#
# PropBank:
#   ARG0: Sean Connery never
#   ARGM-NEG: never won
#   ARG1: an Academy Award .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Overwatch is
#   Attribute: a video game in which players gain cosmetic awards and
#
# PropBank:
#   ARG1: Overwatch is
#   ARG2: a video game in which players gain cosmetic awards and
#
# Verb: gain
#
# VerbAtlas:
#  Frame: OBTAIN
#   Location: a video game in
#   Agent: players gain
#   Theme: cosmetic awards and
#
# PropBank:
#   ARGM-LOC: a video game in
#   R-ARGM-LOC: in which players
#   ARG0: players gain
#   ARG1: cosmetic awards and
#
# Verb: assigns
#
# VerbAtlas:
#  Frame: ASCRIBE
#   Agent: it assigns
#   Attribute: players into
#   Theme: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG0: it assigns
#   ARG1: players into
#   ARG2: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: a style of play known
#   Topic: as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG1: a style of play known
#   ARG2: as Offense , Defense , Tank , and Support .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Overwatch is
#   Attribute: a video game in which players gain cosmetic awards and
#
# PropBank:
#   ARG1: Overwatch is
#   ARG2: a video game in which players gain cosmetic awards and
#
# Verb: gain
#
# VerbAtlas:
#  Frame: OBTAIN
#   Location: a video game in
#   Agent: players gain
#   Theme: cosmetic awards and
#
# PropBank:
#   ARGM-LOC: a video game in
#   R-ARGM-LOC: in which players
#   ARG0: players gain
#   ARG1: cosmetic awards and
#
# Verb: assigns
#
# VerbAtlas:
#  Frame: ASCRIBE
#   Agent: it assigns
#   Attribute: players into
#   Theme: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG0: it assigns
#   ARG1: players into
#   ARG2: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: a style of play known
#   Topic: as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG1: a style of play known
#   ARG2: as Offense , Defense , Tank , and Support .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Régine Chassagne is
#   Attribute: Canadian .
#
# PropBank:
#   ARG1: Régine Chassagne is
#   ARG2: Canadian .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Régine Chassagne is
#   Attribute: Canadian .
#
# PropBank:
#   ARG1: Régine Chassagne is
#   ARG2: Canadian .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Planet of the Apes ( 1968 film ) had
#   Attribute: a script that underwent rewrites .
#
# PropBank:
#   ARG0: Planet of the Apes ( 1968 film ) had
#   ARG1: a script that underwent rewrites .
#
# Verb: underwent
#
# VerbAtlas:
#  Frame: UNDERGO-EXPERIENCE
#   Experiencer: a script that
#   Stimulus: rewrites .
#
# PropBank:
#   ARG1: a script that
#   R-ARG1: that underwent
#   ARG2: rewrites .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Planet of the Apes ( 1968 film ) had
#   Attribute: a script that underwent rewrites .
#
# PropBank:
#   ARG0: Planet of the Apes ( 1968 film ) had
#   ARG1: a script that underwent rewrites .
#
# Verb: underwent
#
# VerbAtlas:
#  Frame: UNDERGO-EXPERIENCE
#   Experiencer: a script that
#   Stimulus: rewrites .
#
# PropBank:
#   ARG1: a script that
#   R-ARG1: that underwent
#   ARG2: rewrites .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Paul Walker acted
#   Location: in movies .
#
# PropBank:
#   ARG0: Paul Walker acted
#   ARGM-LOC: in movies .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Paul Walker acted
#   Location: in movies .
#
# PropBank:
#   ARG0: Paul Walker acted
#   ARGM-LOC: in movies .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Gilmore Girls is
#   Attribute: a Canadian show .
#
# PropBank:
#   ARG1: Gilmore Girls is
#   ARG2: a Canadian show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Gilmore Girls is
#   Attribute: a Canadian show .
#
# PropBank:
#   ARG1: Gilmore Girls is
#   ARG2: a Canadian show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: San Francisco is
#   Attribute: in California .
#
# PropBank:
#   ARG1: San Francisco is
#   ARG2: in California .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: San Francisco is
#   Attribute: in California .
#
# PropBank:
#   ARG1: San Francisco is
#   ARG2: in California .
#
# Verb: received
#
# VerbAtlas:
#  Frame: RECEIVE
#   Agent: George W. Bush received
#   Theme: one of the lowest approval ratings - just 20 % approval - during
#   Time: during the 2008 financial crisis .
#
# PropBank:
#   ARG0: George W. Bush received
#   ARG1: one of the lowest approval ratings - just 20 % approval - during
#   ARGM-TMP: during the 2008 financial crisis .
#
# Verb: received
#
# VerbAtlas:
#  Frame: RECEIVE
#   Agent: George W. Bush received
#   Theme: one of the lowest approval ratings - just 20 % approval - during
#   Time: during the 2008 financial crisis .
#
# PropBank:
#   ARG0: George W. Bush received
#   ARG1: one of the lowest approval ratings - just 20 % approval - during
#   ARGM-TMP: during the 2008 financial crisis .
#
# Verb: wrote
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Lily Collins wrote
#   Recipient: for a U.S magazine that targets teen girls .
#
# PropBank:
#   ARG0: Lily Collins wrote
#   ARG2: for a U.S magazine that targets teen girls .
#
# Verb: targets
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: a U.S magazine that
#   Destination: teen girls .
#
# PropBank:
#   ARG0: a U.S magazine that
#   R-ARG0: that targets
#   ARG1: teen girls .
#
# Verb: wrote
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Lily Collins wrote
#   Recipient: for a U.S magazine that targets teen girls .
#
# PropBank:
#   ARG0: Lily Collins wrote
#   ARG2: for a U.S magazine that targets teen girls .
#
# Verb: targets
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: a U.S magazine that
#   Destination: teen girls .
#
# PropBank:
#   ARG0: a U.S magazine that
#   R-ARG0: that targets
#   ARG1: teen girls .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Naturi Naughton was
#   Time: in the year of 1984 .
#
# PropBank:
#   ARG1: Naturi Naughton was
#   ARGM-TMP: in the year of 1984 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Naturi Naughton was
#   Time: in the year of 1984 .
#
# PropBank:
#   ARG1: Naturi Naughton was
#   ARGM-TMP: in the year of 1984 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Generation X has
#   Attribute: no precise date for its cohort .
#
# PropBank:
#   ARG0: Generation X has
#   ARG1: no precise date for its cohort .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Generation X has
#   Attribute: no precise date for its cohort .
#
# PropBank:
#   ARG0: Generation X has
#   ARG1: no precise date for its cohort .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Agent: Jackie Chan has
#   Patient: an album .
#
# PropBank:
#   ARG0: Jackie Chan has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Agent: Jackie Chan has
#   Patient: an album .
#
# PropBank:
#   ARG0: Jackie Chan has
#   ARG1: an album .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: The Renaissance is
#   Topic: for its cultural developments .
#
# PropBank:
#   ARG1: The Renaissance is
#   ARG2: for its cultural developments .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: The Renaissance is
#   Topic: for its cultural developments .
#
# PropBank:
#   ARG1: The Renaissance is
#   ARG2: for its cultural developments .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Pluto is
#   Negation: not relatively
#   Attribute: relatively small .
#
# PropBank:
#   ARG1: Pluto is
#   ARGM-NEG: not relatively
#   ARG2: relatively small .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Pluto is
#   Negation: not relatively
#   Attribute: relatively small .
#
# PropBank:
#   ARG1: Pluto is
#   ARGM-NEG: not relatively
#   ARG2: relatively small .
#
# Verb: lost
#
# VerbAtlas:
#  Frame: LOSE
#   Agent: William Shatner lost
#   Theme: two Emmy Awards .
#
# PropBank:
#   ARG0: William Shatner lost
#   ARG1: two Emmy Awards .
#
# Verb: lost
#
# VerbAtlas:
#  Frame: LOSE
#   Agent: William Shatner lost
#   Theme: two Emmy Awards .
#
# PropBank:
#   ARG0: William Shatner lost
#   ARG1: two Emmy Awards .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Amanda Show was
#   Attribute: the first female - created show on Nickelodeon .
#
# PropBank:
#   ARG1: The Amanda Show was
#   ARG2: the first female - created show on Nickelodeon .
#
# Verb: created
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: female -
#   Product: show on
#
# PropBank:
#   ARG0: female -
#   ARG1: show on
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Amanda Show was
#   Attribute: the first female - created show on Nickelodeon .
#
# PropBank:
#   ARG1: The Amanda Show was
#   ARG2: the first female - created show on Nickelodeon .
#
# Verb: created
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: female -
#   Product: show on
#
# PropBank:
#   ARG0: female -
#   ARG1: show on
#
# Verb: included
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The 19th G7 summit only
#   Adverbial: only included
#   Patient: Russia .
#
# PropBank:
#   ARG2: The 19th G7 summit only
#   ARGM-ADV: only included
#   ARG1: Russia .
#
# Verb: included
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The 19th G7 summit only
#   Adverbial: only included
#   Patient: Russia .
#
# PropBank:
#   ARG2: The 19th G7 summit only
#   ARGM-ADV: only included
#   ARG1: Russia .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Edward Norton has
#   Attribute: co -
#   Recipient: for TV shows .
#
# PropBank:
#   ARG0: Edward Norton has
#   ARGM-MNR: co -
#   ARG2: for TV shows .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Edward Norton has
#   Attribute: co -
#   Recipient: for TV shows .
#
# PropBank:
#   ARG0: Edward Norton has
#   ARGM-MNR: co -
#   ARG2: for TV shows .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ethiopia has
#   Attribute: bodies of water can be described as rivers .
#
# PropBank:
#   ARG0: Ethiopia has
#   ARG1: bodies of water can be described as rivers .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: described
#
# VerbAtlas:
#  Frame: REPRESENT
#   Theme: bodies of water can
#   Modal: can be
#   Attribute: as rivers .
#
# PropBank:
#   ARG1: bodies of water can
#   ARGM-MOD: can be
#   ARG2: as rivers .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ethiopia has
#   Attribute: bodies of water can be described as rivers .
#
# PropBank:
#   ARG0: Ethiopia has
#   ARG1: bodies of water can be described as rivers .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: described
#
# VerbAtlas:
#  Frame: REPRESENT
#   Theme: bodies of water can
#   Modal: can be
#   Attribute: as rivers .
#
# PropBank:
#   ARG1: bodies of water can
#   ARGM-MOD: can be
#   ARG2: as rivers .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: lined
#
# VerbAtlas:
#  Frame: LIE
#   Location: The Connaught Tunnel was
#   Theme: only with mud and sand .
#
# PropBank:
#   ARG1: The Connaught Tunnel was
#   ARG2: only with mud and sand .
#
# Verb: lined
#
# VerbAtlas:
#  Frame: LIE
#   Location: The Connaught Tunnel was
#   Theme: only with mud and sand .
#
# PropBank:
#   ARG1: The Connaught Tunnel was
#   ARG2: only with mud and sand .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Loki is
#   Attribute: the male sibling of Helblindi and Byleistr .
#
# PropBank:
#   ARG1: Loki is
#   ARG2: the male sibling of Helblindi and Byleistr .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Loki is
#   Attribute: the male sibling of Helblindi and Byleistr .
#
# PropBank:
#   ARG1: Loki is
#   ARG2: the male sibling of Helblindi and Byleistr .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tender Mercies is
#   Attribute: a drama from America .
#
# PropBank:
#   ARG1: Tender Mercies is
#   ARG2: a drama from America .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tender Mercies is
#   Attribute: a drama from America .
#
# PropBank:
#   ARG1: Tender Mercies is
#   ARG2: a drama from America .
#
# Verb: starred
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Baby Driver starred
#   Agent: Eiza González .
#
# PropBank:
#   ARG2: Baby Driver starred
#   ARG1: Eiza González .
#
# Verb: starred
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Baby Driver starred
#   Agent: Eiza González .
#
# PropBank:
#   ARG2: Baby Driver starred
#   ARG1: Eiza González .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: David Dhawan is
#   Attribute: a film director .
#
# PropBank:
#   ARG1: David Dhawan is
#   ARG2: a film director .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: David Dhawan is
#   Attribute: a film director .
#
# PropBank:
#   ARG1: David Dhawan is
#   ARG2: a film director .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: One type of spread is
#   Attribute: Vegemite .
#
# PropBank:
#   ARG1: One type of spread is
#   ARG2: Vegemite .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: One type of spread is
#   Attribute: Vegemite .
#
# PropBank:
#   ARG1: One type of spread is
#   ARG2: Vegemite .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Theme: on by
#   Agent: by Octavia Spencer .
#
# PropBank:
#   ARG1: on by
#   ARG0: by Octavia Spencer .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Theme: on by
#   Agent: by Octavia Spencer .
#
# PropBank:
#   ARG1: on by
#   ARG0: by Octavia Spencer .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: Ramayanam was
#   Agent: by M. S. Reddy and
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by M. S. Reddy and
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Ramayanam was
#   Agent: by Gunasekhar .
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by Gunasekhar .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: Ramayanam was
#   Agent: by M. S. Reddy and
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by M. S. Reddy and
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Ramayanam was
#   Agent: by Gunasekhar .
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by Gunasekhar .
#
# Verb: features
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Man of Steel features
#   Attribute: the DC Comics character Superman .
#
# PropBank:
#   ARG0: Man of Steel features
#   ARG1: the DC Comics character Superman .
#
# Verb: features
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Man of Steel features
#   Attribute: the DC Comics character Superman .
#
# PropBank:
#   ARG0: Man of Steel features
#   ARG1: the DC Comics character Superman .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The Hangover Part III includes
#   Patient: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# PropBank:
#   ARG2: The Hangover Part III includes
#   ARG1: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The Hangover Part III includes
#   Patient: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# PropBank:
#   ARG2: The Hangover Part III includes
#   ARG1: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# Verb: committed
#
# VerbAtlas:
#  Frame: VIOLATE
#   Agent: Ted Bundy committed
#   Theme: assaults in
#   Time: in the seventies .
#
# PropBank:
#   ARG0: Ted Bundy committed
#   ARG1: assaults in
#   ARGM-TMP: in the seventies .
#
# Verb: committed
#
# VerbAtlas:
#  Frame: VIOLATE
#   Agent: Ted Bundy committed
#   Theme: assaults in
#   Time: in the seventies .
#
# PropBank:
#   ARG0: Ted Bundy committed
#   ARG1: assaults in
#   ARGM-TMP: in the seventies .
#
# Verb: associated
#
# VerbAtlas:
#  Frame: CORRELATE
#   Theme: Chinese people only
#   Adverbial: only can
#   Modal: can be
#   Co-Theme: with Spain through
#   Attribute: through nationality .
#
# PropBank:
#   ARG1: Chinese people only
#   ARGM-ADV: only can
#   ARGM-MOD: can be
#   ARG2: with Spain through
#   ARGM-MNR: through nationality .
#
# Verb: associated
#
# VerbAtlas:
#  Frame: CORRELATE
#   Theme: Chinese people only
#   Adverbial: only can
#   Modal: can be
#   Co-Theme: with Spain through
#   Attribute: through nationality .
#
# PropBank:
#   ARG1: Chinese people only
#   ARGM-ADV: only can
#   ARGM-MOD: can be
#   ARG2: with Spain through
#   ARGM-MNR: through nationality .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: Quentin Tarantino directed
#   Theme: a creative work .
#
# PropBank:
#   ARG0: Quentin Tarantino directed
#   ARG1: a creative work .
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: Quentin Tarantino directed
#   Theme: a creative work .
#
# PropBank:
#   ARG0: Quentin Tarantino directed
#   ARG1: a creative work .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Charlize Theron acted
#   Location: in The Burning Plain .
#
# PropBank:
#   ARG0: Charlize Theron acted
#   ARGM-LOC: in The Burning Plain .
#
# Verb: Burning
#
# VerbAtlas:
#  Frame: BURN
#   Patient: Plain .
#
# PropBank:
#   ARG1: Plain .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Charlize Theron acted
#   Location: in The Burning Plain .
#
# PropBank:
#   ARG0: Charlize Theron acted
#   ARGM-LOC: in The Burning Plain .
#
# Verb: Burning
#
# VerbAtlas:
#  Frame: BURN
#   Patient: Plain .
#
# PropBank:
#   ARG1: Plain .
#
# Verb: honors
#
# VerbAtlas:
#  Frame: APPROVE_PRAISE
#   Agent: Edgar Award honors
#   Theme: the best in television dramas .
#
# PropBank:
#   ARG0: Edgar Award honors
#   ARG1: the best in television dramas .
#
# Verb: honors
#
# VerbAtlas:
#  Frame: APPROVE_PRAISE
#   Agent: Edgar Award honors
#   Theme: the best in television dramas .
#
# PropBank:
#   ARG0: Edgar Award honors
#   ARG1: the best in television dramas .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Bermuda is
#   Attribute: an associate member of the Red Sox .
#
# PropBank:
#   ARG1: Bermuda is
#   ARG2: an associate member of the Red Sox .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Bermuda is
#   Attribute: an associate member of the Red Sox .
#
# PropBank:
#   ARG1: Bermuda is
#   ARG2: an associate member of the Red Sox .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: competed
#
# VerbAtlas:
#  Frame: COMPETE
#   Agent: Usain Bolt has
#   Location: in a sprint race in
#   Location: in track and field in
#   Location: in world competitions .
#
# PropBank:
#   ARG0: Usain Bolt has
#   ARGM-LOC: in a sprint race in
#   ARGM-LOC: in track and field in
#   ARGM-LOC: in world competitions .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: competed
#
# VerbAtlas:
#  Frame: COMPETE
#   Agent: Usain Bolt has
#   Location: in a sprint race in
#   Location: in track and field in
#   Location: in world competitions .
#
# PropBank:
#   ARG0: Usain Bolt has
#   ARGM-LOC: in a sprint race in
#   ARGM-LOC: in track and field in
#   ARGM-LOC: in world competitions .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The main successor to the internet was
#   Attribute: the ARPANET .
#
# PropBank:
#   ARG1: The main successor to the internet was
#   ARG2: the ARPANET .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The main successor to the internet was
#   Attribute: the ARPANET .
#
# PropBank:
#   ARG1: The main successor to the internet was
#   ARG2: the ARPANET .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Sarrainodu is
#   Attribute: an action movie .
#
# PropBank:
#   ARG1: Sarrainodu is
#   ARG2: an action movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Sarrainodu is
#   Attribute: an action movie .
#
# PropBank:
#   ARG1: Sarrainodu is
#   ARG2: an action movie .
#
# Verb: owned
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: Kingdom Hearts III is
#   Agent: by Boyz II Men
#
# PropBank:
#   ARG1: Kingdom Hearts III is
#   ARG0: by Boyz II Men
#
# Verb: owned
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: Kingdom Hearts III is
#   Agent: by Boyz II Men
#
# PropBank:
#   ARG1: Kingdom Hearts III is
#   ARG0: by Boyz II Men
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Keanu Reeves is
#   Attribute: a film actor .
#
# PropBank:
#   ARG1: Keanu Reeves is
#   ARG2: a film actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Keanu Reeves is
#   Attribute: a film actor .
#
# PropBank:
#   ARG1: Keanu Reeves is
#   ARG2: a film actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Heartland is
#   Attribute: a canadian TV series .
#
# PropBank:
#   ARG1: Heartland is
#   ARG2: a canadian TV series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Heartland is
#   Attribute: a canadian TV series .
#
# PropBank:
#   ARG1: Heartland is
#   ARG2: a canadian TV series .
#
# Verb: are
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: two major contemporary political parties ,
#
# PropBank:
#   ARG1: two major contemporary political parties ,
#
# Verb: belongs
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: William Jennings Bryan belongs
#   Agent: to one of them .
#
# PropBank:
#   ARG0: William Jennings Bryan belongs
#   ARG1: to one of them .
#
# Verb: are
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: two major contemporary political parties ,
#
# PropBank:
#   ARG1: two major contemporary political parties ,
#
# Verb: belongs
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: William Jennings Bryan belongs
#   Agent: to one of them .
#
# PropBank:
#   ARG0: William Jennings Bryan belongs
#   ARG1: to one of them .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Robert Richardson has
#   Co-Agent: with director John Sayles .
#
# PropBank:
#   ARG0: Robert Richardson has
#   ARG1: with director John Sayles .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Robert Richardson has
#   Co-Agent: with director John Sayles .
#
# PropBank:
#   ARG0: Robert Richardson has
#   ARG1: with director John Sayles .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Leslie Howard was
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Leslie Howard was
#   ARG2: an actor .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Leslie Howard was
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Leslie Howard was
#   ARG2: an actor .
#
# Verb: Catching
#
# VerbAtlas:
#  Frame: CATCH
#   Experiencer: Fire is
#
# PropBank:
#   ARG0: Fire is
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Result: Catching Fire is
#
# PropBank:
#   ARG1: Catching Fire is
#
# Verb: Catching
#
# VerbAtlas:
#  Frame: CATCH
#   Experiencer: Fire is
#
# PropBank:
#   ARG0: Fire is
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Result: Catching Fire is
#
# PropBank:
#   ARG1: Catching Fire is
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
# ...
#
# PropBank:
#   ARG1: Vito Corleone is
#   ARG2: a fictional mountain .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Vito Corleone is
#   Attribute: a fictional mountain .
#
# PropBank:
#   ARG1: Vito Corleone is
#   ARG2: a fictional mountain .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Jaime Lannister is
#   Negation: not a
#   Attribute: a knight .
#
# PropBank:
#   ARG1: Jaime Lannister is
#   ARGM-NEG: not a
#   ARG2: a knight .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Jaime Lannister is
#   Negation: not a
#   Attribute: a knight .
#
# PropBank:
#   ARG1: Jaime Lannister is
#   ARGM-NEG: not a
#   ARG2: a knight .
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Philadelphia is
#   Attribute: a center of illegal activity .
#
# PropBank:
#   ARG1: Philadelphia is
#   ARG2: a center of illegal activity .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Philadelphia is
#   Attribute: a center of illegal activity .
#
# PropBank:
#   ARG1: Philadelphia is
#   ARG2: a center of illegal activity .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: shot
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Lee Harvey Oswald shot
#   Theme: mailboxes in
#   Location: in Dallas .
#
# PropBank:
#   ARG0: Lee Harvey Oswald shot
#   ARG1: mailboxes in
#   ARGM-LOC: in Dallas .
#
# Verb: shot
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Lee Harvey Oswald shot
#   Theme: mailboxes in
#   Location: in Dallas .
#
# PropBank:
#   ARG0: Lee Harvey Oswald shot
#   ARG1: mailboxes in
#   ARGM-LOC: in Dallas .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: cast
#
# VerbAtlas:
#  Frame: THROW
#   Theme: Seth Rogen was
#
# PropBank:
#   ARG1: Seth Rogen was
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: cast
#
# VerbAtlas:
#  Frame: THROW
#   Theme: Seth Rogen was
#
# PropBank:
#   ARG1: Seth Rogen was
#
# Verb: started
#
# VerbAtlas:
#  Frame: BEGIN
#   Agent: Pacific Rim started
#   Theme: production July
#   Time: July 12 , 2013 .
#
# PropBank:
#   ARG0: Pacific Rim started
#   ARG1: production July
#   ARGM-TMP: July 12 , 2013 .
#
# Verb: started
#
# VerbAtlas:
#  Frame: BEGIN
#   Agent: Pacific Rim started
#   Theme: production July
#   Time: July 12 , 2013 .
#
# PropBank:
#   ARG0: Pacific Rim started
#   ARG1: production July
#   ARGM-TMP: July 12 , 2013 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: invoked
#
# VerbAtlas:
#  Frame: ASK_REQUEST
#   Theme: Social justice is
#   Time: today in
#   Location: in philosophical debates about differences among human beings around the world .
#
# PropBank:
#   ARG1: Social justice is
#   ARGM-TMP: today in
#   ARGM-LOC: in philosophical debates about differences among human beings around the world .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: invoked
#
# VerbAtlas:
#  Frame: ASK_REQUEST
#   Theme: Social justice is
#   Time: today in
#   Location: in philosophical debates about differences among human beings around the world .
#
# PropBank:
#   ARG1: Social justice is
#   ARGM-TMP: today in
#   ARGM-LOC: in philosophical debates about differences among human beings around the world .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Patrick Dempsey was
#   Attribute: in the movie Enchanted in
#   Time: in 2007 .
#
# PropBank:
#   ARG1: Patrick Dempsey was
#   ARG2: in the movie Enchanted in
#   ARGM-TMP: in 2007 .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Patrick Dempsey was
#   Attribute: in the movie Enchanted in
#   Time: in 2007 .
#
# PropBank:
#   ARG1: Patrick Dempsey was
#   ARG2: in the movie Enchanted in
#   ARGM-TMP: in 2007 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ben Stiller has
#   Attribute: children .
#
# PropBank:
#   ARG0: Ben Stiller has
#   ARG1: children .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ben Stiller has
#   Attribute: children .
#
# PropBank:
#   ARG0: Ben Stiller has
#   ARG1: children .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Iceland is
#   Attribute: a country .
#
# PropBank:
#   ARG1: Iceland is
#   ARG2: a country .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Iceland is
#   Attribute: a country .
#
# PropBank:
#   ARG1: Iceland is
#   ARG2: a country .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: murdered
#
# VerbAtlas:
#  Frame: KILL
#   Patient: Robin was
#   Agent: by the Joker in
#   Location: in a 1989 book .
#
# PropBank:
#   ARG1: Robin was
#   ARG0: by the Joker in
#   ARGM-LOC: in a 1989 book .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: murdered
#
# VerbAtlas:
#  Frame: KILL
#   Patient: Robin was
#   Agent: by the Joker in
#   Location: in a 1989 book .
#
# PropBank:
#   ARG1: Robin was
#   ARG0: by the Joker in
#   ARGM-LOC: in a 1989 book .
#
# Verb: played
#
# VerbAtlas:
#  Frame: PERFORM
#   Agent: David Schwimmer played
#   Theme: a lawyer in
#   Location: in American Crime Story .
#
# PropBank:
#   ARG0: David Schwimmer played
#   ARG1: a lawyer in
#   ARGM-LOC: in American Crime Story .
#
# Verb: played
#
# VerbAtlas:
#  Frame: PERFORM
#   Agent: David Schwimmer played
#   Theme: a lawyer in
#   Location: in American Crime Story .
#
# PropBank:
#   ARG0: David Schwimmer played
#   ARG1: a lawyer in
#   ARGM-LOC: in American Crime Story .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Avatar was
#   Agent: by James Cameron .
#
# PropBank:
#   ARG1: Avatar was
#   ARG0: by James Cameron .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Avatar was
#   Agent: by James Cameron .
#
# PropBank:
#   ARG1: Avatar was
#   ARG0: by James Cameron .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Cher won
#   Patient: a Cannes Film Festival Award in
#   Time: in 1987 .
#
# PropBank:
#   ARG0: Cher won
#   ARG1: a Cannes Film Festival Award in
#   ARGM-TMP: in 1987 .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Cher won
#   Patient: a Cannes Film Festival Award in
#   Time: in 1987 .
#
# PropBank:
#   ARG0: Cher won
#   ARG1: a Cannes Film Festival Award in
#   ARGM-TMP: in 1987 .
#
# Verb: uses
#
# VerbAtlas:
#  Frame: USE
#   Agent: Shonen Jump uses
#   Patient: abbreviation .
#
# PropBank:
#   ARG0: Shonen Jump uses
#   ARG1: abbreviation .
#
# Verb: uses
#
# VerbAtlas:
#  Frame: USE
#   Agent: Shonen Jump uses
#   Patient: abbreviation .
#
# PropBank:
#   ARG0: Shonen Jump uses
#   ARG1: abbreviation .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Halle Berry has
#   Attribute: 0 children .
#
# PropBank:
#   ARG0: Halle Berry has
#   ARG1: 0 children .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Halle Berry has
#   Attribute: 0 children .
#
# PropBank:
#   ARG0: Halle Berry has
#   ARG1: 0 children .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Haim Saban is
#   Attribute: an Israeli - American musician .
#
# PropBank:
#   ARG1: Haim Saban is
#   ARG2: an Israeli - American musician .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Haim Saban is
#   Attribute: an Israeli - American musician .
#
# PropBank:
#   ARG1: Haim Saban is
#   ARG2: an Israeli - American musician .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Norway has
#   Attribute: over sixty kings and earls .
#
# PropBank:
#   ARG0: Norway has
#   ARG1: over sixty kings and earls .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Norway has
#   Attribute: over sixty kings and earls .
#
# PropBank:
#   ARG0: Norway has
#   ARG1: over sixty kings and earls .
#
# Verb: stars
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Men and a Baby stars
#   Agent: American actor Tom Selleck .
#
# PropBank:
#   ARG2: Men and a Baby stars
#   ARG1: American actor Tom Selleck .
#
# Verb: stars
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Men and a Baby stars
#   Agent: American actor Tom Selleck .
#
# PropBank:
#   ARG2: Men and a Baby stars
#   ARG1: American actor Tom Selleck .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a American film called Maleficent with Ella Purnell in it .
#
# PropBank:
#   ARG1: a American film called Maleficent with Ella Purnell in it .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a American film called
#   Attribute: Maleficent with
#
# PropBank:
#   ARG1: a American film called
#   ARG2: Maleficent with
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a American film called Maleficent with Ella Purnell in it .
#
# PropBank:
#   ARG1: a American film called Maleficent with Ella Purnell in it .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a American film called
#   Attribute: Maleficent with
#
# PropBank:
#   ARG1: a American film called
#   ARG2: Maleficent with
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Alec Baldwin won
#   Patient: seven Screen Actors Guild Awards for 30 Rock in
#   Time: in the 2000s .
#
# PropBank:
#   ARG0: Alec Baldwin won
#   ARG1: seven Screen Actors Guild Awards for 30 Rock in
#   ARGM-TMP: in the 2000s .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Alec Baldwin won
#   Patient: seven Screen Actors Guild Awards for 30 Rock in
#   Time: in the 2000s .
#
# PropBank:
#   ARG0: Alec Baldwin won
#   ARG1: seven Screen Actors Guild Awards for 30 Rock in
#   ARGM-TMP: in the 2000s .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Orson Welles was
#   Negation: not a
#   Attribute: a Shakespearean stage actor .
#
# PropBank:
#   ARG1: Orson Welles was
#   ARGM-NEG: not a
#   ARG2: a Shakespearean stage actor .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Orson Welles was
#   Negation: not a
#   Attribute: a Shakespearean stage actor .
#
# PropBank:
#   ARG1: Orson Welles was
#   ARGM-NEG: not a
#   ARG2: a Shakespearean stage actor .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: The American Broadcasting Company is
#   Adverbial: only called
#   Attribute: by its full name .
#
# PropBank:
#   ARG1: The American Broadcasting Company is
#   ARGM-ADV: only called
#   ARGM-MNR: by its full name .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: The American Broadcasting Company is
#   Adverbial: only called
#   Attribute: by its full name .
#
# PropBank:
#   ARG1: The American Broadcasting Company is
#   ARGM-ADV: only called
#   ARGM-MNR: by its full name .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Steven Gerrard has
#   Attribute: captain of the England national football team since
#   Time: since 2012 .
#
# PropBank:
#   ARG1: Steven Gerrard has
#   ARG2: captain of the England national football team since
#   ARGM-TMP: since 2012 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Steven Gerrard has
#   Attribute: captain of the England national football team since
#   Time: since 2012 .
#
# PropBank:
#   ARG1: Steven Gerrard has
#   ARG2: captain of the England national football team since
#   ARGM-TMP: since 2012 .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: built
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: The Boeing 707 was
#   Agent: by my Uncle Jeff .
#
# PropBank:
#   ARG1: The Boeing 707 was
#   ARG0: by my Uncle Jeff .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: built
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: The Boeing 707 was
#   Agent: by my Uncle Jeff .
#
# PropBank:
#   ARG1: The Boeing 707 was
#   ARG0: by my Uncle Jeff .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: James Wilson is
#   Attribute: a real person yet to be made into a fictional character .
#
# PropBank:
#   ARG1: James Wilson is
#   ARG2: a real person yet to be made into a fictional character .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: made
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: into a fictional character .
#
# PropBank:
#   ARG1: into a fictional character .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: James Wilson is
#   Attribute: a real person yet to be made into a fictional character .
#
# PropBank:
#   ARG1: James Wilson is
#   ARG2: a real person yet to be made into a fictional character .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: made
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: into a fictional character .
#
# PropBank:
#   ARG1: into a fictional character .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: The Great British Sewing Bee premiered
#   Time: on April 2 .
#
# PropBank:
#   ARG1: The Great British Sewing Bee premiered
#   ARGM-TMP: on April 2 .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: The Great British Sewing Bee premiered
#   Time: on April 2 .
#
# PropBank:
#   ARG1: The Great British Sewing Bee premiered
#   ARGM-TMP: on April 2 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Diego Costa is
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 62
#      60 verbatlasRoles_hp.add(role)
#      61 span = role_info['span']
# ---> 62 text = get_text_from_span(tokens_hp, span)
#      63 if (role == 'Location'):
#      64     verbatlasLocations_hp.add(text)
#
# Cell In[6], line 52, in get_text_from_span(tokens, span)
#      51 def get_text_from_span(tokens, span):
# ---> 52     return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1))
#
# Cell In[6], line 52, in <genexpr>(.0)
#      51 def get_text_from_span(tokens, span):
# ---> 52     return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1))
#
# IndexError: list index out of range

# %%
# print(type(nli_dataset["train"]))
# print(type(nli_dataset["train"][0]))
# print(nli_dataset["train"])

#TODO UNDERSTAND BEFORE GO AHEAD!

verbatlasFrame = set()
probankFrame = set()
verbatlasRoles = set()
probankRoles = set()



for elem in nli_dataset["train"]:
    srl = elem['srl']['premise']

    tokens = srl['tokens']
    annotations = srl['annotations']


    for annotation in annotations:
        token_index = annotation['tokenIndex']
        verb = tokens[token_index]['rawText']
        # print(f"Verb: {verb}\n")

        # print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens, span)
            # print(f"  {role}: {text}")
        # print()

        # print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens, span)
            # print(f"  {role}: {text}")
        # print()


    # if count==5:break
    # else:count+=1

    # break

# %%
print("va locations: ",verbatlasLocations)
print("va locations: ",len(verbatlasLocations))
print("pb locations: ",probankLocations)
print("pb locations: ",len(probankLocations))
# Out:
# va locations:  {'in Minneapolis', 'in the Bundesliga , the top tier of the German football league system', 'in Tanzania', 'in Evanston , Illinois', '` Radioactive', 'in the spy - action television show Alias ( 2001 -- 2006 )', 'both indoors and outdoors', 'in the 2006 film The Pursuit of Happyness', 'in Italy', 'in the series Firefly and the follow - up film Serenity', 'outside the United States', 'in circuses', 'in the top five', 'in the battle', 'in the 58th Filmfare Awards South', 'at the southernmost tip of the Balkan Peninsula', 'in American comic books published by Marvel Comics , mostly in association with the X - Men', 'in the Lower Mainland region of British Columbia', 'primarily in California', 'in Continental Europe', 'in the fourth installment of the The Karate Kid franchise , The Next Karate Kid', 'south of the Sahara', 'in ROH', "in Brian De Palma ' s cult thriller Sisters ( 1973 ) ; in the slasher film Black Christmas ( 1974 ) ; and the drama The Great Waldo Pepper ( 1975 ) , opposite Robert Redford", 'at more secluded locations', 'in Modern Icelandic', 'throughout the islands', 'in a bidding war', 'in theater', "in supporting roles including Inventing the Abbotts ( 1997 ) and Robert Altman ' s black comedy Cookie ' s Fortune ( 1999 )", 'the highest paid Indian', 'On the international stage with France', 'on the first season of Sabrina , the Teenage Witch ,', 'on the U.S. Billboard 200', "on the ITF Women ' s Circuit", 'on the southern half of the Korean Peninsula jutting out from the far east of the Asian land mass', 'at the western edge of Caleta del Sebo', 'on ranches in North America', 'under 16 administrations', 'at the Museum of Vinci', "in films such as Ridley Scott ' s American Gangster ( 2007 ) , Takers ( 2010 ) , Thor ( 2011 ) , Prometheus ( 2012 ) , Pacific Rim ( 2013 ) , Thor : The Dark World ( 2013 ) and Beasts of No Nation ( 2015 , for which he received BAFTA and Golden Globe nominations for Best Supporting", 'in the Top 15 of the Billboard 200', 'on a rectangular court', 'on more than 125 pop stations in the U.S. alone', "around social and financial troubles following the Hundred Years ' War , combined with the", 'the U.S. Open', 'on the CBS series Elementary ( 2013 -- 15 )', 'in the Napoleonic Wars', 'in Aleppo', 'in 1929', 'in the coming of age drama Mermaids ( 1990 )', 'Astana', 'the reality show The World According to Paris', "in New York City ' s Madison Square Garden", 'in official competitions', 'at the presidential inauguration of Donald Trump', 'around the solution of a problem or a crime', 'in Reading , Berkshire ,', 'on Columbia', 'on TeenNick', 'on long - haul transoceanic routes', 'on the American Broadcasting Company ( ABC )', 'in Samsung Town , Seoul', 'in his feature - length debut from a screenplay by Sebastian de Souza , and Preston Thompson', 'in the soap opera A World Apart ( 1970 -- 71 )', 'in electronic physics , as well as in fields of chemistry , such as quantum chemistry or electrochemistry', 'for office', 'in print and online sources', 'in India', 'at the Toronto International Film Festival and London Film Festival', 'at the 75th Academy Awards ceremony', 'below the thermocline and above the seabed', 'in X - Men : Days of Future Past ( 2014 ) , and X - Men : Apocalypse ( 2016 )
 2014 ) , and X - Men : Apocalypse ( 2016 )', 'on a $ 2,777,000 budget', "Count Waldstein ' s household", 'in West Bromwich in the West Midlands', 'in the East Cantons located around the High Fens area , and bordering Germany', 'in the Disney Channel series Even Stevens , a role for which LaBeouf received a Young Artist Award nomination in 2001 and won a Daytime Emmy Award in 2003', 'in the underground music community', 'in films and on television', "in The Curse of the Black Pearl ( 2003 ) , Dead Man ' s Chest ( 2006 ) , At World ' s End ( 2007 ) and Dead Men Tell No Tales ( 2017 )", 'in the United States and the United Kingdom', 'on clay and hard court', 'internationally and on the independent circuit', 'on Agony & Irony ( 2008 ) , which was released on V2 Records', 'at 7007 Hollywood Boulevard', "on many critics ' lists of the greatest films ever made", '60 kilo', 'in the telecommunications industry', 'in Girl , Interrupted ( 1999 ) and', 'in upstate New York', 'in the rural town of Bon Temps , Louis ...
# pb locations:  4930

# %%
# Sample set of strings


# Filter to include only words that start with a capital letter
filtered_words_set_va = {word for s in verbatlasLocations for word in s.split() if word[0].isupper()}
print(filtered_words_set_va)
print(len(filtered_words_set_va))
# Out:
# {'Class', 'Regum', 'Vienna', 'Boss', 'Prat', 'Forever', 'Potomac', 'Spencer', 'Erie', 'Confederations', 'Plutarch', 'Olivier', 'Peru', 'Hyattsville', 'Staple', 'Brazilian', 'Mildred', 'Galaxy', 'Clara', 'Everwood', 'Chalk', 'Open', 'Parlophone', 'Adriatic', 'Emily', 'Skarsgård', 'Sites', 'Bactrian', 'Virgil', 'Charing', 'PCs', 'Prix', 'Ivy', 'Avengers', 'Mercury', 'Rye', 'Kentwood', 'Vedanta', 'Lambeth', 'Base', 'Beach', 'Ayutla', 'MCs', 'Deauville', 'Groton', 'Subtle', 'Euclidean', 'Rose', 'Martina', 'Glenwood', 'Fallen', 'Vinci', 'Driver', 'Yugoslavia', 'Another', 'Knights', 'Stockholm', 'Dexter', 'Sunshine', 'Winds', 'Chaplin', 'Eve', 'Luck', 'Luton', 'Semitic', 'News', 'Wisconsin', 'Avenger', 'RCD-25', 'Action', 'Desperate', 'Amendment', 'Ali', 'Man', 'Laferrière', 'Blogette', 'Others', 'Bandai', 'Festivals', 'Memphis', 'Sparta', 'Iowa', 'Serbia', 'PAX', 'Dileep', 'Pakistani', 'Journals', 'Saddam', 'Dry', 'Punjabi', 'Vevey', 'GHV2', 'Trophy', 'Tales', 'Plane', 'TD', 'O', 'Kallergis', 'Antonio', 'Berlin', 'Extended', 'Disney', 'Mercy', 'Vijayawada', 'Révolution', 'Omaha', 'Pain', 'Chuke', 'Fine', 'Korean', 'Skellig', 'Anatomy', 'Fred', 'Genisys', 'Melbourne', 'Urbanized', 'Orleans', 'Creatures', 'Mvezo', 'Tagore', 'Tombstones', 'Allen', 'Assange', 'Greenwood', 'Red', 'Rogers', 'Bites', 'Framlingham', 'Porgy', 'Any', 'Arabia', 'Veronica', 'Mitchell', 'Lawrence', 'Nemo', 'Jamaica', 'Halki', 'Scissors', 'Molly', 'Sheridan', 'Shelton', 'Mediterranean', 'Montclair', 'Capital', 'Buscemi', 'Thin', 'Alabama', 'Review', 'Jess', 'Andrews', 'Naughton', 'Antony', 'Rovers', 'Tanzania', 'Think', 'By', 'Crusade', 'Arlington', 'Gravity', 'Politics', 'Breaking', 'Thompson', 'Pro', 'Bonnet', 'U.S.', 'Media', 'Winnipeg', 'G4', 'Loving', 'Booth', 'Within', 'Thiel', 'Journey', 'Doctor', 'Rosberg', 'Alphabet', 'Coastal', 'Palace', 'Luc', 'Drew', 'Powell', 'Peekskill', 'Pokiri', 'Til', 'Legend', 'Sterling', 'Avenue', 'Selfridges', 'Pirates', 'NBA', 'Snowfield', 'Development', 'Reunion', 'Carlos', 'Avala', 'Protected', 'Twin', 'Parker', 'Spider', 'Screenplays', 'Tanya', 'Sandip', 'Stern', 'Göteborg', 'B', 'Somebody', 'Warren', 'Boulevard', 'Happens', 'Indochina', 'Astana', 'Bug', 'Foxcatcher', 'Simi', 'Chainsaw', 'Des', 'Avon', 'Rolling', 'Incorporated', 'Done', 'Geetha', 'Vicky', 'Majors', 'Heavensbee', 'VH1', 'Quigley', 'Assassin', 'Northern', 'Gunday', 'Apocalypse', 'Wedding', 'Saturday', 'Schaumburg', 'Agreement', 'Chip', 'Productions', 'Moonshine', 'Inch', 'EP', 'Wardenclyffe', 'Swamp', 'Canyon', 'Jonny', 'Ned', 'Beverly', 'Buffy', 'Gallifrey', 'Two', 'Minato', 'Democrat', 'Dark', 'Field', 'BoJack', 'Norton', 'Southeastern', 'Autódromo', 'Parader', 'Do', 'Ripley', 'Surrey', 'Kindergarten', 'Soundgarden', 'Youth', 'Amhara', 'Avatar', 'Hawkins', 'Ningxia', 'Holy', 'Trading', 'Peace', 'L.', 'Maghreb', 'German', 'Flight', 'Croft', 'Dates', 'Bristol', 'Albany', 'Noise', 'Anna', 'Once', 'Ἀθηναίη', 'Deathstro', 'Orson', 'Papa', 'Fest', 'Trinidad', 'Brown', 'Cox', 'Carey', 'Niagara', 'Higher', 'R.', 'Frideric', 'S.H.I.E.L.D.', 'Watson', 'Loss', 'Design', 'Knope', 'Saxony', 'Forfar', 'Zindagi', 'Military', 'Udta', 'Wentworth', 'Olympiada', 'Cold', 'Schuylkill', 'Squad', 'Frutti', 'TriBeCa', 'Anfield', 'Po', 'Horn', 'Armageddon', 'Carpathian', 'Snake', 'McLean', 'Cottesloe', 'Cookie', 'Leste', 'Caspian', 'Pop', 'Scotland', 'Not', 'Romania', 'Plaza', 'Hampshire', 'Ferrigno', 'African', 'Austin', 'Ireland', 'Retail', 'Cemetery', 'Aegon', 'Camelot', 'Pakhtunkhwa', 'Río', 'Seleucid', 'Skin', 'Animated', 'MSNBC', 'Brimsdown', 'Harry', 'Hamlet', 'Vagrant', 'Sanam', "O'Brien", 'Southampton', 'Chamber', 'Filmmakers', 'St', 'Bohemia', 'Bernard', 'Riding', 'Last', 'Brideshead', 'Draft', 'Everest', 'SBS', 'Peninsula', 'Downingtown', 'Aslan', 'Crazies', 'Couples', 'Plains', 'Fortune', 'Michele', 'Uccello', 'Ode', 'Reality', 'Lusignan', 'Pullman', 'Hannah', 'Rattlesnakes', 'Epsom', 'Place', 'Remote', 'Neck', 'Nacional', 'Hockey', 'Attraction', 'Chatsworth', ...
# 4529

# %%
filtered_words_set_pb = {word for s in probankLocations for word in s.split() if word[0].isupper()}
print(filtered_words_set_pb)
print(len(filtered_words_set_pb))
# Out:
# {'Class', 'Regum', 'Vienna', 'Boss', 'Plutarch', 'Forever', 'Potomac', 'Spencer', 'Erie', 'Confederations', 'Prat', 'Olivier', 'Peru', 'Hyattsville', 'Brazilian', 'Mildred', 'Galaxy', 'Clara', 'Everwood', 'Chalk', 'Open', 'Parlophone', 'Emily', 'Skarsgård', 'Sites', 'Bactrian', 'Virgil', 'Charing', 'PCs', 'Prix', 'Ivy', 'Avengers', 'Mercury', 'Rye', 'Kentwood', 'Vedanta', 'Base', 'Beach', 'Ayutla', 'MCs', 'Deauville', 'Groton', 'Subtle', 'Euclidean', 'Rose', 'Martina', 'Glenwood', 'Fallen', 'Vinci', 'Driver', 'Yugoslavia', 'Another', 'Knights', 'Stockholm', 'Dexter', 'Sunshine', 'Winds', 'Chaplin', 'Eve', 'Luck', 'Luton', 'Semitic', 'News', 'Wisconsin', 'Avenger', 'RCD-25', 'Action', 'Desperate', 'Amendment', 'Ali', 'Man', 'Laferrière', 'Blogette', 'Bandai', 'Festivals', 'Memphis', 'Sparta', 'Iowa', 'Serbia', 'PAX', 'Dileep', 'Pakistani', 'Saddam', 'Dry', 'Punjabi', 'Vevey', 'GHV2', 'Trophy', 'Tales', 'Plane', 'TD', 'O', 'Pain', 'Antonio', 'Berlin', 'Extended', 'Disney', 'Mercy', 'Vijayawada', 'Révolution', 'Omaha', 'Chuke', 'Othello', 'Fine', 'Korean', 'Skellig', 'Anatomy', 'Genisys', 'Fred', 'Melbourne', 'Urbanized', 'Orleans', 'Creatures', 'Mvezo', 'Tagore', 'Tombstones', 'Allen', 'Assange', 'Greenwood', 'Red', 'Rogers', 'Bites', 'Framlingham', 'Porgy', 'Any', 'Arabia', 'Veronica', 'Lawrence', 'Nemo', 'Jamaica', 'Halki', 'Scissors', 'Molly', 'Mediterranean', 'Montclair', 'Capital', 'Alabama', 'Review', 'Andrews', 'Naughton', 'Boogie', 'Rovers', 'Tanzania', 'Antony', 'Think', 'By', 'Crusade', 'Arlington', 'Gravity', 'Politics', 'Breaking', 'Thompson', 'Pro', 'Bonnet', 'U.S.', 'Media', 'Winnipeg', 'G4', 'Loving', 'Booth', 'Within', 'Thiel', 'Journey', 'Doctor', 'Rosberg', 'Alphabet', 'Coastal', 'Palace', 'Luc', 'Drew', 'Powell', 'Peekskill', 'Pokiri', 'Til', 'Legend', 'Sterling', 'Avenue', 'Selfridges', 'Pirates', 'NBA', 'Snowfield', 'Development', 'Reunion', 'Carlos', 'Avala', 'Jhalak', 'Protected', 'Twin', 'Parker', 'Spider', 'Screenplays', 'Göteborg', 'Sandip', 'Stern', 'B', 'Somebody', 'Warren', 'Boulevard', 'Happens', 'Cohn', 'Indochina', 'Astana', 'Bug', 'Simi', 'Chainsaw', 'Des', 'Avon', 'Rolling', 'Incorporated', 'Done', 'Geetha', 'Vicky', 'Majors', 'Heavensbee', 'VH1', 'Quigley', 'Northern', 'Gunday', 'Apocalypse', 'Wedding', 'Saturday', 'Schaumburg', 'Agreement', 'Chip', 'Productions', 'Moonshine', 'Inch', 'EP', 'Swamp', 'Canyon', 'Jonny', 'Beverly', 'Buffy', 'Gallifrey', 'Two', 'Minato', 'Democrat', 'Dark', 'Field', 'BoJack', 'Norton', 'Autódromo', 'Parader', 'Ripley', 'Do', 'Surrey', 'Kindergarten', 'Soundgarden', 'Youth', 'Avatar', 'Holy', 'Ningxia', 'Trading', 'Peace', 'L.', 'Maghreb', 'German', 'Flight', 'Croft', 'Dates', 'Bristol', 'Albany', 'Noise', 'Anna', 'Once', 'Deathstro', 'Orson', 'Papa', 'Fest', 'Trinidad', 'Cox', 'Niagara', 'R.', 'Frideric', 'S.H.I.E.L.D.', 'Watson', 'Loss', 'Design', 'Knope', 'Saxony', 'Forfar', 'Zindagi', 'Military', 'Udta', 'Squad', 'Cold', 'Schuylkill', 'Frutti', 'TriBeCa', 'Anfield', 'Po', 'Horn', 'Armageddon', 'Carpathian', 'Snake', 'McLean', 'Cottesloe', 'Cookie', 'Pop', 'Scotland', 'Not', 'Romania', 'Plaza', 'Hampshire', 'Ferrigno', 'African', 'Austin', 'Ireland', 'Retail', 'Cemetery', 'Aegon', 'Camelot', 'Pakhtunkhwa', 'Río', 'Seleucid', 'Skin', 'Animated', 'MSNBC', 'Brimsdown', 'Harry', 'Hamlet', 'Vagrant', 'Sanam', "O'Brien", 'Southampton', 'Chamber', 'Filmmakers', 'St', 'Bohemia', 'Bernard', 'Riding', 'Last', 'Brideshead', 'Draft', 'Everest', 'SBS', 'Peninsula', 'Downingtown', 'Crazies', 'Couples', 'Plains', 'Fortune', 'Michele', 'Uccello', 'Ode', 'Reality', 'Lusignan', 'Pullman', 'Hannah', 'Rattlesnakes', 'Epsom', 'Place', 'Remote', 'Neck', 'Nacional', 'Hockey', 'Attraction', 'Dakota', 'Years', 'DVD', 'Tisch', 'Kapoor', 'Heavy', 'Suburbs', 'Democratic', 'My', 'Excellence', 'Bhojpuri', 'Koval', 'Concert', 'Windward', 'Streets', 'Austria', 'Netflix', 'Jean', 'TARDIS', 'Propaganda', 'Office', 'TeenNick', 'Pam', 'Junction', 'Bhambla', 'Marx', 'Horse', 'ABC', 'UEFA', 'Mi ...
# 4329

# %%
print(filtered_words_set_va.difference(filtered_words_set_pb))
# Out:
# {'Tribunal', 'Radioactive', 'Ἀθηναίη', 'Plateau', 'Rosemont', 'Toledo', 'LL', 'Narnia', 'Staple', 'Taking', 'Brown', 'Bergens', 'Carey', 'Legislature', 'Stripped', 'Mixer', 'Elmet', 'Soprano', 'Baltic', 'Antilia', 'Moose', 'Timor', 'Adriatic', 'Paquin', 'Patel', 'Olympiada', 'Wentworth', 'Matt', 'Fayetteville', 'Runcorn', 'Hun', 'Drift', 'Salado', 'Library', 'Jennifer', 'Locus', 'Eva', 'Junipero', 'Files', 'Lambeth', 'Senators', 'Milky', 'Township', 'Leste', 'Caspian', 'Formosa', 'GD', 'Floyd', 'Naismith', 'Poor', 'Investigation', 'Ural', 'Neptune', 'Zooey', 'Beckinsale', 'Deschanel', 'Presley', 'Pont', 'Angel', 'Wisteria', 'Marmara', 'Norwich', 'Detention', 'Tea', 'Dharma', 'Others', 'Caleta', 'TOP', 'Symoné', 'Leagues', 'Duchovny', 'Endangered', 'Rondell', 'Journals', 'Vice', 'Imperial', 'Aslan', 'SmackDown', 'Keaton', 'Covenant', 'Qatar', 'Sahara', 'Baxter', 'Palais', 'Clares', 'Creed', 'Chatsworth', 'Beetlejuice', 'Gillian', 'Triangle', 'Marple', 'Anthrax', 'Loess', 'Selangor', 'Stormare', 'Scully', 'Newport', 'Scandinavian', 'Presidential', 'Sebo', 'Keymáh', 'Different', 'Oakdale', 'Selina', 'Alec', 'Electronic', 'Organisation', 'Mitchell', 'Twitch', 'Seas', 'Québec', 'Sen', 'Nord', 'Written', 'Hercule', 'Sheridan', 'Shelton', 'Buscemi', 'Kate', 'Nuremberg', 'Damon', 'Macy', 'Thin', 'Platinum', 'Analysis', 'Jess', 'Adolf', 'Andreas', 'BC', 'Hepburn', 'Cambodian', 'Radnor', 'Selene', 'Kathiawar', 'Around', 'Revolution', 'Victor', 'Pine', 'Baldwin', 'Stackhouse', 'Yellow', 'Crazy', 'Ending', 'Anneliese', 'Sof', 'Behavioral', 'Saudi', 'Prussian', 'Elvis', 'BAU', 'Puget', 'Straits', 'Megadeth', 'Haitian', 'Igneel', 'Smithsonian', 'Redmond', 'PC', 'Haryana', 'Geena', 'Sides', 'Estates', 'Bull', 'Dana', 'Species', 'Tanya', 'Coconino', 'Novem', 'Eddie', 'Vanuatu', 'Namdaemun', 'Craig', 'Baker', 'Building', 'Pink', 'Samsung', 'Kaiju', 'Manningham', 'Players', 'Katharine', 'Fairview', 'Netherworld', 'Blake', 'Mariah', 'Foxcatcher', 'Omar', 'Zhongyuan', 'Lycans', 'A140', 'F.', 'Merion', 'Orton', 'Papua', 'Progressive', 'Gaon', 'Assassin', 'Randy', 'Falcón', 'Sangha', 'Sookie', 'Bureau', 'Moskva', 'Riffs', 'Governorate', 'Minor', 'Archbasilica', 'Juan', 'Wardenclyffe', 'Mulder', 'Ethiopia', 'Plate', 'Dealer', 'McLaur', 'Playa', 'Daniel', 'Ned', 'Department', 'Pol', 'Betelgeuse', 'FBI', 'Levine', 'Penin', 'Clapton', 'H', 'MMORPG', 'Gandolfini', 'Alps', 'Southeastern', 'Hoffman', 'Bosphorus', 'Mesoamerica', 'Kane', "T'Keyah", 'Amhara', 'Suez', 'Hawkins', 'Garfield', 'Lateran', 'Pi', 'Mieszko', 'Candyfornia'}

# %%
# IDEA APPLICATA AD UN PARTICOLARE SAMPLE, DA CANCELLARE!


tokens = trovato_tokens
annotations = trovato_annotations

print("tokens: ",tokens)
print("annotations: ",annotations)



# the core of the algorithm
for annotation in annotations:
    token_index = annotation['tokenIndex']
    verb = tokens[token_index]['rawText']
    print(f"Verbo: {verb}\n")

    print("VerbAtlas:")
    verbatlas = annotation['verbatlas']
    frame_name = verbatlas['frameName']
    print(f" Frame: {frame_name}")
    for role_info in verbatlas['roles']:
        role = role_info['role']
        span = role_info['span']
        text = get_text_from_span(tokens, span)
        print(f"  {role}: {text}")
    print()

    print("PropBank:")
    propbank = annotation['englishPropbank']
    frame_name = propbank['frameName']
    print(f" Frame: {frame_name}")
    for role_info in propbank['roles']:
        role = role_info['role']
        span = role_info['span']
        text = get_text_from_span(tokens, span)
        print(f"  {role}: {text}")
    print()
# Out:
# tokens:  [{'index': 0, 'rawText': 'Tennis'}, {'index': 1, 'rawText': 'is'}, {'index': 2, 'rawText': 'a'}, {'index': 3, 'rawText': 'racket'}, {'index': 4, 'rawText': 'sport'}, {'index': 5, 'rawText': 'that'}, {'index': 6, 'rawText': 'can'}, {'index': 7, 'rawText': 'be'}, {'index': 8, 'rawText': 'played'}, {'index': 9, 'rawText': 'individually'}, {'index': 10, 'rawText': 'against'}, {'index': 11, 'rawText': 'a'}, {'index': 12, 'rawText': 'single'}, {'index': 13, 'rawText': 'opponent'}, {'index': 14, 'rawText': '('}, {'index': 15, 'rawText': 'singles'}, {'index': 16, 'rawText': ')'}, {'index': 17, 'rawText': 'or'}, {'index': 18, 'rawText': 'between'}, {'index': 19, 'rawText': 'two'}, {'index': 20, 'rawText': 'teams'}, {'index': 21, 'rawText': 'of'}, {'index': 22, 'rawText': 'two'}, {'index': 23, 'rawText': 'players'}, {'index': 24, 'rawText': 'each'}, {'index': 25, 'rawText': '('}, {'index': 26, 'rawText': 'doubles'}, {'index': 27, 'rawText': ')'}, {'index': 28, 'rawText': '.'}, {'index': 29, 'rawText': 'Tennis'}, {'index': 30, 'rawText': 'is'}, {'index': 31, 'rawText': 'an'}, {'index': 32, 'rawText': 'Olympic'}, {'index': 33, 'rawText': 'sport'}, {'index': 34, 'rawText': 'and'}, {'index': 35, 'rawText': 'is'}, {'index': 36, 'rawText': 'played'}, {'index': 37, 'rawText': 'at'}, {'index': 38, 'rawText': 'all'}, {'index': 39, 'rawText': 'levels'}, {'index': 40, 'rawText': 'of'}, {'index': 41, 'rawText': 'society'}, {'index': 42, 'rawText': 'and'}, {'index': 43, 'rawText': 'at'}, {'index': 44, 'rawText': 'all'}, {'index': 45, 'rawText': 'ages'}, {'index': 46, 'rawText': '.'}, {'index': 47, 'rawText': 'The'}, {'index': 48, 'rawText': 'sport'}, {'index': 49, 'rawText': 'can'}, {'index': 50, 'rawText': 'be'}, {'index': 51, 'rawText': 'played'}, {'index': 52, 'rawText': 'by'}, {'index': 53, 'rawText': 'anyone'}, {'index': 54, 'rawText': 'who'}, {'index': 55, 'rawText': 'can'}, {'index': 56, 'rawText': 'hold'}, {'index': 57, 'rawText': 'a'}, {'index': 58, 'rawText': 'racket'}, {'index': 59, 'rawText': ','}, {'index': 60, 'rawText': 'including'}, {'index': 61, 'rawText': 'wheelchair'}, {'index': 62, 'rawText': 'users'}, {'index': 63, 'rawText': '.'}, {'index': 64, 'rawText': 'A'}, {'index': 65, 'rawText': 'tennis'}, {'index': 66, 'rawText': 'ball'}, {'index': 67, 'rawText': 'is'}, {'index': 68, 'rawText': 'a'}, {'index': 69, 'rawText': 'ball'}, {'index': 70, 'rawText': 'designed'}, {'index': 71, 'rawText': 'for'}, {'index': 72, 'rawText': 'the'}, {'index': 73, 'rawText': 'sport'}, {'index': 74, 'rawText': 'of'}, {'index': 75, 'rawText': 'tennis'}, {'index': 76, 'rawText': '.'}]
# annotations:  [{'tokenIndex': 1, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [0, 1]}, {'role': 'Attribute', 'score': 1.0, 'span': [2, 28]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [0, 1]}, {'role': 'ARG2', 'score': 1.0, 'span': [2, 28]}]}}, {'tokenIndex': 7, 'verbatlas': {'frameName': 'AUXILIARY', 'roles': []}, 'englishPropbank': {'frameName': 'be.03', 'roles': []}}, {'tokenIndex': 8, 'verbatlas': {'frameName': 'PLAY_SPORT/GAME', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [2, 5]}, {'role': 'Modal', 'score': 1.0, 'span': [6, 7]}, {'role': 'Attribute', 'score': 1.0, 'span': [9, 28]}]}, 'englishPropbank': {'frameName': 'play.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [2, 5]}, {'role': 'R-ARG1', 'score': 1.0, 'span': [5, 6]}, {'role': 'ARGM-MOD', 'score': 1.0, 'span': [6, 7]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [9, 10]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [10, 28]}]}}, {'tokenIndex': 30, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [29, 30]}, {'role': 'Attribute', 'score': 1.0, 'span': [31, 34]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [29, 30]}, {'role': 'ARG2', 'score': 1.0, 'span': [31, 34]}]}}, {'tokenIndex': 36, 'verbatlas': {'frameName': 'PLAY_SPORT/GAME', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [29, 30]}, {'role': 'Location', 'score': 1.0, 'span': [37, 46]}]}, 'englishPropbank': {'frameName': 'play.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [29, 30]}, {'role': 'ARGM-LOC', 'score': 1.0, 'span': [37, 46]}]}}, {'tokenIndex': 51, 'verbatlas': {'frameName': 'PLAY_SPORT/GAME', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [47, 49]}, {'role': 'Modal', 'score': 1.0, 'span': [49, 50]}, {'role': 'Agent', 'score': 1.0, 'span': [52, 63]}]}, 'englishPropbank': {'frameName': 'play.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [47, 49]}, {'role': 'ARGM-MOD', 'score': 1.0, 'span': [49, 50]}, {'role': 'ARG0', 'score': 1.0, 'span': [52, 63]}]}}, {'tokenIndex': 56, 'verbatlas': {'frameName': 'POSSESS', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [53, 54]}, {'role': 'Modal', 'score': 1.0, 'span': [55, 56]}, {'role': 'Theme', 'score': 1.0, 'span': [57, 59]}]}, 'englishPropbank': {'frameName': 'hold.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [53, 54]}, {'role': 'R-ARG0', 'score': 1.0, 'span': [54, 55]}, {'role': 'ARGM-MOD', 'score': 1.0, 'span': [55, 56]}, {'role': 'ARG1', 'score': 1.0, 'span': [57, 59]}]}}, {'tokenIndex': 60, 'verbatlas': {'frameName': 'INCLUDE-AS', 'roles': [{'role': 'Goal', 'score': 1.0, 'span': [53, 59]}, {'role': 'Patient', 'score': 1.0, 'span': [61, 63]}]}, 'englishPropbank': {'frameName': 'include.01', 'roles': [{'role': 'ARG2', 'score': 1.0, 'span': [53, 59]}, {'role': 'ARG1', 'score': 1.0, 'span': [61, 63]}]}}, {'tokenIndex': 67, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [64, 67]}, {'role': 'Attribute', 'score': 1.0, 'span': [68, 76]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [64, 67]}, {'role': 'ARG2', 'score': 1.0, 'span': [68, 76]}]}}, {'tokenIndex': 70, 'verbatlas': {'frameName': 'CREATE_MATERIALIZE', 'roles': [{'role': 'Result', 'score': 1.0, 'span': [68, 70]}, {'role': 'Attribute', 'score': 1.0, 'span': [71, 76]}]}, 'englishPropbank': {'frameName': 'design.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [68, 70]}, {'role': 'ARG3', 'score': 1.0, 'span': [71, 76]}]}}]
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tennis
#   Attribute: a racket sport that can be played individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# PropBank:
#  Frame: be.01
#   ARG1: Tennis
#   ARG2: a racket sport that can be played individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# Verbo: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#  Frame: be.03
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: a racket sport
#   Modal: can
#   Attribute: individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# PropBank:
#  Frame: play.01
#   ARG1: a racket sport
#   R-ARG1: that
#   ARGM-MOD: can
#   ARGM-MNR: individually
#   ARGM-MNR: against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tennis
#   Attribute: an Olympic sport
#
# PropBank:
#  Frame: be.01
#   ARG1: Tennis
#   ARG2: an Olympic sport
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: Tennis
#   Location: at all levels of society and at all ages
#
# PropBank:
#  Frame: play.01
#   ARG1: Tennis
#   ARGM-LOC: at all levels of society and at all ages
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: The sport
#   Modal: can
#   Agent: by anyone who can hold a racket , including wheelchair users
#
# PropBank:
#  Frame: play.01
#   ARG1: The sport
#   ARGM-MOD: can
#   ARG0: by anyone who can hold a racket , including wheelchair users
#
# Verbo: hold
#
# VerbAtlas:
#  Frame: POSSESS
#   Agent: anyone
#   Modal: can
#   Theme: a racket
#
# PropBank:
#  Frame: hold.01
#   ARG0: anyone
#   R-ARG0: who
#   ARGM-MOD: can
#   ARG1: a racket
#
# Verbo: including
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: anyone who can hold a racket
#   Patient: wheelchair users
#
# PropBank:
#  Frame: include.01
#   ARG2: anyone who can hold a racket
#   ARG1: wheelchair users
#
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: A tennis ball
#   Attribute: a ball designed for the sport of tennis
#
# PropBank:
#  Frame: be.01
#   ARG1: A tennis ball
#   ARG2: a ball designed for the sport of tennis
#
# Verbo: designed
#
# VerbAtlas:
#  Frame: CREATE_MATERIALIZE
#   Result: a ball
#   Attribute: for the sport of tennis
#
# PropBank:
#  Frame: design.01
#   ARG1: a ball
#   ARG3: for the sport of tennis

# %%
# print(f"verbatlasFrame {verbatlasFrame}")
# print(f"probankFrame {probankFrame}")
# print(f"verbatlasRoles {verbatlasRoles}")
# print(f"probankRoles {probankRoles}")


# verbatlasFrame_complete = verbatlasFrame
# probankFrame_complete = probankFrame
# verbatlasRoles_complete = verbatlasRoles
# probankRoles_complete = probankRoles

print(f"verbatlasFrame {verbatlasFrame_complete}")
print(f"probankFrame {probankFrame_complete}")
print(f"verbatlasRoles {verbatlasRoles_complete}")
print(f"probankRoles {probankRoles_complete}")



# print(f"verbatlasFrame {len(verbatlasFrame)}")
# print(f"probankFrame {len(probankFrame)}")
# print(f"verbatlasRoles {len(verbatlasRoles)}")
# print(f"probankRoles {len(probankRoles)}")
# Out:
# verbatlasFrame {'DISBAND_BREAK-UP', 'INSERT', 'ACCUSE', 'DISLIKE', 'DISCARD', 'DRIVE-BACK', 'PROMOTE', 'KNOW', 'IMAGINE', 'FRUSTRATE_DISAPPOINT', 'MEASURE_EVALUATE', 'ENTER', 'JUSTIFY_EXCUSE', 'FIGHT', 'HEAT', 'BE-LOCATED_BASE', 'CONTRACT-AN-ILLNESS_INFECT', 'LAND_GET-OFF', 'RECORD', 'COMBINE_MIX_UNITE', 'EXPLODE', 'STOP', 'CRITICIZE', 'SETTLE_CONCILIATE', 'CORRELATE', 'DRESS_WEAR', 'CAUSE-SMT', 'NEGOTIATE', 'LURE_ENTICE', 'REFUSE', 'ACHIEVE', 'ODORIZE', 'EXPLAIN', 'BORDER', 'RISK', 'MOVE-ONESELF', 'DIET', 'CHANGE-HANDS', 'EXIST-WITH-FEATURE', 'BEND', 'RESTRAIN', 'MANAGE', 'PUBLISH', 'DANCE', 'HARMONIZE', 'RECOGNIZE_ADMIT_IDENTIFY', 'SHOW', 'HANG', 'INCREASE_ENLARGE_MULTIPLY', 'SING', 'OVERLAP', 'LIGHTEN', 'BREAK_DETERIORATE', 'AFFECT', 'BUY', 'INFLUENCE', 'JOKE', 'CHARGE', 'BRING', 'TOLERATE', 'ASCRIBE', 'LEND', 'STABILIZE_SUPPORT-PHYSICALLY', 'COST', 'DEFEAT', 'FEEL', 'AUXILIARY', 'GROUP', 'OVERCOME_SURPASS', 'REMEMBER', 'FILL', 'PREPARE', 'CHANGE-APPEARANCE/STATE', 'PERCEIVE', 'OBLIGE_FORCE', 'INVERT_REVERSE', 'ORDER', 'WORK', 'INFORM', 'FLOW', 'SLEEP', 'LAUGH', 'DIP_DIVE', 'COMPARE', 'TREAT', 'COPULA', 'REPLACE', 'BURY_PLANT', 'PULL', 'MAKE-A-SOUND', 'BURN', 'COVER_SPREAD_SURMOUNT', 'POSSESS', 'GO-FORWARD', 'INFER', 'CHOOSE', 'FACE_CHALLENGE', 'LEAD_GOVERN', 'OFFER', 'LOAD_PROVIDE_CHARGE_FURNISH', 'ORGANIZE', 'CLOSE', 'STEAL_DEPRIVE', 'DRINK', 'SATISFY_FULFILL', 'REPRESENT', 'EAT_BITE', 'BULGE-OUT', 'NAME', 'RECEIVE', 'FINISH_CONCLUDE_END', 'PLAN_SCHEDULE', 'PUBLICIZE', 'ADD', 'HAVE-A-FUNCTION_SERVE', 'LEAVE-BEHIND', 'RELY', 'ORIENT', 'PUNISH', 'SCORE', 'CONTAIN', 'AROUSE_WAKE_ENLIVEN', 'SLOW-DOWN', 'FOCUS', 'FOLLOW-IN-SPACE', 'WRITE', 'AMELIORATE', 'HELP_HEAL_CARE_CURE', 'HOST_MEAL_INVITE', 'GIVE-BIRTH', 'WORSEN', 'RUN', 'DIVERSIFY', 'TRAVEL', 'DEVELOP_AGE', 'COLOR', 'READ', 'TRY', 'LOSE', 'MESS', 'MEAN', 'ALLY_ASSOCIATE_MARRY', 'CLOUD_SHADOW_HIDE', 'PRINT', 'FLATTEN_SMOOTHEN', 'EXEMPT', 'PLAY_SPORT/GAME', 'PUT_APPLY_PLACE_PAVE', 'CHANGE-TASTE', 'REPEAT', 'BEGIN', 'ASK_REQUEST', 'EMPTY_UNLOAD', 'LOCATE-IN-TIME_DATE', 'REQUIRE_NEED_WANT_HOPE', 'COOL', 'OPEN', 'COOK', 'SHARE', 'REACT', 'DISCUSS', 'COURT', 'APPROVE_PRAISE', 'RAISE', 'PERFORM', 'PRECLUDE_FORBID_EXPEL', 'LIGHT_SHINE', 'FLY', 'CELEBRATE_PARTY', 'COMMUNIZE', 'LEAVE_DEPART_RUN-AWAY', 'BELIEVE', 'ATTACK_BOMB', 'OBEY', 'OPERATE', 'MISTAKE', 'SUBJECTIVE-JUDGING', 'ATTACH', 'CRY', 'GENERATE', 'HIT', 'INCLUDE-AS', 'RESIGN_RETIRE', 'WIN', 'OBTAIN', 'CALCULATE_ESTIMATE', 'DROP', 'TAKE', 'QUARREL_POLEMICIZE', 'BETRAY', 'TOUCH', 'SELL', 'MATCH', 'DRY', 'DELAY', 'MEET', 'DESTROY', 'JOIN_CONNECT', 'AGREE_ACCEPT', 'CHANGE_SWITCH', 'UNDERGO-EXPERIENCE', 'WASH_CLEAN', 'SOLVE', 'FIT', 'STAY_DWELL', 'REMAIN', 'RESERVE', 'SIMPLIFY', 'PRESS_PUSH_FOLD', 'TEACH', 'THROW', 'WAIT', 'LEARN', 'TRANSMIT', 'REVEAL', 'RESULT_CONSEQUENCE', 'SHAPE', 'PRECEDE', 'REFLECT', 'DOWNPLAY_HUMILIATE', 'FACIAL-EXPRESSION', 'HURT_HARM_ACHE', 'SEND', 'AUTHORIZE_ADMIT', 'HAPPEN_OCCUR', 'DISMISS_FIRE-SMN', 'MISS_OMIT_LACK', 'REMOVE_TAKE-AW
# verbatlasRoles {'Modal', 'Result', 'Goal', 'Co-Agent', 'Agent', 'Patient', 'Location', 'Negation', 'Topic', 'Instrument', 'Purpose', 'Extent', 'Source', 'Cause', 'Asset', 'Time', 'Attribute', 'Recipient', 'Co-Patient', 'Beneficiary', 'Destination', 'Idiom', 'Stimulus', 'Material', 'Predicative', 'Product', 'Theme', 'Co-Theme', 'Adverbial', 'Experiencer'}
# probankRoles {'R-ARG2', 'R-ARG3', 'R-ARGM-MNR', 'R-ARGM-GOL', 'ARGM-ADJ', 'C-ARG2', 'C-ARG0', 'C-ARG1', 'ARG2', 'ARG5', 'ARGM-ADV', 'ARGM-DIS', 'ARGM-GOL', 'ARGM-COM', 'ARG1', 'R-ARG0', 'ARGM-TMP', 'ARGM-PNC', 'ARGM-MNR', 'R-ARG1', 'R-ARGM-DIR', 'ARGM-NEG', 'R-ARGM-LOC', 'C-ARGM-MNR', 'ARGM-DIR', 'ARGM-CAU', 'ARGM-PRP', 'ARGM-LVB', 'ARGM-REC', 'R-ARGM-CAU', 'ARG3', 'C-ARG4', 'ARGM-LOC', 'ARGM-EXT', 'ARG4', 'ARGM-MOD', 'ARGM-PRD', 'R-ARGM-TMP', 'ARG0', 'C-ARGM-LOC'}
# verbatlasFrame 388
# probankFrame 1932
# verbatlasRoles 30
# probankRoles 40

# %% [markdown]
# # Idea: Leveraging the information about birthday

# %%
# IDEA: leverage information about bithday
from tqdm import tqdm
from datetime import datetime
import sys




months_list = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]





def clean_name(name):
    # Remove trailing characters like '(' and strip any leading/trailing whitespace
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    # Split the name into components and check if all components start with a capital letter
    name_components = cleaned_name.split()
    if all(component[0].isupper() for component in name_components):
        return cleaned_name
    return False

def strip_name(name):
    pronoms = {'he','she'}
    final_name = ''
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    name_components = cleaned_name.split()
    for index,component in enumerate(name_components):
        if component.lower() in pronoms: return False
        if component[0].isupper(): final_name+=component.strip()
        if index != len(name_components)-1: final_name+=' '
    return final_name

def clean_time(date_str):
        # Remove parentheses and "born"
        date_str = date_str.strip('() ').replace('born ', '')
        try:
            # Parse the date
            date_obj = datetime.strptime(date_str, '%B, %d , %Y')
            # Format the date in the desired format
            return date_obj.strftime('%B, %d, %Y')
        except ValueError as e:
            print(f"Error parsing date: {date_str}")
            return False  # Return original date string if parsing fails
        
def extract_date_components(date_str,pattern,months_list):
    matches = pattern.findall(date_str)
    day, month, year = None, None, None
    for match in matches:
        if match[0]:
            day = match[0]
      
        if match[1]:
            month = match[1]
        if match[2]:
            year = match[2]
        
        # more check to avoid error!
        if day and not (1 <= int(day) <= 31):
            day = None
        if month and month not in months_list:
            month = None
        
    return day, month, year

def check_location(text):
    doc = nlp(text)
    locations = []
    
    # iterate over the entities 
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE (Geopolitical Entity) is the label used for locations
            locations.append(ent.text)    

    return locations




#AUXILIAR METHOD FOR EACH CASE
def be():
    pass




## TODO: manca solo da creare nuovi sample
def create_birthday_samples(filtered_dataset,months_list):

    most_frequent_verbs = {}
    is_data = set()
    nb_data = set()
    new_samples = []
    info_elements = []
    possible_locations = []
    marriage_role = set()
    marriages_info = []
    verbs= set()
    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')
    for index,elem in tqdm(enumerate(filtered_dataset)):

        new_sample = {}

        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']
        subject_added = False
        marriage_added = False

        # print()
        # print(f"srl {srl['annotations']}")
        # print(f"srl {srl['tokens']}")


        # matches = re.findall(pattern_birth, premise)


        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']


        # find the born event in srl annotations


        for annotation_pre in annotations_pre:

            #reference verb of annotation
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']


            if (verb in most_frequent_verbs):
                most_frequent_verbs[verb] +=1
            else:
                most_frequent_verbs[verb] = 0

            #Check born event
            if frame_name == 'GIVE-BIRTH':
                for role in roles:
                    span = role['span']
                    if role['role'] == 'Patient':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            subject_added = True
                            info_elem['subject'] = name
                    elif role['role'] == 'Time':
                        text = get_text_from_span(tokens_pre,span)
                        day,month,year = extract_date_components(text,pattern_time,months_list)
                        if (day or month or year):
                            format_time = ''
                            if (day!=None): 
                                format_time+=day+','
                            else: 
                                format_time+='None,'
                            if (month!=None): 
                                format_time+=month+','
                            else: 
                                format_time+='None,'
                            if (year!=None): 
                                format_time+=year+''
                            else: 
                                format_time+='None'
                            info_elem['whenBorn'] = format_time
                    elif role['role'] == 'Location':
                        text = get_text_from_span(tokens_pre,span)
                        locations = check_location(text)
                        if(len(locations)>0):
                            list_loc = ''
                            for i in range(len(locations)):
                                list_loc += locations[i]
                                if (i!= len(locations)-1): list_loc+=','
                            info_elem['whereBorn'] = list_loc
                    elif role['role'] == 'Agent':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            info_elem['parent'] = name
           
            roles_pb = propbankAnn['roles']
            


            if (frame_name_pb == "be.01"):
                for role in roles_pb:
                    role_info = role['role']
                    span = role['span']
                    text = get_text_from_span(tokens_pre, span)
                    is_data.add(role_info)








            # marry.01
            if (frame_name_pb == "sostituisci con marry.01"):
                # verbs.add(verb)
                


                arg1 = None
                arg2 = None
   

                for role in roles_pb:
                    role_info = role['role']
                    span = role['span']
                    text = get_text_from_span(tokens_pre, span)
                    marriage_role.add(role_info)
                    if role_info == 'ARG1':
                        name = strip_name(text)
                        if (name):
                            marriage_info['Arg1'] = name
                            arg1 = name

                    elif role_info == 'ARG2':
                        name = strip_name(text)
                        if (name):
                            marriage_info['Arg2'] = name
                            arg2 = name
                if arg1 and arg2: 
                    marriage_added = True
                    if verb in {'marry', 'remarries', 'wed', 'marrying', 'marries', 'married'}:
                        new_sample['hypothesis'] = arg1 + ' ' + verb + ' ' + arg2 
                        new_sample['premise'] = text_pre
                        new_samples.append(new_sample)




            # I need to extract information about other actions that have been done from patient
            # elif frame_name == '':


        if(subject_added):info_elements.append(info_elem)
        if(marriage_added):marriages_info.append(marriage_info)


        # print("info extracted -> ",info_elem)
        # break

    
    for elem in is_data:
        print("is data:: ",elem)

    return new_samples


info_elements = create_birthday_samples(nli_dataset['train'],months_list)
# print(len(nli_dataset['train']))
# Out:
# 2963it [00:03, 952.26it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 278
#     273         print("is data:: ",elem)
#     275     return new_samples
# --> 278 info_elements = create_birthday_samples(nli_dataset['train'],months_list)
#     279 # print(len(nli_dataset['train']))
#
# Cell In[18], line 214, in create_birthday_samples(filtered_dataset, months_list)
#     212         role_info = role['role']
#     213         span = role['span']
# --> 214         text = get_text_from_span(tokens_pre, span)
#     215         is_data.add(role_info)
#     224 # marry.01
#
# Cell In[17], line 56, in get_text_from_span(tokens, span)
#      54 i = span[0]
#      55 while span[0] <= i <= span[1]:
# ---> 56     result.join(tokens[i]['rawText'])
#      57     i+=1
#      58 return result
#
# IndexError: list index out of range

# %%
for elem in info_elements:
    print(elem)
# Out:
# {'hypothesis': 'Earp  married    Urilla Sutherland Earp               ', 'premise': 'Wyatt Earp . In 1870 , Earp married his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'hypothesis': ' American          married  Paul McCartney   Beatles', 'premise': 'Linda Louise , Lady McCartney ( née Eastman ; formerly See ; September 24 , 1941 -- April 17 , 1998 ) was an American musician , photographer , animal rights activist , entrepreneur and publisher who was married to Paul McCartney of the Beatles .'}
# {'hypothesis': 'Earp  married    Urilla Sutherland Earp               ', 'premise': 'Wyatt Earp . In 1870 , Earp married his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born . In 1876 , he followed his brother James to Dodge City , Kansas , where he became an assistant city marshal . Earp was a lifelong gambler and was always looking for a quick way to make money .'}
# {'hypothesis': 'Pompeo  married  Chris Ivery ', 'premise': "Ellen Pompeo . Pompeo married producer Chris Ivery in 2007 and the couple have three children together . Alexandra Caroline `` Lexie '' Grey , M.D. is a fictional character from the medical drama television series Grey 's Anatomy , which airs on ABC in the United States ."}
# {'hypothesis': 'Harald  married Sonja Haraldsen ', 'premise': 'Harald V of Norway . Harald married Sonja Haraldsen in 1968 , with their relationship initially being controversial due to her status as a commoner .'}
# {'hypothesis': ' American          married  Paul McCartney   Beatles', 'premise': 'Linda Louise , Lady McCartney ( née Eastman ; formerly See ; September 24 , 1941 -- April 17 , 1998 ) was an American musician , photographer , animal rights activist , entrepreneur and publisher who was married to Paul McCartney of the Beatles .'}
# {'hypothesis': 'Garner  married Ben Affleck ', 'premise': 'Jennifer Garner . Garner married Ben Affleck in 2005 , with whom she has three children ; they separated in 2015 and filed for divorce in April 2017 .'}
# {'hypothesis': 'Earp  married    Urilla Sutherland Earp               ', 'premise': 'Wyatt Earp . In 1870 , Earp married his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'hypothesis': 'Harald  married Sonja Haraldsen ', 'premise': 'Harald V of Norway . Harald married Sonja Haraldsen in 1968 , with their relationship initially being controversial due to her status as a commoner .'}
# {'hypothesis': 'Earp  married    Urilla Sutherland Earp               ', 'premise': 'Wyatt Earp . In 1870 , Earp married his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'hypothesis': 'Tate  married Roman Polanski        The Fearless Vampire Killers', 'premise': "Sharon Marie Tate Polanski ( January 24 , 1943 -- August 9 , 1969 ) was an American actress and model . In January 20 , 1968 , Tate married Roman Polanski , her director and co-star in 1967 's The Fearless Vampire Killers ."}
# {'hypothesis': 'Price  married   Peter Andre    Alex Reid        Kieran Hayler', 'premise': 'Katie Price . Price has had many highly publicised relationships and has been married three times , to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part-time stripper Kieran Hayler ( 2013 -- ) .'}
# {'hypothesis': ' American          married  Paul McCartney   Beatles', 'premise': 'Linda Louise , Lady McCartney ( née Eastman ; formerly See ; September 24 , 1941 -- April 17 , 1998 ) was an American musician , photographer , animal rights activist , entrepreneur and publisher who was married to Paul McCartney of the Beatles . In 1995 she was diagnosed with breast cancer and died from the disease in 1998 at the age of 56 .'}
# {'hypothesis': 'Harald  married Sonja Haraldsen ', 'premise': 'Haakon, Crown Prince of Norway . Haakon , Crown Prince of Norway ( [ ˈhoːkʊn ] ; Haakon Magnus ; born 20 July 1973 ) is the only son and younger child of King Harald V and heir apparent to the throne of Norway . Harald V ( [ ˈhɑrːɑɫ ] ; born 21 February 1937 ) is the King of Norway , having ascended the throne following the death of his father on 17 January 1991 . Harald married Sonja Haraldsen in 1968 , with their relationship initially being controversial due to her status as a commoner . Harald succeeded his father as king in 1991 , with Haakon becoming his heir apparent .'}
# {'hypothesis': 'Brooks  married  Oscar   Anne Bancroft ', 'premise': 'Mel Brooks . He also created , with Buck Henry , the hit television comedy series Get Smart , which ran from 1965 to 1970 . In middle age , Brooks became one of the most successful film directors of the 1970s , with many of his films being among the top 10 moneymakers of the year they were released . He received a Kennedy Center Honor in 2009 , the Hollywood Walk of Fame in 2010 , the 41st AFI Life Achievement Award in June 2013 , a British Film Institute Fellowship in March 2015 , a National Medal of Arts in September 2016 , and a BAFTA Fellowship in February 2017 . Brooks was married to Oscar-winning actress Anne Bancroft from 1964 until her death in 2005 .'}
# {'hypothesis': 'Garner  married Ben Affleck ', 'premise': 'Jennifer Garner . Gar
# {'hypothesis': 'Pompeo  married  Chris Ivery ', 'premise': 'Ellen Pompeo . Pompeo married producer Chris Ivery in 2007 and the couple have three children together .'}
# {'hypothesis': '  marry Geoffrey  Anjou ', 'premise': 'Empress Matilda . The daughter of King Henry I of England , she moved to Germany as a child when she married the future Holy Roman Emperor Henry V .'}
# {'hypothesis': '  marry Geoffrey  Anjou ', 'premise': "Empress Matilda . On Henry V 's death , Matilda was recalled to Normandy by her father , who arranged for her to marry Geoffrey of Anjou to form an alliance to protect his southern borders ."}

# %%
for elem in info_elements:
    print(elem)
    # if (elem.get('whereBorn')):
    #     print("id:  ",elem['id'])
    #     print("Locations: ",elem['whereBorn'])

print(len(info_elements))
print("ok")
# Out:
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Arg1': 'Man ('}
# {'Arg2': 'with Children ('}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Time': 'from 1998 to 2003 ,', 'Arg1': 'they married'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'Man ('}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'He marries', 'Arg2': 'Elizabeth Swann in', 'Location': "in At World ' s End ,"}
# {'Arg1': 'He marries', 'Arg2': 'Elizabeth Swann in', 'Location': "in At World ' s End ,"}
# {'Arg1': 'He marries', 'Arg2': 'Elizabeth Swann in', 'Location': "in At World ' s End ,"}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Arg1': 'Crawford married', 'Time': 'four times .'}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Time': 'In 1947 ,', 'Arg1': 'she married', 'Arg2': 'Philip , Duke of Edinburgh , a former prince of Greece and Denmark , with whom she has four children : Charles , Prince of Wales ;'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'Brinkley has', 'Time': 'four times ,', 'Adverbial': 'most notably to musician Billy Joel , several of whose music videos she appeared in .'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Crawford married', 'Time': 'four times .'}
# {'Arg1': 'Barack and Michelle married', 'Time': 'in 1992 and'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Time': 'Two years later ,', 'Arg1': 'he married', 'Arg2': 'the Bourbon princess Henrietta Maria of France instead', 'Adverbial': 'instead .'}
# {'Arg1': 'Man ('}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'Barack and Michelle married', 'Time': 'in 1992 and'}
# {'Time': 'Two years later ,', 'Arg1': 'he married', 'Arg2': 'the Bourbon princess Henrietta Maria of France instead', 'Adverbial': 'instead .'}
# {'Arg1': 'Brooks was', 'Arg2': 'to Oscar - winning actress Anne Bancroft from', 'Time': 'until her death in 2005 .'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Arg1': 'the couple married', 'Time': 'in 2014 and'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Man ('}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'she married', 'Time': 'in 1968 she', 'Arg2': 'Aristotle Onassis .'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Time': 'in 2005 ,', 'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Manner': 'legitimately marrying', 'Arg2': 'McMahon in', 'Time': 'in 2003 ,', 'Arg1': 'he became'}
# {'Manner': 'legitimately marrying', 'Arg2': 'McMahon in', 'Time': 'in 2003 ,', 'Arg1': 'he became'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Kris Jenner has', 'Time': 'twice ;', 'Arg2': 'to television personality and retired Olympic Games champion , Bruce Jenner ( now known as Caitlyn ) .'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Mamie married', 'Time': 'in 1916 .', 'Arg2': 'Dwight Eisenhower at'}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Elizabeth would', 'Modal': 'would marry'}
# {'Time': 'in 2005 ,', 'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'Rachel Getting'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Arg1': 'who became', 'Arg2': 'Prince Rainier III ,', 'Time': 'in April 1956 .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'he married', 'Arg2': 'Eleanor Roosevelt ,'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'high school teacher to'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'she was', 'Arg2': 'Mötley Crüe drummer Tommy Lee .'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'her to', 'Arg2': 'a distant cousin , King Henry III of Navarre ,'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Elizabeth would', 'Modal': 'would marry'}
# {'Time': 'At the age of 18 ,', 'Arg1': 'he married', 'Arg2': 'Anne Hathaway , with whom he had three children : Susanna , and twins Hamnet and Judith .'}
# {'Time': 'At the age of 18 ,', 'Arg1': 'he married', 'Arg2': 'Anne Hathaway , with whom he had three children : Susanna , and twins Hamnet and Judith .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Man ('}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg2': 'to the Mob ('}
# {'Arg2': 'to the Mob ('}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Arg1': 'He graduated', 'Time': 'later married', 'Arg2': 'Mamie Doud , with whom he had two sons .'}
# {'Arg1': 'Bündchen married', 'Arg2': 'New England Patriots quarterback Tom Brady in', 'Time': 'in 2009 .'}
# {'Arg1': 'Bündchen married', 'Arg2': 'New England Patriots quarterback Tom Brady in', 'Time': 'in 2009 .'}
# {'Arg1': 'Bündchen married', 'Arg2': 'New England Patriots quarterback Tom Brady in', 'Time': 'in 2009 .'}
# {'Arg1': 'a couple who'}
# {'Arg1': 'they are'}
# {'Time': 'in 2005 ,', 'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Arg1': 'they are'}
# {'Arg1': 'Rachel Getting'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Adverbial': 'According to the Book of Genesis ,', 'Arg1': 'Abraham married', 'Arg2': 'Keturah after', 'Time': 'after the death of his first wife , Sarah ;'}
# {'Arg1': 'Crawford married', 'Time': 'four times .'}
# {'Arg1': 'he married', 'Arg2': 'Eleanor Roosevelt ,'}
# {'Arg1': 'He graduated', 'Time': 'later married', 'Arg2': 'Mamie Doud , with whom he had two sons .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Time': 'when he', 'Arg1': 'he remarries'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Arg1': 'an Army nurse named Diana Prince who', 'R-Arg1': 'who went', 'Arg2': 'her fiancé to', 'Purpose': 'to become Dia na'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Man ('}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'He graduated', 'Time': 'later married', 'Arg2': 'Mamie Doud , with whom he had two sons .'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'who became', 'Arg2': 'Prince Rainier III ,', 'Time': 'in April 1956 .'}
# {'Arg1': 'who became', 'Arg2': 'Prince Rainier III ,', 'Time': 'in April 1956 .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'a couple who'}
# {'Arg1': 'she was', 'R-Arg1': 'who was', 'Arg2': 'Paul ,'}
# {'Arg1': 'he married', 'Arg2': 'Eleanor Roosevelt ,'}
# {'Arg1': 'the two married', 'Location': 'in Rye , New York in', 'Time': 'while he was on leave during his deployment as a Naval officer in World War II .'}
# {'Arg1': 'who became', 'Arg2': 'Prince Rainier III ,', 'Time': 'in April 1956 .'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Time': 'in 2005 ,', 'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'Edward abdicated'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg0': 'John , who announced he was bisexual in 1976 and has been openly gay since 1988 ,', 'Time': 'on 21 December 2014 .', 'Arg1': 'Furnish on'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Brinkley has', 'Time': 'four times ,', 'Adverbial': 'most notably to musician Billy Joel , several of whose music videos she appeared in .'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Brinkley has', 'Time': 'four times ,', 'Adverbial': 'most notably to musician Billy Joel , several of whose music videos she appeared in .'}
# {'Arg1': 'She married', 'Arg2': 'John McCain in', 'Time': 'in 1980 and'}
# {'Arg1': 'Man ('}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'they are'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'high school teacher to'}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Arg2': 'Paul ,', 'Arg1': 'she was'}
# {'Arg2': 'Paul ,', 'Arg1': 'she was'}
# {'R-Arg1': 'Born and raised in Los Angeles ,', 'Arg1': 'Monroe spent', 'Time': 'at the age of sixteen .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Peggy Sue Got'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Arg1': 'her to', 'Arg2': 'a distant cousin , King Henry III of Navarre ,'}
# {'Arg1': 'Crawford married', 'Time': 'four times .'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'Man ('}
# {'Arg1': 'they are'}
# {'Arg1': 'He later', 'Time': 'later returned'}
# {'Arg1': 'He later', 'Time': 'later returned'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Man ('}
# {'Arg1': 'She married', 'Arg2': 'John McCain in', 'Time': 'in 1980 and'}
# {'Arg1': 'Peggy Sue Got'}
# {'Time': 'in 1791 he', 'Arg1': 'he married', 'Arg2': 'Rachel Donelson Robards .'}
# {'Time': 'in 1791 he', 'Arg1': 'he married', 'Arg2': 'Rachel Donelson Robards .'}
# {'Time': 'in 1791 he', 'Arg1': 'he married', 'Arg2': 'Rachel Donelson Robards .'}
# {'Time': 'in 1791 he', 'Arg1': 'he married', 'Arg2': 'Rachel Donelson Robards .'}
# {'Arg1': 'He graduated', 'Time': 'later married', 'Arg2': 'Mamie Doud , with whom he had two sons .'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'the couple married', 'Time': 'in 2014 and'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'She was', 'Arg2': 'to actor Robert Wagner twice', 'Time': 'twice ,'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg1': 'the two married', 'Location': 'in Rye , New York in', 'Time': 'while he was on leave during his deployment as a Naval officer in World War II .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Arg1': 'He married', 'Arg2': 'Lady Elizabeth Bowes - Lyon in', 'Time': 'in 1923 and'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'Rachel Getting'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Adverbial': 'According to the Book of Genesis ,', 'Arg1': 'Abraham married', 'Arg2': 'Keturah after', 'Time': 'after the death of his first wife , Sarah ;'}
# {'Adverbial': 'According to the Book of Genesis ,', 'Arg1': 'Abraham married', 'Arg2': 'Keturah after', 'Time': 'after the death of his first wife , Sarah ;'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Man ('}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'couple surprised'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'actor Abhishek Bachchan in', 'Time': 'in 2007 with', 'C-Arg2': 'with whom she has one daughter .'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'Barack and Michelle married', 'Time': 'in 1992 and'}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg1': 'he married', 'Arg2': 'Eleanor Roosevelt ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Time': 'in 2005 ,', 'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'C-Arg2': 'with whom she has three children ;'}
# {'Arg1': 'She served'}
# {'Time': 'Two years later ,', 'Arg1': 'he married', 'Arg2': 'the Bourbon princess Henrietta Maria of France instead', 'Adverbial': 'instead .'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'She married', 'Arg2': 'John McCain in', 'Time': 'in 1980 and'}
# {'Arg1': 'Presley has', 'Time': 'before marrying music producer Michael Lockwood , father of her twin girls .', 'Arg2': 'music producer Michael Lockwood , father of her twin girls .'}
# {'Arg1': 'Presley has', 'Time': 'before marrying music producer Michael Lockwood , father of her twin girls .', 'Arg2': 'music producer Michael Lockwood , father of her twin girls .'}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'Price has', 'Time': 'three times ,', 'Arg2': 'to singer Peter Andre ( 2005 -- 2009 ) , to professional fighter Alex Reid ( 2010 -- 2011 ) and to builder and part - time stripper Kieran Hayler ( 2013 -- ) .'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Time': 'Two years later ,', 'Arg1': 'he married', 'Arg2': 'the Bourbon princess Henrietta Maria of France instead', 'Adverbial': 'instead .'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Time': 'when she', 'Arg1': 'she married', 'Arg2': 'the future Holy Roman Emperor Henry V .'}
# {'Arg1': 'his ,', 'Adverbial': 'also married'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'actor Abhishek Bachchan in', 'Time': 'in 2007 with', 'C-Arg2': 'with whom she has one daughter .'}
# {'Arg1': 'Willis married', 'Arg2': 'actress Demi Moore in', 'Time': 'in 1987 ,'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He married', 'Arg2': 'Ann Davies in', 'Time': 'in 1969 ,'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Time': 'In 2008 ,', 'Arg1': 'she married', 'Arg2': 'her longtime girlfriend Portia de Rossi .'}
# {'Arg1': 'her to', 'Arg2': 'a distant cousin , King Henry III of Navarre ,'}
# {'Arg2': 'actress Jennifer Aniston ,', 'R-Arg2': 'to whom he', 'Arg1': 'he was', 'Time': 'for five years ,'}
# {'Arg2': 'actress Jennifer Aniston ,', 'R-Arg2': 'to whom he', 'Arg1': 'he was', 'Time': 'for five years ,'}
# {'Arg2': 'actress Jennifer Aniston ,', 'R-Arg2': 'to whom he', 'Arg1': 'he was', 'Time': 'for five years ,'}
# {'Arg2': 'actress Jennifer Aniston ,', 'R-Arg2': 'to whom he', 'Arg1': 'he was', 'Time': 'for five years ,'}
# {'Arg2': 'actress Jennifer Aniston ,', 'R-Arg2': 'to whom he', 'Arg1': 'he was', 'Time': 'for five years ,'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg2': 'to actor Justin Theroux since', 'R-Arg2': 'to whom she', 'Arg1': 'she has', 'Time': 'since 2015 .', 'R-Arg1': 'Divorced from actor Brad Pitt , to whom she was married for five years ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'She married', 'Arg2': 'John McCain in', 'Time': 'in 1980 and'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Brinkley has', 'Time': 'four times ,', 'Adverbial': 'most notably to musician Billy Joel , several of whose music videos she appeared in .'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg2': 'with Children ('}
# {'Arg1': 'He has', 'Time': 'three times and'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Harald married', 'Arg2': 'Sonja Haraldsen in', 'Time': 'in 1968 ,', 'Adverbial': 'with their relationship initially being controversial due to her status as a commoner .'}
# {'Arg1': 'Their nine children married', 'Arg2': 'into royal and noble families across', 'Location': 'across the continent ,', 'Adverbial': "tying them together and earning her the sobriquet ` ` the grandmother of Europe '' ."}
# {'Manner': 'How to', 'Arg2': 'a Millionaire is'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire is'}
# {'Time': 'In January 20 , 1968 ,', 'Arg1': 'Tate married', 'Arg2': "Roman Polanski , her director and co - star in 1967 ' s The Fearless Vampire Killers ."}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Time': 'a few weeks after meeting at a Bad Boy photo shoot .'}
# {'Arg1': 'Garner married', 'Arg2': 'Ben Affleck in', 'Time': 'in 2005 ,', 'C-Arg2': 'with whom she has three children ;'}
# {'Time': 'In 1870 ,', 'Arg1': 'Earp married', 'Arg2': 'his first wife , Urilla Sutherland Earp , who contracted typhoid fever and died shortly before their first child was to be born .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'an American musician , photographer , animal rights activist , entrepreneur and publisher who', 'R-Arg1': 'who was', 'Arg2': 'to Paul McCartney of the Beatles .'}
# {'Arg1': 'he could', 'Modal': 'could not', 'Negation': 'not marry', 'Arg2': 'Wallis and'}
# {'Arg1': 'He married', 'Arg2': 'the frontwoman of the group , Selena , on', 'Time': 'on April 2 , 1992 .'}
# {'Arg1': 'He married', 'Arg2': 'the frontwoman of the group , Selena , on', 'Time': 'on April 2 , 1992 .'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'actor Abhishek Bachchan in', 'Time': 'in 2007 with', 'C-Arg2': 'with whom she has one daughter .'}
# {'Arg1': 'actor Dax Shepard in', 'Time': 'in 2013 ,', 'C-Arg2': 'with whom she has two daughters .'}
# {'Arg1': 'actor Dax Shepard in', 'Time': 'in 2013 ,', 'C-Arg2': 'with whom she has two daughters .'}
# {'Arg1': 'the couple married', 'Time': 'in 2014 and'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg2': 'My Life with Stephen ,', 'R-Arg2': 'to whom she', 'Arg1': 'she was'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'He graduated', 'Time': 'later married', 'Arg2': 'Mamie Doud , with whom he had two sons .'}
# {'Arg2': 'with Children ('}
# {'Arg2': 'with Children ('}
# {'Arg1': 'she married', 'R-Arg1': 'whom she', 'Manner': 'as per Egyptian custom ,'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Arg1': 'a couple who'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Pompeo married', 'Arg2': 'producer Chris Ivery in', 'Time': 'in 2007 and'}
# {'Arg1': 'the couple married', 'Time': 'in 2014 and'}
# {'Arg1': 'Peggy Sue Got'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'She is', 'Arg2': 'to David Beckham ,'}
# {'Arg1': 'he married', 'Arg2': 'Eleanor Roosevelt ,'}
# {'Arg1': 'He married', 'Arg2': 'Patti Scialfa in', 'Time': 'in 1991 ,'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Arg1': 'he married', 'Arg2': 'Lady Diana Spencer and'}
# {'Arg1': 'She attended', 'Arg2': 'Mitt Romney in', 'Time': 'in 1969 ,'}
# {'Arg1': 'Man ('}
# {'Arg1': 'her to', 'Arg2': 'Geoffrey of Anjou to', 'Purpose': 'to form an alliance to protect his southern borders .'}
# {'Arg1': 'her to', 'Arg2': 'Geoffrey of Anjou to', 'Purpose': 'to form an alliance to protect his southern borders .'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Manner': 'How to', 'Arg2': 'a Millionaire ,'}
# {'Arg1': 'Man ('}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# {'Arg1': 'Rachel Getting'}
# 400
# ok

# %%
# Print the last example to verify the addition
born_dataset = nli_dataset['train'].filter(lambda example: 'born' in example['premise'].lower() or 'born' in example['hypothesis'].lower())
pattern = r'\(\s*born\s+(?:[A-Za-z]+\s+\d{1,2}\s*,?\s*\d{4}|[A-Za-z]+\s+\d{1,2}\s*\d{4})\s*\)'
new_samples = create_birthday_samples(born_dataset,pattern,months_list)
# Out:
# 0it [00:00, ?it/s]
# match -> ( born December 24 , 1974 )
# [{'tokenIndex': 4, 'verbatlas': {'frameName': 'GIVE-BIRTH', 'roles': [{'role': 'Patient', 'score': 1.0, 'span': [0, 3]}, {'role': 'Time', 'score': 1.0, 'span': [5, 9]}]}, 'englishPropbank': {'frameName': 'bear.02', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [0, 3]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [5, 9]}]}}, {'tokenIndex': 10, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [0, 10]}, {'role': 'Attribute', 'score': 1.0, 'span': [11, 20]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [0, 10]}, {'role': 'ARG2', 'score': 1.0, 'span': [11, 20]}]}}, {'tokenIndex': 22, 'verbatlas': {'frameName': 'BEGIN', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [21, 22]}, {'role': 'Theme', 'score': 1.0, 'span': [23, 35]}, {'role': 'Time', 'score': 1.0, 'span': [35, 39]}]}, 'englishPropbank': {'frameName': 'begin.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [21, 22]}, {'role': 'ARG1', 'score': 1.0, 'span': [23, 35]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [35, 39]}]}}, {'tokenIndex': 25, 'verbatlas': {'frameName': 'HOST_MEAL_INVITE', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [21, 22]}, {'role': 'Attribute', 'score': 1.0, 'span': [23, 24]}, {'role': 'Beneficiary', 'score': 1.0, 'span': [26, 27]}, {'role': 'Attribute', 'score': 1.0, 'span': [31, 35]}, {'role': 'Time', 'score': 1.0, 'span': [35, 37]}]}, 'englishPropbank': {'frameName': 'host.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [21, 22]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [23, 24]}, {'role': 'ARG1', 'score': 1.0, 'span': [26, 27]}, {'role': 'ARGM-COM', 'score': 1.0, 'span': [27, 31]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [31, 35]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [35, 37]}]}}, {'tokenIndex': 41, 'verbatlas': {'frameName': 'RECEIVE', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [40, 41]}, {'role': 'Theme', 'score': 1.0, 'span': [42, 48]}]}, 'englishPropbank': {'frameName': 'receive.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [40, 41]}, {'role': 'ARG1', 'score': 1.0, 'span': [42, 48]}]}}, {'tokenIndex': 50, 'verbatlas': {'frameName': 'WIN', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [40, 41]}, {'role': 'Patient', 'score': 1.0, 'span': [51, 53]}, {'role': 'Cause', 'score': 1.0, 'span': [53, 61]}]}, 'englishPropbank': {'frameName': 'win.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [40, 41]}, {'role': 'ARG1', 'score': 1.0, 'span': [51, 53]}, {'role': 'ARGM-CAU', 'score': 1.0, 'span': [53, 61]}]}}, {'tokenIndex': 54, 'verbatlas': {'frameName': 'MOUNT_ASSEMBLE_PRODUCE', 'roles': [{'role': 'Product', 'score': 1.0, 'span': [55, 61]}]}, 'englishPropbank': {'frameName': 'produce.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [55, 61]}]}}]

# %% [markdown]
# # Model

# %%
# MODEL
# Initialize the model

model = AutoModelForSequenceClassification.from_pretrained(language_model_name,
                                                                   ignore_mismatched_sizes=True,
                                                                   output_attentions=False, output_hidden_states=False,
                                                                   num_labels=3) # number of the classes to change to 3

tokenizer = AutoTokenizer.from_pretrained(language_model_name)

# padding with the most long sentence!
data_collator = DataCollatorWithPadding(tokenizer=tokenizer) # avoid to use can reduce the memory on GPU

#examples are batch!
def tokenize_function(examples):
    examples["label"] = [labels_mapping[label] for label in examples["label"]]
    return tokenizer(examples["premise"], examples["hypothesis"],padding = True, truncation=True)




# Tokenize the dataset ...
print("Tokenize the dataset ...")
labels_mapping = {"ENTAILMENT":0, "CONTRADICTION":1, "NEUTRAL":2 }
tokenized_nli_dataset= nli_dataset.map(tokenize_function, batched=True)

print(tokenized_nli_dataset["train"][0])

# %%
# DATASET EXPLORATION
print(f"nli_dataset -> {nli_dataset}")

#MODEL TRAINING

training_args = TrainingArguments(
    output_dir="training_dir",                    # output directory [Mandatory]
    num_train_epochs=epochs,                      # total number of training epochs
    per_device_train_batch_size=batch_size,       # batch size per device during training
    warmup_steps=500,                             # number of warmup steps for learning rate scheduler
    weight_decay=weight_decay,                    # strength of weight decay
    save_strategy="no",                           # save the model
    learning_rate=learning_rate,                  # learning rate
    gradient_checkpointing = True                 # to reduce memory usage
    # fp16 = True                                 # to reduce more memory usage
)


trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=tokenized_nli_dataset["train"],
   eval_dataset=tokenized_nli_dataset["validation"],
   tokenizer=tokenizer,
   data_collator=data_collator,
   compute_metrics=compute_metrics,
)


trainer.train()

# %%
trainer.evaluate()
