# %% [markdown]
# # Import

# %%
import torch
import numpy as np 
import pandas as pd
from typing import Dict
import torch
from datasets import load_dataset, Dataset
from transformers import DataCollatorWithPadding
from datasets import load_metric,load_from_disk
from transformers import (
    AutoConfig,
    AutoModelForSequenceClassification,
    AutoTokenizer,
    EvalPrediction,
    Trainer,
    TrainingArguments,
    set_seed,
)

from tqdm import tqdm
from datetime import datetime
import re
import random

import nltk
from nltk.corpus import wordnet as wn
nltk.download('wordnet')

import spacy
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package wordnet to /home/bitfra/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
## MODEL PARAMETERS
# we will use with Distil-BERT
language_model_name = "distilbert-base-uncased"

### Training Argurments

# this GPU should be enough for this task to handle 32 samples per batch
batch_size = 32

# optim
learning_rate = 1e-4
weight_decay = 0.001 # we could use e.g. 0.01 in case of very low and very high amount of data for regularization

# training
epochs = 1
device = "cuda" if torch.cuda.is_available() else "cpu"
set_seed(42)
# load our dataset
adversarial_set = load_dataset("iperbole/adversarial_fever_nli")
nli_dataset = load_dataset("tommasobonomo/sem_augmented_fever_nli",trust_remote_code=True)

# %%
from transformers import BertTokenizer, BertModel

import torch
import numpy as np

device = "cuda" if torch.cuda.is_available() else "cpu"
# model_clip, preprocess_clip = clip.load("ViT-B/32", device=device)


tokenizer_bert = BertTokenizer.from_pretrained('bert-base-uncased')
model_bert = BertModel.from_pretrained('bert-base-uncased')
# tokenizer_debert = DebertaTokenizer.from_pretrained('microsoft/deberta-base')
# model_debert = DebertaModel.from_pretrained('microsoft/deberta-base')

# %% [markdown]
# # Metric def and save the dataset

# %%
#SAVE DATASET
# nli_dataset.save_to_disk('nli_data')
# copy_dataset = load_from_disk('nli_data')
# print(copy_dataset)

# %%
# METRIC DEFINITION
# Metrics
def compute_metrics(eval_pred):
   load_accuracy = load_metric("accuracy")
   load_f1 = load_metric("f1")
   logits, labels = eval_pred
   predictions = np.argmax(logits, axis=-1)
   accuracy = load_accuracy.compute(predictions=predictions, references=labels)["accuracy"]
   f1 = load_f1.compute(predictions=predictions, references=labels,accuracy="weigthed")["f1"]
   return {"accuracy": accuracy, "f1": f1}

# %% [markdown]
# # Utilities

# %%
def get_word_embedding(word,tokenizer,model):
    inputs = tokenizer(word, return_tensors='pt')
    outputs = model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).squeeze()

def cosine_similarity(embedding1, embedding2):
    return torch.nn.functional.cosine_similarity(embedding1, embedding2, dim=0).item()






def get_synonyms(word, pos):
    synonyms = set()
    for syn in wn.synsets(word, pos=pos):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return list(synonyms)



def get_synset_by_offset(offset):
    offset_num = int(''.join(filter(str.isdigit, offset)))
    pos = offset[-1]
    return wn.synset_from_pos_and_offset(pos, offset_num)



def get_related_words(synset):
    
    synonyms = synset.lemma_names()

    
    hypernyms = synset.hypernyms()
    hypernym_words = set()
    for hypernym in hypernyms:
        hypernym_words.update(hypernym.lemma_names())

    
    hyponyms = synset.hyponyms()
    hyponym_words = set()
    for hyponym in hyponyms:
        hyponym_words.update(hyponym.lemma_names())


    
    antonym_words = set()
    for lemma in synset.lemmas():
        for antonym in lemma.antonyms():
            antonym_words.add(antonym.name())

    return {
        'synonyms': list(synonyms),
        'hypernyms': list(hypernym_words),
        'hyponyms': list(hyponym_words),
        'antonyms': list(antonym_words)
    }



# extract the text from span information
def get_text_from_span(tokens, span):
    try:
        # print(f"tokens -> {tokens}")
        # print(f"span[0] -> {span[0]}")
        # print(f"span[1] -> {span[1]}")
        return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1 ))
    except:
        # print(f"tokens -> {tokens}")
        # print(f"span[0] -> {span[0]}")
        # print(f"span[1] -> {span[1]}")
        return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1]))

# %%
# TEST OF PRETRAINED MODEL

w1 = 'maybe'
w2 = 'this'


emb1_2 = get_word_embedding(w1,tokenizer_bert,model_bert)
emb2_2 = get_word_embedding(w2,tokenizer_bert,model_bert)

score_2 = cosine_similarity(emb1_2,emb2_2)

# print(score)
print(score_2)
# Out:
# 0.8056880831718445

# %%
from tqdm import tqdm
from datetime import datetime
import sys

months_list = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]


def clean_name(name):
    # Remove trailing characters like '(' and strip any leading/trailing whitespace
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    # Split the name into components and check if all components start with a capital letter
    name_components = cleaned_name.split()
    if all(component[0].isupper() for component in name_components):
        return cleaned_name
    return False

def strip_name(name):
    pronoms = {'he','she'}
    final_name = ''
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    name_components = cleaned_name.split()
    for index,component in enumerate(name_components):
        if component.lower() in pronoms: return False
        if component[0].isupper(): final_name+=component.strip()
        if index != len(name_components)-1: final_name+=' '
    return final_name

def clean_time(date_str):
        # Remove parentheses and "born"
        date_str = date_str.strip('() ').replace('born ', '')
        try:
            # Parse the date
            date_obj = datetime.strptime(date_str, '%B, %d , %Y')
            # Format the date in the desired format
            return date_obj.strftime('%B, %d, %Y')
        except ValueError as e:
            print(f"Error parsing date: {date_str}")
            return False  # Return original date string if parsing fails
        
def extract_date_components(date_str,pattern,months_list):
    matches = pattern.findall(date_str)
    day, month, year = None, None, None
    for match in matches:
        if match[0]:
            day = match[0]
      
        if match[1]:
            month = match[1]
        if match[2]:
            year = match[2]
        
        # more check to avoid error!
        if day and not (1 <= int(day) <= 31):
            day = None
        if month and month not in months_list:
            month = None
    return day, month, year

def check_location(text):
    doc = nlp(text)
    locations = []
    
    # iterate over the entities 
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE (Geopolitical Entity) is the label used for locations
            locations.append(ent.text)    

    return locations


def change_time(time,what='y',add=False):

    months_days = {
    "January": 31, "February": 28, "March": 31, "April": 30, "May": 31, "June": 30,
    "July": 31, "August": 31, "September": 30, "October": 31, "November": 30, "December": 31
    }

    try:
        time_split = time.split(',')
        year = int(time_split[2])

        #change only the year
        if what=='y':
            quantity = random.randint(10,40)
            if add: year+=quantity
            else: year-=quantity
        
        time_split[2] = str(year)
        if time_split[1] == 'None':
            #choice one month!
            month = random.choice(list(months_days.keys()))
            # time_split[1] = month
            time_split[1] = month

        if time_split[0] == 'None':
            month = time_split[1].strip()
            day = random.randint(1, months_days[month])
            time_split[0] = str(day)
            

        return ','.join(elem for elem in time_split)
    except:
        print(f"error time -> {time}")
        sys.exit()

def create_hp(wordsList):
    return ' '.join(word for word in wordsList)

# %% [markdown]
# # Idea (synonyms and hypernyms)

# %%
# import sys
def join_strings_smartly(words):
    """ Joins a list of words smartly:
    - Adds spaces between words when appropriate.
    - Avoids adding spaces before punctuation.
    """
    punctuation = {'.', ',', ';', ':', '!', '?',')'}
    result = words[0]
    prev = result

    for word in words[1:]:
      if word in punctuation or \
        "'" in prev or \
        word.startswith("'") or \
        ("." in prev and "." in word) or \
        ("(" in prev) :
        # add word without space
        result += word
      else:
        # add with space
        result += " " + word
      # keep track of previous word  
      prev = word

    return result




def change_withBert(dataset,model,tokenizer,best_score=True):
    # count=0
    new_samples = []
    for elem in dataset:
        new_sample = {}
        text_pre = elem['premise']
        label = elem['label']
        text_hp_original = elem['hypothesis']
        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        changes = 0
        new_hp = []

        for wsd in wsd_hp:
            pos = wsd['pos']
            word = wsd['text']
            wn_offset = wsd['wnSynsetOffset']
            if (wn_offset!='O'):
                synset = get_synset_by_offset(wn_offset)
                info = get_related_words(synset)
                
                synonyms = info['synonyms']
                hypernyms = info['hypernyms']
                hyponyms = info['hyponyms']
                antonyms = info['antonyms']

                if word in synonyms:
                    synonyms.remove(word)
                if word in hypernyms:
                    hypernyms.remove(word)

                best_sim_syn_score = -1
                best_sim_syn_word = word
                best_sim_hyp_score = -1
                best_sim_hyp_word = word
                emb_word = get_word_embedding(word,tokenizer,model)

                change_prob = random.random()

                if change_prob > 0.5:
                    # the idea is to change only that terms that have for me enough synonyms
                    if len(synonyms)>=3:
                        #now you can substitute synonyms

                        if best_score:
                            for candidate in synonyms:
                                emb_cand = get_word_embedding(candidate,tokenizer,model)
                                sim = cosine_similarity(emb_word,emb_cand)
                                if sim > best_sim_syn_score:
                                    best_sim_syn_score = sim
                                    best_sim_syn_word = candidate
                            new_word = best_sim_syn_word.replace('_', ' ')
                            new_hp.append(new_word)
                            changes += 1
                        else:
                            rand_index = random.randint(0,len(synonyms)-1)
                            new_word = synonyms[rand_index]
                            new_word = synonyms[rand_index]
                            new_word = new_word.replace('_', ' ')
                            new_hp.append(new_word)
                            changes += 1
                    else:
                        new_hp.append(word)
                elif change_prob <=0.5:
                    if len(hypernyms) >=1:
                        if best_score:
                            for candidate in hypernyms:
                                emb_cand = get_word_embedding(candidate,tokenizer,model)
                                sim = cosine_similarity(emb_word,emb_cand)
                                if sim > best_sim_hyp_score:
                                    best_sim_hyp_score = sim
                                    best_sim_hyp_word = candidate
                            new_word = best_sim_hyp_word.replace('_',' ')
                            new_hp.append(new_word)
                            changes += 1
                        else:
                            rand_index = random.randint(0,len(hypernyms)-1)
                            new_word = hypernyms[rand_index]
                            new_word = hypernyms[rand_index]
                            new_word = new_word.replace('_', ' ')
                            new_hp.append(new_word)
                            changes += 1
                    else:
                        new_hp.append(word)
            else:
                new_hp.append(word)

        
        if changes > 1:
            new_hp = join_strings_smartly(new_hp)
            new_sample['premise'] = text_pre
            new_sample['hypothesis'] = new_hp
            new_sample['original'] = text_hp_original
            new_sample['label'] = label
            new_samples.append(new_sample)



        # print(f"wsd_hp -> {wsd_hp}")
    return new_samples

                
sample_size = 2000
random_subset = nli_dataset['train'].select(range(sample_size))

new_samples_with_bert = change_withBert(random_subset,model_bert, tokenizer_bert,best_score=True)
# new_samples_with_bert = change_withBert(nli_dataset['train'],best_score=True)

# %%
# print(new_samples_synonyms)
for elem in new_samples_with_bert:
    print()
    print("ORIGINAL: ",elem['original'])
    print("NEW: ",elem['hypothesis'])
    print()
# Out:
# ORIGINAL:  There is a movie called The Hunger Games.
# NEW:  There is a film label The Hunger Games.
#
#
# ORIGINAL:  Selena recorded music.
# NEW:  Selena record auditory communication.
#
#
# ORIGINAL:  Selena recorded music.
# NEW:  Selena record auditory communication.
#
#
# ORIGINAL:  Whoopi Goldberg co-produced an American dance tournament.
# NEW:  Whoopi Goldberg co - produced an American art competition.
#
#
# ORIGINAL:  The Smurfs (film) was released.
# NEW:  The Smurfs (movie) was bare.
#
#
# ORIGINAL:  The Fosters is a television series.
# NEW:  The Fosters is a broadcasting program.
#
#
# ORIGINAL:  Liverpool F.C. was valued at $1.55 billion at one point.
# NEW:  Liverpool F.C. was set at $ 1.55 billion at one quantity.
#
#
# ORIGINAL:  Martin Scorsese worked on commission.
# NEW:  Martin Scorsese work on fee.
#
#
# ORIGINAL:  On the Road (film) premiered at a film festival.
# NEW:  On the Road (movie) premiered at a production festival.
#
#
# ORIGINAL:  On the Road (film) premiered at a film festival.
# NEW:  On the Road (production) premiered at a movie festival.
#
#
# ORIGINAL:  Overwatch is a video game in which players gain cosmetic awards and it assigns players into two teams of six, each player with a style of play known as Offense, Defense, Tank, and Support.
# NEW:  defeat is a broadcasting activity in which players acquire cosmetic awards and it assign contestant into two unit of six, each contestant with a fashion of play known as Offense, Defense, Tank, and Support.
#
#
# ORIGINAL:  International Relations only includes the entertainment industry.
# NEW:  International Relations exclusively includes the entertainment commercial enterprise.
#
#
# ORIGINAL:  Planet of the Apes (1968 film) had a script that underwent rewrites.
# NEW:  celestial body of the Apes (1968 movie) had a dramatic composition that underwent rewrite.
#
#
# ORIGINAL:  Paul Walker acted in movies.
# NEW:  Paul Walker act in production.
#
#
# ORIGINAL:  George W. Bush received one of the lowest approval ratings - just 20% approval - during the 2008 financial crisis.
# NEW:  George W. Bush received one of the lowest liking assessment - simply 20 proportion liking - during the 2008 financial situation.
#
#
# ORIGINAL:  Lily Collins wrote for a U.S magazine that targets teen girls.
# NEW:  Lily Collins wrote for a U.S press that target teen girl.
#
#
# ORIGINAL:  Naturi Naughton was born in the year of 1984.
# NEW:  Naturi Naughton was birth in the period of 1984.
#
#
# ORIGINAL:  Canada possesses a constitution.
# NEW:  Canada have a law.
#
#
# ORIGINAL:  The Amanda Show was the first female-created show on Nickelodeon.
# NEW:  The Amanda Show was the first mortal - created entertainment on Nickelodeon.
#
#
# ORIGINAL:  Edward Norton has co-written for TV shows.
# NEW:  Edward Norton has co - pen for television shows.
#
#
# ORIGINAL:  Ethiopia has bodies of water can be described as rivers.
# NEW:  Ethiopia has natural object of water can be inform as rivers.
#
#
# ORIGINAL:  David Dhawan is a film director.
# NEW:  David Dhawan is a production supervisor.
#
#
# ORIGINAL:  The Challenge was a reality game show.
# NEW:  The Challenge was a actuality game social event.
#
#
# ORIGINAL:  The Challenge was a reality game show.
# NEW:  The Challenge was a reality creature social event.
#
#
# ORIGINAL:  One type of spread is Vegemite.
# NEW:  One kind of meal is Vegemite.
#
#
# ORIGINAL:  The Divergent film series was worked on by Octavia Spencer.
# NEW:  The Divergent production series was work on by Octavia Spencer.
#
#
# ORIGINAL:  Ted Bundy committed assaults in the seventies.
# NEW:  Ted Bundy commit engagement in the large integer.
#
#
# ORIGINAL:  Chinese people only can be associated with Spain through nationality.
# NEW:  Chinese grouping only can be relate with Spain through status.
#
#
# ORIGINAL:  Edgar Award honors the best in television dramas.
# NEW:  Edgar Award recognise the best in TV play.
#
#
# ORIGINAL:  Usain Bolt has competed in a sprint race in track and field in world competitions.
# NEW:  Usain Bolt has competed in a sprint race in track and parcel in Earth social event.
#
#
# ORIGINAL:  Keanu Reeves is a film actor.
# NEW:  Keanu Reeves is a movie performer.
#
#
# ORIGINAL:  Heartland is a canadian TV series.
# NEW:  Heartland is a canadian television program.
#
#
# ORIGINAL:  Robert Richardson has collaborated with director John Sayles.
# NEW:  Robert Richardson has collaborate with supervisor John Sayles.
#
#
# ORIGINAL:  Ruth Negga only acts in Irish cinema.
# NEW:  Ruth Negga exclusively perform in Irish medium.
#
#
# ORIGINAL:  Huntington's disease research is being conducted on non-human animals.
# NEW:  Huntington'sillness research is being manage on non sorry human organism.
#
#
# ORIGINAL:  Billy Bob Thornton directed a movie.
# NEW:  Billy Bob Thornton make a film.
#
#
# ORIGINAL:  Abraham Lincoln had at least one rival.
# NEW:  Abraham Lincoln had at all least one competitor.
#
#
# ORIGINAL:  Interstellar is a narrative in a visual medium.
# NEW:  Interstellar is a substance in a visual instrumentality.
#
#
# ORIGINAL:  The Hermetic Order of the Golden Dawn was uninterested in the study of the occult.
# NEW:  The Hermetic Order of the Golden Dawn was uninterested in the subject of the pattern.
#
#
# ORIGINAL:  There is a geologic period that spans 43 million years called Paleogene.
# NEW:  There is a geologic period that span 43 million period called Paleogene.
#
#
# ORIGINAL:  Cher has sold more than 100 million music records worldwide.
# NEW:  Cher has exchange more than 100 million auditory communication record worldwide.
#
#
# ORIGINAL:  Reese Witherspoon's breakthrough role was in a film.
# NEW:  Reese Witherspoon'sbeginning characterization was in a production.
#
#
# ORIGINAL:  The Belko Experiment is an American horror film released in 2016.
# NEW:  The Belko Experiment is an American fear movie release in 2016.
#
#
# ORIGINAL:  There is a video game called Overwatch (video game).
# NEW:  There is a TV diversion label Overwatch (TV game).
#
#
# ORIGINAL:  Farrah Fawcett acted in the romantic comedy Love is a Funny Thing.
# NEW:  Farrah Fawcett act in the romantic comedy Love is a Funny situation.
#
#
# ORIGINAL:  Alex Rodriguez never hit a home run.
# NEW:  Alex Rodriguez never impel a base sequence.
#
#
# ORIGINAL:  Robert Redford is a film director.
# NEW:  Robert Redford is a production supervisor.
#
#
# ORIGINAL:  Carrie Fisher's middle name is Frances, a family name.
# NEW:  Carrie Fisher'smiddle language unit is Frances, a lineage language unit.
#
#
# ORIGINAL:  Mukesh Ambani's parents were farmers.
# NEW:  Mukesh Ambani'sgenitor were farmer.
#
#
# ORIGINAL:  Neymar was born and raised in Brazil.
# NEW:  Neymar was produce and raise in Brazil.
#
#
# ORIGINAL:  Slash was born in 1965.
# NEW:  cutting was birth in 1965.
#
#
# ORIGINAL:  The Citadelle Laferrière is a large red fortress.
# NEW:  The Citadelle Laferrière is a large crimson defence.
#
#
# ORIGINAL:  Russia is a recognized biologic weapon state.
# NEW:  Russia is a recognize biologic instrument political unit.
#
#
# ORIGINAL:  Doctor Who was written by the Ancient Greeks.
# NEW:  play Who was create verbally by the Ancient Greeks.
#
#
# ORIGINAL:  Will Ferrell is considered to be part of the Frat Pack.
# NEW:  Will Ferrell is regard to be portion of the Frat Pack.
#
#
# ORIGINAL:  The Magna Carta promised access to swift marriages.
# NEW:  The Magna Carta declare access to swift ritual.
#
#
# ORIGINAL:  There is a group of Americans in the motion picture industry called the Directos Guild of America.
# NEW:  There is a abstraction of Americans in the optical illusion product commercial enterprise called the Directos Guild of America.
#
#
# ORIGINAL:  Gorgeous Ladies of Wrestling is a wrestling promotion for women.
# NEW:  Gorgeous Ladies of Wrestling is a wrestling message for female.
#
#
# ORIGINAL:  Gustave Eiffel made significant contributions to aerodynamics.
# NEW:  Gustave Eiffel do significant contribution to mechanics.
#
#
# ORIGINAL:  Idris Elba has been nominated four times for a Golden Globe Award in acting.
# NEW:  Idris Elba has been nominate four times for a Golden Globe Award in re-create.
#
#
# ORIGINAL:  The Uruguay national football team won two FIFA World Cups.
# NEW:  The Uruguay national field game unit won two FIFA World Cups.
#
#
# ORIGINAL:  Kumail Nanjiani has declined to act in any movies.
# NEW:  Kumail Nanjiani has declined to re-create in any production.
#
#
# ORIGINAL:  Tiger Woods has not competed in a golf tournament.
# NEW:  Tiger Woods has not compete in a outdoor game tournament.
#
#
# ORIGINAL:  Star Wars' soundtrack was recorded in England.
# NEW:  Star Wars'audio was record in England.
#
#
# ORIGINAL:  Friendship has been studied in academic disciplines like anthropology.
# NEW:  Friendship has been studied in academic domain like social science.
#
#
# ORIGINAL:  Slipknot (band) attended an American band school.
# NEW:  Slipknot (musical group) be an American band school.
#
#
# ORIGINAL:  Super Metroid is a movie sequel.
# NEW:  Super Metroid is a film resultant.
#
#
# ORIGINAL:  Richard Eyre is a television director.
# NEW:  Richard Eyre is a TV supervisor.
#
#
# ORIGINAL:  Furious 7 began principal photography in the summer of 2013.
# NEW:  furious 7 begin principal photography in the season of 2013.
#
#
# ORIGINAL:  There is a film called Absolute Beginners.
# NEW:  There is a production label Absolute Beginners.
#
#
# ORIGINAL:  None of lung cancer's symptoms is chest pains.
# NEW:  service of respiratory organ malignant tumor'sgrounds is body part pains.
#
#
# ORIGINAL:  Dan Aykroyd has received zero Academy Award nominations.
# NEW:  Dan Aykroyd has get zero Academy Award nomination.
#
#
# ORIGINAL:  Arsenic and Old Lace was released in 1964.
# NEW:  organism and Old Lace was release in 1964.
#
#
# ORIGINAL:  The Catalyst is a rock song.
# NEW:  The Catalyst is a rock music piece.
#
#
# ORIGINAL:  Lionel Messi won three awards by record voting margins.
# NEW:  Lionel Messi win three awards by attainment vote amount.
#
#
# ORIGINAL:  The television series Fargo has an anthology format, setting each season in a different era with a different story and cast.
# NEW:  The TV program Fargo has an collection appearance, represent each season in a different era with a different tale and cast.
#
#
# ORIGINAL:  An annual training camp is hosted by the Carolina Panthers.
# NEW:  An annual activity camp is entertain by the Carolina Panthers.
#
#
# ORIGINAL:  Born This Way is a piece of music.
# NEW:  produce This condition is a music of music.
#
#
# ORIGINAL:  Google has been the second most valuable brand in the world for 4 blue years.
# NEW:  Google has been the second most valuable brand name in the world for 4 blue period.
#
#
# ORIGINAL:  Snooki & Jwoww was renewed by at least one channel.
# NEW:  Snooki & Jwoww was re-create by at all least one TV station.
#
#
# ORIGINAL:  Wikipedia has articles in only english.
# NEW:  Wikipedia has artifact in exclusively english.
#
#
# ORIGINAL:  Kurt Angle won a gold medal in freestyle wrestling at the 1995 World Wrestling Championships.
# NEW:  Kurt Angle get a gold honour in race contact sport at the 1995 World Wrestling Championships.
#
#
# ORIGINAL:  Jim Carrey appeared in a film that is based on a comic book and cats.
# NEW:  Jim Carrey appeared in a production that is based on a comic book and felid.
#
#
# ORIGINAL:  International Relations includes technology and engineering, economics, communication studies, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender studies, cultural studies, culturology, and diplomacy, globalization, diplomatic relations, state sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, global finance, as well as terrorism and organized crime, human security, foreign interventionism, and human rights, as well, as, more recently, comparative religion.
# NEW:  International Relations includes technology and technology, economics, deed domain, history, international law, demography, humanities, geography, social learning, sociology, social science, sociology, science, gender domain, cultural study, culturology, and negotiation, globalization, diplomatic traffic, political unit sovereignty, international safety, ecological sustainability, nuclear proliferation, nationalism, economic development, global finance, as well as terrorism and join offence, human security, foreign terrorism, and human abstraction, as well, as, more recently, comparative belief.
#
#
# ORIGINAL:  Avenged Sevenfold released an album.
# NEW:  avenge Sevenfold issue an medium.
#
#
# ORIGINAL:  Toy Story is a movie of the buddy comedy adventure genres.
# NEW:  Toy Story is a show of the friend drama dangerous undertaking art.
#
#
# ORIGINAL:  Jeff Bridges played a role in an American Revisionist Western film.
# NEW:  Jeff Bridges move a characterization in an American Revisionist Western movie.
#
#
# ORIGINAL:  World War II did not include a military campaign lasting 6 years.
# NEW:  World War II did not include a military operation lasting 6 year.
#
#
# ORIGINAL:  Steel (1997 film) has Judd Nelson in its cast who originally tried out for Shaq's part.
# NEW:  Steel (1997 movie) has Judd Nelson in its gathering who originally try out for Shaq'srole.
#
#
# ORIGINAL:  Mediterranean cuisine dishes are variants of salted cured fish roe.
# NEW:  Mediterranean cuisine dishes are type of preserve cured food spawn.
#
#
# ORIGINAL:  Jackie Robinson died in the seventies.
# NEW:  Jackie Robinson exit in the seventy.
#
#
# ORIGINAL:  Angela Lansbury was born to a family that was upper-middle-class.
# NEW:  Angela Lansbury was produce to a clan that was upper - center - people.
#
#
# ORIGINAL:  XXx: Return of Xander Cage has the writer F. Scott Frazier.
# NEW:  sex chromosome: Return of Xander Cage has the communicator F. Scott Frazier.
#
#
# ORIGINAL:  The Ten Commandments (1956 film) is a 1956 American movie.
# NEW:  The Ten Commandments (1956 movie) is a 1956 American film.
#
#
# ORIGINAL:  Lewis Hamilton is a race car driver.
# NEW:  Lewis Hamilton is a competition motorcar operator.
#
#
# ORIGINAL:  Lewis Hamilton is a race car driver.
# NEW:  Lewis Hamilton is a competition motor vehicle operator.
#
#
# ORIGINAL:  Rhona Mitra writes songs.
# NEW:  Rhona Mitra create mentally composition.
#
#
# ORIGINAL:  Steven Soderbergh directed a biographical film and received acclaim.
# NEW:  Steven Soderbergh make a biographical movie and receive approval.
#
#
# ORIGINAL:  Led Zeppelin II was only released in Japan on October 31, 1969.
# NEW:  lead Zeppelin II was exclusively bare in Japan on October 31, 1969.
#
#
# ORIGINAL:  Brian Helgeland won an award.
# NEW:  Brian Helgeland win an gift.
#
#
# ORIGINAL:  De Profundis was written during an imprisonment.
# NEW:  De Profundis was create verbally during an captivity.
#
#
# ORIGINAL:  The Incredible Hulk is the second episode in a series.
# NEW:  The Incredible Hulk is the second occurrence in a program.
#
#
# ORIGINAL:  Baahubali: The Beginning was released in 2000.
# NEW:  Baahubali: The happening was release in 2000.
#
#
# ORIGINAL:  Baahubali: The Beginning was released in 2000.
# NEW:  Baahubali: The happening was bare in 2000.
#
#
# ORIGINAL:  Faith Evans works solely as an actress.
# NEW:  Faith Evans work solely as an actor.
#
#
# ORIGINAL:  Havoc went to the public on November 29, 2005.
# NEW:  Havoc turn to the people on November 29, 2005.
#
#
# ORIGINAL:  Event management includes decor.
# NEW:  psychological feature social control includes decor.
#
#
# ORIGINAL:  Shawn Mendes is represented by a Canadian record label.
# NEW:  Shawn Mendes is be by a Canadian audio label.
#
#
# ORIGINAL:  A cause of anti-nuclear antibodies are are anti-sp100 antibodies.
# NEW:  A origin of anti - nuclear protein are are anti - sp100 antibodies.
#
#
# ORIGINAL:  Toy Story is a television show.
# NEW:  Toy Story is a TV entertainment.
#
#
# ORIGINAL:  Chris Terrio is a film director from the United States.
# NEW:  Chris Terrio is a production supervisor from the United States.
#
#
# ORIGINAL:  The Caspian Sea is bounded by Uzbekistan to the southeast.
# NEW:  The Caspian Sea is confine by Uzbekistan to the SE.
#
#
# ORIGINAL:  Roald Dahl writes books.
# NEW:  Roald Dahl create mentally publication.
#
#
# ORIGINAL:  Roald Dahl writes books.
# NEW:  Roald Dahl create mentally publication.
#
#
# ORIGINAL:  By area, Nepal is the ninety-third largest country on Earth.
# NEW:  By region, Nepal is the ninety - third largest territorial division on Earth.
#
#
# ORIGINAL:  Conquest of the Planet of the Apes is genre fiction.
# NEW:  Conquest of the Planet of the Apes is art literary work.
#
#
# ORIGINAL:  Bill Clinton served a term in office.
# NEW:  Bill Clinton spend a period in state.
#
#
# ORIGINAL:  Troy Baker was the rhythm guitarist for Tripp Fontaine.
# NEW:  Troy Baker was the musical time musician for Tripp Fontaine.
#
#
# ORIGINAL:  Sarah Palin ran for presidency alongside a senator from Arizona.
# NEW:  Sarah Palin run for presidency alongside a legislator from Arizona.
#
#
# ORIGINAL:  Noam Chomsky is credited in the creation of the universal syntax theory.
# NEW:  Noam Chomsky is credited in the activity of the worldwide syntax explanation.
#
#
# ORIGINAL:  Christopher Lee portrayed Francisco Scaramanga in the film The Man with the Golden Gun.
# NEW:  Christopher Lee represent Francisco Scaramanga in the movie The Man with the Golden Gun.
#
#
# ORIGINAL:  Superior Donuts is a noir film.
# NEW:  Superior Donuts is a silent production.
#
#
# ORIGINAL:  Usain Bolt is incapable of competing in sports.
# NEW:  Usain Bolt is incapable of compete in recreation.
#
#
# ORIGINAL:  Megan Fox ended her acting career in 2001.
# NEW:  Megan Fox ended her activity business in 2001.
#
#
# ORIGINAL:  Nick Nolte turned down the role he was offered in Tropic Thunder.
# NEW:  Nick Nolte change down the character he was offered in Tropic Thunder.
#
#
# ORIGINAL:  Ryuk (Death Note) is from a manga series that later became an anime.
# NEW:  Ryuk (Death Note) is from a naked series that subsequently became an natural resin.
#
#
# ORIGINAL:  Russell Brand lacks the ability to portray other individuals.
# NEW:  Russell Brand lacks the knowledge to represent other person.
#
#
# ORIGINAL:  Anna Paquin was unable to perform the role of Flora McGrath.
# NEW:  Anna Paquin was unable to re-create the characterization of Flora McGrath.
#
#
# ORIGINAL:  Niall Horan wrote a song called Love.
# NEW:  Niall Horan create verbally a piece called Love.
#
#
# ORIGINAL:  Stephen Rider turned down the opportunity to work in the series Lucky 7.
# NEW:  Stephen Rider change down the possibility to work in the series Lucky 7.
#
#
# ORIGINAL:  Roger Penrose was a co-recipient of the 1988 Wolf Prize for physics along with Stephen Hawking.
# NEW:  Roger Penrose was a co dwelling acquirer of the 1988 Wolf Prize for physic along with Stephen Hawking.
#
#
# ORIGINAL:  Margot Kidder appeared on the children's television series R.L. Stine's The Haunting Hour.
# NEW:  Margot Kidder do on the child'sbroadcasting series R.L. Stine'sThe Haunting Hour.
#
#
# ORIGINAL:  Elephants have been featured in places.
# NEW:  proboscidean have been featured in place.
#
#
# ORIGINAL:  Napoleon's campaigns are studied at schools.
# NEW:  Napoleon'soperation are studied at educational institution.
#
#
# ORIGINAL:  Indonesia's wilderness supports a variety of life.
# NEW:  Indonesia'sgeographical region support a mixture of living thing.
#
#
# ORIGINAL:  The life of the writer of Thirteen is the basis for the story.
# NEW:  The existence of the writer of Thirteen is the foundation for the fiction.
#
#
# ORIGINAL:  Taylor Schilling starred in the horror film The Matrix.
# NEW:  Taylor Schilling feature in the fear movie The Matrix.
#
#
# ORIGINAL:  O. J. Simpson died before football was invented.
# NEW:  O.J. Simpson turn before field game was create mentally.
#
#
# ORIGINAL:  Moana is a work in the medium of animation.
# NEW:  Moana is a product in the instrumentality of cinematography.
# ORIGINAL:  There is a science fiction film called Star Trek.
# NEW:  There is a discipline fiction production label Star Trek.
#
#
# ORIGINAL:  Robert Downey Jr. was rejected for the film Sherlock Holmes: A Game of Shadows.
# NEW:  Robert Downey Jr. was reject for the movie Sherlock Holmes: A Game of Shadows.
#
#
# ORIGINAL:  Kolyma has rich reserves of gold, silver, tin, tungsten, mercury, copper, antimony, coal, oil, and peat.
# NEW:  Kolyma has rich reserve of gold, conductor, tin, wolfram, metal, copper, antimony, coal, lipoid, and vegetable matter.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is based upon a fictional person created by a writer from the US.
# NEW:  The Legend of Tarzan (movie) is based upon a fictional organism created by a communicator from the US.
#
#
# ORIGINAL:  The Formula (1980 film) is directed by Michael Bay.
# NEW:  The Formula (1980 movie) is make by Michael Bay.
#
#
# ORIGINAL:  Hugh Jackman plays a role.
# NEW:  Hugh Jackman sound a character.
#
#
# ORIGINAL:  Friends with Benefits features a cute puppy.
# NEW:  Christian with payment features a cute dog.
#
#
# ORIGINAL:  One studio album is Born Naked.
# NEW:  One studio medium is produce Naked.
#
#
# ORIGINAL:  Rebecca Ferguson has only been in films directed solely by Francis Ford Coppola.
# NEW:  Rebecca Ferguson has exclusively been in film directed solely by Francis Ford Coppola.
#
#
# ORIGINAL:  Alice is a reworking of an English film.
# NEW:  Alice is a writing of an English movie.
#
#
# ORIGINAL:  Snowpiercer is a film that is on many critic's top ten cinematic film list.
# NEW:  Snowpiercer is a production that is on many critic'stop ten cinematic production list.
#
#
# ORIGINAL:  Paul Newman co-founded a company with author A. E. Hotchner.
# NEW:  Paul Newman lead flee establish a company with communicator A.E. Hotchner.
#
#
# ORIGINAL:  Gimli (Middle-earth) is from J. R. R. Tolkien's Middle-earth legendarium.
# NEW:  Gimli (Middle - Earth) is from J.R.R. Tolkien'sMiddle - Earth legendarium.
#
#
# ORIGINAL:  Splatoon 2 is the sequel of Splatoon.
# NEW:  someone 2 is the resultant of Splatoon.
#
#
# ORIGINAL:  Eleveneleven was founded by a comedian.
# NEW:  Eleveneleven was open by a performer.
#
#
# ORIGINAL:  Assassin's Creed is released for a Nintendo console.
# NEW:  Assassin'sCreed is release for a Nintendo scientific instrument.
#
#
# ORIGINAL:  There Will Be Blood has gotten numerous awards.
# NEW:  There Will Be humor has hit numerous gift.
#
#
# ORIGINAL:  Outlander is a British-American drama television series.
# NEW:  traveler is a British - American genre broadcasting program.
#
#
# ORIGINAL:  Legion is based on three X-men characters.
# NEW:  Legion is found on three X one-person men character.
#
#
# ORIGINAL:  Divergent was released on Blu-ray.
# NEW:  Divergent was bare on Blu - beam.
#
#
# ORIGINAL:  Each month, Wikipedia has nearly 500 million visitors.
# NEW:  Each period, Wikipedia has almost 500 million traveler.
#
#
# ORIGINAL:  Natalie Wood was born in 1943, three years before her sister Lana Wood.
# NEW:  Natalie Wood was birth in 1943, three period before her female sibling Lana Wood.
#
#
# ORIGINAL:  Dennis Hastert won the Illinois House of Representatives election in 1981.
# NEW:  Dennis Hastert get the Illinois House of Representatives vote in 1981.
#
#
# ORIGINAL:  Memento follows the life of Joe Pantoliano.
# NEW:  Memento analyze the existence of Joe Pantoliano.
#
#
# ORIGINAL:  Jamie Foxx is a record producer and he acts.
# NEW:  Jamie Foxx is a audio creator and he perform.
#
#
# ORIGINAL:  Alfred Hitchcock used innovative forms of film editing.
# NEW:  Alfred Hitchcock use innovative form of production writing.
#
#
# ORIGINAL:  Veronika Decides to Die is written by James Cameron.
# NEW:  Veronika Decides to suffer is create verbally by James Cameron.
#
#
# ORIGINAL:  A loss of supply can involve a constitutional convention.
# NEW:  A transferred possession of indefinite quantity can involve a constitutional convention.
#
#
# ORIGINAL:  Alice is a reworking of a Federico Fellini film.
# NEW:  Alice is a rewrite of a Federico Fellini production.
#
#
# ORIGINAL:  AC/DC has dubbed their music as rock and roll.
# NEW:  AC / DC has name their auditory communication as popular music and roll.
#
#
# ORIGINAL:  Richard III of England was a brand of clothing.
# NEW:  Richard III of England was a brand name of wear.
#
#
# ORIGINAL:  Phantoms is a science fiction horror film.
# NEW:  spirit is a discipline fiction fear production.
#
#
# ORIGINAL:  Leonardo da Vinci invented the revolving bridge.
# NEW:  Leonardo da Vinci create mentally the revolving structure.
#
#
# ORIGINAL:  The Matrix Revolutions is a film released in the early 2000s.
# NEW:  The Matrix Revolutions is a production bare in the early 2000s.
#
#
# ORIGINAL:  Jerry Maguire was inspired by a sports competition named Leigh Steinberg.
# NEW:  Jerry Maguire was inspired by a recreation competition label Leigh Steinberg.
#
#
# ORIGINAL:  Following is a film.
# NEW:  simulate is a production.
#
#
# ORIGINAL:  The Hundred-Foot Journey (film) stars a car.
# NEW:  The Hundred - Foot Journey (production) stars a motor vehicle.
#
#
# ORIGINAL:  Taiwan is the 22nd-largest economy in the world.
# NEW:  Taiwan is the 2nd - largest economy in the Earth.
#
#
# ORIGINAL:  Andorra is a television show.
# NEW:  Andorra is a TV entertainment.
#
#
# ORIGINAL:  Timothy Olyphant made his acting debut in a house.
# NEW:  Timothy Olyphant do his re-create start in a house.
#
#
# ORIGINAL:  Music Bank (TV series) has so far been hosted exclusively by Brits.
# NEW:  Music Bank (broadcasting program) has so far been hosted solely by Briton.
#
#
# ORIGINAL:  Tardigrades are non-segmented animals.
# NEW:  arthropod are non sorry segmented organism.
#
#
# ORIGINAL:  The Dark Knight used IMAX 70 mm film cameras to film some traps.
# NEW:  The Dark Knight used IMAX 70 metric linear unit production cameras to record some traps.
#
#
# ORIGINAL:  BoA was a judge on K-pop Star 2.
# NEW:  BoA was a judge on Ketalar - sound Star 2.
#
#
# ORIGINAL:  Captain America: The Winter Soldier was exclusively based on a story by Ernest Hemingway.
# NEW:  Captain America: The Winter Soldier was solely found on a fiction by Ernest Hemingway.
#
#
# ORIGINAL:  Mukesh Ambani is on the 2016 Forbes list of the world's most powerful people, at number 38.
# NEW:  Mukesh Ambani is on the 2016 Forbes database of the Earth'smost powerful people, at definite quantity 38.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando move characterization in a production in 1953.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando move role in a movie in 1953.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando took role in a production in 1953.
#
#
# ORIGINAL:  Despicable Me is illustrated.
# NEW:  despicable Me is picture.
#
#
# ORIGINAL:  Rashida Jones co-wrote a screenplay.
# NEW:  Rashida Jones contestant mold pen a script.
#
#
# ORIGINAL:  Anne Hathaway won a Critics' Choice Movie Award.
# NEW:  Anne Hathaway win a professional'Choice Movie Award.
#
#
# ORIGINAL:  All original members of Stone Temple Pilots were born in September.
# NEW:  All original associate of Stone Temple Pilots were birth in September.
#
#
# ORIGINAL:  Audrey Horne was introduced in anything except a series that premiered on Sunday, April 8, 1990.
# NEW:  Audrey Horne was introduce in anything except a program that premiered on Sunday, April 8, 1990.
#
#
# ORIGINAL:  Franklin D. Roosevelt started the development of a nuclear weapon.
# NEW:  Franklin D. Roosevelt started the improvement of a nuclear instrument.
#
#
# ORIGINAL:  Los Angeles is a clothing brand in Southern California.
# NEW:  Los Angeles is a wear name in Southern California.
#
#
# ORIGINAL:  KFC is the second biggest restaurant chain in the world.
# NEW:  KFC is the second biggest building concern in the Earth.
#
#
# ORIGINAL:  Walt Disney founded a company headquartered in Burbank.
# NEW:  Walt Disney open a institution headquartered in Burbank.
#
#
# ORIGINAL:  The Beatles have only two surviving books left.
# NEW:  The Beatles have just two survive books left.
#
#
# ORIGINAL:  Motorola makes recording equipment.
# NEW:  Motorola makes creating from raw materials instrumentation.
#
#
# ORIGINAL:  Racism was addressed in Beverly Hills, 90210.
# NEW:  racism was label in Beverly Hills, 90210.
#
#
# ORIGINAL:  Transformers: Dark of the Moon is a movie.
# NEW:  electrical device: Dark of the Moon is a film.
#
#
# ORIGINAL:  The Host stars an actor born on June 18.
# NEW:  The Host stars an player produce on June 18.
#
#
# ORIGINAL:  Sicario (2015 film) was nominated for an Academy Award for Best Sound Editing.
# NEW:  Sicario (2015 movie) was nominate for an Academy Award for Best Sound Editing.
#
#
# ORIGINAL:  England was inhabited by humans.
# NEW:  England was inhabit by human.
#
#
# ORIGINAL:  Childhood was the time of Ben Affleck's life when he began his career.
# NEW:  Childhood was the period of Ben Affleck'slife when he began his business.
#
#
# ORIGINAL:  The blue-ringed octopus is an animal.
# NEW:  The blue - attach octopod is an organism.
#
#
# ORIGINAL:  Outlander (TV series) adapts the Lord of the Rings novels.
# NEW:  Outlander (broadcasting program) change the Lord of the Rings novels.
#
#
# ORIGINAL:  Courtney Love was a comedic actress.
# NEW:  Courtney Love was a comical actor.
#
#
# ORIGINAL:  Labor Day involves honoring the collective organization of working people developed to represent and campaign for better working conditions and treatment from their employers and, by the implementation of labour and employment laws, their governments also known as the American labor movement.
# NEW:  Labor Day involves recognise the collective social group of working people become to represent and promote for better working conditions and treatment from their employers and, by the enforcement of labor and state laws, their authorities also known as the American reform movement movement.
#
#
# ORIGINAL:  San Francisco is located in the state of California.
# NEW:  San Francisco is find in the administrative district of California.
#
#
# ORIGINAL:  The characters in Grey's Anatomy try to maintain personal lives only.
# NEW:  The characterization in Grey'sAnatomy move to keep personal lives only.
#
#
# ORIGINAL:  Ronald Reagan came after a person.
# NEW:  Ronald Reagan change after a someone.
#
#
# ORIGINAL:  Marilyn Monroe did not play comic characters.
# NEW:  Marilyn Monroe did not re-create comic character.
#
#
# ORIGINAL:  Breaking Bad received multiple awards.
# NEW:  Breaking Bad get multiple gift.
#
#
# ORIGINAL:  Meek Mill sings the track "Young & Gettin' It."
# NEW:  Meek Mill sing the selection " Young & Gettin'It. "
#
#
# ORIGINAL:  Patton Oswalt is a stand-up comedian focusing on his own personal quirks.
# NEW:  Patton Oswalt is a stand - up performer focus on his own personal quirk.
#
#
# ORIGINAL:  Alien: Covenant is a critically panned 2017 American science fiction horror film that was co-written by John Logan and Dante Harper.
# NEW:  Alien: Covenant is a critically pan 2017 American discipline literary work horror production that was co - create verbally by John Logan and Dante Harper.
#
#
# ORIGINAL:  Fantastic Beasts and Where to Find Them was released in 70MM and IMAX 4K Laser.
# NEW:  Fantastic organism and Where to Find Them was bare in 70MM and IMAX 4 K Laser.
#
#
# ORIGINAL:  Solange Knowles refused to ever sing or write songs.
# NEW:  Solange Knowles respond to ever speak or create verbally composition.
#
#
# ORIGINAL:  Shaggy is a nickname shared by 4 Scooby-Doo characters.
# NEW:  Shaggy is a nickname overlap by 4 Scooby - Doo character.
#
#
# ORIGINAL:  United Kingdom has the ninth-largest economy by economic theory that states that the exchange rate between two currencies equal the ratio of the currencies' respective purchasing power called purchasing power parity.
# NEW:  United Kingdom has the ninth - largest economy by economic theory that state that the commercialism charge between two currencies equal the quantitative relation of the currencies'respective purchasing mathematical notation called purchasing quality mirror symmetry.
#
#
# ORIGINAL:  Cricket is followed on television.
# NEW:  field game is followed on tv.
#
#
# ORIGINAL:  Travis Barker collaborated with an alternative rock band.
# NEW:  Travis Barker collaborate with an alternative rock music musical group.
#
#
# ORIGINAL:  Juliette Binoche acted in a horror film.
# NEW:  Juliette Binoche perform in a horror movie.
#
#
# ORIGINAL:  Matthew Modine played the title character of the TV series Birdy.
# NEW:  Matthew Modine play the name character of the television program Birdy.
#
#
# ORIGINAL:  Hungary is bordered by Slovakia to the north, Romania to the east, Serbia to the south, Croatia to the southwest, Slovenia to the west, Austria to the northwest, and Ukraine to the northeast.
# NEW:  Hungary is touch by Slovakia to the cardinal compass point, Romania to the cardinal compass point, Serbia to the southward, Croatia to the point, Slovenia to the westward, Austria to the NW, and Ukraine to the point.
#
#
# ORIGINAL:  Twilight's first novel has a released companion novel called Midnight Sun.
# NEW:  Twilight'sfirst fiction has a bare friend fiction label Midnight Sun.
#
#
# ORIGINAL:  Role Models is a motion picture.
# NEW:  Role Models is a movement product.
#
#
# ORIGINAL:  Elvis Presley had a string of highly profitable assassination plots.
# NEW:  Elvis Presley had a series of highly profitable murder scheme.
#
#
# ORIGINAL:  Role-playing games should be conducted in silence.
# NEW:  activity -playing recreation should be conduct in silence.
#
#
# ORIGINAL:  Amsterdam Airport Schiphol serves as a hub for Vueling.
# NEW:  Amsterdam Airport Schiphol serve as a centre for Vueling.
#
#
# ORIGINAL:  Tom Morello worked creatively with Rage Against the Machine.
# NEW:  Tom Morello work creatively with Rage Against the person.
#
#
# ORIGINAL:  William Shatner is an actor in multiple series.
# NEW:  William Shatner is an performer in multiple program.
#
#
# ORIGINAL:  Ted Kaczynski grew up in a city.
# NEW:  Ted Kaczynski become up in a municipality.
#
#
# ORIGINAL:  Susan Sarandon received nominations for plays.
# NEW:  Susan Sarandon received status for dramatic work.
#
#
# ORIGINAL:  Quentin Tarantino makes movies.
# NEW:  Quentin Tarantino do production.
#
#
# ORIGINAL:  Quentin Tarantino makes movies.
# NEW:  Quentin Tarantino do movie.
#
#
# ORIGINAL:  Quentin Tarantino makes movies.
# NEW:  Quentin Tarantino do production.
#
#
# ORIGINAL:  Spider-Man is consumed with rejection, inadequacy, and loneliness.
# NEW:  Spider - Man is ruin with situation, weakness, and isolation.
#
#
# ORIGINAL:  Dustin Hoffman has starred in a movie.
# NEW:  Dustin Hoffman has feature in a show.
#
#
# ORIGINAL:  Katherine Heigl acted in a series co-written by a team.
# NEW:  Katherine Heigl perform in a program co - pen by a team.
#
#
# ORIGINAL:  Bertrand Russell's work has had a considerable influence on the core of artificial intelligence.
# NEW:  Bertrand Russell'sproduct has had a considerable influence on the marrow of artificial power.
#
#
# ORIGINAL:  One movie actress is Anne Hathaway.
# NEW:  One film actor is Anne Hathaway.
#
#
# ORIGINAL:  One movie actress is Anne Hathaway.
# NEW:  One film actor is Anne Hathaway.
#
#
# ORIGINAL:  One movie actress is Anne Hathaway.
# NEW:  One show actor is Anne Hathaway.
#
#
# ORIGINAL:  Margaret of Valois spent time imprisoned.
# NEW:  Margaret of Valois spent period confine.
#
#
# ORIGINAL:  Some people in Tanzania speak Swahili.
# NEW:  Some grouping in Tanzania communicate Swahili.
#
#
# ORIGINAL:  The Divergent Series: Insurgent is based on the third book in the Divergent trilogy.
# NEW:  The Divergent Series: insurgent is based on the third section in the Divergent trilogy.
#
#
# ORIGINAL:  Oh Yeon-seo is a former member of a band and she is musical.
# NEW:  Oh someone - someone is a former member of a band and she is musical.
#
#
# ORIGINAL:  A loss of supply affects prime ministers to the point of resignation.
# NEW:  A loss of supply modify prime public service to the state of speech act.
#
#
# ORIGINAL:  Investment funds are also referred to as managed funds or simply funds.
# NEW:  Investment money are likewise classify to as manage money or simply funds.
#
#
# ORIGINAL:  Kate Nash released three albums.
# NEW:  Kate Nash release three medium.
#
#
# ORIGINAL:  Tardigrades have been found only in deserts.
# NEW:  arthropod have been find only in parcel.
#
#
# ORIGINAL:  Angela Lansbury contributed to live-action films.
# NEW:  Angela Lansbury give to live - action film.
#
#
# ORIGINAL:  Diane Ruggiero lived in a state in the Northeastern and mid-Atlantic regions of the United States.
# NEW:  Diane Ruggiero dwell in a administrative district in the Northeastern and mid - Atlantic regions of the United States.
#
#
# ORIGINAL:  Oh Yeon-seo is an actress.
# NEW:  Oh organism - someone is an actor.
#
#
# ORIGINAL:  Cary Grant costarred in the film She Done Him Wrong.
# NEW:  Cary Grant teach in the movie She Done Him Wrong.
#
#
# ORIGINAL:  Kolyma has reserves of limestone.
# NEW:  Kolyma has accumulation of stone.
#
#
# ORIGINAL:  Marion Cotillard played a French cabaret singer in La Vie en Rose (2007).
# NEW:  Marion Cotillard re-create a French spot musician in La Vie en Rose (2007).
#
#
# ORIGINAL:  Dracula was only a film.
# NEW:  Dracula was just a movie.
#
#
# ORIGINAL:  Bowie's music draws from industrial and jungle styles.
# NEW:  Bowie'smusic select from industrial and forest styles.
#
#
# ORIGINAL:  Philip V of Spain was the king of a sovereign state located in Europe.
# NEW:  Philip V of Spain was the monarch of a sovereign state find in Europe.
#
#
# ORIGINAL:  Alan Ladd was a method actor.
# NEW:  Alan Ladd was a playing performer.
#
#
# ORIGINAL:  Donald Trump died before the nominees of the 2016 election were chosen.
# NEW:  Donald Trump exit before the nominee of the 2016 election were select.
#
#
# ORIGINAL:  Three Men and a Baby stars at least one American actor.
# NEW:  Three Men and a Baby player at least one American performer.
#
#
# ORIGINAL:  Beverly Hills, 90210 was a non-political or social commentary show.
# NEW:  Beverly Hills, 90210 was a non - political or social statement entertainment.
#
#
# ORIGINAL:  Pixar started as part of an American film and television award show.
# NEW:  Pixar commence as relation of an American production and TV gift show.
#
#
# ORIGINAL:  Taylor Swift has ranked first in a hotdog eating contest.
# NEW:  Taylor Swift has be first in a hotdog eat social event.
#
#
# ORIGINAL:  Splatoon 2 is a team-based third-person RPG.
# NEW:  organism 2 is a unit - based third - someone RPG.
#
#
# ORIGINAL:  Ballet Shoes is an award-winning children's novel.
# NEW:  Ballet Shoes is an award - win juvenile'sfiction.
#
#
# ORIGINAL:  April was the month when the Fate of the Furious was theatrically released in the United States.
# NEW:  April was the period when the Fate of the Furious was theatrically release in the United States.
#
#
# ORIGINAL:  Lana Del Rey released the album Born to Die on April 18, 2012.
# NEW:  Lana Del Rey issue the album birth to turn on April 18, 2012.
#
#
# ORIGINAL:  Try is on an artist's album.
# NEW:  move is on an creator'smedium.
#
#
# ORIGINAL:  Just Dance finally reached the summit of the chart in January 2009.
# NEW:  Just Dance finally reach the peak of the visual communication in January 2009.
#
#
# ORIGINAL:  Serena Williams is a tennis player.
# NEW:  Serena Williams is a court game contestant.
#
#
# ORIGINAL:  Leslie Uggams was in a superhero movie.
# NEW:  Leslie Uggams was in a pic film.
#
#
# ORIGINAL:  Doug Jones did not star in a science fiction horror film.
# NEW:  Doug Jones did not feature in a discipline literary work fear production.
#
#
# ORIGINAL:  Little Mix is a girl group.
# NEW:  Little Mix is a missy abstraction.
#
#
# ORIGINAL:  Little Mix is a girl group.
# NEW:  Little Mix is a woman abstraction.
#
#
# ORIGINAL:  Gone Girl was not written by Gillian Flynn.
# NEW:  go Girl was not pen by Gillian Flynn.
#
#
# ORIGINAL:  Arrested Development filmed scenes in California.
# NEW:  Arrested Development record dramatic work in California.
#
#
# ORIGINAL:  Jennifer Jason Leigh had a role in a film.
# NEW:  Jennifer Jason Leigh had a characterization in a production.
#
#
# ORIGINAL:  Jennifer Jason Leigh had a role in a film.
# NEW:  Jennifer Jason Leigh had a characterization in a production.
#
#
# ORIGINAL:  Writing is Nat Faxon's profession.
# NEW:  verbal creation is Nat Faxon'sbusiness.
#
#
# ORIGINAL:  George Gershwin composed Summertime (George Gershwin song) for an opera.
# NEW:  George Gershwin make Summertime (George Gershwin song) for an classical.
#
#
# ORIGINAL:  There is an actor named Philip Seymour Hoffman.
# NEW:  There is an player label Philip Seymour Hoffman.
#
#
# ORIGINAL:  Dirty Diana is a song by Michael Joseph Jackson.
# NEW:  dirty Diana is a piece by Michael Joseph Jackson.
#
#
# ORIGINAL:  In Her Shoes was based on Jennifer Weiner's novel.
# NEW:  In Her Shoes was found on Jennifer Weiner'sfiction.
#
#
# ORIGINAL:  Radiohead pioneered alternative release platforms.
# NEW:  Radiohead make alternative product platforms.
#
#
# ORIGINAL:  Inhumans have a television series based on them.
# NEW:  Inhumans have a broadcasting program based on them.
#
#
# ORIGINAL:  Tom Brady played football.
# NEW:  Tom Brady sound field game.
#
#
# ORIGINAL:  James Garner did not act in multiple films.
# NEW:  James Garner did not perform in multiple production.
#
#
# ORIGINAL:  The Wolf of Wall Street starred an actor.
# NEW:  The Wolf of Wall Street feature an performer.
#
#
# ORIGINAL:  Drop Dead Gorgeous features various contestants dying in suspicious ways.
# NEW:  change Dead Gorgeous features various contestants exit in wary way.
#
#
# ORIGINAL:  Dubai is located on the southeast coast of the Persian Gulf.
# NEW:  Dubai is find on the southeast shore of the Persian Gulf.
#
#
# ORIGINAL:  Taylor Swift released at least one album.
# NEW:  Taylor Swift bare at all least one medium.
#
#
# ORIGINAL:  Taylor Swift released at least one album.
# NEW:  Taylor Swift bare at all least one medium.
#
#
# ORIGINAL:  Taylor Swift released at least one album.
# NEW:  Taylor Swift bare at all least one medium.
#
#
# ORIGINAL:  Taylor Swift released at least one album.
# NEW:  Taylor Swift release at all least one medium.
#
#
# ORIGINAL:  Taylor Swift released at least one album.
# NEW:  Taylor Swift release at all least one medium.
#
#
# ORIGINAL:  Adrienne Bailon is an American singer-songwriter.
# NEW:  Adrienne Bailon is an American vocalist - composer.
#
#
# ORIGINAL:  Cara Delevingne played a merchant in Paper Towns (2015).
# NEW:  Cara Delevingne play a merchant in Paper municipality (2015).
#
#
# ORIGINAL:  Black Sabbath released a debut album.
# NEW:  Black Sabbath release a entry album.
#
#
# ORIGINAL:  Motorola does not have business and government customers.
# NEW:  Motorola does not have enterprise and government consumer.
#
#
# ORIGINAL:  The second and third installments of two series featured the performance of Karl Urban.
# NEW:  The second and third text of two show featured the performance of Karl Urban.
#
#
# ORIGINAL:  Leukemia is a group of cancers beginning in bone marrow and producing abnormal white blood cells.
# NEW:  leukemia is a group of cancers beginning in connective tissue marrow and produce abnormal white humor cells.
#
#
# ORIGINAL:  Jon Pertwee was in a series and he acted.
# NEW:  Jon Pertwee was in a program and he perform.
#
#
# ORIGINAL:  Welcome Back (film) is the first film in a series.
# NEW:  Welcome Back (movie) is the first production in a series.
#
#
# ORIGINAL:  Ronald Reagan left office in March 8th, 1989.
# NEW:  Ronald Reagan change state in March 8th, 1989.
#
#
# ORIGINAL:  Dhoom 3 was barely directed by Vijay Krishna Acharya.
# NEW:  organism 3 was hardly directed by Vijay Krishna Acharya.
#
#
# ORIGINAL:  Saif Ali Khan had a role in two films which include Dil Chahta Hai and Kal Ho Naa Ho.
# NEW:  Saif Ali Khan had a character in two film which include Dil Chahta Hai and Kal Ho Naa Ho.
#
#
# ORIGINAL:  Vito Corleone is a fictional mountain.
# NEW:  Vito Corleone is a fictitious elevation.
#
#
# ORIGINAL:  Future and a Canadian singer have collaborated.
# NEW:  Future and a Canadian vocalist have work.
#
#
# ORIGINAL:  Future and a Canadian singer have collaborated.
# NEW:  tense and a Canadian vocalist have work.
#
#
# ORIGINAL:  Nick Jonas is a recording artist.
# NEW:  Nick Jonas is a creating from raw materials creator.
#
#
# ORIGINAL:  Nick Jonas is a recording artist.
# NEW:  Nick Jonas is a creating from raw materials creator.
#
#
# ORIGINAL:  Nick Jonas is a recording artist.
# NEW:  Nick Jonas is a creating from raw materials creator.
#
#
# ORIGINAL:  Pacific Rim started production July 12, 2013.
# NEW:  Pacific Rim commence presentation July 12, 2013.
#
#
# ORIGINAL:  Social justice is invoked today in philosophical debates about differences among human beings around the world.
# NEW:  Social righteousness is create today in philosophical debate about quality among human living thing around the world.
#
#
# ORIGINAL:  Patrick Dempsey was in the movie Enchanted in 2007.
# NEW:  Patrick Dempsey was in the film delight in 2007.
#
#
# ORIGINAL:  Michelle Williams has stayed away from an acting entirely.
# NEW:  Michelle Williams has stay away from an activity entirely.
#
#
# ORIGINAL:  Michelle Williams has stayed away from an acting entirely.
# NEW:  Michelle Williams has stay away from an performing entirely.
#
#
# ORIGINAL:  Robin was murdered by the Joker in a 1989 book.
# NEW:  Robin was kill by the Joker in a 1989 section.
#
#
# ORIGINAL:  David Schwimmer played a lawyer in American Crime Story.
# NEW:  David Schwimmer re-create a professional in American Crime Story.
#
#
# ORIGINAL:  Shonen Jump uses abbreviation.
# ...
# NEW:  Novak Djokovic get a honour at the Summer Olympics in 2008.
#
#
# ORIGINAL:  Zootopia was an animated film made by Disney.
# NEW:  Zootopia was an alter movie make by Disney.
#
#
# ORIGINAL:  Zootopia was an animated film made by Disney.
# NEW:  Zootopia was an animate production make by Disney.
#
#
# ORIGINAL:  On the Road (film) features an American actor born in 1984.
# NEW:  On the Road (production) features an American performer birth in 1984.
#
#
# ORIGINAL:  Dileep (actor) began his film career in 1991.
# NEW:  Dileep (player) began his production business in 1991.
#
#
# ORIGINAL:  Claire Danes is married to a film actor.
# NEW:  Claire Danes is married to a production performer.
#
#
# ORIGINAL:  Octopuses defend themselves against predators.
# NEW:  octopod defend themselves against animal.
#
#
# ORIGINAL:  Dennis Quaid was in a musical drama film.
# NEW:  Dennis Quaid was in a musical genre production.
#
#
# ORIGINAL:  Natalie Portman directed a 2015 drama film.
# NEW:  Natalie Portman make a 2015 drama production.
#
#
# ORIGINAL:  Paul Newman and A.E. Hotchner founded a food company.
# NEW:  Paul Newman and A.E. Hotchner open a substance company.
#
#
# ORIGINAL:  Hotel Hell is airs only on NBC.
# NEW:  Hotel Hell is medium exclusively on NBC.
#
#
# ORIGINAL:  Game of Thrones had multiple actors being fired.
# NEW:  Game of Thrones had multiple performer being remove.
#
#
# ORIGINAL:  Peter Davison is a professional television actor.
# NEW:  Peter Davison is a professional broadcasting performer.
#
#
# ORIGINAL:  Matt Damon is unable to break into the film industry.
# NEW:  Matt Damon is unable to separate into the production industry.
#
#
# ORIGINAL:  J. Howard Marshall is the second of his dance class.
# NEW:  J. Howard Marshall is the second of his art gathering.
#
#
# ORIGINAL:  Intimacy (film) features a performance by Kerry Fox.
# NEW:  Intimacy (production) features a presentation by Kerry Fox.
#
#
# ORIGINAL:  Alia Bhatt is a film actress.
# NEW:  Alia Bhatt is a production actor.
#
#
# ORIGINAL:  Twitter is a consumer of breaking news.
# NEW:  Twitter is a user of break interest.
#
#
# ORIGINAL:  Rihanna is one of the best-selling artists ever.
# NEW:  Rihanna is one of the best - be creator ever.
#
#
# ORIGINAL:  Kenny Rogers released the album, Kenny.
# NEW:  Kenny Rogers issue the medium, Kenny.
#
#
# ORIGINAL:  Alice is a reworking of a horror film.
# NEW:  Alice is a writing of a horror movie.
#
#
# ORIGINAL:  Judi Dench had a role in a movie.
# NEW:  Judi Dench had a character in a film.
#
#
# ORIGINAL:  Judi Dench had a role in a movie.
# NEW:  Judi Dench had a characterization in a film.
#
#
# ORIGINAL:  Ready Player One received an award from a nonprofit organization.
# NEW:  Ready Player One get an gift from a nonprofit social group.
#
#
# ORIGINAL:  Fences stars an actor.
# NEW:  Fences feature an player.
#
#
# ORIGINAL:  License to Wed was released in the 2000's.
# NEW:  liberty to We d was release in the 2000's.
#
#
# ORIGINAL:  Soundgarden was a band that epitomized grunge, or the Seattle Sound.
# NEW:  Soundgarden was a band that typify dirtiness, or the Seattle Sound.
#
#
# ORIGINAL:  David Beckham played football.
# NEW:  David Beckham move field game.
#
#
# ORIGINAL:  Alicia Keys has appeared in two films that were adapted from novels in 2002.
# NEW:  Alicia Keys has do in two production that were adapted from fiction in 2002.
#
#
# ORIGINAL:  George Washington played a part in the American Revolution.
# NEW:  George Washington move a role in the American Revolution.
#
#
# ORIGINAL:  One Direction performs music as a group.
# NEW:  One Direction perform music as a abstraction.
#
#
# ORIGINAL:  Passengers was released in 2016.
# NEW:  traveller was release in 2016.
#
#
# ORIGINAL:  There is a country called the United Kingdom.
# NEW:  There is a territorial division label the United Kingdom.
#
#
# ORIGINAL:  Jurassic World broke the record for opening weekend earnings.
# NEW:  Jurassic World broke the attainment for opening period income.
#
#
# ORIGINAL:  James Marsden gained prominence with his portrayal of Cyclops.
# NEW:  James Marsden get standing with his characterization of Cyclops.
#
#
# ORIGINAL:  Home Alone is a Christmas movie.
# NEW:  residence alone is a Christmas show.
#
#
# ORIGINAL:  Davis Guggenheim is a television show-runner.
# NEW:  Davis Guggenheim is a TV show - athlete.
#
#
# ORIGINAL:  Bane has only ever been a real person.
# NEW:  Bane has exclusively ever been a real organism.
#
#
# ORIGINAL:  The Conjuring is a horror film.
# NEW:  The conjuring is a fear production.
#
#
# ORIGINAL:  Deadpool was initially depicted as a cat.
# NEW:  Deadpool was initially interpret as a felid.
#
#
# ORIGINAL:  Linda McCartney died from breast cancer in 1998.
# NEW:  Linda McCartney exit from bosom cancer in 1998.
#
#
# ORIGINAL:  Sister Act has an all-male cast.
# NEW:  Sister Act has an all - mortal gathering.
#
#
# ORIGINAL:  Sunrise created anime.
# NEW:  hour create anime.
#
#
# ORIGINAL:  Dead Man Down stars a Swedish actress.
# NEW:  Dead Man down feature a Swedish actor.
#
#
# ORIGINAL:  Jennifer Garner had a leading role in the 2004 film 13 Going On 30.
# NEW:  Jennifer Garner had a prima characterization in the 2004 movie 13 Going On 30.
#
#
# ORIGINAL:  Minos fathered a dog.
# NEW:  Minos make a canine.
#
#
# ORIGINAL:  Basketball is a sport that involves working together.
# NEW:  basketball is a recreation that involves working together.
#
#
# ORIGINAL:  Deadpool (film) is a superhero television show only.
# NEW:  Deadpool (movie) is a pic TV social event just.
#
#
# ORIGINAL:  There is a series called Grey's Anatomy.
# NEW:  There is a program called Grey'sanatomy.
#
#
# ORIGINAL:  There is a series called Grey's Anatomy.
# NEW:  There is a program label Grey'sbody.
#
#
# ORIGINAL:  There is a series called Grey's Anatomy.
# NEW:  There is a series label Grey'sbody.
#
#
# ORIGINAL:  There is a series called Grey's Anatomy.
# NEW:  There is a program label Grey'sanatomy.
#
#
# ORIGINAL:  The Wolf of Wall Street (2013 film) did not win any money.
# NEW:  The Wolf of Wall Street (2013 movie) did not win any monetary system.
#
#
# ORIGINAL:  Douglas Aircraft Company and McDonnell Aircraft are part of the history of McDonnell Douglas.
# NEW:  Douglas Aircraft Company and McDonnell Aircraft are portion of the past of McDonnell Douglas.
#
#
# ORIGINAL:  Event management includes site selection and budgeting.
# NEW:  Event social control includes parcel option and finance.
#
#
# ORIGINAL:  Hansel and Gretel is also known as a fairy tale.
# NEW:  Hansel and Gretel is likewise known as a supernatural being story.
#
#
# ORIGINAL:  Margaret Osborne duPont was born in New York on March 4, 1918.
# NEW:  Margaret Osborne organism was birth in New York on March 4, 1918.
#
#
# ORIGINAL:  Pregnancy symptoms include tender breasts.
# NEW:  physical condition grounds include tender breast.
#
#
# ORIGINAL:  Ad-Rock is married to a person.
# NEW:  packaging organism is married to a someone.
#
#
# ORIGINAL:  Boyz II Men is incapable of finding fame in the 1990s.
# NEW:  Boyz II Men is incapable of bump honor in the 1990s.
#
#
# ORIGINAL:  Punisher was born Francis Castiglione and is fictional.
# NEW:  social control was birth Francis Castiglione and is fictional.
#
#
# ORIGINAL:  Above the Law is strictly a comedy film.
# NEW:  Above the Law is strictly a drama production.
#
#
# ORIGINAL:  The Vampire Diaries is a television series.
# NEW:  The Vampire Diaries is a TV program.
#
#
# ORIGINAL:  The Vampire Diaries is a television series.
# NEW:  The Vampire Diaries is a TV program.
#
#
# ORIGINAL:  New Girl did not gain nominations for multiple awards.
# NEW:  New Girl did not acquire status for multiple awards.
#
#
# ORIGINAL:  Caroline Blakiston died before any of the Star Wars films began production.
# NEW:  Caroline Blakiston turn before any of the Star Wars production began production.
#
#
# ORIGINAL:  Sleeping Beauty was the first Competition entry to be screened in Sao Paolo.
# NEW:  sleep Beauty was the first Competition written account to be show in Sao Paolo.
#
#
# ORIGINAL:  Boeing 737s avoid markets previously filled by 707 airliners.
# NEW:  Boeing 737s avoid class previously filled by 707 aeroplane.
#
#
# ORIGINAL:  Twitter had millions of tweets during an election.
# NEW:  Twitter had large indefinite quantity of tweets during an vote.
#
#
# ORIGINAL:  Audrey Hepburn gave to the organizations since 1954.
# NEW:  Audrey Hepburn transfer to the social group since 1954.
#
#
# ORIGINAL:  Diseases did not also spread along the Silk Road.
# NEW:  illness did not likewise spread along the Silk Road.
#
#
# ORIGINAL:  Emily Browning made her first appearance in a movie in an Australian television movie.
# NEW:  Emily Browning get her first arrival in a show in an Australian TV show.
#
#
# ORIGINAL:  The Entire History of You was the only section not penned by Charlie Brooker.
# NEW:  The entire history of You was the sole section not create verbally by Charlie Brooker.
#
#
# ORIGINAL:  The G20 economies account for two-thirds of the world population.
# NEW:  The G20 economies account for two - simple fraction of the world integer.
#
#
# ORIGINAL:  Blackhat stars the czar.
# NEW:  Blackhat feature the despot.
#
#
# ORIGINAL:  Sterling Archer is the main character of an animated series called Archer.
# NEW:  Sterling Archer is the main imaginary creature of an alter program called Archer.
#
#
# ORIGINAL:  Stockard Channing worked with an American actor.
# NEW:  Stockard Channing work with an American player.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is a film that had zero reviews from critics only.
# NEW:  The Legend of Tarzan (movie) is a production that had zero review from critics only.
#
#
# ORIGINAL:  Baahubali: The Beginning is a movie.
# NEW:  Baahubali: The happening is a show.
#
#
# ORIGINAL:  Baahubali: The Beginning is a movie.
# NEW:  Baahubali: The happening is a show.
#
#
# ORIGINAL:  Baahubali: The Beginning is a movie.
# NEW:  Baahubali: The happening is a film.
#
#
# ORIGINAL:  Tiger Woods won professional major golf championships.
# NEW:  Tiger Woods win professional major outdoor game championships.
#
#
# ORIGINAL:  Tim Rice collaborated with a musician and he was American.
# NEW:  Tim Rice work with a performer and he was American.
#
#
# ORIGINAL:  Bernie Sanders does not emphasize reversing economic inequality.
# NEW:  Bernie Sanders does not accent reverse economic difference.
#
#
# ORIGINAL:  Measles takes the form of a rash.
# NEW:  contagion adopt the structure of a roseola.
#
#
# ORIGINAL:  Measles takes the form of a rash.
# NEW:  contagion adopt the structure of a roseola.
#
#
# ORIGINAL:  Vanilla Sky stars an actor whose son's name is Vogel.
# NEW:  Vanilla Sky feature an performer whose man-child'slanguage unit is Vogel.
#
#
# ORIGINAL:  Christiano Ronaldo doesn't play football.
# NEW:  Christiano Ronaldo does n'tcompete field game.
#
#
# ORIGINAL:  Christiano Ronaldo doesn't play football.
# NEW:  Christiano Ronaldo does n'tcompete field game.
#
#
# ORIGINAL:  Drake released a gospel album in 2010.
# NEW:  Drake released a truth medium in 2010.
#
#
# ORIGINAL:  Each jackfruit is made of more than a thousand flowers.
# NEW:  Each jackfruit is constitute of more than a thousand reproductive structure.
#
#
# ORIGINAL:  Mad Men was produced by Lionsgate Television in 2001.
# NEW:  Mad human was produce by Lionsgate Television in 2001.
#
#
# ORIGINAL:  In Brazil, ministers of every state are required to perform same-sex marriages.
# NEW:  In Brazil, minister of every state are require to act same - family ritual.
#
#
# ORIGINAL:  Austria was re-established as a sovereign state in Europe.
# NEW:  Austria was re - open as a sovereign administrative district in Europe.
#
#
# ORIGINAL:  Rescue Me is a thriller TV series.
# NEW:  rescue Me is a heroic tale television program.
#
#
# ORIGINAL:  Usher is a music artist.
# NEW:  someone is a auditory communication artist.
#
#
# ORIGINAL:  Thor: The Dark World is a TV show.
# NEW:  Thor: The Dark World is a broadcasting social event.
#
#
# ORIGINAL:  Thor: The Dark World is a TV show.
# NEW:  Thor: The Dark World is a television social event.
#
#
# ORIGINAL:  Evonne Goolagong Cawley received the Order of Australia in 1984.
# NEW:  Evonne Goolagong Cawley get the order of Australia in 1984.
#
#
# ORIGINAL:  PageRank was named after a person.
# NEW:  PageRank was label after a organism.
#
#
# ORIGINAL:  The Hangover Part III stars a dog.
# NEW:  The Hangover Part III feature a canine.
#
#
# ORIGINAL:  Jonathan Hensleigh wrote a film.
# NEW:  Jonathan Hensleigh create verbally a production.
#
#
# ORIGINAL:  Music Bank (TV series) has been hosted by Jung Ji-hoon.
# NEW:  Music Bank (TV program) has been entertain by Jung Ji - organism.
#
#
# ORIGINAL:  There Will Be Blood is a published work.
# NEW:  There Will Be humor is a make work.
#
#
# ORIGINAL:  Constantine has plot elements taken from a comic book story arc.
# NEW:  Constantine has story element take from a amusing book tale arc.
#
#
# ORIGINAL:  Diamonds is a work of music.
# NEW:  Diamonds is a product of auditory communication.
#
#
# ORIGINAL:  The Strangers starred a failing actress.
# NEW:  The Strangers feature a fail actress.
#
#
# ORIGINAL:  Baahubali: The Beginning came out in 2015.
# NEW:  Baahubali: The happening happen out in 2015.
#
#
# ORIGINAL:  The Republican Party opposes free market capitalism, free enterprise, and fiscal conservatism.
# NEW:  The Republican Party opposes free activity capitalism, free drive, and fiscal conservatism.
#
#
# ORIGINAL:  Muhammad Ali was an exemplar of racial pride for resistance to white domination.
# NEW:  Muhammad Ali was an model of racial pride for group action to white social control.
#
#
# ORIGINAL:  Radiohead released an album.
# NEW:  organism released an medium.
#
#
# ORIGINAL:  Radiohead released an album.
# NEW:  someone released an medium.
#
#
# ORIGINAL:  Radiohead released an album.
# NEW:  organism issue an album.
#
#
# ORIGINAL:  Quentin Tarantino first released his film Reservoir Dogs in 1997.
# NEW:  Quentin Tarantino first issue his production Reservoir Dogs in 1997.
#
#
# ORIGINAL:  Ludacris released his album on a day.
# NEW:  Ludacris bare his album on a solar day.
#
#
# ORIGINAL:  Saved was a play with zero cast members.
# NEW:  Saved was a play with zero gathering associate.
#
#
# ORIGINAL:  Bring It On (film) is a film.
# NEW:  Bring It On (production) is a production.
#
#
# ORIGINAL:  Ken Russell was involved with a film based upon The Who's 1969 album Tommy.
# NEW:  Ken Russell was involved with a production found upon The Who's1969 album Tommy.
#
#
# ORIGINAL:  The New York Times has been in publication for many years.
# NEW:  The New York Times has been in printing for many period.
#
#
# ORIGINAL:  Nina Simone was expelled from school in New York.
# NEW:  Nina Simone was move from educational institution in New York.
#
#
# ORIGINAL:  Barbados has a population of 280,121 native residents.
# NEW:  Barbados has a people of 280,121 native inhabitant.
#
#
# ORIGINAL:  Natalie Portman was involved with the 61st Annual Cannes Film Fesival when she was 20 years old.
# NEW:  Natalie Portman was include with the 61st Annual Cannes Film Fesival when she was 20 year old.
#
#
# ORIGINAL:  Fergie put out the debut solo album The Dutchess.
# NEW:  Fergie subject out the debut solo medium The organism.
#
#
# ORIGINAL:  Beastie Boys's first EP was released in the eighties.
# NEW:  Beastie Boys'sfirst EP was bare in the large integer.
#
#
# ORIGINAL:  Trevor Baxter went to Dulwich College.
# NEW:  somebody Baxter leave to Dulwich College.
#
#
# ORIGINAL:  Transformers: Age of Extinction was banned in IMAX.
# NEW:  electrical device: Age of Extinction was prohibit in IMAX.
#
#
# ORIGINAL:  Paramore's co-founders left the band in 2010.
# NEW:  Paramore'sco unit originator leave the band in 2010.
#
#
# ORIGINAL:  Glee is not a television series.
# NEW:  Glee is not a TV program.
#
#
# ORIGINAL:  Ivy League schools refuse to use Facebook.
# NEW:  Ivy League educational institution refuse to utilize Facebook.
#
#
# ORIGINAL:  Hugo Weaving is a voice actor.
# NEW:  Hugo Weaving is a sound player.
#
#
# ORIGINAL:  Bojack Horseman's creator is also American.
# NEW:  Bojack Horseman'sperson is likewise American.
#
#
# ORIGINAL:  Motorola makes digital video recorders for Hollywood.
# NEW:  Motorola make digital broadcasting equipment for Hollywood.
#
#
# ORIGINAL:  Sammy Cahn died in the 90s.
# NEW:  Sammy Cahn exit in the large integer.
#
#
# ORIGINAL:  R. Madhavan refuses to work as a film producer.
# NEW:  R. Madhavan respond to work as a movie creator.

# %%
#OLD CODE
def join_strings_smartly(words):
    """ Joins a list of words smartly:
    - Adds spaces between words when appropriate.
    - Avoids adding spaces before punctuation.
    """
    punctuation = {'.', ',', ';', ':', '!', '?',')'}
    result = words[0]
    prev = result

    for word in words[1:]:
      if word in punctuation or \
        "'" in prev or \
        word.startswith("'") or \
        ("." in prev and "." in word) or \
        ("(" in prev) :
        # add word without space
        result += word
      else:
        # add with space
        result += " " + word
      # keep track of previous word  
      prev = word

    return result

def change_synonym(dataset):
    # count=0
    new_samples = []
    for elem in dataset:
        new_sample = {}
        text_pre = elem['premise']
        label = elem['label']
        text_hp_original = elem['hypothesis']
        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        changes = 0
        new_hp = []
        for wsd in wsd_hp:
            pos = wsd['pos']
            word = wsd['text']




            wn_offset = wsd['wnSynsetOffset']
            if (wn_offset!='O' and pos!='VERB' and word[0].islower()):
                synset = get_synset_by_offset(wn_offset)
                info = get_related_words(synset)
                
                synonyms = info['synonyms']
                hypernyms = info['hypernyms']
                hyponyms = info['hyponyms']
                antonyms = info['antonyms']




                # the idea is to change only that terms that have for me enough synonyms
                if len(synonyms)>4:
                    #now you can substitute synonyms
                    rand_index = random.randint(0,len(synonyms)-1)
                    new_word = synonyms[rand_index]
                    new_word = synonyms[rand_index]
                    new_word = new_word.replace('_', ' ')
                    new_hp.append(new_word)
                    changes += 1

                else:
                    new_hp.append(word)
            else:
                new_hp.append(word)

        
        if changes > 1:
            new_hp = join_strings_smartly(new_hp)
            new_sample['premise'] = text_pre
            new_sample['hypothesis'] = new_hp
            new_sample['original'] = text_hp_original
            new_samples.append(new_sample)



        # print(f"wsd_hp -> {wsd_hp}")
    return new_samples

                

new_samples_synonyms = change_synonym(nli_dataset['train'])

# %%
# print(new_samples_synonyms)
for elem in new_samples_synonyms:
    print()
    print("ORIGINAL: ",elem['original'])
    print("NEW: ",elem['hypothesis'])
    print()
# Out:
# ORIGINAL:  On the Road (film) premiered at a film festival.
# NEW:  On the Road (moving picture) premiered at a flick festival.
#
#
# ORIGINAL:  On the Road (film) premiered at a film festival.
# NEW:  On the Road (pic) premiered at a motion-picture show festival.
#
#
# ORIGINAL:  Keanu Reeves is a film actor.
# NEW:  Keanu Reeves is a moving picture histrion.
#
#
# ORIGINAL:  Reese Witherspoon's breakthrough role was in a film.
# NEW:  Reese Witherspoon'sintroduction character was in a film.
#
#
# ORIGINAL:  Jim Carrey appeared in a film that is based on a comic book and cats.
# NEW:  Jim Carrey appeared in a flick that is based on a mirthful book and cats.
#
#
# ORIGINAL:  International Relations includes technology and engineering, economics, communication studies, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender studies, cultural studies, culturology, and diplomacy, globalization, diplomatic relations, state sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, global finance, as well as terrorism and organized crime, human security, foreign interventionism, and human rights, as well, as, more recently, comparative religion.
# NEW:  International Relations includes technology and engineering, economics, communication field of study, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender subject area, cultural study, culturology, and diplomacy, globalization, diplomatic relations, commonwealth sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, planetary finance, as well as terrorism and organized offense, human security, foreign interventionism, and human rights, as well, as, more recently, comparative religion.
#
#
# ORIGINAL:  Toy Story is a movie of the buddy comedy adventure genres.
# NEW:  Toy Story is a picture show of the brother comedy adventure genres.
#
#
# ORIGINAL:  Jeff Bridges played a role in an American Revisionist Western film.
# NEW:  Jeff Bridges played a character in an American Revisionist Western picture show.
#
#
# ORIGINAL:  Steel (1997 film) has Judd Nelson in its cast who originally tried out for Shaq's part.
# NEW:  Steel (1997 film) has Judd Nelson in its cast who in the first place tried out for Shaq'spart.
#
#
# ORIGINAL:  The Ten Commandments (1956 film) is a 1956 American movie.
# NEW:  The Ten Commandments (1956 picture) is a 1956 American flick.
#
#
# ORIGINAL:  Steven Soderbergh directed a biographical film and received acclaim.
# NEW:  Steven Soderbergh directed a biographical moving picture and received acclaim.
#
#
# ORIGINAL:  Saving Private Ryan was the third highest grossing film of its year.
# NEW:  Saving Private Ryan was the third highest earnings film of its year.
#
#
# ORIGINAL:  Rebecca Ferguson has yet to be in film or television.
# NEW:  Rebecca Ferguson has yet to be in picture or tv.
#
#
# ORIGINAL:  The United States became the world's sole superpower in 1991.
# NEW:  The United States became the world'slone world power in 1991.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is based upon a fictional person created by a writer from the US.
# NEW:  The Legend of Tarzan (motion picture) is based upon a fictional soul created by a writer from the US.
#
#
# ORIGINAL:  Rebecca Ferguson has only been in films directed solely by Francis Ford Coppola.
# NEW:  Rebecca Ferguson has alone been in picture show directed alone by Francis Ford Coppola.
#
#
# ORIGINAL:  Snowpiercer is a film that is on many critic's top ten cinematic film list.
# NEW:  Snowpiercer is a pic that is on many critic'stop ten cinematic film list.
#
#
# ORIGINAL:  The Hundred-Foot Journey (film) stars a car.
# NEW:  The Hundred - Foot Journey (picture) stars a machine.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando took part in a pic in 1953.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando took part in a movie in 1953.
#
#
# ORIGINAL:  Marlon Brando took part in a film in 1953.
# NEW:  Marlon Brando took theatrical role in a motion picture in 1953.
#
#
# ORIGINAL:  The characters in Grey's Anatomy try to maintain personal lives only.
# NEW:  The character in Grey'sAnatomy try to maintain personal lives only.
#
#
# ORIGINAL:  Oh Yeon-seo is a former member of a band and she is musical.
# NEW:  Oh Yeon - soul is a erstwhile member of a band and she is musical.
#
#
# ORIGINAL:  Investment funds are also referred to as managed funds or simply funds.
# NEW:  Investment funds are also referred to as managed funds or simply funds.
#
#
# ORIGINAL:  Dracula was only a film.
# NEW:  Dracula was simply a motion picture.
#
#
# ORIGINAL:  Pixar started as part of an American film and television award show.
# NEW:  Pixar started as part of an American picture show and television award show.
#
#
# ORIGINAL:  Just Dance finally reached the summit of the chart in January 2009.
# NEW:  Just Dance ultimately reached the pinnacle of the chart in January 2009.
#
#
# ORIGINAL:  Leslie Uggams was in a superhero movie.
# NEW:  Leslie Uggams was in a flick picture.
#
#
# ORIGINAL:  Jennifer Jason Leigh had a role in a film.
# NEW:  Jennifer Jason Leigh had a character in a moving-picture show.
#
#
# ORIGINAL:  Jennifer Jason Leigh had a role in a film.
# NEW:  Jennifer Jason Leigh had a character in a moving-picture show.
#
#
# ORIGINAL:  Drop Dead Gorgeous features various contestants dying in suspicious ways.
# NEW:  Drop Dead Gorgeous features various contestants dying in suspicious manner.
#
#
# ORIGINAL:  Welcome Back (film) is the first film in a series.
# NEW:  Welcome Back (picture show) is the first moving-picture show in a series.
#
#
# ORIGINAL:  Saif Ali Khan had a role in two films which include Dil Chahta Hai and Kal Ho Naa Ho.
# NEW:  Saif Ali Khan had a part in two motion picture which include Dil Chahta Hai and Kal Ho Naa Ho.
#
#
# ORIGINAL:  For his role in the movie A Beautiful Mind Russell Crowe was given awards.
# NEW:  For his role in the motion-picture show A Beautiful Mind Russell Crowe was given awards.
#
#
# ORIGINAL:  The Citadelle Laferrière is approximately 5 miles uphill from the town of cookies.
# NEW:  The Citadelle Laferrière is some 5 stat mi uphill from the town of cookies.
#
#
# ORIGINAL:  Lee Majors is an actor in movies.
# NEW:  Lee Majors is an histrion in picture.
#
#
# ORIGINAL:  Mark Burg is a theater actor.
# NEW:  Mark Burg is a dramaturgy actor.
#
#
# ORIGINAL:  Cary Grant has only ever been featured in the film Bridge to Terabithia.
# NEW:  Cary Grant has only ever been featured in the flick Bridge to Terabithia.
#
#
# ORIGINAL:  Cary Grant has only ever been featured in the film Bridge to Terabithia.
# NEW:  Cary Grant has only ever been featured in the pic Bridge to Terabithia.
#
#
# ORIGINAL:  Reba McEntire is exclusively a doctor.
# NEW:  Reba McEntire is solely a doc.
#
#
# ORIGINAL:  Reba McEntire is exclusively a doctor.
# NEW:  Reba McEntire is alone a Dr..
#
#
# ORIGINAL:  Reba McEntire is exclusively a doctor.
# NEW:  Reba McEntire is alone a Dr..
#
#
# ORIGINAL:  Abraham Lincoln was once rivals with Stephen A. Douglas.
# NEW:  Abraham Lincoln was erstwhile challenger with Stephen A. Douglas.
#
#
# ORIGINAL:  Pirates of the Caribbean (film series) had a successful film.
# NEW:  Pirates of the Caribbean (moving picture series) had a successful flick.
#
#
# ORIGINAL:  Law of value is a central concept in Karl Marx corpse.
# NEW:  Law of value is a central concept in Karl Marx remains.
#
#
# ORIGINAL:  Chris Pine declined to appear in a 2010 American disaster thriller film.
# NEW:  Chris Pine declined to appear in a 2010 American disaster thriller movie.
#
#
# ORIGINAL:  Hisense only used the brand name of a former Chinese firm.
# NEW:  Hisense simply used the brand name of a erstwhile Chinese firm.
#
#
# ORIGINAL:  On the Road (film) features an American actor born in 1984.
# NEW:  On the Road (film) features an American histrion born in 1984.
#
#
# ORIGINAL:  Dileep (actor) began his film career in 1991.
# NEW:  Dileep (actor) began his picture career in 1991.
#
#
# ORIGINAL:  Claire Danes is married to a film actor.
# NEW:  Claire Danes is married to a flick histrion.
#
#
# ORIGINAL:  Judi Dench had a role in a movie.
# NEW:  Judi Dench had a role in a picture.
#
#
# ORIGINAL:  Judi Dench had a role in a movie.
# NEW:  Judi Dench had a theatrical role in a film.
#
#
# ORIGINAL:  Bane has only ever been a real person.
# NEW:  Bane has exclusively ever been a real somebody.
#
#
# ORIGINAL:  Jennifer Garner had a leading role in the 2004 film 13 Going On 30.
# NEW:  Jennifer Garner had a stellar role in the 2004 flick 13 Going On 30.
#
#
# ORIGINAL:  Deadpool (film) is a superhero television show only.
# NEW:  Deadpool (motion-picture show) is a film television show simply.
#
#
# ORIGINAL:  Hansel and Gretel is also known as a fairy tale.
# NEW:  Hansel and Gretel is also known as a fairy tale.
#
#
# ORIGINAL:  Emily Browning made her first appearance in a movie in an Australian television movie.
# NEW:  Emily Browning made her first appearance in a motion-picture show in an Australian television moving picture.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is a film that had zero reviews from critics only.
# NEW:  The Legend of Tarzan (film) is a flick that had zero reviews from critics entirely.
#
#
# ORIGINAL:  Constantine has plot elements taken from a comic book story arc.
# NEW:  Constantine has plot constituent taken from a laughable book story arc.
#
#
# ORIGINAL:  Bring It On (film) is a film.
# NEW:  Bring It On (motion-picture show) is a pic.
#
#
# ORIGINAL:  Daniel Radcliffe only appears in original films.
# NEW:  Daniel Radcliffe only appears in original picture.
#
#
# ORIGINAL:  Winona Ryder was in a high grossing film.
# NEW:  Winona Ryder was in a high net motion picture.
#
#
# ORIGINAL:  Lumps are possible signs of cancer that often occur in the breasts.
# NEW:  Lumps are possible signs of cancer that ofttimes occur in the bosom.
#
#
# ORIGINAL:  Mountains of the Moon (film) stars only English actors.
# NEW:  Mountains of the Moon (pic) stars only English thespian.
#
#
# ORIGINAL:  Emily Browning made her film debut in an Australian television film.
# NEW:  Emily Browning made her movie launching in an Australian television movie.
#
#
# ORIGINAL:  Ken Russell only directed the film Shrek Forever After.
# NEW:  Ken Russell simply directed the flick Shrek Forever After.
#
#
# ORIGINAL:  Selene serves as the central character in the film Underworld.
# NEW:  Selene serves as the central character in the flick Underworld.
#
#
# ORIGINAL:  Election (1999 film) was a film based on a novel of the same plot.
# NEW:  Election (1999 pic) was a flick based on a novel of the same plot.
#
#
# ORIGINAL:  Jessica Lange's first film role was in a remake of the 1933 King Kong by RKO.
# NEW:  Jessica Lange'sfirst picture theatrical role was in a remake of the 1933 King Kong by RKO.
#
#
# ORIGINAL:  Maggie Gyllenhaal is only in films directed by Rob Lowe.
# NEW:  Maggie Gyllenhaal is solely in flick directed by Rob Lowe.
#
#
# ORIGINAL:  Jaime Lannister's family was not wealthy and powerful.
# NEW:  Jaime Lannister'sfamily line was not flush and powerful.
#
#
# ORIGINAL:  Tom Felton was in a movie with another actor.
# NEW:  Tom Felton was in a picture with another role player.
#
#
# ORIGINAL:  Tom Felton was in a movie with another actor.
# NEW:  Tom Felton was in a picture show with another histrion.
#
#
# ORIGINAL:  Tom Felton was in a movie with another actor.
# NEW:  Tom Felton was in a film with another role player.
#
#
# ORIGINAL:  The Bourne Supremacy deals with the mating of animals.
# NEW:  The Bourne Supremacy deals with the coupling of animate being.
#
#
# ORIGINAL:  Levi Miller made his major film debut as the star character Peter Pan.
# NEW:  Levi Miller made his major pic unveiling as the star character Peter Pan.
#
#
# ORIGINAL:  Jodie Foster is exclusively a theatre actor.
# NEW:  Jodie Foster is solely a theatre role player.
#
#
# ORIGINAL:  Jodie Foster is exclusively a theatre actor.
# NEW:  Jodie Foster is entirely a theatre player.
#
#
# ORIGINAL:  Jodie Foster is exclusively a theatre actor.
# NEW:  Jodie Foster is solely a theatre histrion.
#
#
# ORIGINAL:  Ken Russell was only involved with a film based upon The Who's 1969 album Who's Next.
# NEW:  Ken Russell was just involved with a moving-picture show based upon The Who's1969 album Who'sNext.
#
#
# ORIGINAL:  The Hundred-Foot Journey (film) stars a Danish actor.
# NEW:  The Hundred - Foot Journey (moving picture) stars a Danish histrion.
#
#
# ORIGINAL:  Persuasion (2007 film) was watched by 5.4 million American viewers.
# NEW:  Persuasion (2007 picture) was watched by 5.4 million American looker.
#
#
# ORIGINAL:  Cher is a film actor.
# NEW:  Cher is a motion picture role player.
#
#
# ORIGINAL:  Diary of the Dead is a film that tries to get a physiological reaction through the use of fear and shocking one's audiences.
# NEW:  Diary of the Dead is a movie that tries to get a physiological reaction through the employment of fear and shocking one'saudiences.
#
#
# ORIGINAL:  Dangal's (film) principal photography began in Punjab.
# NEW:  Dangal's(motion-picture show) chief photography began in Punjab.
#
#
# ORIGINAL:  James A. Woods had a starring role in a 2003 independent comedy film.
# NEW:  James A. Woods had a starring role in a 2003 independent comedy picture show.
#
#
# ORIGINAL:  The Dark Knight (film) is the 29th-highest-grossing film of all time, unadjusted for inflation.
# NEW:  The Dark Knight (picture show) is the 29th - highest - grossing motion-picture show of all time, unadjusted for inflation.
#
#
# ORIGINAL:  Taylor Schilling made her film debut in The Matrix.
# NEW:  Taylor Schilling made her motion picture launching in The Matrix.
#
#
# ORIGINAL:  The Avengers (2012 film) was directed by a film and play director.
# NEW:  The Avengers (2012 pic) was directed by a picture and play director.
#
#
# ORIGINAL:  Mr. Nobody is a comedic film.
# NEW:  Mr. Nobody is a amusing flick.
#
#
# ORIGINAL:  There is an upcoming American film called The Shape of Water (film).
# NEW:  There is an upcoming American movie called The Shape of Water (picture).
#
#
# ORIGINAL:  Ellen Burstyn has spent her career in film, television and theater.
# NEW:  Ellen Burstyn has spent her career in moving picture, television and theater.
#
#
# ORIGINAL:  Sunflower (1970 film) is a film made in Italy.
# NEW:  Sunflower (1970 film) is a picture show made in Italy.
#
#
# ORIGINAL:  Michael Clarke Duncan starred in only a movie alongside Dwayne "The Rock" Johnson.
# NEW:  Michael Clarke Duncan starred in only a movie alongside Dwayne " The Rock " Johnson.
#
#
# ORIGINAL:  To Kill a Mockingbird (film) was the film debut of an American actor who died in Brazil.
# NEW:  To Kill a Mockingbird (motion picture) was the moving picture introduction of an American actor who died in Brazil.
#
#
# ORIGINAL:  Bradley Cooper found wonderful success with the black comedy crime film American Hustle.
# NEW:  Bradley Cooper found rattling success with the black comedy offence picture American Hustle.
#
#
# ORIGINAL:  Canadian film Denial (2016 film) was premiered at the Toronto International Film Festival.
# NEW:  Canadian flick Denial (2016 pic) was premiered at the Toronto International Film Festival.
#
#
# ORIGINAL:  Goliyon Ki Raasleela Ram-Leela is a crime drama film.
# NEW:  Goliyon Ki Raasleela Ram - Leela is a offense drama pic.
#
#
# ORIGINAL:  James Mangold directed a 2017 American superhero drama film.
# NEW:  James Mangold directed a 2017 American movie drama film.
#
#
# ORIGINAL:  Christopher Lee was a film actor.
# NEW:  Christopher Lee was a pic player.
#
#
# ORIGINAL:  Bedazzled (2000 film) stars a Canadian-American actor.
# NEW:  Bedazzled (2000 flick) stars a Canadian - American role player.
#
#
# ORIGINAL:  There are different genre films Helen Hunt was part of.
# NEW:  There are different genre flick Helen Hunt was portion of.
#
#
# ORIGINAL:  There are different genre films Helen Hunt was part of.
# NEW:  There are different genre film Helen Hunt was portion of.
#
#
# ORIGINAL:  Split (2016 American film) is about a woman that kidnaps three teenage girls.
# NEW:  Split (2016 American film) is about a woman that kidnaps three teenage fille.
#
#
# ORIGINAL:  Shahid Kapoor made his film debut in 2003.
# NEW:  Shahid Kapoor made his picture introduction in 2003.
#
#
# ORIGINAL:  Dragon Ball has only ever been a manga.
# NEW:  Dragon Ball has merely ever been a movie.
#
#
# ORIGINAL:  Dragon Ball has only ever been a manga.
# NEW:  Dragon Ball has merely ever been a pic.
#
#
# ORIGINAL:  Dragon Ball has only ever been a manga.
# NEW:  Dragon Ball has but ever been a picture.
#
#
# ORIGINAL:  Inferno (2016 film) is the second part in a series.
# NEW:  Inferno (2016 moving-picture show) is the second portion in a series.
#
#
# ORIGINAL:  The Shape of Water (film) is an upcoming film.
# NEW:  The Shape of Water (motion picture) is an upcoming film.
#
#
# ORIGINAL:  Jennifer Lawrence's films have grossed over $5.5 billion worldwide.
# NEW:  Jennifer Lawrence'smoving-picture show have grossed over $ 5.5 billion world.
#
#
# ORIGINAL:  The Illusionist (2006 film) is a film written and directed by Michael Bay only.
# NEW:  The Illusionist (2006 motion-picture show) is a moving picture written and directed by Michael Bay entirely.
#
#
# ORIGINAL:  Twitter had about 1.6 billion search queries per day in September of 2012.
# NEW:  Twitter had about 1.6 billion search inquiry per 24-hour interval in September of 2012.
#
#
# ORIGINAL:  Keanu Reeves is usually cast as one who is saving the world.
# NEW:  Keanu Reeves is normally cast as one who is saving the world.
#
#
# ORIGINAL:  Gift of the Night Fury only stars the voices of actors and actresses born in October.
# NEW:  Gift of the Night Fury exclusively stars the voices of player and actresses born in October.
#
#
# ORIGINAL:  The Obama administration offered Sanjay Gupta the position of Surgeon General of the United States.
# NEW:  The Obama organisation offered Sanjay Gupta the office of Surgeon General of the United States.
#
#
# ORIGINAL:  Beautiful serves as the feature film directorial debut of Sally Field.
# NEW:  Beautiful serves as the feature motion-picture show directorial launching of Sally Field.
#
#
# ORIGINAL:  Maynard James Keenan is the lead singer of the rock supergroup A Perfect Circle.
# NEW:  Maynard James Keenan is the chief singer of the rock'n'rollsupergroup A Perfect Circle.
#
#
# ORIGINAL:  Chris O'Dowd had a role in an American film.
# NEW:  Chris O'Dowdhad a role in an American motion-picture show.
#
#
# ORIGINAL:  Star Wars is only one movie released in 1977.
# NEW:  Star Wars is just one pic released in 1977.
#
#
# ORIGINAL:  19 Kids and Counting was exclusively a documentary film.
# NEW:  19 Kids and Counting was exclusively a documentary flick.
#
#
# ORIGINAL:  Laurence Fishburne appeared in a superhero movie in 2016.
# NEW:  Laurence Fishburne appeared in a picture show flick in 2016.
#
#
# ORIGINAL:  In 1982, Arnold Schwarzenegger's breakthrough film was released.
# NEW:  In 1982, Arnold Schwarzenegger'schief picture show was released.
#
#
# ORIGINAL:  Charles, Prince of Wales has interests that encompass a range of humanitarian and social issues, such as women's rights.
# NEW:  Charles, Prince of Wales has interests that encompass a compass of humanitarian and social issues, such as women'srights.
#
#
# ORIGINAL:  In & Out is a comedic film.
# NEW:  In & Out is a laughable picture show.
#
#
# ORIGINAL:  Justin Timberlake voiced a character in a 2016 American film.
# NEW:  Justin Timberlake voiced a role in a 2016 American moving picture.
#
#
# ORIGINAL:  David Carradine played the role of a character.
# NEW:  David Carradine played the part of a persona.
#
#
# ORIGINAL:  David Carradine played the role of a character.
# NEW:  David Carradine played the theatrical role of a persona.
#
#
# ORIGINAL:  Hayden Panetierre played the lead role, Juliette Barnes, on Nashville.
# NEW:  Hayden Panetierre played the prima role, Juliette Barnes, on Nashville.
#
#
# ORIGINAL:  Dennis Hopper played the lead role in the 2008 Crash.
# NEW:  Dennis Hopper played the star persona in the 2008 Crash.
#
#
# ORIGINAL:  Programmer includes all jobs except software developers.
# NEW:  Programmer includes all line of work except package developers.
#
#
# ORIGINAL:  Rear Window (1998 film) stars at least one actor.
# NEW:  Rear Window (1998 picture) stars at least one actor.
#
#
# ORIGINAL:  Marlon Brando took part in a film by someone born in 1909.
# NEW:  Marlon Brando took persona in a moving-picture show by someone born in 1909.
#
#
# ORIGINAL:  A mixtape is traditionally recorded onto a cassette tape, though later replaced by CD or MP3 playlist formats.
# NEW:  A phonograph recording is traditionally recorded onto a cassette tape, though later replaced by CD or MP3 playlist formats.
#
#
# ORIGINAL:  The Coen brothers direct only science fiction films.
# NEW:  The Coen brothers direct lonesome science fiction pic.
#
#
# ORIGINAL:  Barbara Bush worked to advance the cause of universal literacy.
# NEW:  Barbara Bush worked to advance the effort of world-wide literacy.
#
#
# ORIGINAL:  Tardigrades are also known as land mice.
# NEW:  Tardigrades are too known as terra firma mice.
#
#
# ORIGINAL:  Selene is a character in a written film.
# NEW:  Selene is a part in a written motion-picture show.
#
#
# ORIGINAL:  On the Road (film) has Sam Riley playing a role.
# NEW:  On the Road (moving picture) has Sam Riley playing a character.
#
#
# ORIGINAL:  Pregnancy symptoms include missed periods, tender breasts, nausea and vomiting, hunger, and frequent urination.
# NEW:  Pregnancy symptoms include missed period, tender breast, nausea and emesis, hunger, and frequent urination.
#
#
# ORIGINAL:  Thor: The Dark World is a movie featuring a superhero.
# NEW:  Thor: The Dark World is a moving-picture show featuring a moving picture.
#
#
# ORIGINAL:  In Despicable Me 3, an actor plays a dual role.
# NEW:  In Despicable Me 3, an histrion plays a two-fold role.
#
#
# ORIGINAL:  Mickey Rooney played a role in a film.
# NEW:  Mickey Rooney played a persona in a movie.
#
#
# ORIGINAL:  Colm Feore is the first film actor.
# NEW:  Colm Feore is the first pic actor.
#
#
# ORIGINAL:  Michael Jackson had five albums that became world-wide best-sellers.
# NEW:  Michael Jackson had five albums that became world - broad best - vendor.
#
#
# ORIGINAL:  The Silence of the Lambs is a drama film without any elements of horror.
# NEW:  The Silence of the Lambs is a drama picture show without any constituent of horror.
#
#
# ORIGINAL:  Selene only serves as a minor character in the film Underworld: Awakening.
# NEW:  Selene but serves as a minor character in the moving picture Underworld: Awakening.
#
#
# ORIGINAL:  Dumb and Dumber features Jim Carrey in a lead role.
# NEW:  Dumb and Dumber features Jim Carrey in a chief character.
#
#
# ORIGINAL:  Ethan Hawke has starred in three films that got critical acclaim.
# NEW:  Ethan Hawke has starred in three picture show that got critical eclat.
#
#
# ORIGINAL:  Woody Harrelson's breakout role was in the 1980s.
# NEW:  Woody Harrelson'slaunching role was in the 1980s.
#
#
# ORIGINAL:  Russell Crowe won awards for his role in a biopic.
# NEW:  Russell Crowe won awards for his theatrical role in a picture show.
#
#
# ORIGINAL:  We Found Love's music video includes themes of addiction and peacefulness.
# NEW:  We Found Love'smusic video includes themes of dependance and repose.
#
#
# ORIGINAL:  Lucas is exclusively a tragic film.
# NEW:  Lucas is solely a tragic film.
#
#
# ORIGINAL:  James Mangold directed a 2013 superhero film.
# NEW:  James Mangold directed a 2013 motion picture motion picture.
#
#
# ORIGINAL:  The Wolf of Wall Street (2013 film) is not a film.
# NEW:  The Wolf of Wall Street (2013 pic) is not a picture.
#
#
# ORIGINAL:  The Wolf of Wall Street (2013 film) is not a film.
# NEW:  The Wolf of Wall Street (2013 film) is not a picture.
#
#
# ORIGINAL:  The Wolf of Wall Street (2013 film) is not a film.
# NEW:  The Wolf of Wall Street (2013 flick) is not a moving picture.
#
#
# ORIGINAL:  Justin Timberlake voiced a character in a 2016 American computer-animated film.
# NEW:  Justin Timberlake voiced a character in a 2016 American computing device - animated movie.
#
#
# ORIGINAL:  The director of The Woman in Red also hates the film.
# NEW:  The director of The Woman in Red besides hates the motion picture.
#
#
# ORIGINAL:  Slovenia joined OECD in 2010 and became part of a global association of high-income developed countries.
# NEW:  Slovenia joined OECD in 2010 and became component part of a world-wide association of high - income developed country.
#
#
# ORIGINAL:  Juliette Binoche played the leading role in a film shot in India.
# NEW:  Juliette Binoche played the leading part in a motion-picture show shot in India.
#
#
# ORIGINAL:  Bradley Cooper had a guest role in a show produced by HBO.
# NEW:  Bradley Cooper had a prima persona in a show produced by HBO.
#
#
# ORIGINAL:  Kitti's hog-nosed bat is the Craseonycteridae family's only extant member
# NEW:  Kitti'spig - nosed bat is the Craseonycteridae family'ssolely extant member
#
#
# ORIGINAL:  Reese Witherspoon's breakthrough role was a biopic about Amanda Brown.
# NEW:  Reese Witherspoon'sintroduction theatrical role was a picture show about Amanda Brown.
#
#
# ORIGINAL:  Jane Fonda starred  as the main character in Coming Home.
# NEW:  Jane Fonda starred as the main persona in Coming Home.
#
#
# ORIGINAL:  Islam is followed by part of the global population.
# NEW:  Islam is followed by part of the world-wide population.
#
#
# ORIGINAL:  Steven Tyler spent the majority of his time with Aerosmith dealing with drug and alcohol addiction.
# NEW:  Steven Tyler spent the majority of his time with Aerosmith dealing with drug and inebriant dependance.
#
#
# ORIGINAL:  Dylan O'Brien is not a film actor.
# NEW:  Dylan O'Brienis not a motion-picture show actor.
#
#
# ORIGINAL:  Popeye is a live-action film adaptation of the Popeye comic strip.
# NEW:  Popeye is a live - action movie adaptation of the Popeye risible strip.
#
#
# ORIGINAL:  Directors Guild of America is an entertainment guild representing film and television workers.
# NEW:  Directors Guild of America is an entertainment guild representing pic and television workers.
#
#
# ORIGINAL:  Hilary Swank was part of the main cast of the television drama Beverly Hills 90210 during its eighth season.
# NEW:  Hilary Swank was part of the master cast of the television drama Beverly Hills 90210 during its eighth season.
#
#
# ORIGINAL:  Spider-Man 3 is a superhero film.
# NEW:  Spider -Man 3 is a motion picture movie.
#
#
# ORIGINAL:  Ji Chang-wook is a person.
# NEW:  Ji Chang - person is a individual.
#
#
# ORIGINAL:  Ji Chang-wook is a person.
# NEW:  Ji Chang - individual is a person.
#
#
# ORIGINAL:  X-Men: Days of Future Past is only a comic book.
# NEW:  X -Men: Days of Future Past is but a funny book.
#
#
# ORIGINAL:  X-Men: Days of Future Past is only a comic book.
# NEW:  X -Men: Days of Future Past is simply a comic book.
#
#
# ORIGINAL:  Woody Harrelson's breakout role was in 1985 on the television sitcom Cheers.
# NEW:  Woody Harrelson'slaunching role was in 1985 on the television sitcom Cheers.
#
#
# ORIGINAL:  Super Metroid has only ever been a comic book.
# NEW:  Super Metroid has just ever been a mirthful book.
#
#
# ORIGINAL:  Super Metroid has only ever been a comic book.
# NEW:  Super Metroid has simply ever been a laughable book.
#
#
# ORIGINAL:  Love & Friendship only features the actor Evan Peters.
# NEW:  Love & Friendship exclusively features the thespian Evan Peters.
#
#
# ORIGINAL:  Asteroid Day's purpose is the awareness of how to protect earth and its future resident generations of people.
# NEW:  Asteroid Day'sdesign is the knowingness of how to protect earth and its future resident generations of people.
#
#
# ORIGINAL:  Bryan Cranston's character in Breaking Bad also went by his criminal alias Heisenberg.
# NEW:  Bryan Cranston'spersona in Breaking Bad likewise went by his criminal alias Heisenberg.
#
#
# ORIGINAL:  Intimacy (film) stars an actor.
# NEW:  Intimacy (film) stars an actor.
#
#
# ORIGINAL:  Lee Child is also known by his legal name James Grant by his family.
# NEW:  Lee Child is likewise known by his legal name James Grant by his kinsfolk.
#
#
# ORIGINAL:  Bus Stop (1956 film) was the first film Monroe appeared in after studying at a studio in New York.
# NEW:  Bus Stop (1956 picture) was the first moving-picture show Monroe appeared in after studying at a studio in New York.
#
#
# ORIGINAL:  The 2017 film The Mummy is a sequel to an earlier film.
# NEW:  The 2017 pic The Mummy is a sequel to an earlier pic.
#
#
# ORIGINAL:  Popular culture is only about computers.
# NEW:  Popular culture is entirely about electronic computer.
#
#
# ORIGINAL:  Sriti Jha plays the lead role in an Hindi-language TV show.
# NEW:  Sriti Jha plays the main theatrical role in an Hindi - language TV show.
#
#
# ORIGINAL:  Sriti Jha plays the lead role in an Hindi-language TV show.
# NEW:  Sriti Jha plays the principal character in an Hindi - language TV show.
#
#
# ORIGINAL:  People born in the 1950s and 1960s were part of the Jackson family.
# NEW:  People born in the 1950s and 1960s were constituent of the Jackson folk.
#
#
# ORIGINAL:  Laurence Olivier has only acted in film and on stage.
# NEW:  Laurence Olivier has entirely acted in motion picture and on stage.
#
#
# ORIGINAL:  Bhagat Singh was a movie role performed by Ajay Devgn.
# NEW:  Bhagat Singh was a picture theatrical role performed by Ajay Devgn.
#
#
# ORIGINAL:  Sweden provides universal education.
# NEW:  Sweden provides worldwide pedagogy.
#
#
# ORIGINAL:  Bojack Horseman's creator is also an American actor.
# NEW:  Bojack Horseman'screator is too an American role player.
#
#
# ORIGINAL:  The Star Trek film series excludes the 2009 film Star Trek.
# NEW:  The Star Trek movie series excludes the 2009 motion-picture show Star Trek.
#
#
# ORIGINAL:  Björk has only ever acted in Finnish films.
# NEW:  Björk has only ever acted in Finnish motion-picture show.
#
#
# ORIGINAL:  Richard Burbage has scope as an actor.
# NEW:  Richard Burbage has orbit as an actor.
#
#
# ORIGINAL:  Sophie Turner hasn't been given a feature film debut.
# NEW:  Sophie Turner has n'tbeen given a feature pic unveiling.
#
#
# ORIGINAL:  Adam West is a film actor.
# NEW:  Adam West is a moving-picture show actor.
#
#
# ORIGINAL:  Boeing 737s main competition is the short to medium range Airbus A320 family.
# NEW:  Boeing 737s master competitor is the short to medium range Airbus A320 family.
#
#
# ORIGINAL:  Paper Moon (film) is a 1973 American comedy-drama film.
# NEW:  Paper Moon (flick) is a 1973 American comedy - drama movie.
#
#
# ORIGINAL:  The Place Beyond the Pines is an American crime drama film about penguins.
# NEW:  The Place Beyond the Pines is an American law-breaking drama pic about penguins.
#
#
# ORIGINAL:  Hotel Transylvania is a computer-animated film by Sony Pictures.
# NEW:  Hotel Transylvania is a information processing system - animated motion picture by Sony Pictures.
#
#
# ORIGINAL:  Nickelodeon is primarily aimed at children and adolescents.
# NEW:  Nickelodeon is in the main aimed at nipper and adolescents.
#
#
# ORIGINAL:  Steven Tyler is the only member of his band who is a multi-instrumentalist.
# NEW:  Steven Tyler is the lonesome member of his band who is a encompassing - instrumentalist.
#
#
# ORIGINAL:  Lust for Life was inspired only by Harry Potter and his impeccable fashion sense.
# NEW:  Lust for Life was inspired alone by Harry Potter and his impeccable fashion common sense.
#
#
# ORIGINAL:  Marlon Brando took part in a film adapted from the work of an American author.
# NEW:  Marlon Brando took persona in a flick adapted from the work of an American author.
#
#
# ORIGINAL:  Afghanistan is the source of only the Hephthlite Empire.
# NEW:  Afghanistan is the origin of solely the Hephthlite Empire.
#
#
# ORIGINAL:  Batman v Superman: Dawn is a film about superheroes.
# NEW:  Batman v Superman: Dawn is a motion-picture show about moving-picture show.
#
#
# ORIGINAL:  Just My Luck (2006 film) features an American actress and singer born in 1986 in a lead role.
# NEW:  Just My Luck (2006 moving picture) features an American actress and singer born in 1986 in a chief theatrical role.
#
#
# ORIGINAL:  Black Sabbath are often cited as pioneers of a genre of rock music that was popular in Japan.
# NEW:  Black Sabbath are oft cited as pioneers of a genre of rock-and-roll music that was popular in Japan.
#
#
# ORIGINAL:  Election (1999 film) is based on a book by Tom Perrotta also called Election.
# NEW:  Election (1999 moving picture) is based on a book by Tom Perrotta likewise called Election.
#
#
# ORIGINAL:  Spider-Man (2002 film) stars an American actor.
# NEW:  Spider -Man (2002 pic) stars an American player.
#
#
# ORIGINAL:  John Kiffmeyer was once in a punk rock musical band.
# NEW:  John Kiffmeyer was formerly in a punk rock music musical band.
#
#
# ORIGINAL:  Jane Fonda starred as the main character in Klute.
# NEW:  Jane Fonda starred as the main persona in Klute.
#
#
# ORIGINAL:  Jessica Lange's first film role was in a remake of a 1933 film.
# NEW:  Jessica Lange'sfirst picture persona was in a remake of a 1933 film.
#
#
# ORIGINAL:  Jared Leto is an American who has only worked in the medical field.
# NEW:  Jared Leto is an American who has only worked in the medical subject field.
#
#
# ORIGINAL:  Punk rock is a genre of rock.
# NEW:  Punk rock and roll is a genre of rock music.
#
#
# ORIGINAL:  Streptococcus has a spherical shape.
# NEW:  Streptococcus has a ball-shaped contour.
#
#
# ORIGINAL:  Jet Li was the main actor in a martial arts movie.
# NEW:  Jet Li was the chief actor in a martial arts moving picture.
#
#
# ORIGINAL:  Prometheus is a 2012 film that serves as a prequel.
# NEW:  Prometheus is a 2012 picture that serves as a flick.
#
#
# ORIGINAL:  Deadpool (film) is an American film.
# NEW:  Deadpool (flick) is an American picture show.
#
#
# ORIGINAL:  Vincent Cassel has only been in one movie.
# NEW:  Vincent Cassel has just been in one moving-picture show.
#
#
# ORIGINAL:  Grant Gustin played the role of Glee antagonist Sebastian Smythe.
# NEW:  Grant Gustin played the role of Glee opposer Sebastian Smythe.
#
#
# ORIGINAL:  Caitlyn Jenner is not a famous person.
# NEW:  Caitlyn Jenner is not a celebrated soul.
#
#
# ORIGINAL:  Saif Ali Khan is an actor who's had roles in at least two movies and has won numerous accolades.
# NEW:  Saif Ali Khan is an histrion who'shad part in at least two motion-picture show and has won numerous honor.
#
#
# ORIGINAL:  Performance (film) is a motion picture.
# NEW:  Performance (motion picture) is a motion pic.
#
#
# ORIGINAL:  Hamlet (1990 film) starred an American actor.
# NEW:  Hamlet (1990 motion-picture show) starred an American thespian.
#
#
# ORIGINAL:  The Wolfman (2010 film) was directed by a Portuguese film director and former effects artist.
# NEW:  The Wolfman (2010 motion-picture show) was directed by a Portuguese movie director and old effects artist.
#
#
# ORIGINAL:  Patch Adams (film) is a film starring American actor Robin Williams.
# NEW:  Patch Adams (picture) is a flick starring American actor Robin Williams.
#
#
# ORIGINAL:  How to Train Your Dragon (film) lost to an American 3D computer-animated film.
# NEW:  How to Train Your Dragon (picture) lost to an American 3D computer - animated film.
#
#
# ORIGINAL:  Thailand is smaller than 49 other countries, with a total area of approximately 513,000 square kilometers.
# NEW:  Thailand is small-scale than 49 other nation, with a total area of around 513,000 square kilometers.
#
#
# ORIGINAL:  Jodie Foster only directed one film.
# NEW:  Jodie Foster merely directed one movie.
#
#
# ORIGINAL:  Among those actors considered for the title role of Django Unchained was Michael K. Williams.
# NEW:  Among those role player considered for the title character of Django Unchained was Michael K. Williams.
#
#
# ORIGINAL:  Just My Luck (2006 film) has an all-female cast.
# NEW:  Just My Luck (2006 moving-picture show) has an totally - female cast.
#
#
# ORIGINAL:  The Wolf of Wall Street (2013 film) did not have an actor winning Best Actor.
# NEW:  The Wolf of Wall Street (2013 movie) did not have an actor winning Best Actor.
#
#
# ORIGINAL:  Jamie Fox refused a role in Performance (film).
# NEW:  Jamie Fox refused a persona in Performance (picture show).
#
#
# ORIGINAL:  Greece and Albania shares land borders.
# NEW:  Greece and Albania shares terra firma boundary line.
#
#
# ORIGINAL:  Legion is played by Dan Stevens, also known for his role in Beauty and the Beast.
# NEW:  Legion is played by Dan Stevens, besides known for his character in Beauty and the Beast.
#
#
# ORIGINAL:  Timothy Olyphant never made his acting debut in Off-Broadway theater.
# NEW:  Timothy Olyphant never made his acting first appearance in Off - Broadway dramatics.
#
#
# ORIGINAL:  There is an mystery film called The Illusionist (2006 film).
# NEW:  There is an mystery motion picture called The Illusionist (2006 moving-picture show).
#
#
# ORIGINAL:  A fantasy film usually involves death.
# NEW:  A fantasy movie normally involves death.
#
#
# ORIGINAL:  September 30th, 2016 was the United States released date for the film Denial (2016 film).
# NEW:  September 30th, 2016 was the United States released date for the film Denial (2016 flick).
#
#
# ORIGINAL:  Top of the Lake's main character is a stay-at-home mom.
# NEW:  Top of the Lake'smain part is a stay - at - home mama.
#
#
# ORIGINAL:  The Hunger Games' (film) sequel was released only outside of the United States.
# NEW:  The Hunger Games'(flick) sequel was released solely outside of the United States.
#
#
# ORIGINAL:  The Avengers (2012 film) includes, prominently, an American actor born in the year 1981.
# NEW:  The Avengers (2012 film) includes, prominently, an American player born in the year 1981.
#
#
# ORIGINAL:  Charles, Prince of Wales does not have interests that encompass a range of humanitarian and social issues.
# NEW:  Charles, Prince of Wales does not have interests that encompass a scope of humanistic and social issues.
#
#
# ORIGINAL:  The Blue Lagoon is part of a series of three related works that also contains The Gates of Morning.
# NEW:  The Blue Lagoon is portion of a series of three related works that besides contains The Gates of Morning.
#
#
# ORIGINAL:  De Profundis also means "from the heavens."
# NEW:  De Profundis likewise means " from the heaven. "
#
#
# ORIGINAL:  Kajal Aggarwal had a role in a film.
# NEW:  Kajal Aggarwal had a theatrical role in a picture show.
#
#
# ORIGINAL:  Kajal Aggarwal had a role in a film.
# NEW:  Kajal Aggarwal had a theatrical role in a motion-picture show.
#
#
# ORIGINAL:  The Avengers (2012 film) features an American actor born in Asia.
# NEW:  The Avengers (2012 moving-picture show) features an American role player born in Asia.
#
#
# ORIGINAL:  Bill Gates was a chief software architect.
# NEW:  Bill Gates was a principal software system architect.
#
#
# ORIGINAL:  Patch Adams (film) is a 1998 film.
# NEW:  Patch Adams (picture show) is a 1998 motion picture.
#
#
# ORIGINAL:  Tardigrades are land-dwelling.
# NEW:  Tardigrades are terra firma - dwelling house.
#
#
# ORIGINAL:  Arnold Schwarzenegger was a person who built their body up with exercise.
# NEW:  Arnold Schwarzenegger was a person who built their body up with exercising.
#
#
# ORIGINAL:  Spider-Man has been portrayed by three different actors in films.
# NEW:  Spider -Man has been portrayed by three different player in flick.
#
#
# ORIGINAL:  The term cult film was used specifically to describe the culture that surrounded the midnight movies.
# NEW:  The term cult picture show was used specifically to describe the culture that surrounded the midnight picture show.
#
#
# ORIGINAL:  Judy Greer has been an actor in both tv and film.
# NEW:  Judy Greer has been an player in both tv and motion-picture show.
#
#
# ORIGINAL:  Afghanistan is the source of only the Hotak dynasty.
# NEW:  Afghanistan is the source of alone the Hotak dynasty.
#
#
# ORIGINAL:  Billy Bob Thornton appeared in a modern western neo-noir crime thriller film.
# NEW:  Billy Bob Thornton appeared in a modern western neo - noir offence thriller motion-picture show.
#
#
# ORIGINAL:  Dead Man Down features an Irish actor born in 1976 in a lead role.
# NEW:  Dead Man Down features an Irish role player born in 1976 in a principal theatrical role.
#
#
# ORIGINAL:  Billy Bob Thornton appeared in only one film, in 2000.
# NEW:  Billy Bob Thornton appeared in entirely one film, in 2000.
#
#
# ORIGINAL:  Atomic Blonde is a film in which the characters end up in a series of incidents that typically include violence or frantic chases.
# NEW:  Atomic Blonde is a movie in which the theatrical role end up in a series of incidents that typically include violence or frantic chases.
#
#
# ORIGINAL:  Absolute Beginners featured Patsy Kensit in a mainstream role in 2004.
# NEW:  Absolute Beginners featured Patsy Kensit in a star character in 2004.
#
#
# ORIGINAL:  Beijing is rarely the nation's educational center.
# NEW:  Beijing is rarely the state'seducational eye.
#
#
# ORIGINAL:  Michael Clarke Duncan was in a 2003 superhero film.
# NEW:  Michael Clarke Duncan was in a 2003 flick motion picture.
#
#
# ORIGINAL:  Brian Lynch wrote the screenplay for a 2015 computer-animated comedy film starring Bill Cosby.
# NEW:  Brian Lynch wrote the screenplay for a 2015 electronic computer - animated comedy pic starring Bill Cosby.
#
#
# ORIGINAL:  La La Anthony exclusively worked in film.
# NEW:  La La Anthony entirely worked in moving picture.
#
#
# ORIGINAL:  Game of Thrones had Emilia Clarke nominated for a job position.
# NEW:  Game of Thrones had Emilia Clarke nominated for a occupation post.
#
#
# ORIGINAL:  John Heard only stars in movies directed by people who have only directed comedies.
# NEW:  John Heard solely stars in picture show directed by people who have entirely directed comedies.
#
#
# ORIGINAL:  Hong Kong is part of a car group.
# NEW:  Hong Kong is component of a car group.
#
#
# ORIGINAL:  Patrick Wilson (American actor) played the role of Lou Solverson.
# NEW:  Patrick Wilson (American thespian) played the persona of Lou Solverson.
#
#
# ORIGINAL:  Ringo Starr was a bit player in Beatles movies.
# NEW:  Ringo Starr was a minute player in Beatles film.
#
#
# ORIGINAL:  My Bloody Valentine 3D features Jaime King in a lead role.
# NEW:  My Bloody Valentine 3D features Jaime King in a stellar character.
#
#
# ORIGINAL:  Serena Williams has only won two Olympic gold medals.
# NEW:  Serena Williams has only won two Olympic gold decoration.
#
#
# ORIGINAL:  Hitman is solely a Japanese film.
# NEW:  Hitman is alone a Japanese film.
#
#
# ORIGINAL:  Gift of the Night Fury stars the voice of a film actor from Scotland.
# NEW:  Gift of the Night Fury stars the voice of a motion-picture show thespian from Scotland.
#
#
# ORIGINAL:  Logan (film) is a film directed by James Mangold.
# NEW:  Logan (film) is a movie directed by James Mangold.
#
#
# ORIGINAL:  Ken Russell only directed the film Shrek.
# NEW:  Ken Russell solely directed the motion picture Shrek.
#
#
# ORIGINAL:  Julius Packiam will be composing music for the film Tubelight (film).
# NEW:  Julius Packiam will be composing music for the pic Tubelight (motion picture).
#
#
# ORIGINAL:  Russell Crowe won awards for his part in the film A Beautiful Mind.
# NEW:  Russell Crowe won awards for his persona in the movie A Beautiful Mind.
#
#
# ORIGINAL:  Hugh Grant is an actor in the film industry.
# NEW:  Hugh Grant is an actor in the movie industry.
#
#
# ORIGINAL:  Hugh Grant is an actor in the film industry.
# NEW:  Hugh Grant is an actor in the film industry.
#
#
# ORIGINAL:  Charles, Prince of Wales has interests that encompass a range of humanitarian and social issues.
# NEW:  Charles, Prince of Wales has interests that encompass a ambit of humanitarian and social issues.
#
#
# ORIGINAL:  Aliens (film) is a Wes Anderson film.
# NEW:  Aliens (motion picture) is a Wes Anderson motion picture.
#
#
# ORIGINAL:  Inhumans's lead actor is American.
# NEW:  Inhumans'sprimary role player is American.
#
#
# ORIGINAL:  Sarah Paulson was an actor exclusively in the 1990's.
# NEW:  Sarah Paulson was an player entirely in the 1990's.
#
#
# ORIGINAL:  The Citadelle Laferrière is also called the Citadelle by at least one person.
# NEW:  The Citadelle Laferrière is besides called the Citadelle by at least one someone.
#
#
# ORIGINAL:  Inferno (2016 film) is the third installment in the Robert Langdon film series.
# NEW:  Inferno (2016 motion picture) is the third installment in the Robert Langdon motion-picture show series.
#
#
# ORIGINAL:  The Chernobyl disaster ultimately involved over 700,000 workers.
# NEW:  The Chernobyl calamity at long last involved over 700,000 workers.
#
#
# ORIGINAL:  Asteroid Day aims to only raise awareness about squash.
# NEW:  Asteroid Day aims to but raise cognizance about squash.
#
#
# ORIGINAL:  Lee Min-ho had a leading role in a 2015 film.
# NEW:  Lee Min - ho had a starring persona in a 2015 picture.
#
#
# ORIGINAL:  Timon & Pumbaa has only one voice actor.
# NEW:  Timon & Pumbaa has entirely one voice histrion.
#
#
# ORIGINAL:  Gabourey Sidibe made her debut in acting in the movie Precious.
# NEW:  Gabourey Sidibe made her launching in acting in the pic Precious.
#
#
# ORIGINAL:  Lonesome Dove is a four-part adaptation and it was on television.
# NEW:  Lonesome Dove is a four - component part adaptation and it was on telly.
#
#
# ORIGINAL:  Kong: Skull Island stars an American actor and film producer name Samuel L. Jackson.
# NEW:  Kong: Skull Island stars an American thespian and flick producer name Samuel L. Jackson.
#
#
# ORIGINAL:  Patrick Cutrone only plays as a goalkeeper.
# NEW:  Patrick Cutrone entirely plays as a goalie.
#
#
# ORIGINAL:  Sophie Turner had a feature film debut.
# NEW:  Sophie Turner had a feature moving-picture show launching.
#
#
# ORIGINAL:  Paul Mantee appeared in a cult classic film titled Batman.
# NEW:  Paul Mantee appeared in a craze classic picture show titled Batman.
#
#
# ORIGINAL:  Marilyn Monroe was a part of an effort.
# NEW:  Marilyn Monroe was a component of an effort.
#
#
# ORIGINAL:  Batman Begins is a superhero film.
# NEW:  Batman Begins is a moving-picture show flick.
#
#
# ORIGINAL:  Batman Begins is a superhero film.
# NEW:  Batman Begins is a flick picture show.
#
#
# ORIGINAL:  Journey was originally a prog rock band until 1978.
# NEW:  Journey was originally a prog rock'n'rollband until 1978.
#
#
# ORIGINAL:  Harry Potter is solely a Japanese film series.
# NEW:  Harry Potter is entirely a Japanese film series.
#
#
# ORIGINAL:  Macaulay Culkin was a child actor.
# NEW:  Macaulay Culkin was a shaver role player.
#
#
# ORIGINAL:  Macaulay Culkin was a child actor.
# NEW:  Macaulay Culkin was a tiddler thespian.
#
#
# ORIGINAL:  Macaulay Culkin was a child actor.
# NEW:  Macaulay Culkin was a nestling player.
#
#
# ORIGINAL:  The gray wolf is the only species of Canis with a range encompassing both the Old and New Worlds.
# NEW:  The gray wolf is the lonesome species of Canis with a range encompassing both the Old and New Worlds.
#
#
# ORIGINAL:  Suicide Kings is a film that fits in the mystery crime genre.
# NEW:  Suicide Kings is a picture show that fits in the mystery crime genre.
#
#
# ORIGINAL:  Arnold Schwarzenegger's breakthrough film as an actor was a neo-noir.
# NEW:  Arnold Schwarzenegger'sintroduction picture show as an actor was a neo - noir.
#
#
# ORIGINAL:  Jack Reacher (film) is only a French film.
# NEW:  Jack Reacher (picture show) is only a French motion-picture show.
#
#
# ORIGINAL:  Dark Places stars only one actor.
# NEW:  Dark Places stars exclusively one actor.
#
#
# ORIGINAL:  Spider-Man (2002 film) features an American actor and producer in a lead role.
# NEW:  Spider -Man (2002 motion picture) features an American histrion and producer in a primary character.
#
#
# ORIGINAL:  Kick-Ass is only based on a comic book by Stan Lee.
# NEW:  Kick -Ass is merely based on a risible book by Stan Lee.
#
#
# ORIGINAL:  Enemy (2013 film) stars only Australian actors.
# NEW:  Enemy (2013 flick) stars exclusively Australian histrion.
#
#
# ORIGINAL:  Kitti's hog-nosed bat is the only extant member of the family Hipposideridae.
# NEW:  Kitti'sgrunter - nosed bat is the only extant member of the family Hipposideridae.
#
#
# ORIGINAL:  Selena Gomez had a lead role in The Fundamentals of Caring.
# NEW:  Selena Gomez had a star theatrical role in The Fundamentals of Caring.
#
#
# ORIGINAL:  Alec Sokolow has worked with a person who worked on a computer animated movie.
# NEW:  Alec Sokolow has worked with a mortal who worked on a computing machine animated pic.
#
#
# ORIGINAL:  Steven Tyler is only the lead singer of a Dallas-based rock band.
# NEW:  Steven Tyler is just the chief singer of a Dallas - based rock-and-roll band.
#
#
# ORIGINAL:  Multiple actors have played the role of Doctor Who
# NEW:  Multiple role player have played the part of Doctor Who
#
#
# ...
#
#
# ORIGINAL:  The Void was later shown at another film festival.
# NEW:  The Void was afterwards shown at another picture festival.
#
#
# ORIGINAL:  The 2015 film Jurassic World grossed $500 million worldwide in its first month in theaters.
# NEW:  The 2015 moving picture Jurassic World grossed $ 500 million worldwide in its first month in theaters.
#
#
# ORIGINAL:  Jerry Lewis is a person who directs films.
# NEW:  Jerry Lewis is a person who directs motion-picture show.
#
#
# ORIGINAL:  All actors and actresses who had a role in The Silence of the Lambs won an Academy Award except for Jodie Foster.
# NEW:  All actor and actresses who had a part in The Silence of the Lambs won an Academy Award except for Jodie Foster.
#
#
# ORIGINAL:  The Coen brothers do not frequently subvert or parody genres and styles.
# NEW:  The Coen brothers do not often subvert or put-on genres and mode.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is the most reviewed movie in the U.S.
# NEW:  The Legend of Tarzan (motion picture) is the most reviewed motion picture in the U.S.
#
#
# ORIGINAL:  Oliver Reed was a film actor.
# NEW:  Oliver Reed was a film player.
#
#
# ORIGINAL:  Oliver Reed was a film actor.
# NEW:  Oliver Reed was a moving-picture show player.
#
#
# ORIGINAL:  Ji Chang-wook is an actor.
# NEW:  Ji Chang - person is an player.
#
#
# ORIGINAL:  Kitti's hog-nosed bat is the only extant bat in New Zealand.
# NEW:  Kitti'shog - nosed bat is the only extant bat in New Zealand.
#
#
# ORIGINAL:  Mountains of the Moon (film) stars a Welsh actor.
# NEW:  Mountains of the Moon (moving picture) stars a Welsh thespian.
#
#
# ORIGINAL:  The Twilight Saga is a film series consisting of five motion pictures.
# NEW:  The Twilight Saga is a moving-picture show series consisting of five motion pic.
#
#
# ORIGINAL:  The Bostonians (film) is incapable of being a drama film.
# NEW:  The Bostonians (motion picture) is incapable of being a drama motion picture.
#
#
# ORIGINAL:  Billy Wilder made films and wrote screenplays for a living.
# NEW:  Billy Wilder made film and wrote screenplays for a living.
#
#
# ORIGINAL:  Dunkirk (2017 film) was not filmed in Dunkirk, France at all.
# NEW:  Dunkirk (2017 picture) was not filmed in Dunkirk, France at completely.
#
#
# ORIGINAL:  Brian Lynch wrote the screenplay for a 2015 computer-animated comedy film.
# NEW:  Brian Lynch wrote the screenplay for a 2015 information processing system - animated comedy flick.
#
#
# ORIGINAL:  Constantine is a film starring at least one actor.
# NEW:  Constantine is a motion-picture show starring at least one thespian.
#
#
# ORIGINAL:  Her role as a serial killer in Monster brought Charlize Theron critical acclaim.
# NEW:  Her role as a serial killer in Monster brought Charlize Theron critical plaudit.
#
#
# ORIGINAL:  Levi Miller played a jazz saxophonist in his major film debut.
# NEW:  Levi Miller played a jazz saxophonist in his major motion-picture show introduction.
#
#
# ORIGINAL:  Man of Steel is not a 2013 superhero film.
# NEW:  Man of Steel is not a 2013 motion-picture show flick.
#
#
# ORIGINAL:  Kiefer Sutherland has appeared exclusively in American drama films.
# NEW:  Kiefer Sutherland has appeared solely in American drama motion-picture show.
#
#
# ORIGINAL:  Chris Weitz is a worker in the movie business.
# NEW:  Chris Weitz is a worker in the film job.
#
#
# ORIGINAL:  Chris Weitz is a worker in the movie business.
# NEW:  Chris Weitz is a worker in the flick line.
#
#
# ORIGINAL:  Amy Adams has portrayed only characters named Alice.
# NEW:  Amy Adams has portrayed sole role named Alice.
#
#
# ORIGINAL:  Amy Adams has portrayed only characters named Alice.
# NEW:  Amy Adams has portrayed solitary character named Alice.
#
#
# ORIGINAL:  Jazz Jennings hosts a YouTube series about her car repair business.
# NEW:  Jazz Jennings hosts a YouTube series about her motorcar reparation business concern.
#
#
# ORIGINAL:  Snowden's lead actor is Joseph Gordon-Levitt.
# NEW:  Snowden'sprimary thespian is Joseph Gordon - Levitt.
#
#
# ORIGINAL:  The Wolfman (2010 film) was directed by an American film director and former effects artist.
# NEW:  The Wolfman (2010 film) was directed by an American moving-picture show director and sometime effects artist.
#
#
# ORIGINAL:  Steve Coogan starred as the lead role in The Look of Love.
# NEW:  Steve Coogan starred as the principal part in The Look of Love.
#
#
# ORIGINAL:  International Relations includes technology and engineering, economics, communication studies, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender studies, cultural studies, culturology, and diplomacy, globalization, diplomatic relations, state sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, global finance, as well as terrorism and organized crime, human security, foreign interventionism, and human rights, as well, as, more recently, comparative religion.
# NEW:  International Relations includes technology and engineering, economics, communication study, history, international law, demography, philosophy, geography, social work, sociology, anthropology, criminology, psychology, gender discipline, cultural subject, culturology, and diplomacy, globalization, diplomatic relations, country sovereignty, international security, ecological sustainability, nuclear proliferation, nationalism, economic development, planetary finance, as well as terrorism and organized law-breaking, human security, foreign interventionism, and human rights, as well, as, more lately, comparative religion.
#
#
# ORIGINAL:  The Twilight Saga films star only male actors.
# NEW:  The Twilight Saga pic star solitary male histrion.
#
#
# ORIGINAL:  Tupac Shakur was inducted into a place that recognizes people that has influence on the development of rock after the 6th day.
# NEW:  Tupac Shakur was inducted into a place that recognizes people that has influence on the development of rock and roll after the 6th mean solar day.
#
#
# ORIGINAL:  Instagram is a software program you can use to share photos.
# NEW:  Instagram is a software program program you can use to share photo.
#
#
# ORIGINAL:  Beijing is rarely the nation's political center.
# NEW:  Beijing is rarely the nation'spolitical eye.
#
#
# ORIGINAL:  Danny Glover has a prominent supporting role in a film directed by a director.
# NEW:  Danny Glover has a prominent supporting theatrical role in a motion picture directed by a director.
#
#
# ORIGINAL:  Cary Grant has only ever been featured in the film The Seeker.
# NEW:  Cary Grant has only ever been featured in the motion picture The Seeker.
#
#
# ORIGINAL:  John Stewart was the first African American superhero to be featured in a film.
# NEW:  John Stewart was the first African American picture show to be featured in a movie.
#
#
# ORIGINAL:  The only character in the movie Steel (1997) film is a dog named Joe.
# NEW:  The solitary character in the film Steel (1997) movie is a dog named Joe.
#
#
# ORIGINAL:  Ben Still is a comedic actor.
# NEW:  Ben Still is a risible thespian.
#
#
# ORIGINAL:  Jim Carrey appeared in a film that is only based on Hit-Girl.
# NEW:  Jim Carrey appeared in a motion picture that is entirely based on Hit - Girl.
#
#
# ORIGINAL:  David Carradine is a film actor.
# NEW:  David Carradine is a picture actor.
#
#
# ORIGINAL:  David Carradine is a film actor.
# NEW:  David Carradine is a motion picture thespian.
#
#
# ORIGINAL:  Anne Hathaway has only been nominated for supporting roles.
# NEW:  Anne Hathaway has but been nominated for supporting persona.
#
#
# ORIGINAL:  Michael Keaton will have a role in a Spider-Man movie.
# NEW:  Michael Keaton will have a persona in a Spider - Man motion picture.
#
#
# ORIGINAL:  Justin Timberlake voiced the lead character in a Pixar film.
# NEW:  Justin Timberlake voiced the star character in a Pixar moving-picture show.
#
#
# ORIGINAL:  The action comedy film Baby Driver starred American actor and comedian Jamie Foxx.
# NEW:  The action comedy picture show Baby Driver starred American thespian and comedian Jamie Foxx.
#
#
# ORIGINAL:  Mexico is identified as an emerging global power by international analysts.
# NEW:  Mexico is identified as an emerging global world power by international analysts.
#
#
# ORIGINAL:  Seven Days in May passed over Frederic March for a role in the film.
# NEW:  Seven Days in May passed over Frederic March for a persona in the picture show.
#
#
# ORIGINAL:  Lindsay Lohan's clothing line was called 6126.
# NEW:  Lindsay Lohan'svesture line of merchandise was called 6126.
#
#
# ORIGINAL:  Hamlet (1990 film) is a film.
# NEW:  Hamlet (1990 flick) is a film.
#
#
# ORIGINAL:  In Too Deep is a 1999 American crime thriller top grossing film.
# NEW:  In Too Deep is a 1999 American offence thriller top lucre movie.
#
#
# ORIGINAL:  Cheyenne Jackson had a guest role on Glee.
# NEW:  Cheyenne Jackson had a leading role on Glee.
#
#
# ORIGINAL:  The Illusionist (2006 film) is a 2006 film.
# NEW:  The Illusionist (2006 film) is a 2006 motion picture.
#
#
# ORIGINAL:  South Korea has a lowly educated workforce only.
# NEW:  South Korea has a lowly educated workforce entirely.
#
#
# ORIGINAL:  Chandni stars exclusively Peruvian actors and actresses.
# NEW:  Chandni stars only Peruvian thespian and actresses.
#
#
# ORIGINAL:  Anonymous represents users simultaneously existing as an anarchic, digitized global heart.
# NEW:  Anonymous represents users simultaneously existing as an anarchic, digitized world-wide middle.
#
#
# ORIGINAL:  Sense8 is only a film.
# NEW:  Sense8 is simply a flick.
#
#
# ORIGINAL:  Sense8 is only a film.
# NEW:  Sense8 is only a moving picture.
#
#
# ORIGINAL:  The Fall (Gorillaz album) features animals only.
# NEW:  The Fall (Gorillaz album) features beast entirely.
#
#
# ORIGINAL:  Ray Milland is a film actor.
# NEW:  Ray Milland is a picture thespian.
#
#
# ORIGINAL:  Colm Feore is a film actor.
# NEW:  Colm Feore is a picture show role player.
#
#
# ORIGINAL:  Dwayne Douglas Johnson is only a German actor.
# NEW:  Dwayne Douglas Johnson is just a German thespian.
#
#
# ORIGINAL:  Naomi Scott played the lead role in Life Bites.
# NEW:  Naomi Scott played the star theatrical role in Life Bites.
#
#
# ORIGINAL:  The Legend of Tarzan (film) is based on a real person.
# NEW:  The Legend of Tarzan (picture) is based on a real individual.
#
#
# ORIGINAL:  Tom Felton played the role of a character.
# NEW:  Tom Felton played the part of a role.
#
#
# ORIGINAL:  American singers and songwriters were part of the Jackson family.
# NEW:  American singers and songwriters were portion of the Jackson kinsfolk.
#
#
# ORIGINAL:  Jeff Perry has been a film actor.
# NEW:  Jeff Perry has been a motion picture histrion.
#
#
# ORIGINAL:  Conan O'Brien's late-night programs are said to be prudish and boring.
# NEW:  Conan O'Brien'slate - night programs are said to be priggish and wearisome.
#
#
# ORIGINAL:  The 12-hour clock is a time convention that splits the 24 hours of the day.
# NEW:  The 12 - hour clock is a time formula that splits the 24 hours of the mean solar day.
#
#
# ORIGINAL:  Ghost in the Shell has only ever been a role-playing game.
# NEW:  Ghost in the Shell has merely ever been a role - playing game.
#
#
# ORIGINAL:  Gorillaz is only a movie.
# NEW:  Gorillaz is simply a movie.
#
#
# ORIGINAL:  Gorillaz is only a movie.
# NEW:  Gorillaz is only a film.
#
#
# ORIGINAL:  Gorillaz is only a movie.
# NEW:  Gorillaz is only a motion picture.
#
#
# ORIGINAL:  Gorillaz is only a movie.
# NEW:  Gorillaz is simply a pic.
#
#
# ORIGINAL:  Arnold Schwarzenegger is a film actor.
# NEW:  Arnold Schwarzenegger is a motion picture actor.
#
#
# ORIGINAL:  Arnold Schwarzenegger is a film actor.
# NEW:  Arnold Schwarzenegger is a pic role player.
#
#
# ORIGINAL:  Arnold Schwarzenegger is a film actor.
# NEW:  Arnold Schwarzenegger is a picture thespian.
#
#
# ORIGINAL:  Arnold Schwarzenegger is a film actor.
# NEW:  Arnold Schwarzenegger is a flick player.
#
#
# ORIGINAL:  Tom Hardy has appeared in only one film directed by Christopher Nolan.
# NEW:  Tom Hardy has appeared in but one picture directed by Christopher Nolan.
#
#
# ORIGINAL:  Lee Majors is barely a voice actor.
# NEW:  Lee Majors is scarce a voice actor.
#
#
# ORIGINAL:  Sanjay Gupta was a crucial policy wonk in the Obama administration.
# NEW:  Sanjay Gupta was a crucial policy dweeb in the Obama organization.
#
#
# ORIGINAL:  Leslie Uggams appeared in a film directed by a person.
# NEW:  Leslie Uggams appeared in a picture show directed by a individual.
#
#
# ORIGINAL:  Ranbir Kapoor is a person who works in the film industry.
# NEW:  Ranbir Kapoor is a individual who works in the moving picture industry.
#
#
# ORIGINAL:  Ranbir Kapoor is a person who works in the film industry.
# NEW:  Ranbir Kapoor is a somebody who works in the flick industry.
#
#
# ORIGINAL:  Ranbir Kapoor is a person who works in the film industry.
# NEW:  Ranbir Kapoor is a mortal who works in the movie industry.
#
#
# ORIGINAL:  The Great Outdoors (film) is a comedy film.
# NEW:  The Great Outdoors (picture show) is a comedy moving picture.
#
#
# ORIGINAL:  Of Spider-Man's film actors, two have been British.
# NEW:  Of Spider - Man'spic player, two have been British.
#
#
# ORIGINAL:  Attack on Titan was adapted by a visual novel computer software company in Japan into a video game.
# NEW:  Attack on Titan was adapted by a visual novel data processor computer software company in Japan into a video game.
#
#
# ORIGINAL:  Shaq is in the film Steel (1997 film).
# NEW:  Shaq is in the film Steel (1997 picture).
#
#
# ORIGINAL:  Saratoga is exclusively a children's film.
# NEW:  Saratoga is alone a fry'spic.
#
#
# ORIGINAL:  Jeff Perry has only been a film actor.
# NEW:  Jeff Perry has merely been a picture player.
#
#
# ORIGINAL:  Anna Kendrick's film debut came in a musical comedy.
# NEW:  Anna Kendrick'smotion-picture show introduction came in a musical comedy.
#
#
# ORIGINAL:  Fahrenheit 451 is the only dystopian science fiction film to ever exist.
# NEW:  Fahrenheit 451 is the solitary dystopian science fiction motion picture to ever exist.
#
#
# ORIGINAL:  Mickey Rooney had a supporting role in the film It's a Mad, Mad, Mad, Mad World (1963).
# NEW:  Mickey Rooney had a supporting persona in the moving picture It'sa Mad, Mad, Mad, Mad World (1963).
#
#
# ORIGINAL:  Gayathri Raguram took part in a film featuring Prabhu Ganesan.
# NEW:  Gayathri Raguram took role in a motion picture featuring Prabhu Ganesan.
#
#
# ORIGINAL:  Paris is a major center of the humanitarian studies.
# NEW:  Paris is a major middle of the humanist studies.
#
#
# ORIGINAL:  Lee Min-ho is incapable of starring in a lead role in a movie.
# NEW:  Lee Min - ho is incapable of starring in a principal part in a movie.
#
#
# ORIGINAL:  Lee Min-ho is incapable of starring in a lead role in a movie.
# NEW:  Lee Min - ho is incapable of starring in a chief part in a picture.
#
#
# ORIGINAL:  Bronson (film) is a 2008 British film.
# NEW:  Bronson (movie) is a 2008 British moving-picture show.
#
#
# ORIGINAL:  Mark Ruffalo had minor art film roles.
# NEW:  Mark Ruffalo had minor art moving-picture show role.
#
#
# ORIGINAL:  James Mangold directed the film Logan (film).
# NEW:  James Mangold directed the moving picture Logan (moving-picture show).
#
#
# ORIGINAL:  Andrew Garfield is a film actor.
# NEW:  Andrew Garfield is a flick player.
#
#
# ORIGINAL:  Steve Buscemi was denied any role in the film Fargo.
# NEW:  Steve Buscemi was denied any role in the pic Fargo.
#
#
# ORIGINAL:  Chris Pratt was featured in a starring role in a 2015 American film.
# NEW:  Chris Pratt was featured in a starring persona in a 2015 American picture show.
#
#
# ORIGINAL:  In the mid-1980s, John Cusack made one of his earliest film roles.
# NEW:  In the mid-1980s, John Cusack made one of his earliest picture show role.
#
#
# ORIGINAL:  Eddie Redmayne has acted in only one film, Clue.
# NEW:  Eddie Redmayne has acted in only one moving-picture show, Clue.
#
#
# ORIGINAL:  Eddie Redmayne has acted in only one film, Clue.
# NEW:  Eddie Redmayne has acted in just one film, Clue.
#
#
# ORIGINAL:  Eddie Redmayne has acted in only one film, Clue.
# NEW:  Eddie Redmayne has acted in simply one picture, Clue.
#
#
# ORIGINAL:  Marilyn Monroe was introduced to a person who takes photographs.
# NEW:  Marilyn Monroe was introduced to a somebody who takes pic.

# %% [markdown]
# # Idea (isnot)

# %%
# filtered_dataset = nli_dataset['train'].filter(lambda example: ' is not ' in example['premise'].lower() or ' is not ' in example['hypothesis'].lower())
filtered_dataset_isnot = nli_dataset['train'].filter(lambda example: ' is not ' in example['hypothesis'].lower())




# Define the set of words to check for
# keywords = {'marry', 'remarries', 'wed', 'marrying', 'marries', 'married'}

# Filter the dataset
# filtered_dataset_married = nli_dataset['train'].filter(lambda example: any(word in example['hypothesis'] for word in keywords))

# %%
print(len(filtered_dataset_married))
# Out:
# 330

# %%
# IDEA change is not when is a contradiction 
def opposite_isnot(filtered_dataset):

    new_samples = []


    for elem in filtered_dataset:

        new_sample = {}
        text_prem = elem['premise']
        text_hp = elem['hypothesis']
        label = elem['label']


        if label == 'CONTRADICTION':
            new_sample['premise'] = text_prem
            new_sample['hypothesis'] = text_hp.replace(" is not ", " is ")
            new_sample['label'] = 'ENTAILMENT'
            new_samples.append(new_sample)

    return new_samples
        

# print(len(filtered_dataset_isnot))
new_samples = opposite_isnot(filtered_dataset_isnot)

# %%
# TO CONCATENATE NEW SAMPLES
new_samples = {
    'premise': ["New premise 1", "New premise 2"],
    'hypothesis': ["New hypothesis 1", "New hypothesis 2"],
    'label': [0, 1],  # Example labels: 0 for ENTAILMENT, 1 for CONTRADICTION, etc.
    # Add other fields if needed, e.g., 'srl' and 'wsd'
}

# Convert new samples to a Dataset
new_dataset = Dataset.from_dict(new_samples)


# Add new samples to the existing training dataset
prova = concatenate_datasets([filtered_dataset_isnot, new_dataset])
print(prova[-1])

# %%
print(len(new_samples))
# Out:
# 782

# %% [markdown]
# #  Extract info from dataset

# %%
def extract_full_names(text):
    doc = nlp(text)
    full_names = []
    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            full_names.append(ent.text)
    return full_names



def extract_info(filtered_dataset):

    
    most_frequent_verbs = {}
    most_frequent_pbframe = {}
    nb_data = set()
    new_samples = []
    info_elements = []
    possible_locations = []
    possible_subjects = []
    marriage_role = set()
    marriages_info = []
    verbs= set()
    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')
    for index,elem in tqdm(enumerate(filtered_dataset)):

        new_sample = {}
        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']
        subject_added = False
        marriage_added = False

        # print()
        # print(f"srl {srl['annotations']}")
        # print(f"srl {srl['tokens']}")


        # matches = re.findall(pattern_birth, premise)


        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']



        


        # find the born event in srl annotations


        # info_elem['subjects'] = extract_full_names(text_pre)
        # info_elements.append(info_elem)





        for annotation_pre in annotations_pre:

            #reference verb of annotation
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            rolespb = propbankAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']

            if frame_name_pb == 'win.01':
                verbs.add(verb)

            if verb == 'won':
              for role in roles:
                  print("role ",role)
                  span = role['span']
                  text = get_text_from_span(tokens_pre,span)
                  print(f"text -> {text}")
            


            # if (frame_name_pb in most_frequent_pbframe):
            #     most_frequent_pbframe[frame_name_pb] +=1
            # else:
            #     most_frequent_pbframe[frame_name_pb] = 0


        #     if (verb in most_frequent_verbs):
        #         most_frequent_verbs[verb] +=1
        #     else:
        #         most_frequent_verbs[verb] = 1

           

    # return info_elements
    return verbs
    return most_frequent_verbs,most_frequent_pbframe,verbs

verbs = extract_info(nli_dataset['train'])
# info_elements = extract_info(nli_dataset['train'])
# most_frequent_verbs,most_frequent_pbframe,verbs = extract_info(nli_dataset['train'])

# %%
print("win -> ",verbs)
# for elem in info_elements:
#     print(elem)
# print(info_elements)


# for elem in verbs:
#     print(elem)
# print(info_elements)
# Out:
# win ->  {'Winning', 'winning', 'Wins', 'won', 'Won', 'win', 'wins', 'Win', 'wining', 'ving'}

# %%
# Ordina il dizionario in base ai valori in ordine decrescente
most_frequent_pbframe_sorted = dict(sorted(most_frequent_pbframe.items(), key=lambda item: item[1], reverse=True))

# Stampa il dizionario ordinato
for chiave, valore in most_frequent_pbframe_sorted.items():
    print(f"{chiave}: {valore}")
# Out:
# be.01: 54298
# bear.02: 10215
# star.01: 7927
# know.01: 7891
# be.03: 7287
# direct.01: 6440
# include.01: 6279
# win.01: 6193
# have.01: 5611
# write.01: 5550
# release.01: 5171
# become.01: 3568
# receive.01: 3395
# produce.01: 3296
# appear.01: 2953
# have.03: 2527
# begin.01: 2455
# base.02: 2296
# play.02: 2014
# earn.01: 1864
# follow.01: 1740
# nominate.01: 1719
# create.01: 1672
# serve.01: 1596
# feature.01: 1525
# sell.01: 1380
# premiere.01: 1326
# found.01: 1198
# play.01: 1197
# work.01: 1141
# portray.01: 1138
# publish.01: 1069
# support.01: 1067
# make.02: 1063
# rank.01: 1047
# lead.01: 1020
# refer.01: 1002
# default.01: 0
# wedge.01: 0
# contradict.01: 0
# capitalize.02: 0
# pass.04: 0
# inhale.01: 0
# absorb.01: 0
# cure.01: 0
# interrupt.01: 0
# trip.01: 0
# conform.01: 0
# route.01: 0
# inflate.01: 0
# blow.04: 0
# outnumber.01: 0
# frustrate.01: 0
# swear.01: 0
# takeover.01: 0
# unload.01: 0
# shoot.06: 0
# penetrate.01: 0
# circumscribe.01: 0
# wreck.01: 0
# propagate.01: 0
# cater.01: 0
# exaggerate.01: 0
# carve.01: 0
# carve.02: 0
# outrage.01: 0
# band.01: 0
# tumble.01: 0
# look.07: 0
# reopen.01: 0
# analysis.01: 0
# deliberate.01: 0
# graze.01: 0
# crouch.01: 0
# subjugate.01: 0
# torment.01: 0
# clean.01: 0
# distribution.01: 0
# spew.01: 0
# brand.01: 0
# spare.01: 0
# tip.03: 0
# seal.01: 0
# hurry.01: 0
# recuperate.01: 0
# mature.01: 0
# intrigue.01: 0
# curtail.01: 0
# alienate.01: 0
# patent.01: 0
# pack.01: 0
# rob.01: 0
# burgeon.01: 0
# eclipse.01: 0
# indict.01: 0
# tailor.01: 0
# breach.01: 0
# knead.01: 0
# scoop.02: 0
# untie.01: 0
# blink.01: 0
# muse.01: 0
# bomb.01: 0
# tilt.01: 0
# charge.02: 0
# unfold.02: 0
# inflame.01: 0
# carry.02: 0
# disgust.01: 0
# startle.01: 0
# nurse.01: 0
# estrange.01: 0
# worry.02: 0
# cool.01: 0
# cook.01: 0
# vote.03: 0
# jump.01: 0
# stem.02: 0
# cry.03: 0
# mediate.01: 0

# %% [markdown]
# # Scheme to follow to extract info from srl

# %%
# print(type(nli_dataset["train"]))
# print(type(nli_dataset["train"][0]))
# print(nli_dataset["train"])

#TODO UNDERSTAND BEFORE GO AHEAD!
#THIS IS THE SCHEME THAT YOU HAVE TO FOLLOW TO IMPLEMENT THE VARIOUS IDEA THAT YOU HAVE.    

verbatlasFrame_pre = set()
probankFrame_pre = set()
verbatlasRoles_pre = set()
probankRoles_pre = set()


verbatlasFrame_hp = set()
probankFrame_hp = set()
verbatlasRoles_hp = set()
probankRoles_hp = set()


verbatlasLocations_pre = set()
probankLocations_pre = set()
verbatlasLocations_hp = set()
probankLocations_hp = set()

count = 0


# FOR EACH ELEMENT
for elem in nli_dataset["train"]:
    srl_hp = elem['srl']['hypothesis']
    srl_pre = elem['srl']['premise']

    tokens_pre = srl_pre['tokens']
    annotations_pre = srl_pre['annotations']    
    
    tokens_hp = srl_hp['tokens']
    annotations_hp = srl_hp['annotations']


    ## If you want to find a particular element
    # if elem['id'] == '15454': 
    #     count = 1
    #     print("trovato")
    #     trovato_tokens = tokens
    #     trovato_annotations = annotations

#EXTRACT INFO FROM PREMISE
    for annotation in annotations_hp:
        token_index = annotation['tokenIndex']
        verb = tokens_hp[token_index]['rawText']
        print(f"Verb: {verb}\n")

        print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame_hp.add(frame_name)
        print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'Location'):
                verbatlasLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()

        print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame_hp.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'ARGM-LOC'):
                probankLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()


## EXTRACT INFO FROM HYPOTHEIS
    for annotation in annotations_hp:
        token_index = annotation['tokenIndex']
        verb = tokens_hp[token_index]['rawText']
        print(f"Verb: {verb}\n")

        print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame_hp.add(frame_name)
        print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'Location'):
                verbatlasLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()

        print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame_hp.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles_hp.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens_hp, span)
            if (role == 'ARGM-LOC'):
                probankLocations_hp.add(text)
            print(f"  {role}: {text}")
        print()



    
    # if count==1:break
    # else:count+=1

    # break
# Out:
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Roman Atwood is
#   Attribute: a content creator .
#
# PropBank:
#   ARG1: Roman Atwood is
#   ARG2: a content creator .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Roman Atwood is
#   Attribute: a content creator .
#
# PropBank:
#   ARG1: Roman Atwood is
#   ARG2: a content creator .
#
# Verb: play
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Agent: The Boston Celtics play
#   Theme: their home games at
#   Location: at TD Garden .
#
# PropBank:
#   ARG0: The Boston Celtics play
#   ARG1: their home games at
#   ARGM-LOC: at TD Garden .
#
# Verb: play
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Agent: The Boston Celtics play
#   Theme: their home games at
#   Location: at TD Garden .
#
# PropBank:
#   ARG0: The Boston Celtics play
#   ARG1: their home games at
#   ARGM-LOC: at TD Garden .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a movie called The Hunger Games .
#
# PropBank:
#   ARG1: a movie called The Hunger Games .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a movie called
#   Attribute: The Hunger Games .
#
# PropBank:
#   ARG1: a movie called
#   ARG2: The Hunger Games .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a movie called The Hunger Games .
#
# PropBank:
#   ARG1: a movie called The Hunger Games .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a movie called
#   Attribute: The Hunger Games .
#
# PropBank:
#   ARG1: a movie called
#   ARG2: The Hunger Games .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Ryan Seacrest is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Ryan Seacrest is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Ryan Seacrest is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Ryan Seacrest is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Stranger than Fiction is
#   Attribute: a film .
#
# PropBank:
#   ARG1: Stranger than Fiction is
#   ARG2: a film .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Stranger than Fiction is
#   Attribute: a film .
#
# PropBank:
#   ARG1: Stranger than Fiction is
#   ARG2: a film .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: recorded
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Selena recorded
#   Theme: music .
#
# PropBank:
#   ARG0: Selena recorded
#   ARG1: music .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: John Wick : Chapter 2 was
#   Attribute: theatrically released
#   Location: in the Oregon .
#
# PropBank:
#   ARG1: John Wick : Chapter 2 was
#   ARGM-MNR: theatrically released
#   ARGM-LOC: in the Oregon .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: John Wick : Chapter 2 was
#   Attribute: theatrically released
#   Location: in the Oregon .
#
# PropBank:
#   ARG1: John Wick : Chapter 2 was
#   ARGM-MNR: theatrically released
#   ARGM-LOC: in the Oregon .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Afghanistan is
#   Attribute: the source of the Kushan dynasty .
#
# PropBank:
#   ARG1: Afghanistan is
#   ARG2: the source of the Kushan dynasty .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Afghanistan is
#   Attribute: the source of the Kushan dynasty .
#
# PropBank:
#   ARG1: Afghanistan is
#   ARG2: the source of the Kushan dynasty .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Tupac Shakur was
#   Location: Lesane Parish Crooks .
#
# PropBank:
#   ARG1: Tupac Shakur was
#   ARGM-LOC: Lesane Parish Crooks .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Tupac Shakur was
#   Location: Lesane Parish Crooks .
#
# PropBank:
#   ARG1: Tupac Shakur was
#   ARGM-LOC: Lesane Parish Crooks .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Whoopi Goldberg co
#   Attribute: co -
#   Product: an American dance tournament .
#
# PropBank:
#   ARG0: Whoopi Goldberg co
#   ARGM-MNR: co -
#   ARG1: an American dance tournament .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Whoopi Goldberg co
#   Attribute: co -
#   Product: an American dance tournament .
#
# PropBank:
#   ARG0: Whoopi Goldberg co
#   ARGM-MNR: co -
#   ARG1: an American dance tournament .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Grace Jones is
#   Attribute: a dancer .
#
# PropBank:
#   ARG1: Grace Jones is
#   ARG2: a dancer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Grace Jones is
#   Attribute: a dancer .
#
# PropBank:
#   ARG1: Grace Jones is
#   ARG2: a dancer .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Lisbon has
#   Attribute: a population larger than 1 .
#
# PropBank:
#   ARG0: Lisbon has
#   ARG1: a population larger than 1 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Lisbon has
#   Attribute: a population larger than 1 .
#
# PropBank:
#   ARG0: Lisbon has
#   ARG1: a population larger than 1 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Newfoundland and Labrador is
#   Attribute: the most linguistically homogeneous of Canada .
#
# PropBank:
#   ARG1: Newfoundland and Labrador is
#   ARG2: the most linguistically homogeneous of Canada .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Newfoundland and Labrador is
#   Attribute: the most linguistically homogeneous of Canada .
#
# PropBank:
#   ARG1: Newfoundland and Labrador is
#   ARG2: the most linguistically homogeneous of Canada .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Sophie Turner was
#   Time: in the 1990s .
#
# PropBank:
#   ARG1: Sophie Turner was
#   ARGM-TMP: in the 1990s .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Sophie Turner was
#   Time: in the 1990s .
#
# PropBank:
#   ARG1: Sophie Turner was
#   ARGM-TMP: in the 1990s .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: The Smurfs ( film ) was
#
# PropBank:
#   ARG1: The Smurfs ( film ) was
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: The Smurfs ( film ) was
#
# PropBank:
#   ARG1: The Smurfs ( film ) was
#
# Verb: led
#
# VerbAtlas:
#  Frame: MOVE-SOMETHING
#   Agent: Jimmy Carter led
#   Theme: the international boycott of the 2010 Olympics .
#
# PropBank:
#   ARG0: Jimmy Carter led
#   ARG1: the international boycott of the 2010 Olympics .
#
# Verb: led
#
# VerbAtlas:
#  Frame: MOVE-SOMETHING
#   Agent: Jimmy Carter led
#   Theme: the international boycott of the 2010 Olympics .
#
# PropBank:
#   ARG0: Jimmy Carter led
#   ARG1: the international boycott of the 2010 Olympics .
#
# Verb: came
#
# VerbAtlas:
#  Frame: HAPPEN_OCCUR
#   Theme: Hacksaw Ridge came
#   Location: in America on
#   Time: on November 4 , 2016 .
#
# PropBank:
#   ARG1: Hacksaw Ridge came
#   ARGM-LOC: in America on
#   ARGM-TMP: on November 4 , 2016 .
#
# Verb: came
#
# VerbAtlas:
#  Frame: HAPPEN_OCCUR
#   Theme: Hacksaw Ridge came
#   Location: in America on
#   Time: on November 4 , 2016 .
#
# PropBank:
#   ARG1: Hacksaw Ridge came
#   ARGM-LOC: in America on
#   ARGM-TMP: on November 4 , 2016 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Michael Fassbender is
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Michael Fassbender is
#   ARG2: an actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Uzbekistan is
#   Attribute: a part of the Commonwealth of Independent States ( CIS ) .
#
# PropBank:
#   ARG1: Uzbekistan is
#   ARG2: a part of the Commonwealth of Independent States ( CIS ) .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Uzbekistan is
#   Attribute: a part of the Commonwealth of Independent States ( CIS ) .
#
# PropBank:
#   ARG1: Uzbekistan is
#   ARG2: a part of the Commonwealth of Independent States ( CIS ) .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Paul Wesley is
#   Attribute: a professional alias .
#
# PropBank:
#   ARG1: Paul Wesley is
#   ARG2: a professional alias .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Paul Wesley is
#   Attribute: a professional alias .
#
# PropBank:
#   ARG1: Paul Wesley is
#   ARG2: a professional alias .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Negation: not a
#   Attribute: a singer .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARGM-NEG: not a
#   ARG2: a singer .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Brian Wilson was
#   Attribute: part of the Beach Boys .
#
# PropBank:
#   ARG1: Brian Wilson was
#   ARG2: part of the Beach Boys .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Brian Wilson was
#   Attribute: part of the Beach Boys .
#
# PropBank:
#   ARG1: Brian Wilson was
#   ARG2: part of the Beach Boys .
#
# Verb: argued
#
# VerbAtlas:
#  Frame: SPEAK
#   Topic: The Existence of God has
#   Attribute: through the Five Ways .
#
# PropBank:
#   ARG1: The Existence of God has
#   ARGM-MNR: through the Five Ways .
#
# Verb: argued
#
# VerbAtlas:
#  Frame: SPEAK
#   Topic: The Existence of God has
#   Attribute: through the Five Ways .
#
# PropBank:
#   ARG1: The Existence of God has
#   ARGM-MNR: through the Five Ways .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Led Zeppelin is
#   Attribute: a band .
#
# PropBank:
#   ARG1: Led Zeppelin is
#   ARG2: a band .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Richard Harris was
#   Time: on October 25 , 2002 .
#
# PropBank:
#   ARG1: Richard Harris was
#   ARGM-TMP: on October 25 , 2002 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Richard Harris was
#   Time: on October 25 , 2002 .
#
# PropBank:
#   ARG1: Richard Harris was
#   ARGM-TMP: on October 25 , 2002 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Fosters is
#   Attribute: a television series .
#
# PropBank:
#   ARG1: The Fosters is
#   ARG2: a television series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Fosters is
#   Attribute: a television series .
#
# PropBank:
#   ARG1: The Fosters is
#   ARG2: a television series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Filmfare is
#   Attribute: about cheese .
#
# PropBank:
#   ARG1: Filmfare is
#   ARG2: about cheese .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Filmfare is
#   Attribute: about cheese .
#
# PropBank:
#   ARG1: Filmfare is
#   ARG2: about cheese .
#
# Verb: lacks
#
# VerbAtlas:
#  Frame: MISS_OMIT_LACK
#   Agent: Buckingham Palace lacks
#   Theme: brightly colored scagliola .
#
# PropBank:
#   ARG0: Buckingham Palace lacks
#   ARG1: brightly colored scagliola .
#
# Verb: colored
#
# VerbAtlas:
#  Frame: COLOR
#   Attribute: brightly colored
#   Patient: scagliola .
#
# PropBank:
#   ARGM-MNR: brightly colored
#   ARG1: scagliola .
#
# Verb: lacks
#
# VerbAtlas:
#  Frame: MISS_OMIT_LACK
#   Agent: Buckingham Palace lacks
#   Theme: brightly colored scagliola .
#
# PropBank:
#   ARG0: Buckingham Palace lacks
#   ARG1: brightly colored scagliola .
#
# Verb: colored
#
# VerbAtlas:
#  Frame: COLOR
#   Attribute: brightly colored
#   Patient: scagliola .
#
# PropBank:
#   ARGM-MNR: brightly colored
#   ARG1: scagliola .
#
# Verb: valued
#
# VerbAtlas:
#  Frame: CALCULATE_ESTIMATE
#   Theme: Liverpool F.C. was
#   Time: at one point .
#
# PropBank:
#   ARG1: Liverpool F.C. was
#   ARG2: at $ 1.55 billion at
#   ARGM-TMP: at one point .
#
# Verb: valued
#
# VerbAtlas:
#  Frame: CALCULATE_ESTIMATE
#   Theme: Liverpool F.C. was
#   Time: at one point .
#
# PropBank:
#   ARG1: Liverpool F.C. was
#   ARG2: at $ 1.55 billion at
#   ARGM-TMP: at one point .
#
# Verb: makes
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Land Rover makes
#   Product: cars .
#
# PropBank:
#   ARG0: Land Rover makes
#   ARG1: cars .
#
# Verb: makes
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: Land Rover makes
#   Product: cars .
#
# PropBank:
#   ARG0: Land Rover makes
#   ARG1: cars .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Agent: Martin Scorsese worked
#   Theme: on commission .
#
# PropBank:
#   ARG0: Martin Scorsese worked
#   ARG1: on commission .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Agent: Martin Scorsese worked
#   Theme: on commission .
#
# PropBank:
#   ARG0: Martin Scorsese worked
#   ARG1: on commission .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: On the Road ( film ) premiered
#   Location: at a film festival .
#
# PropBank:
#   ARG1: On the Road ( film ) premiered
#   ARGM-LOC: at a film festival .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Peter Davison has
#   Attribute: in a BBC show .
#
# PropBank:
#   ARG1: Peter Davison has
#   ARG2: in a BBC show .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Peter Davison has
#   Attribute: in a BBC show .
#
# PropBank:
#   ARG1: Peter Davison has
#   ARG2: in a BBC show .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: 21 Jump Street was
#   Time: June 16 , 2012 .
#
# PropBank:
#   ARG1: 21 Jump Street was
#   ARGM-TMP: June 16 , 2012 .
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Patient: 21 Jump Street was
#   Time: June 16 , 2012 .
#
# PropBank:
#   ARG1: 21 Jump Street was
#   ARGM-TMP: June 16 , 2012 .
#
# Verb: featured
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Attribute: T. J. Miller was
#   Cause: in Deadpool 2 .
#
# PropBank:
#   ARG1: T. J. Miller was
#   ARG2: in Deadpool 2 .
#
# Verb: featured
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Attribute: T. J. Miller was
#   Cause: in Deadpool 2 .
#
# PropBank:
#   ARG1: T. J. Miller was
#   ARG2: in Deadpool 2 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Chris Terrio was
#   Location: in Kansas .
#
# PropBank:
#   ARG1: Chris Terrio was
#   ARGM-LOC: in Kansas .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Chris Terrio was
#   Location: in Kansas .
#
# PropBank:
#   ARG1: Chris Terrio was
#   ARGM-LOC: in Kansas .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: named
#
# VerbAtlas:
#  Frame: NAME
#   Theme: Mariah Carey was
#   Time: on the 27th .
#
# PropBank:
#   ARG1: Mariah Carey was
#   ARGM-TMP: on the 27th .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: named
#
# VerbAtlas:
#  Frame: NAME
#   Theme: Mariah Carey was
#   Time: on the 27th .
#
# PropBank:
#   ARG1: Mariah Carey was
#   ARGM-TMP: on the 27th .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Giancarlo Stanton was
#   Attribute: in the 2017 MLB draft .
#
# PropBank:
#   ARG1: Giancarlo Stanton was
#   ARG2: in the 2017 MLB draft .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Giancarlo Stanton was
#   Attribute: in the 2017 MLB draft .
#
# PropBank:
#   ARG1: Giancarlo Stanton was
#   ARG2: in the 2017 MLB draft .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Sean Connery never
#   Negation: never won
#   Patient: an Academy Award .
#
# PropBank:
#   ARG0: Sean Connery never
#   ARGM-NEG: never won
#   ARG1: an Academy Award .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Sean Connery never
#   Negation: never won
#   Patient: an Academy Award .
#
# PropBank:
#   ARG0: Sean Connery never
#   ARGM-NEG: never won
#   ARG1: an Academy Award .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Overwatch is
#   Attribute: a video game in which players gain cosmetic awards and
#
# PropBank:
#   ARG1: Overwatch is
#   ARG2: a video game in which players gain cosmetic awards and
#
# Verb: gain
#
# VerbAtlas:
#  Frame: OBTAIN
#   Location: a video game in
#   Agent: players gain
#   Theme: cosmetic awards and
#
# PropBank:
#   ARGM-LOC: a video game in
#   R-ARGM-LOC: in which players
#   ARG0: players gain
#   ARG1: cosmetic awards and
#
# Verb: assigns
#
# VerbAtlas:
#  Frame: ASCRIBE
#   Agent: it assigns
#   Attribute: players into
#   Theme: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG0: it assigns
#   ARG1: players into
#   ARG2: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: a style of play known
#   Topic: as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG1: a style of play known
#   ARG2: as Offense , Defense , Tank , and Support .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Overwatch is
#   Attribute: a video game in which players gain cosmetic awards and
#
# PropBank:
#   ARG1: Overwatch is
#   ARG2: a video game in which players gain cosmetic awards and
#
# Verb: gain
#
# VerbAtlas:
#  Frame: OBTAIN
#   Location: a video game in
#   Agent: players gain
#   Theme: cosmetic awards and
#
# PropBank:
#   ARGM-LOC: a video game in
#   R-ARGM-LOC: in which players
#   ARG0: players gain
#   ARG1: cosmetic awards and
#
# Verb: assigns
#
# VerbAtlas:
#  Frame: ASCRIBE
#   Agent: it assigns
#   Attribute: players into
#   Theme: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG0: it assigns
#   ARG1: players into
#   ARG2: into two teams of six , each player with a style of play known as Offense , Defense , Tank , and Support .
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: a style of play known
#   Topic: as Offense , Defense , Tank , and Support .
#
# PropBank:
#   ARG1: a style of play known
#   ARG2: as Offense , Defense , Tank , and Support .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Lily James has
#   Attribute: on TV .
#
# PropBank:
#   ARG1: Lily James has
#   ARG2: on TV .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: International Relations only
#   Adverbial: only includes
#   Patient: the entertainment industry .
#
# PropBank:
#   ARG2: International Relations only
#   ARGM-ADV: only includes
#   ARG1: the entertainment industry .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Régine Chassagne is
#   Attribute: Canadian .
#
# PropBank:
#   ARG1: Régine Chassagne is
#   ARG2: Canadian .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Régine Chassagne is
#   Attribute: Canadian .
#
# PropBank:
#   ARG1: Régine Chassagne is
#   ARG2: Canadian .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: works
#
# VerbAtlas:
#  Frame: WORK
#   Agent: John McCain works
#   Theme: in politics .
#
# PropBank:
#   ARG0: John McCain works
#   ARG1: in politics .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Planet of the Apes ( 1968 film ) had
#   Attribute: a script that underwent rewrites .
#
# PropBank:
#   ARG0: Planet of the Apes ( 1968 film ) had
#   ARG1: a script that underwent rewrites .
#
# Verb: underwent
#
# VerbAtlas:
#  Frame: UNDERGO-EXPERIENCE
#   Experiencer: a script that
#   Stimulus: rewrites .
#
# PropBank:
#   ARG1: a script that
#   R-ARG1: that underwent
#   ARG2: rewrites .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Planet of the Apes ( 1968 film ) had
#   Attribute: a script that underwent rewrites .
#
# PropBank:
#   ARG0: Planet of the Apes ( 1968 film ) had
#   ARG1: a script that underwent rewrites .
#
# Verb: underwent
#
# VerbAtlas:
#  Frame: UNDERGO-EXPERIENCE
#   Experiencer: a script that
#   Stimulus: rewrites .
#
# PropBank:
#   ARG1: a script that
#   R-ARG1: that underwent
#   ARG2: rewrites .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Star vs . the Forces of Evil is
#   Attribute: a series .
#
# PropBank:
#   ARG1: Star vs . the Forces of Evil is
#   ARG2: a series .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Paul Walker acted
#   Location: in movies .
#
# PropBank:
#   ARG0: Paul Walker acted
#   ARGM-LOC: in movies .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Paul Walker acted
#   Location: in movies .
#
# PropBank:
#   ARG0: Paul Walker acted
#   ARGM-LOC: in movies .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Gilmore Girls is
#   Attribute: a Canadian show .
#
# PropBank:
#   ARG1: Gilmore Girls is
#   ARG2: a Canadian show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Gilmore Girls is
#   Attribute: a Canadian show .
#
# PropBank:
#   ARG1: Gilmore Girls is
#   ARG2: a Canadian show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: San Francisco is
#   Attribute: in California .
#
# PropBank:
#   ARG1: San Francisco is
#   ARG2: in California .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: San Francisco is
#   Attribute: in California .
#
# PropBank:
#   ARG1: San Francisco is
#   ARG2: in California .
#
# Verb: received
#
# VerbAtlas:
#  Frame: RECEIVE
#   Agent: George W. Bush received
#   Theme: one of the lowest approval ratings - just 20 % approval - during
#   Time: during the 2008 financial crisis .
#
# PropBank:
#   ARG0: George W. Bush received
#   ARG1: one of the lowest approval ratings - just 20 % approval - during
#   ARGM-TMP: during the 2008 financial crisis .
#
# Verb: received
#
# VerbAtlas:
#  Frame: RECEIVE
#   Agent: George W. Bush received
#   Theme: one of the lowest approval ratings - just 20 % approval - during
#   Time: during the 2008 financial crisis .
#
# PropBank:
#   ARG0: George W. Bush received
#   ARG1: one of the lowest approval ratings - just 20 % approval - during
#   ARGM-TMP: during the 2008 financial crisis .
#
# Verb: wrote
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Lily Collins wrote
#   Recipient: for a U.S magazine that targets teen girls .
#
# PropBank:
#   ARG0: Lily Collins wrote
#   ARG2: for a U.S magazine that targets teen girls .
#
# Verb: targets
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: a U.S magazine that
#   Destination: teen girls .
#
# PropBank:
#   ARG0: a U.S magazine that
#   R-ARG0: that targets
#   ARG1: teen girls .
#
# Verb: wrote
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Lily Collins wrote
#   Recipient: for a U.S magazine that targets teen girls .
#
# PropBank:
#   ARG0: Lily Collins wrote
#   ARG2: for a U.S magazine that targets teen girls .
#
# Verb: targets
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: a U.S magazine that
#   Destination: teen girls .
#
# PropBank:
#   ARG0: a U.S magazine that
#   R-ARG0: that targets
#   ARG1: teen girls .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Naturi Naughton was
#   Time: in the year of 1984 .
#
# PropBank:
#   ARG1: Naturi Naughton was
#   ARGM-TMP: in the year of 1984 .
#
# Verb: born
#
# VerbAtlas:
#  Frame: GIVE-BIRTH
#   Patient: Naturi Naughton was
#   Time: in the year of 1984 .
#
# PropBank:
#   ARG1: Naturi Naughton was
#   ARGM-TMP: in the year of 1984 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Generation X has
#   Attribute: no precise date for its cohort .
#
# PropBank:
#   ARG0: Generation X has
#   ARG1: no precise date for its cohort .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Generation X has
#   Attribute: no precise date for its cohort .
#
# PropBank:
#   ARG0: Generation X has
#   ARG1: no precise date for its cohort .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Agent: Jackie Chan has
#   Patient: an album .
#
# PropBank:
#   ARG0: Jackie Chan has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: released
#
# VerbAtlas:
#  Frame: LIBERATE_ALLOW_AFFORD
#   Agent: Jackie Chan has
#   Patient: an album .
#
# PropBank:
#   ARG0: Jackie Chan has
#   ARG1: an album .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: possesses
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Canada possesses
#   Attribute: a constitution .
#
# PropBank:
#   ARG0: Canada possesses
#   ARG1: a constitution .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: The Renaissance is
#   Topic: for its cultural developments .
#
# PropBank:
#   ARG1: The Renaissance is
#   ARG2: for its cultural developments .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: known
#
# VerbAtlas:
#  Frame: KNOW
#   Theme: The Renaissance is
#   Topic: for its cultural developments .
#
# PropBank:
#   ARG1: The Renaissance is
#   ARG2: for its cultural developments .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Pluto is
#   Negation: not relatively
#   Attribute: relatively small .
#
# PropBank:
#   ARG1: Pluto is
#   ARGM-NEG: not relatively
#   ARG2: relatively small .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Pluto is
#   Negation: not relatively
#   Attribute: relatively small .
#
# PropBank:
#   ARG1: Pluto is
#   ARGM-NEG: not relatively
#   ARG2: relatively small .
#
# Verb: lost
#
# VerbAtlas:
#  Frame: LOSE
#   Agent: William Shatner lost
#   Theme: two Emmy Awards .
#
# PropBank:
#   ARG0: William Shatner lost
#   ARG1: two Emmy Awards .
#
# Verb: lost
#
# VerbAtlas:
#  Frame: LOSE
#   Agent: William Shatner lost
#   Theme: two Emmy Awards .
#
# PropBank:
#   ARG0: William Shatner lost
#   ARG1: two Emmy Awards .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Amanda Show was
#   Attribute: the first female - created show on Nickelodeon .
#
# PropBank:
#   ARG1: The Amanda Show was
#   ARG2: the first female - created show on Nickelodeon .
#
# Verb: created
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: female -
#   Product: show on
#
# PropBank:
#   ARG0: female -
#   ARG1: show on
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Amanda Show was
#   Attribute: the first female - created show on Nickelodeon .
#
# PropBank:
#   ARG1: The Amanda Show was
#   ARG2: the first female - created show on Nickelodeon .
#
# Verb: created
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Agent: female -
#   Product: show on
#
# PropBank:
#   ARG0: female -
#   ARG1: show on
#
# Verb: included
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The 19th G7 summit only
#   Adverbial: only included
#   Patient: Russia .
#
# PropBank:
#   ARG2: The 19th G7 summit only
#   ARGM-ADV: only included
#   ARG1: Russia .
#
# Verb: included
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The 19th G7 summit only
#   Adverbial: only included
#   Patient: Russia .
#
# PropBank:
#   ARG2: The 19th G7 summit only
#   ARGM-ADV: only included
#   ARG1: Russia .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Edward Norton has
#   Attribute: co -
#   Recipient: for TV shows .
#
# PropBank:
#   ARG0: Edward Norton has
#   ARGM-MNR: co -
#   ARG2: for TV shows .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Agent: Edward Norton has
#   Attribute: co -
#   Recipient: for TV shows .
#
# PropBank:
#   ARG0: Edward Norton has
#   ARGM-MNR: co -
#   ARG2: for TV shows .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ethiopia has
#   Attribute: bodies of water can be described as rivers .
#
# PropBank:
#   ARG0: Ethiopia has
#   ARG1: bodies of water can be described as rivers .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: described
#
# VerbAtlas:
#  Frame: REPRESENT
#   Theme: bodies of water can
#   Modal: can be
#   Attribute: as rivers .
#
# PropBank:
#   ARG1: bodies of water can
#   ARGM-MOD: can be
#   ARG2: as rivers .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ethiopia has
#   Attribute: bodies of water can be described as rivers .
#
# PropBank:
#   ARG0: Ethiopia has
#   ARG1: bodies of water can be described as rivers .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: described
#
# VerbAtlas:
#  Frame: REPRESENT
#   Theme: bodies of water can
#   Modal: can be
#   Attribute: as rivers .
#
# PropBank:
#   ARG1: bodies of water can
#   ARGM-MOD: can be
#   ARG2: as rivers .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Eminem has
#   Attribute: an album .
#
# PropBank:
#   ARG0: Eminem has
#   ARG1: an album .
#
# Verb: lined
#
# VerbAtlas:
#  Frame: LIE
#   Location: The Connaught Tunnel was
#   Theme: only with mud and sand .
#
# PropBank:
#   ARG1: The Connaught Tunnel was
#   ARG2: only with mud and sand .
#
# Verb: lined
#
# VerbAtlas:
#  Frame: LIE
#   Location: The Connaught Tunnel was
#   Theme: only with mud and sand .
#
# PropBank:
#   ARG1: The Connaught Tunnel was
#   ARG2: only with mud and sand .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Thor : The Dark World is
#   Attribute: a movie .
#
# PropBank:
#   ARG1: Thor : The Dark World is
#   ARG2: a movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Loki is
#   Attribute: the male sibling of Helblindi and Byleistr .
#
# PropBank:
#   ARG1: Loki is
#   ARG2: the male sibling of Helblindi and Byleistr .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Loki is
#   Attribute: the male sibling of Helblindi and Byleistr .
#
# PropBank:
#   ARG1: Loki is
#   ARG2: the male sibling of Helblindi and Byleistr .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Chester Bennington is
#   Attribute: a person .
#
# PropBank:
#   ARG1: Chester Bennington is
#   ARG2: a person .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tender Mercies is
#   Attribute: a drama from America .
#
# PropBank:
#   ARG1: Tender Mercies is
#   ARG2: a drama from America .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tender Mercies is
#   Attribute: a drama from America .
#
# PropBank:
#   ARG1: Tender Mercies is
#   ARG2: a drama from America .
#
# Verb: starred
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Baby Driver starred
#   Agent: Eiza González .
#
# PropBank:
#   ARG2: Baby Driver starred
#   ARG1: Eiza González .
#
# Verb: starred
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Baby Driver starred
#   Agent: Eiza González .
#
# PropBank:
#   ARG2: Baby Driver starred
#   ARG1: Eiza González .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: David Dhawan is
#   Attribute: a film director .
#
# PropBank:
#   ARG1: David Dhawan is
#   ARG2: a film director .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: David Dhawan is
#   Attribute: a film director .
#
# PropBank:
#   ARG1: David Dhawan is
#   ARG2: a film director .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The Challenge was
#   Attribute: a reality game show .
#
# PropBank:
#   ARG1: The Challenge was
#   ARG2: a reality game show .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: One type of spread is
#   Attribute: Vegemite .
#
# PropBank:
#   ARG1: One type of spread is
#   ARG2: Vegemite .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: One type of spread is
#   Attribute: Vegemite .
#
# PropBank:
#   ARG1: One type of spread is
#   ARG2: Vegemite .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Theme: on by
#   Agent: by Octavia Spencer .
#
# PropBank:
#   ARG1: on by
#   ARG0: by Octavia Spencer .
#
# Verb: worked
#
# VerbAtlas:
#  Frame: WORK
#   Theme: on by
#   Agent: by Octavia Spencer .
#
# PropBank:
#   ARG1: on by
#   ARG0: by Octavia Spencer .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: Ramayanam was
#   Agent: by M. S. Reddy and
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by M. S. Reddy and
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Ramayanam was
#   Agent: by Gunasekhar .
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by Gunasekhar .
#
# Verb: produced
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: Ramayanam was
#   Agent: by M. S. Reddy and
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by M. S. Reddy and
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Ramayanam was
#   Agent: by Gunasekhar .
#
# PropBank:
#   ARG1: Ramayanam was
#   ARG0: by Gunasekhar .
#
# Verb: features
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Man of Steel features
#   Attribute: the DC Comics character Superman .
#
# PropBank:
#   ARG0: Man of Steel features
#   ARG1: the DC Comics character Superman .
#
# Verb: features
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Man of Steel features
#   Attribute: the DC Comics character Superman .
#
# PropBank:
#   ARG0: Man of Steel features
#   ARG1: the DC Comics character Superman .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The Hangover Part III includes
#   Patient: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# PropBank:
#   ARG2: The Hangover Part III includes
#   ARG1: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# Verb: includes
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: The Hangover Part III includes
#   Patient: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# PropBank:
#   ARG2: The Hangover Part III includes
#   ARG1: Bradley Cooper , Ed Helms , Zach Galifianakis , Justin Bartha , and Ken Jeong , Jeffrey Tambor , Heather Graham , Mike Epps , Melissa McCarthy and John Goodman .
#
# Verb: committed
#
# VerbAtlas:
#  Frame: VIOLATE
#   Agent: Ted Bundy committed
#   Theme: assaults in
#   Time: in the seventies .
#
# PropBank:
#   ARG0: Ted Bundy committed
#   ARG1: assaults in
#   ARGM-TMP: in the seventies .
#
# Verb: committed
#
# VerbAtlas:
#  Frame: VIOLATE
#   Agent: Ted Bundy committed
#   Theme: assaults in
#   Time: in the seventies .
#
# PropBank:
#   ARG0: Ted Bundy committed
#   ARG1: assaults in
#   ARGM-TMP: in the seventies .
#
# Verb: associated
#
# VerbAtlas:
#  Frame: CORRELATE
#   Theme: Chinese people only
#   Adverbial: only can
#   Modal: can be
#   Co-Theme: with Spain through
#   Attribute: through nationality .
#
# PropBank:
#   ARG1: Chinese people only
#   ARGM-ADV: only can
#   ARGM-MOD: can be
#   ARG2: with Spain through
#   ARGM-MNR: through nationality .
#
# Verb: associated
#
# VerbAtlas:
#  Frame: CORRELATE
#   Theme: Chinese people only
#   Adverbial: only can
#   Modal: can be
#   Co-Theme: with Spain through
#   Attribute: through nationality .
#
# PropBank:
#   ARG1: Chinese people only
#   ARGM-ADV: only can
#   ARGM-MOD: can be
#   ARG2: with Spain through
#   ARGM-MNR: through nationality .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Zeus is
#   Attribute: an angel .
#
# PropBank:
#   ARG1: Zeus is
#   ARG2: an angel .
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: Quentin Tarantino directed
#   Theme: a creative work .
#
# PropBank:
#   ARG0: Quentin Tarantino directed
#   ARG1: a creative work .
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Agent: Quentin Tarantino directed
#   Theme: a creative work .
#
# PropBank:
#   ARG0: Quentin Tarantino directed
#   ARG1: a creative work .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Charlize Theron acted
#   Location: in The Burning Plain .
#
# PropBank:
#   ARG0: Charlize Theron acted
#   ARGM-LOC: in The Burning Plain .
#
# Verb: Burning
#
# VerbAtlas:
#  Frame: BURN
#   Patient: Plain .
#
# PropBank:
#   ARG1: Plain .
#
# Verb: acted
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Charlize Theron acted
#   Location: in The Burning Plain .
#
# PropBank:
#   ARG0: Charlize Theron acted
#   ARGM-LOC: in The Burning Plain .
#
# Verb: Burning
#
# VerbAtlas:
#  Frame: BURN
#   Patient: Plain .
#
# PropBank:
#   ARG1: Plain .
#
# Verb: honors
#
# VerbAtlas:
#  Frame: APPROVE_PRAISE
#   Agent: Edgar Award honors
#   Theme: the best in television dramas .
#
# PropBank:
#   ARG0: Edgar Award honors
#   ARG1: the best in television dramas .
#
# Verb: honors
#
# VerbAtlas:
#  Frame: APPROVE_PRAISE
#   Agent: Edgar Award honors
#   Theme: the best in television dramas .
#
# PropBank:
#   ARG0: Edgar Award honors
#   ARG1: the best in television dramas .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Bermuda is
#   Attribute: an associate member of the Red Sox .
#
# PropBank:
#   ARG1: Bermuda is
#   ARG2: an associate member of the Red Sox .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Bermuda is
#   Attribute: an associate member of the Red Sox .
#
# PropBank:
#   ARG1: Bermuda is
#   ARG2: an associate member of the Red Sox .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: competed
#
# VerbAtlas:
#  Frame: COMPETE
#   Agent: Usain Bolt has
#   Location: in a sprint race in
#   Location: in track and field in
#   Location: in world competitions .
#
# PropBank:
#   ARG0: Usain Bolt has
#   ARGM-LOC: in a sprint race in
#   ARGM-LOC: in track and field in
#   ARGM-LOC: in world competitions .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: competed
#
# VerbAtlas:
#  Frame: COMPETE
#   Agent: Usain Bolt has
#   Location: in a sprint race in
#   Location: in track and field in
#   Location: in world competitions .
#
# PropBank:
#   ARG0: Usain Bolt has
#   ARGM-LOC: in a sprint race in
#   ARGM-LOC: in track and field in
#   ARGM-LOC: in world competitions .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The main successor to the internet was
#   Attribute: the ARPANET .
#
# PropBank:
#   ARG1: The main successor to the internet was
#   ARG2: the ARPANET .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: The main successor to the internet was
#   Attribute: the ARPANET .
#
# PropBank:
#   ARG1: The main successor to the internet was
#   ARG2: the ARPANET .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Sarrainodu is
#   Attribute: an action movie .
#
# PropBank:
#   ARG1: Sarrainodu is
#   ARG2: an action movie .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Sarrainodu is
#   Attribute: an action movie .
#
# PropBank:
#   ARG1: Sarrainodu is
#   ARG2: an action movie .
#
# Verb: owned
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: Kingdom Hearts III is
#   Agent: by Boyz II Men
#
# PropBank:
#   ARG1: Kingdom Hearts III is
#   ARG0: by Boyz II Men
#
# Verb: owned
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: Kingdom Hearts III is
#   Agent: by Boyz II Men
#
# PropBank:
#   ARG1: Kingdom Hearts III is
#   ARG0: by Boyz II Men
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Keanu Reeves is
#   Attribute: a film actor .
#
# PropBank:
#   ARG1: Keanu Reeves is
#   ARG2: a film actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Keanu Reeves is
#   Attribute: a film actor .
#
# PropBank:
#   ARG1: Keanu Reeves is
#   ARG2: a film actor .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Heartland is
#   Attribute: a canadian TV series .
#
# PropBank:
#   ARG1: Heartland is
#   ARG2: a canadian TV series .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Heartland is
#   Attribute: a canadian TV series .
#
# PropBank:
#   ARG1: Heartland is
#   ARG2: a canadian TV series .
#
# Verb: are
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: two major contemporary political parties ,
#
# PropBank:
#   ARG1: two major contemporary political parties ,
#
# Verb: belongs
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: William Jennings Bryan belongs
#   Agent: to one of them .
#
# PropBank:
#   ARG0: William Jennings Bryan belongs
#   ARG1: to one of them .
#
# Verb: are
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: two major contemporary political parties ,
#
# PropBank:
#   ARG1: two major contemporary political parties ,
#
# Verb: belongs
#
# VerbAtlas:
#  Frame: POSSESS
#   Theme: William Jennings Bryan belongs
#   Agent: to one of them .
#
# PropBank:
#   ARG0: William Jennings Bryan belongs
#   ARG1: to one of them .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Robert Richardson has
#   Co-Agent: with director John Sayles .
#
# PropBank:
#   ARG0: Robert Richardson has
#   ARG1: with director John Sayles .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Robert Richardson has
#   Co-Agent: with director John Sayles .
#
# PropBank:
#   ARG0: Robert Richardson has
#   ARG1: with director John Sayles .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Leslie Howard was
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Leslie Howard was
#   ARG2: an actor .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Leslie Howard was
#   Attribute: an actor .
#
# PropBank:
#   ARG1: Leslie Howard was
#   ARG2: an actor .
#
# Verb: Catching
#
# VerbAtlas:
#  Frame: CATCH
#   Experiencer: Fire is
#
# PropBank:
#   ARG0: Fire is
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Result: Catching Fire is
#
# PropBank:
#   ARG1: Catching Fire is
#
# Verb: Catching
#
# VerbAtlas:
#  Frame: CATCH
#   Experiencer: Fire is
#
# PropBank:
#   ARG0: Fire is
#
# Verb: written
#
# VerbAtlas:
#  Frame: WRITE
#   Result: Catching Fire is
#
# PropBank:
#   ARG1: Catching Fire is
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
#   Agent: Ruth Negga only
#   Adverbial: only acts
#   Location: in Irish cinema .
#
# PropBank:
#   ARG0: Ruth Negga only
#   ARGM-ADV: only acts
#   ARGM-LOC: in Irish cinema .
#
# Verb: acts
#
# VerbAtlas:
#  Frame: BEHAVE
# ...
#
# PropBank:
#   ARG1: Vito Corleone is
#   ARG2: a fictional mountain .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Vito Corleone is
#   Attribute: a fictional mountain .
#
# PropBank:
#   ARG1: Vito Corleone is
#   ARG2: a fictional mountain .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Jaime Lannister is
#   Negation: not a
#   Attribute: a knight .
#
# PropBank:
#   ARG1: Jaime Lannister is
#   ARGM-NEG: not a
#   ARG2: a knight .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Jaime Lannister is
#   Negation: not a
#   Attribute: a knight .
#
# PropBank:
#   ARG1: Jaime Lannister is
#   ARGM-NEG: not a
#   ARG2: a knight .
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: have
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: collaborated
#
# VerbAtlas:
#  Frame: ALLY_ASSOCIATE_MARRY
#   Agent: Future and a Canadian singer have
#
# PropBank:
#   ARG0: Future and a Canadian singer have
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Philadelphia is
#   Attribute: a center of illegal activity .
#
# PropBank:
#   ARG1: Philadelphia is
#   ARG2: a center of illegal activity .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Philadelphia is
#   Attribute: a center of illegal activity .
#
# PropBank:
#   ARG1: Philadelphia is
#   ARG2: a center of illegal activity .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Nick Jonas is
#   Attribute: a recording artist .
#
# PropBank:
#   ARG1: Nick Jonas is
#   ARG2: a recording artist .
#
# Verb: shot
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Lee Harvey Oswald shot
#   Theme: mailboxes in
#   Location: in Dallas .
#
# PropBank:
#   ARG0: Lee Harvey Oswald shot
#   ARG1: mailboxes in
#   ARGM-LOC: in Dallas .
#
# Verb: shot
#
# VerbAtlas:
#  Frame: RECORD
#   Agent: Lee Harvey Oswald shot
#   Theme: mailboxes in
#   Location: in Dallas .
#
# PropBank:
#   ARG0: Lee Harvey Oswald shot
#   ARG1: mailboxes in
#   ARGM-LOC: in Dallas .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: cast
#
# VerbAtlas:
#  Frame: THROW
#   Theme: Seth Rogen was
#
# PropBank:
#   ARG1: Seth Rogen was
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: cast
#
# VerbAtlas:
#  Frame: THROW
#   Theme: Seth Rogen was
#
# PropBank:
#   ARG1: Seth Rogen was
#
# Verb: started
#
# VerbAtlas:
#  Frame: BEGIN
#   Agent: Pacific Rim started
#   Theme: production July
#   Time: July 12 , 2013 .
#
# PropBank:
#   ARG0: Pacific Rim started
#   ARG1: production July
#   ARGM-TMP: July 12 , 2013 .
#
# Verb: started
#
# VerbAtlas:
#  Frame: BEGIN
#   Agent: Pacific Rim started
#   Theme: production July
#   Time: July 12 , 2013 .
#
# PropBank:
#   ARG0: Pacific Rim started
#   ARG1: production July
#   ARGM-TMP: July 12 , 2013 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: invoked
#
# VerbAtlas:
#  Frame: ASK_REQUEST
#   Theme: Social justice is
#   Time: today in
#   Location: in philosophical debates about differences among human beings around the world .
#
# PropBank:
#   ARG1: Social justice is
#   ARGM-TMP: today in
#   ARGM-LOC: in philosophical debates about differences among human beings around the world .
#
# Verb: is
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: invoked
#
# VerbAtlas:
#  Frame: ASK_REQUEST
#   Theme: Social justice is
#   Time: today in
#   Location: in philosophical debates about differences among human beings around the world .
#
# PropBank:
#   ARG1: Social justice is
#   ARGM-TMP: today in
#   ARGM-LOC: in philosophical debates about differences among human beings around the world .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Patrick Dempsey was
#   Attribute: in the movie Enchanted in
#   Time: in 2007 .
#
# PropBank:
#   ARG1: Patrick Dempsey was
#   ARG2: in the movie Enchanted in
#   ARGM-TMP: in 2007 .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Patrick Dempsey was
#   Attribute: in the movie Enchanted in
#   Time: in 2007 .
#
# PropBank:
#   ARG1: Patrick Dempsey was
#   ARG2: in the movie Enchanted in
#   ARGM-TMP: in 2007 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ben Stiller has
#   Attribute: children .
#
# PropBank:
#   ARG0: Ben Stiller has
#   ARG1: children .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Ben Stiller has
#   Attribute: children .
#
# PropBank:
#   ARG0: Ben Stiller has
#   ARG1: children .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Iceland is
#   Attribute: a country .
#
# PropBank:
#   ARG1: Iceland is
#   ARG2: a country .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Iceland is
#   Attribute: a country .
#
# PropBank:
#   ARG1: Iceland is
#   ARG2: a country .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: stayed
#
# VerbAtlas:
#  Frame: REMAIN
#   Theme: Michelle Williams has
#   Attribute: away from an acting entirely
#   Adverbial: entirely .
#
# PropBank:
#   ARG1: Michelle Williams has
#   ARG3: away from an acting entirely
#   ARGM-ADV: entirely .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: murdered
#
# VerbAtlas:
#  Frame: KILL
#   Patient: Robin was
#   Agent: by the Joker in
#   Location: in a 1989 book .
#
# PropBank:
#   ARG1: Robin was
#   ARG0: by the Joker in
#   ARGM-LOC: in a 1989 book .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: murdered
#
# VerbAtlas:
#  Frame: KILL
#   Patient: Robin was
#   Agent: by the Joker in
#   Location: in a 1989 book .
#
# PropBank:
#   ARG1: Robin was
#   ARG0: by the Joker in
#   ARGM-LOC: in a 1989 book .
#
# Verb: played
#
# VerbAtlas:
#  Frame: PERFORM
#   Agent: David Schwimmer played
#   Theme: a lawyer in
#   Location: in American Crime Story .
#
# PropBank:
#   ARG0: David Schwimmer played
#   ARG1: a lawyer in
#   ARGM-LOC: in American Crime Story .
#
# Verb: played
#
# VerbAtlas:
#  Frame: PERFORM
#   Agent: David Schwimmer played
#   Theme: a lawyer in
#   Location: in American Crime Story .
#
# PropBank:
#   ARG0: David Schwimmer played
#   ARG1: a lawyer in
#   ARGM-LOC: in American Crime Story .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Avatar was
#   Agent: by James Cameron .
#
# PropBank:
#   ARG1: Avatar was
#   ARG0: by James Cameron .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: directed
#
# VerbAtlas:
#  Frame: DIRECT_AIM_MANEUVER
#   Theme: Avatar was
#   Agent: by James Cameron .
#
# PropBank:
#   ARG1: Avatar was
#   ARG0: by James Cameron .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Cher won
#   Patient: a Cannes Film Festival Award in
#   Time: in 1987 .
#
# PropBank:
#   ARG0: Cher won
#   ARG1: a Cannes Film Festival Award in
#   ARGM-TMP: in 1987 .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Cher won
#   Patient: a Cannes Film Festival Award in
#   Time: in 1987 .
#
# PropBank:
#   ARG0: Cher won
#   ARG1: a Cannes Film Festival Award in
#   ARGM-TMP: in 1987 .
#
# Verb: uses
#
# VerbAtlas:
#  Frame: USE
#   Agent: Shonen Jump uses
#   Patient: abbreviation .
#
# PropBank:
#   ARG0: Shonen Jump uses
#   ARG1: abbreviation .
#
# Verb: uses
#
# VerbAtlas:
#  Frame: USE
#   Agent: Shonen Jump uses
#   Patient: abbreviation .
#
# PropBank:
#   ARG0: Shonen Jump uses
#   ARG1: abbreviation .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Halle Berry has
#   Attribute: 0 children .
#
# PropBank:
#   ARG0: Halle Berry has
#   ARG1: 0 children .
#
# Verb: has
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Halle Berry has
#   Attribute: 0 children .
#
# PropBank:
#   ARG0: Halle Berry has
#   ARG1: 0 children .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Haim Saban is
#   Attribute: an Israeli - American musician .
#
# PropBank:
#   ARG1: Haim Saban is
#   ARG2: an Israeli - American musician .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Haim Saban is
#   Attribute: an Israeli - American musician .
#
# PropBank:
#   ARG1: Haim Saban is
#   ARG2: an Israeli - American musician .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Norway has
#   Attribute: over sixty kings and earls .
#
# PropBank:
#   ARG0: Norway has
#   ARG1: over sixty kings and earls .
#
# Verb: had
#
# VerbAtlas:
#  Frame: EXIST-WITH-FEATURE
#   Theme: Norway has
#   Attribute: over sixty kings and earls .
#
# PropBank:
#   ARG0: Norway has
#   ARG1: over sixty kings and earls .
#
# Verb: stars
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Men and a Baby stars
#   Agent: American actor Tom Selleck .
#
# PropBank:
#   ARG2: Men and a Baby stars
#   ARG1: American actor Tom Selleck .
#
# Verb: stars
#
# VerbAtlas:
#  Frame: PERFORM
#   Theme: Men and a Baby stars
#   Agent: American actor Tom Selleck .
#
# PropBank:
#   ARG2: Men and a Baby stars
#   ARG1: American actor Tom Selleck .
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a American film called Maleficent with Ella Purnell in it .
#
# PropBank:
#   ARG1: a American film called Maleficent with Ella Purnell in it .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a American film called
#   Attribute: Maleficent with
#
# PropBank:
#   ARG1: a American film called
#   ARG2: Maleficent with
#
# Verb: is
#
# VerbAtlas:
#  Frame: EXIST_LIVE
#   Theme: a American film called Maleficent with Ella Purnell in it .
#
# PropBank:
#   ARG1: a American film called Maleficent with Ella Purnell in it .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: a American film called
#   Attribute: Maleficent with
#
# PropBank:
#   ARG1: a American film called
#   ARG2: Maleficent with
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Alec Baldwin won
#   Patient: seven Screen Actors Guild Awards for 30 Rock in
#   Time: in the 2000s .
#
# PropBank:
#   ARG0: Alec Baldwin won
#   ARG1: seven Screen Actors Guild Awards for 30 Rock in
#   ARGM-TMP: in the 2000s .
#
# Verb: won
#
# VerbAtlas:
#  Frame: WIN
#   Agent: Alec Baldwin won
#   Patient: seven Screen Actors Guild Awards for 30 Rock in
#   Time: in the 2000s .
#
# PropBank:
#   ARG0: Alec Baldwin won
#   ARG1: seven Screen Actors Guild Awards for 30 Rock in
#   ARGM-TMP: in the 2000s .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Orson Welles was
#   Negation: not a
#   Attribute: a Shakespearean stage actor .
#
# PropBank:
#   ARG1: Orson Welles was
#   ARGM-NEG: not a
#   ARG2: a Shakespearean stage actor .
#
# Verb: was
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Orson Welles was
#   Negation: not a
#   Attribute: a Shakespearean stage actor .
#
# PropBank:
#   ARG1: Orson Welles was
#   ARGM-NEG: not a
#   ARG2: a Shakespearean stage actor .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: The American Broadcasting Company is
#   Adverbial: only called
#   Attribute: by its full name .
#
# PropBank:
#   ARG1: The American Broadcasting Company is
#   ARGM-ADV: only called
#   ARGM-MNR: by its full name .
#
# Verb: called
#
# VerbAtlas:
#  Frame: NAME
#   Theme: The American Broadcasting Company is
#   Adverbial: only called
#   Attribute: by its full name .
#
# PropBank:
#   ARG1: The American Broadcasting Company is
#   ARGM-ADV: only called
#   ARGM-MNR: by its full name .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Steven Gerrard has
#   Attribute: captain of the England national football team since
#   Time: since 2012 .
#
# PropBank:
#   ARG1: Steven Gerrard has
#   ARG2: captain of the England national football team since
#   ARGM-TMP: since 2012 .
#
# Verb: has
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: been
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Steven Gerrard has
#   Attribute: captain of the England national football team since
#   Time: since 2012 .
#
# PropBank:
#   ARG1: Steven Gerrard has
#   ARG2: captain of the England national football team since
#   ARGM-TMP: since 2012 .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: built
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: The Boeing 707 was
#   Agent: by my Uncle Jeff .
#
# PropBank:
#   ARG1: The Boeing 707 was
#   ARG0: by my Uncle Jeff .
#
# Verb: was
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: built
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: The Boeing 707 was
#   Agent: by my Uncle Jeff .
#
# PropBank:
#   ARG1: The Boeing 707 was
#   ARG0: by my Uncle Jeff .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: James Wilson is
#   Attribute: a real person yet to be made into a fictional character .
#
# PropBank:
#   ARG1: James Wilson is
#   ARG2: a real person yet to be made into a fictional character .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: made
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: into a fictional character .
#
# PropBank:
#   ARG1: into a fictional character .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: James Wilson is
#   Attribute: a real person yet to be made into a fictional character .
#
# PropBank:
#   ARG1: James Wilson is
#   ARG2: a real person yet to be made into a fictional character .
#
# Verb: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#
# Verb: made
#
# VerbAtlas:
#  Frame: MOUNT_ASSEMBLE_PRODUCE
#   Product: into a fictional character .
#
# PropBank:
#   ARG1: into a fictional character .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: The Great British Sewing Bee premiered
#   Time: on April 2 .
#
# PropBank:
#   ARG1: The Great British Sewing Bee premiered
#   ARGM-TMP: on April 2 .
#
# Verb: premiered
#
# VerbAtlas:
#  Frame: SHOW
#   Theme: The Great British Sewing Bee premiered
#   Time: on April 2 .
#
# PropBank:
#   ARG1: The Great British Sewing Bee premiered
#   ARGM-TMP: on April 2 .
#
# Verb: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Diego Costa is
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 62
#      60 verbatlasRoles_hp.add(role)
#      61 span = role_info['span']
# ---> 62 text = get_text_from_span(tokens_hp, span)
#      63 if (role == 'Location'):
#      64     verbatlasLocations_hp.add(text)
#
# Cell In[6], line 52, in get_text_from_span(tokens, span)
#      51 def get_text_from_span(tokens, span):
# ---> 52     return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1))
#
# Cell In[6], line 52, in <genexpr>(.0)
#      51 def get_text_from_span(tokens, span):
# ---> 52     return ' '.join(tokens[i]['rawText'] for i in range(span[0], span[1] + 1))
#
# IndexError: list index out of range

# %%
# print(type(nli_dataset["train"]))
# print(type(nli_dataset["train"][0]))
# print(nli_dataset["train"])

#TODO UNDERSTAND BEFORE GO AHEAD!

verbatlasFrame = set()
probankFrame = set()
verbatlasRoles = set()
probankRoles = set()



for elem in nli_dataset["train"]:
    srl = elem['srl']['premise']

    tokens = srl['tokens']
    annotations = srl['annotations']


    for annotation in annotations:
        token_index = annotation['tokenIndex']
        verb = tokens[token_index]['rawText']
        # print(f"Verb: {verb}\n")

        # print("VerbAtlas:")
        verbatlas = annotation['verbatlas']
        frame_name = verbatlas['frameName']
        verbatlasFrame.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in verbatlas['roles']:
            role = role_info['role']
            verbatlasRoles.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens, span)
            # print(f"  {role}: {text}")
        # print()

        # print("PropBank:")
        propbank = annotation['englishPropbank']
        frame_name = propbank['frameName']
        probankFrame.add(frame_name)
        # print(f" Frame: {frame_name}")
        for role_info in propbank['roles']:
            role = role_info['role']
            probankRoles.add(role)
            span = role_info['span']
            text = get_text_from_span(tokens, span)
            # print(f"  {role}: {text}")
        # print()


    # if count==5:break
    # else:count+=1

    # break

# %%
print("va locations: ",verbatlasLocations)
print("va locations: ",len(verbatlasLocations))
print("pb locations: ",probankLocations)
print("pb locations: ",len(probankLocations))
# Out:
# va locations:  {'in Minneapolis', 'in the Bundesliga , the top tier of the German football league system', 'in Tanzania', 'in Evanston , Illinois', '` Radioactive', 'in the spy - action television show Alias ( 2001 -- 2006 )', 'both indoors and outdoors', 'in the 2006 film The Pursuit of Happyness', 'in Italy', 'in the series Firefly and the follow - up film Serenity', 'outside the United States', 'in circuses', 'in the top five', 'in the battle', 'in the 58th Filmfare Awards South', 'at the southernmost tip of the Balkan Peninsula', 'in American comic books published by Marvel Comics , mostly in association with the X - Men', 'in the Lower Mainland region of British Columbia', 'primarily in California', 'in Continental Europe', 'in the fourth installment of the The Karate Kid franchise , The Next Karate Kid', 'south of the Sahara', 'in ROH', "in Brian De Palma ' s cult thriller Sisters ( 1973 ) ; in the slasher film Black Christmas ( 1974 ) ; and the drama The Great Waldo Pepper ( 1975 ) , opposite Robert Redford", 'at more secluded locations', 'in Modern Icelandic', 'throughout the islands', 'in a bidding war', 'in theater', "in supporting roles including Inventing the Abbotts ( 1997 ) and Robert Altman ' s black comedy Cookie ' s Fortune ( 1999 )", 'the highest paid Indian', 'On the international stage with France', 'on the first season of Sabrina , the Teenage Witch ,', 'on the U.S. Billboard 200', "on the ITF Women ' s Circuit", 'on the southern half of the Korean Peninsula jutting out from the far east of the Asian land mass', 'at the western edge of Caleta del Sebo', 'on ranches in North America', 'under 16 administrations', 'at the Museum of Vinci', "in films such as Ridley Scott ' s American Gangster ( 2007 ) , Takers ( 2010 ) , Thor ( 2011 ) , Prometheus ( 2012 ) , Pacific Rim ( 2013 ) , Thor : The Dark World ( 2013 ) and Beasts of No Nation ( 2015 , for which he received BAFTA and Golden Globe nominations for Best Supporting", 'in the Top 15 of the Billboard 200', 'on a rectangular court', 'on more than
013 ) , Thor : The Dark World ( 2013 ) and Beasts of No Nation ( 2015 , for which he received BAFTA and Golden Globe nominations for Best Supporting", 'in the Top 15 of the Billboard 200', 'on a rectangular court', 'on more than 125 pop stations in the U.S. alone', 'the U.S. Open', 'on the CBS series Elementary ( 2013 -- 15 )', 'in the Napoleonic Wars', 'in Aleppo', 'in the coming of age drama Mermaids ( 1990 )', 'Astana', 'the reality show The World According to Paris', "in New York City ' s Madison Square Garden", 'in official competitions', 'at the presidential inauguration of Donald Trump', 'in Reading , Berkshire ,', 'on Columbia', 'on TeenNick', 'on long - haul transoceanic routes', 'on the American Broadcasting Company ( ABC )', 'in his feature - length debut from a screenplay by Sebastian de Souza , and Preston Thompson', 'in the soap opera A World Apart ( 1970 -- 71 )', 'in electronic physics , as well as in fields of chemistry , such as quantum chemistry or electrochemistry', 'in print and online sources', 'in India', 'at the Toronto International Film Festival and London Film Festival', 'at the 75th Academy Awards ceremony', 'below the thermocline and above the seabed', 'in X - Men : Days of Future Past ( 2014 ) , and X - Men : Apocalypse ( 2016 )', 'on a $ 2,777,000 budget', "Count Waldstein ' s household", 'in West Bromwich in the West Midlands', 'in the East Cantons located around the High Fens area , and bordering Germany', 'in the Disney Channel series Even Stevens , a role for which LaBeouf received a Young Artist Award nomination in 2001 and won a Daytime Emmy Award in 2003', 'in the underground music community', 'in films and on television', "in The Curse of the Black Pearl ( 2003 ) , Dead Man ' s Chest ( 2006 ) , At World ' s End ( 2007 ) and Dead Men Tell No Tales ( 2017 )", 'in the United States and the United Kingdom', 'on clay and hard court', 'internationally and on the independent circuit', 'on Agony & Irony ( 2008 ) , which was released on V2 Records', 'at 7007 Hollywood Boulevard', "on many critics ' lists of the greatest films ever made", '60 kilo', 'in the telecommunications industry', 'in Girl , Interrupted ( 1999 ) and', 'in upstate New York', 'in the rural town of Bon Temps , Louis ...
# pb locations:  4930

# %%
# Sample set of strings


# Filter to include only words that start with a capital letter
filtered_words_set_va = {word for s in verbatlasLocations for word in s.split() if word[0].isupper()}
print(filtered_words_set_va)
print(len(filtered_words_set_va))
# Out:
# {'Class', 'Regum', 'Vienna', 'Boss', 'Prat', 'Forever', 'Potomac', 'Spencer', 'Erie', 'Confederations', 'Plutarch', 'Olivier', 'Peru', 'Hyattsville', 'Staple', 'Brazilian', 'Mildred', 'Galaxy', 'Clara', 'Everwood', 'Chalk', 'Open', 'Parlophone', 'Adriatic', 'Emily', 'Skarsgård', 'Sites', 'Bactrian', 'Virgil', 'Charing', 'PCs', 'Prix', 'Ivy', 'Avengers', 'Mercury', 'Rye', 'Kentwood', 'Vedanta', 'Lambeth', 'Base', 'Beach', 'Ayutla', 'MCs', 'Deauville', 'Groton', 'Subtle', 'Euclidean', 'Rose', 'Martina', 'Glenwood', 'Fallen', 'Vinci', 'Driver', 'Yugoslavia', 'Another', 'Knights', 'Stockholm', 'Dexter', 'Sunshine', 'Winds', 'Chaplin', 'Eve', 'Luck', 'Luton', 'Semitic', 'News', 'Wisconsin', 'Avenger', 'RCD-25', 
', 'Loss', 'Design', 'Knope', 'Saxony', 'Forfar', 'Zindagi', 'Military', 'Udta', 'Wentworth', 'Olympiada', 'Cold', 'Schuylkill', 'Squad', 'Frutti', 'TriBeCa', 'Anfield', 'Po', 'Horn', 'Armageddon', 'Carpathian', 'Snake', 'McLean', 'Cottesloe', 'Cookie', 'Leste', 'Caspian', 'Pop', 'Scotland', 'Not', 'Romania', 'Plaza', 'Hampshire', 'Ferrigno', 'African', 'Austin', 'Ireland', 'Retail', 'Cemetery', 'Aegon', 'Camelot', 'Pakhtunkhwa', 'Río', 'Seleucid', 'Skin', 'Animated', 'MSNBC', 'Brimsdown', 'Harry', 'Hamlet', 'Vagrant', 'Sanam', "O'Brien", 'Southampton', 'Chamber', 'Filmmakers', 'St', 'Bohemia', 'Bernard', 'Riding', 'Last', 'Brideshead', 'Draft', 'Everest', 'SBS', 'Peninsula', 'Downingtown', 'Aslan', 'Crazies', 'Couples', 'Plains', 'Fortune', 'Michele', 'Uccello', 'Ode', 'Reality', 'Lusignan', 'Pullman', 'Hannah', 'Rattlesnakes', 'Epsom', 'Place', 'Remote', 'Neck', 'Nacional', 'Hockey', 'Attraction', 'Chatsworth', ...
# 4529

# %%
filtered_words_set_pb = {word for s in probankLocations for word in s.split() if word[0].isupper()}
print(filtered_words_set_pb)
print(len(filtered_words_set_pb))
# Out:
# {'Class', 'Regum', 'Vienna', 'Boss', 'Plutarch', 'Forever', 'Potomac', 'Spencer', 'Erie', 'Confederations', 'Prat', 'Olivier', 'Peru', 'Hyattsville', 'Brazilian', 'Mildred', 'Galaxy', 'Clara', 'Everwood', 'Chalk', 'Open', 'Parlophone', 'Emily', 'Skarsgård', 'Sites', 'Bactrian', 'Virgil', 'Charing', 'PCs', 'Prix', 'Ivy', 'Avengers', 'Mercury', 'Rye', 'Kentwood', 'Vedanta', 'Base', 'Beach', 'Ayutla', 'MCs', 'Deauville', 'Groton', 'Subtle', 'Euclidean', 'Rose', 'Martina', 'Glenwood', 'Fallen', 'Vinci', 'Driver', 'Yugoslavia', 'Another', 'Knights', 'Stockholm', 'Dexter', 'Sunshine', 'Winds', 'Chaplin', 'Eve', 'Luck', 'Luton', 'Semitic', 'News', 'Wisconsin', 'Avenger', 'RCD-25', 'Action', 'Desperate', 'Amendment', 'Ali', 'Man', 'Laferrière', 'Blogette', 'Bandai', 'Festivals', 'Memphis', 'Sparta', 'Iowa', 'Serbia', 'PAX', 'Dileep', 'Pakistani', 'Saddam', 'Dry', 'Punjabi', 'Vevey', 'GHV2', 'Trophy', 'Tales', 'Plane', 'TD', 'O', 'Pain', 'Antonio', 'Berlin', 'Extended', 'Disney', 'Mercy', 'Vijayawada', 'Révolution', 'Omaha', 'Chuke', 'Othello', 'Fine', 'Korean', 'Skellig', 'Anatomy', 'Genisys', 'Fred', 'Melbourne', 'Urbanized', 'Orleans', 'Creatures', 'Mvezo', 'Tagore', 'Tombstones', 'Allen', 'Assange', 'Greenwood', 'Red', 'Rogers', 'Bites', 'Framlingham', 'Porgy', '
'Place', 'Remote', 'Neck', 'Nacional', 'Hockey', 'Attraction', 'Dakota', 'Years', 'DVD', 'Tisch', 'Kapoor', 'Heavy', 'Suburbs', 'Democratic', 'My', 'Excellence', 'Bhojpuri', 'Koval', 'Concert', 'Windward', 'Streets', 'Austria', 'Netflix', 'Jean', 'TARDIS', 'Propaganda', 'Office', 'TeenNick', 'Pam', 'Junction', 'Bhambla', 'Marx', 'Horse', 'ABC', 'UEFA', 'Mi ...
# 4329

# %%
print(filtered_words_set_va.difference(filtered_words_set_pb))
# Out:
# {'Tribunal', 'Radioactive', 'Ἀθηναίη', 'Plateau', 'Rosemont', 'Toledo', 'LL', 'Narnia', 'Staple', 'Taking', 'Brown', 'Bergens', 'Carey', 'Legislature', 'Stripped', 'Mixer', 'Elmet', 'Soprano', 'Baltic', 'Antilia', 'Moose', 'Timor', 'Adriatic', 'Paquin', 'Patel', 'Olympiada', 'Wentworth', 'Matt', 'Fayetteville', 'Runcorn', 'Hun', 'Drift', 'Salado', 'Library', 'Jennifer', 'Locus', 'Eva', 'Junipero', 'Files', 'Lambeth', 'Senators', 'Milky', 'Township', 'Leste', 'Caspian', 'Formosa', 'GD', 'Floyd', 'Naismith', 'Poor', 'Investigation', 'Ural', 'Neptune', 'Zooey', 'Beckinsale', 'Deschanel', 'Presley', 'Pont', 'Angel', 'Wisteria', 'Marmara', 'Norwich', 'Detention', 'Tea', 'Dharma', 'Others', 'Caleta', 'TOP', 'Symoné', 'Leagues', 'Duchovny', 'Endangered', 'Rondell', 'Journals', 'Vice', 'Imperial', 'Aslan', 'SmackDown', 'Keaton', 'Covenant', 'Qatar', 'Sahara', 'Baxter', 'Palais', 'Clares', 'Creed', 'Chatsworth', 'Beetlejuice', 'Gillian', 'Triangle', 'Marple', 'Anthrax', 'Loess', 'Selangor', 'Stormare', 'Scully', 'Newport', 'Scandinavian', 'Presidential', 'Sebo', 'Keymáh', 'Different', 'Oakdale', 'Selina', 'Alec', 'Electronic', 'Organisation', 'Mitchell', 'Twitch', 'Seas', 'Québec', 'Sen', 'Nord', 'Written', 'Hercule', 'Sheridan', 'Shelton', 'Buscemi', 'Kate', 'Nuremberg', 'Damon', 'Macy', 'Thin', 'Platinum', 'Analysis', 'Jess', 'Adolf', 'Andreas', 'BC', 'Hepburn', 'Cambodian', 'Radnor', 'Selene', 'Kathiawar', 'Around', 'Revolution', 'Victor', 'Pine', 'Baldwin', 'Stackhouse', 'Yellow', 'Crazy', 'Ending', 'Anneliese', 'Sof', 'Behavioral', 'Saudi', 'Prussian', 'Elvis', 'BAU', 'Puget', 'Straits', 'Megadeth', 'Haitian', 'Igneel', 'Smithsonian', 'Redmond', 'PC', 'Haryana', 'Geena', 'Sides', 'Estates', 'Bull', 'Dana', 'Species', 'Tanya', 'Coconino', 'Novem', 'Eddie', 'Vanuatu', 'Namdaemun', 'Craig', 'Baker', 'Building', 'Pink', 'Samsung', 'Kaiju', 'Manningham', 'Players', 'Katharine', 'Fairview', 'Netherworld', 'Blake', 'Mariah', 'Foxcatcher', 'Omar', 'Zhongyuan', 'Lycans', 'A140', 'F.', 'Merion', 'Orton', 'Papua', 'Progressive', 'Gaon', 'Assassin', 'Randy', 'Falcón', 'Sangha', 'Sookie', 'Bureau', 'Moskva', 'Riffs', 'Governorate', 'Minor', 'Archbasilica', 'Juan', 'Wardenclyffe', 'Mulder', 'Ethiopia', 'Plate', 'Dealer', 'McLaur', 'Playa', 'Daniel', 'Ned', 'Department', 'Pol', 'Betelgeuse', 'FBI', 'Levine', 'Penin', 'Clapton', 'H', 'MMORPG', 'Gandolfini', 'Alps', 'Southeastern', 'Hoffman', 'Bosphorus', 'Mesoamerica', 'Kane', "T'Keyah", 'Amhara', 'Suez', 'Hawkins', 'Garfield', 'Lateran', 'Pi', 'Mieszko', 'Candyfornia'}

# %%
# IDEA APPLICATA AD UN PARTICOLARE SAMPLE, DA CANCELLARE!


tokens = trovato_tokens
annotations = trovato_annotations

print("tokens: ",tokens)
print("annotations: ",annotations)



# the core of the algorithm
for annotation in annotations:
    token_index = annotation['tokenIndex']
    verb = tokens[token_index]['rawText']
    print(f"Verbo: {verb}\n")

    print("VerbAtlas:")
    verbatlas = annotation['verbatlas']
    frame_name = verbatlas['frameName']
    print(f" Frame: {frame_name}")
    for role_info in verbatlas['roles']:
        role = role_info['role']
        span = role_info['span']
        text = get_text_from_span(tokens, span)
        print(f"  {role}: {text}")
    print()

    print("PropBank:")
    propbank = annotation['englishPropbank']
    frame_name = propbank['frameName']
    print(f" Frame: {frame_name}")
    for role_info in propbank['roles']:
        role = role_info['role']
        span = role_info['span']
        text = get_text_from_span(tokens, span)
        print(f"  {role}: {text}")
    print()
# Out:
# tokens:  [{'index': 0, 'rawText': 'Tennis'}, {'index': 1, 'rawText': 'is'}, {'index': 2, 'rawText': 'a'}, {'index': 3, 'rawText': 'racket'}, {'index': 4, 'rawText': 'sport'}, {'index': 5, 'rawText': 'that'}, {'index': 6, 'rawText': 'can'}, {'index': 7, 'rawText': 'be'}, {'index': 8, 'rawText': 'played'}, {'index': 9, 'rawText': 'individually'}, {'index': 10, 'rawText': 'against'}, {'index': 11, 'rawText': 'a'}, {'index': 12, 'rawText': 'single'}, {'index': 13, 'rawText': 'opponent'}, {'index': 14, 'rawText': '('}, {'index': 15, 'rawText': 'singles'}, {'index': 16, 'rawText': ')'}, {'index': 17, 'rawText': 'or'}, {'index': 18, 'rawText': 'between'}, {'index': 19, 'rawText': 'two'}, {'index': 20, 'rawText': 'teams'}, {'index': 21, 'rawText': 'of'}, {'index': 22, 'rawText': 'two'}, {'index': 23, 'rawText': 'players'}, {'index': 24, 'rawText': 'each'}, {'index': 25, 'rawText': '('}, {'index': 26, 'rawText': 'doubles'}, {'index': 27, 'rawText': ')'}, {'index': 28, 'rawText': '.'}, {'index': 29, 'rawText': 'Tennis'}, {'index': 30, 'rawText': 'is'}, {'index': 31, 'rawText': 'an'}, {'index': 32, 'rawText': 'Olympic'}, {'index': 33, 'rawText': 'sport'}, {'index': 34, 'rawText': 'and'}, {'
01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [29, 30]}, {'role': 'ARGM-LOC', 'score': 1.0, 'span': [37, 46]}]}}, {'tokenIndex': 51, 'verbatlas': {'frameName': 'PLAY_SPORT/GAME', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [47, 49]}, {'role': 'Modal', 'score': 1.0, 'span': [49, 50]}, {'role': 'Agent', 'score': 1.0, 'span': [52, 63]}]}, 'englishPropbank': {'frameName': 'play.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [47, 49]}, {'role': 'ARGM-MOD', 'score': 1.0, 'span': [49, 50]}, {'role': 'ARG0', 'score': 1.0, 'span': [52, 63]}]}}, {'tokenIndex': 56, 'verbatlas': {'frameName': 'POSSESS', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [53, 54]}, {'role': 'Modal', 'score': 1.0, 'span': [55, 56]}, {'role': 'Theme', 'score': 1.0, 'span': [57, 59]}]}, 'englishPropbank': {'frameName': 'hold.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [53, 54]}, {'role': 'R-ARG0', 'score': 1.0, 'span': [54, 55]}, {'role': 'ARGM-MOD', 'score': 1.0, 'span': [55, 56]}, {'role': 'ARG1', 'score': 1.0, 'span': [57, 59]}]}}, {'tokenIndex': 60, 'verbatlas': {'frameName': 'INCLUDE-AS', 'roles': [{'role': 'Goal', 'score': 1.0, 'span': [53, 59]}, {'role': 'Patient', 'score': 1.0, 'span': [61, 63]}]}, 'englishPropbank': {'frameName': 'include.01', 'roles': [{'role': 'ARG2', 'score': 1.0, 'span': [53, 59]}, {'role': 'ARG1', 'score': 1.0, 'span': [61, 63]}]}}, {'tokenIndex': 67, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [64, 67]}, {'role': 'Attribute', 'score': 1.0, 'span': [68, 76]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [64, 67]}, {'role': 'ARG2', 'score': 1.0, 'span': [68, 76]}]}}, {'tokenIndex': 70, 'verbatlas': {'frameName': 'CREATE_MATERIALIZE', 'roles': [{'role': 'Result', 'score': 1.0, 'span': [68, 70]}, {'role': 'Attribute', 'score': 1.0, 'span': [71, 76]}]}, 'englishPropbank': {'frameName': 'design.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [68, 70]}, {'role': 'ARG3', 'score': 1.0, 'span': [71, 76]}]}}]
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tennis
#   Attribute: a racket sport that can be played individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# PropBank:
#  Frame: be.01
#   ARG1: Tennis
#   ARG2: a racket sport that can be played individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# Verbo: be
#
# VerbAtlas:
#  Frame: AUXILIARY
#
# PropBank:
#  Frame: be.03
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: a racket sport
#   Modal: can
#   Attribute: individually against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# PropBank:
#  Frame: play.01
#   ARG1: a racket sport
#   R-ARG1: that
#   ARGM-MOD: can
#   ARGM-MNR: individually
#   ARGM-MNR: against a single opponent ( singles ) or between two teams of two players each ( doubles )
#
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: Tennis
#   Attribute: an Olympic sport
#
# PropBank:
#  Frame: be.01
#   ARG1: Tennis
#   ARG2: an Olympic sport
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: Tennis
#   Location: at all levels of society and at all ages
#
# PropBank:
#  Frame: play.01
#   ARG1: Tennis
#   ARGM-LOC: at all levels of society and at all ages
#
# Verbo: played
#
# VerbAtlas:
#  Frame: PLAY_SPORT/GAME
#   Theme: The sport
#   Modal: can
#   Agent: by anyone who can hold a racket , including wheelchair users
#
# PropBank:
#  Frame: play.01
#   ARG1: The sport
#   ARGM-MOD: can
#   ARG0: by anyone who can hold a racket , including wheelchair users
#
# Verbo: hold
#
# VerbAtlas:
#  Frame: POSSESS
#   Agent: anyone
#   Modal: can
#   Theme: a racket
#
# PropBank:
#  Frame: hold.01
#   ARG0: anyone
#   R-ARG0: who
#   ARGM-MOD: can
#   ARG1: a racket
#
# Verbo: including
#
# VerbAtlas:
#  Frame: INCLUDE-AS
#   Goal: anyone who can hold a racket
#   Patient: wheelchair users
#
# PropBank:
#  Frame: include.01
#   ARG2: anyone who can hold a racket
#   ARG1: wheelchair users
#
# Verbo: is
#
# VerbAtlas:
#  Frame: COPULA
#   Theme: A tennis ball
#   Attribute: a ball designed for the sport of tennis
#
# PropBank:
#  Frame: be.01
#   ARG1: A tennis ball
#   ARG2: a ball designed for the sport of tennis
#
# Verbo: designed
#
# VerbAtlas:
#  Frame: CREATE_MATERIALIZE
#   Result: a ball
#   Attribute: for the sport of tennis
#
# PropBank:
#  Frame: design.01
#   ARG1: a ball
#   ARG3: for the sport of tennis

# %%
# print(f"verbatlasFrame {verbatlasFrame}")
# print(f"probankFrame {probankFrame}")
# print(f"verbatlasRoles {verbatlasRoles}")
# print(f"probankRoles {probankRoles}")


# verbatlasFrame_complete = verbatlasFrame
# probankFrame_complete = probankFrame
# verbatlasRoles_complete = verbatlasRoles
# probankRoles_complete = probankRoles

print(f"verbatlasFrame {verbatlasFrame_complete}")
print(f"probankFrame {probankFrame_complete}")
print(f"verbatlasRoles {verbatlasRoles_complete}")
print(f"probankRoles {probankRoles_complete}")



# print(f"verbatlasFrame {len(verbatlasFrame)}")
# print(f"probankFrame {len(probankFrame)}")
# print(f"verbatlasRoles {len(verbatlasRoles)}")
# print(f"probankRoles {len(probankRoles)}")
# Out:
# verbatlasFrame {'DISBAND_BREAK-UP', 'INSERT', 'ACCUSE', 'DISLIKE', 'DISCARD', 'DRIVE-BACK', 'PROMOTE', 'KNOW', 'IMAGINE', 'FRUSTRATE_DISAPPOINT', 'MEASURE_EVALUATE', 'ENTER', 'JUSTIFY_EXCUSE', 'FIGHT', 'HEAT', 'BE-LOCATED_BASE', 'CONTRACT-AN-ILLNESS_INFECT', 'LAND_GET-OFF', 'RECORD', 'COMBINE_MIX_UNITE', 'EXPLODE', 'STOP', 'CRITICIZE', 'SETTLE_CONCILIATE', 'CORRELATE', 'DRESS_WEAR', 'CAUSE-SMT', 'NEGOTIATE', 'LURE_ENTICE', 'REFUSE', 'ACHIEVE', 'ODORIZE', 'EXPLAIN', 'BORDER', 'RISK', 'MOVE-ONESELF', 'DIET', 'CHANGE-HANDS', 'EXIST-WITH-FEATURE', 'BEND', 'RESTRAIN', 'MANAGE', 'PUBLISH', 'DANCE', 'HARMONIZE', 'RECOGNIZE_ADMIT_IDENTIFY', 'SHOW', 'HANG', 'INCREASE_ENLARGE_MULTIPLY', 'SING', 'OVERLAP', 'LIGHTEN', 'BREAK_DETERIORATE', 'AFFECT', 'BUY', 'INFLUENCE', 'JOKE', 'CHARGE', 'BRING', 'TOLERATE', 'ASCRIBE', 'LEND', 'STABILIZE_SUPPORT-PHYSICALLY', 'COST', 'DEFEAT', 'FEEL', 'AUXILIARY', 'GROUP', 'OVERCOME_SURPASS', 'REMEMBER', 'FILL', 'PREPARE', 'CHANGE-APPEARANCE/STATE', 'PERCEIVE', 'OBLIGE_FORCE', 'INVERT_REVERSE', 'ORDER', 'WORK', 'INFORM', 'FLOW', 'SLEEP', 'LAUGH', 'DIP_DIVE', 'COMPARE', 'TREAT', 'COPULA', 'REPLACE', 'BURY_PLANT', 'PULL', 'MAKE-A-SOUND', 'BURN', 'COVER_SPREAD_SURMOUNT', 'POSSESS', 'GO-FORWARD', 'INFER', 'CHOOSE', 'FACE_CHALLENGE', 'LEAD_GOVERN', 'OFFER', 'LOAD_PROVIDE_CHARGE_FURNISH', 'ORGANIZE', 'CLOSE', 'STEAL_DEPRIVE', 'DRINK', 'SATISFY_FULFILL', 'REPRESENT', 'EAT_BITE', 'BULGE-OUT', 'NAME', 'RECEIVE', 'FINISH_CONCLUDE_END', 'PLAN_SCHEDULE', 'PUBLICIZE', 'ADD', 'HAVE-A-FUNCTION_SERVE', 'LEAVE-BEHIND', 'RELY', 'ORIENT', 'PUNISH', 'SCORE', 'CONTAIN', 'AROUSE_WAKE_ENLIVEN', 'SLOW-DOWN', 'FOCUS', 'FOLLOW-IN-SPACE', 'WRITE', 'AMELIORATE', 'HELP_HEAL_CARE_CURE', 'HOST_MEAL_INVITE', 'GIVE-BIRTH', 'WORSEN', 'RUN', 'DIVERSIFY', 'TRAVEL', 'DEVELOP_AGE', 'COLOR', 'READ', 'TRY', 'LOSE', 'MESS', 'MEAN', 'ALLY_ASSOCIATE_MARRY', 'CLOUD_SHADOW_HIDE', 'PRINT', 'FLATTEN_SMOOTHEN', 'EXEMPT', 'PLAY_SPORT/GAME', 'PUT_APPLY_PLACE_PAVE', 'CHANGE-TASTE', 'REPEAT', 'BEGIN', 'ASK_REQUEST', 'EMPTY_UNLOAD', 'LOCATE-IN-TIME_DATE', 'REQUIRE_NEED_WANT_HOPE', 'COOL', 'OPEN', 'COOK', 'SHARE', 'REACT', 'DISCUSS', 'COURT', 'APPROVE_PRAISE', 'RAISE', 'PERFORM', 'PRECLUDE_FORBID_EXPEL', 'LIGHT_SHINE', 'FLY', 'CELEBRATE_PARTY', 'COMMUNIZE', 'LEAVE_DEPART_RUN-AWAY', 'BELIEVE', 'ATTACK_BOMB', 'OBEY', 'OPERATE', 'MISTAKE', 'SUBJECTIVE-JUDGING', 'ATTACH', 'CRY', 'GENERATE', 'HIT', 'INCLUDE-AS', 'RESIGN_RETIRE', 'WIN', 'OBTAIN', 'CALCULATE_ESTIMATE', 'DROP', 'TAKE', 'QUARREL_POLEMICIZE', 'BETRAY', 'TOUCH', 'SELL', 'MATCH', 'DRY', 'DELAY', 'MEET', 'DESTROY', 'JOIN_CONNECT', 'AGREE_ACCEPT', 'CHANGE_SWITCH', 'UNDERGO-EXPERIENCE', 'WASH_CLEAN', 'SOLVE', 'FIT', 'STAY_DWELL', 'REMAIN', 'RESERVE', 'SIMPLIFY', 'PRESS_PUSH_FOLD', 'TEACH', 'THROW', 'WAIT', 'LEARN', 'TRANSMIT', 'REVEAL', 'RESULT_CONSEQUENCE', 'SHAPE', 'PRECEDE', 'REFLECT', 'DOWNPLAY_HUMILIATE', 'FACIAL-EXPRESSION', 'HURT_HARM_ACHE', 'SEND', 'AUTHORIZE_ADMIT', 'HAPPEN_OCCUR', 'DISMISS_FIRE-SMN', 'MISS_OMIT_LACK', 'REMOVE_TAKE-AWAY_KIDNAP', 'SEE', 'DECREE_DECLARE', 'LOWER', 'CITE', 'ALTERNATE', 'REDUCE_DIMINISH', 'CREATE_MATERIALIZE', 'EARN', 'INTERPRET', 'REFER', 'GIVE_GIFT', 'DIRECT_AIM_MANEUVER', 'REACH', 'SEEM', 'ANSWER', 'EXHAUST', 'OPPOSE_REBEL_DISSENT', 'THINK', 'SPEND-TIME_PASS-TIME', 'MAKE-RELAX', 'FIND', 'MOVE-SOMETHING', 'PARDON', 'FORGET', 'CARRY_TRANSPORT', 'VIOLATE', 'GUESS', 'HUNT', 'AFFIRM', 'EMIT', 'BENEFIT_EXPLOIT', 'SWITCH-OFF_TURN-OFF_SHUT-DOWN', 'KNOCK-DOWN', 'SUMMARIZE', 'VERIFY', 'COME-AFTER_FOLLOW-IN-TIME', 'CUT', 'SUMMON', 'GUARANTEE_ENSURE_PROMISE', 'EMBELLISH', 'DISTINGUISH_DIFFER', 'UNDERSTAND', 'HIRE', 'CARRY-OUT-ACTION', 'GIVE-UP_ABOLISH_ABANDON', 'WASTE', 'CATCH', 'RETAIN_KEEP_SAVE-MONEY', 'KILL', 'PAY', 'ABSTAIN_AVOID_REFRAIN', 'RENEW', 'ENJOY', 'MOVE-BACK', 'PROPOSE', 'SUBJUGATE', 'RESTORE-TO-PREVIOUS/INITIAL-STATE_UNDO_UNWIND', 'CONSUME_SPEND', 'CAVE_CARVE', 'EXTEND', 'PRONOUNCE', 'EXTRACT', 'BEFRIEND', 'DEBASE_ADULTERATE', 'EXIST_LIVE', 'CO-OPT', 'COMMUNE', 'SP ...
# probankFrame {'try.04', 'single.01', 'amass.01', 'reflect.01', 'elude.01', 'fall.05', 'march.01', 'tend.01', 'brand.01', 'publish.01', 'air.01', 'come.01', 'save.03', 'term.01', 'defy.01', 'unveil.01', 'monetize.01', 'size.01', 'stem.02', 'want.01', 'take.01', 'deliver.01', 'elevate.01', 'rely.01', 'disavow.01', 'experiment.01', 'bother.02', '
 'commute.01', 'hear.01', 'land.01', 'exacerbate.01', 'pay.01', 'pressure.01', 'shrink.01', 'mount.03', 'induce.02', 'look.09', 'fold.03', 'prevail.01', 'interrupt.01', 'extract.01', 'invite.01', 'steal.01', 'originate.01', 'spawn.01', 'conceive.01', 'take.13', 'have.03', 'enforce.01', 'write.01', 'weave.01', 'nationalize.01', 'empower.01', 'limit.01', 'hand.03', 'exert.01', 'spark.01', 'fine.01', 'fabricate.01', 'fulfill.01', 'assure.01', 'fear.01', 'accommodate.01', 'headquarter.01', 'take.04', 'spin.02', 'render.01', 'accept.01', 'hold.04', 'look.02', 'address.02', 'forecast.01', 'shelve.01', 'structure.01', 'distinguish.01', 'cope.01', 'submerge.01', 'climb.01', 'transit.01', 'take.22', 'sweep.02', 'empty.01', 'elicit.01', 'fail.01', 'exercise.01', 'regulate.01', 'inaugurate.02', 'free.01', 'subvert.01', 'transport.01', 'besiege.01', 'lack.01', 'freeze.01', 'utilize.01', 'default.01', 'revolutionize.01 ...
# verbatlasRoles {'Modal', 'Result', 'Goal', 'Co-Agent', 'Agent', 'Patient', 'Location', 'Negation', 'Topic', 'Instrument', 'Purpose', 'Extent', 'Source', 'Cause', 'Asset', 'Time', 'Attribute', 'Recipient', 'Co-Patient', 'Beneficiary', 'Destination', 'Idiom', 'Stimulus', 'Material', 'Predicative', 'Product', 'Theme', 'Co-Theme', 'Adverbial', 'Experiencer'}
# probankRoles {'R-ARG2', 'R-ARG3', 'R-ARGM-MNR', 'R-ARGM-GOL', 'ARGM-ADJ', 'C-ARG2', 'C-ARG0', 'C-ARG1', 'ARG2', 'ARG5', 'ARGM-ADV', 'ARGM-DIS', 'ARGM-GOL', 'ARGM-COM', 'ARG1', 'R-ARG0', 'ARGM-TMP', 'ARGM-PNC', 'ARGM-MNR', 'R-ARG1', 'R-ARGM-DIR', 'ARGM-NEG', 'R-ARGM-LOC', 'C-ARGM-MNR', 'ARGM-DIR', 'ARGM-CAU', 'ARGM-PRP', 'ARGM-LVB', 'ARGM-REC', 'R-ARGM-CAU', 'ARG3', 'C-ARG4', 'ARGM-LOC', 'ARGM-EXT', 'ARG4', 'ARGM-MOD', 'ARGM-PRD', 'R-ARGM-TMP', 'ARG0', 'C-ARGM-LOC'}
# verbatlasFrame 388
# probankFrame 1932
# verbatlasRoles 30
# probankRoles 40

# %% [markdown]
# # Idea: Leveraging the information about subject

# %%
def create_birthday_samples(filtered_dataset,months_list):


    new_samples = []
    info_elements = []
    possible_locations = []
    possible_subjects = {}
    marriage_role = set()
    marriages_info = []
    verbs= set()


    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')


    for index,elem in tqdm(enumerate(filtered_dataset)):

        born_event = False

        symm_relations = {'have married'}
        antisymm_relations = {'have killed'}
        antisymm_relations = {'have killed'}
        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

    

        id = elem['id']
        original_label = elem['label']


        info_elem['id'] = id
        info_elem['OtherPatients'] = []
        info_elem['OtherAgents'] = []
        info_elem['frane_name_pb'] = []
        info_elem['premise'] = text_pre
        info_elem['original_label'] = original_label

        possible_subjects[id] = []


        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']
        subject_added = False
        
        marriage_added = False

        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']
        


        for annotation_pre in annotations_pre:
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]  #reference verb of annotation
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            roles = verbatlasAnn['roles']
            rolespb = propbankAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']
            info_elem['frane_name_pb'].append(frame_name_pb)

            #Check born event
            if frame_name == 'GIVE-BIRTH':
                born_event = True # in this sample there is a relation born
                for role in roles:
                    span = role['span']
                    if role['role'] == 'Patient':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            subject_added = True
                            if name not in possible_subjects[id]:
                                possible_subjects[id].append(name)
                            info_elem['subject'] = name
                    elif role['role'] == 'Time':
                        text = get_text_from_span(tokens_pre,span)
                        day,month,year = extract_date_components(text,pattern_time,months_list)
                        if (year):
                            format_time = ''
                            if (day!=None): 
                                format_time+=day+','
                            else: 
                                format_time+='None,'
                            if (month!=None): 
                                format_time+=month+','
                            else: 
                                format_time+='None,'
                            if (year!=None): 
                                format_time+=year+''
                            else: 
                                format_time+='None'
                            info_elem['whenBorn'] = format_time
                    elif role['role'] == 'Location':
                        text = get_text_from_span(tokens_pre,span)
                        locations = check_location(text)
                        if(len(locations)>0):
                            list_loc = ''
                            for i in range(len(locations)):
                                list_loc += locations[i]
                                if (i!= len(locations)-1): list_loc+=','
                            info_elem['whereBorn'] = list_loc
                    elif role['role'] == 'Agent':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            info_elem['parent'] = name

            else:
                for role in roles:
                    span = role['span']
                    if role['role'] == 'Patient':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            if name not in possible_subjects[id]:
                                possible_subjects[id].append(name)
                            info_elem['OtherPatients'].append(name)
                    elif role['role'] == 'Agent':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            info_elem['OtherAgents'].append(name)
                for role in rolespb:
                    span = role['span']
                    if role['role'] == 'Arg0':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            info_elem['OtherPatients'].append(name)
                    elif role['role'] == 'Arg1':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if(name):
                            if name not in possible_subjects[id]:
                                possible_subjects[id].append(name)
                            info_elem['OtherAgents'].append(name)
            



        # add what needed
        if(subject_added):info_elements.append(info_elem)
        if(marriage_added):marriages_info.append(marriage_info)

    return info_elements,possible_subjects


info_elements,possible_subjects  = create_birthday_samples(nli_dataset['train'],months_list)
# print(len(nli_dataset['train']))
# Out:
# 51086it [00:50, 1006.30it/s]

# %%
def add_hp(person1,verb,person2,time=None,location=None):
    elements = [person1,verb,person2]
    if time is not None:
        elements+=(['in',time])
    if location is not None:
        elements+=(['at',location])
    hp = create_hp(elements)
    return hp
    



verbs_to_past = {
    'kill.01': 'killed',
    'marry.01': 'married',
    'support.01': 'supported',
    'call.01': 'called',
    'find.01': 'found',
    'inspire.01': 'inspired',
    'meet.02': 'met',
    'attack.01': 'attacked',
    'judge.01': 'judged',
    'advise.01': 'advised',
    'love.01': 'loved',
    'criticize.01': 'criticized',
    'help.01': 'helped',
    'thank.01': 'thanked',
    'train.01': 'trained',
    'fight.01': 'fought',
    'follow.01': 'followed',
    'influence.01': 'influenced',
    'observe.01': 'observed',
    'protect.01': 'protected',
}



def from_info_to_samples(info_elements,possible_persons,verbs):

    new_samples = []
    # if there is born event I exploit it to create contradiction samples!
    # TODO THIS IS ALPHA VERSION I NEED TO IMPROVE MAYBE GENERALIZE!

    # Filtraggio delle chiavi che accedono a liste con lunghezza superiore a 1
    list_keys = [key for key, value in possible_persons.items() if len(value) > 1]

    for info_elem in info_elements:


        neutrals = []
        contrs = []


        date_born = None
        text_pre = info_elem['premise']
        location_born = None
        new_hps_contr = []
        new_hps_neutral = []
        

        subject = info_elem.get('subject')
        date_born = info_elem.get('whenBorn')
        id = info_elem['id']
        

        #CREATE CONTRADICTIONS THANKS TO WRONG DATE
        if date_born is not None and subject is not None:
            time_before = change_time(date_born)
            time_after = change_time(date_born)
            location_born = info_elem.get('whereBorn')

            list_other_subjects = []
            list_other_patients = info_elem.get('OtherPatients')
            list_other_agents = info_elem.get('OtherAgents')

            if list_other_agents is not None:
                list_other_subjects += list_other_patients
            if list_other_agents is not None:
                list_other_subjects += list_other_agents
            

            
            if len(list_other_subjects) >= 1:
                #get a random name
                random_index_name = random.randint(0,len(list_other_subjects)-1)
                name =list_other_subjects[random_index_name] 
                contr = True
            else:
                #get a random name from the all possible!
                casual_key = random.choice(list_keys)
                # print(f"casual key -> {casual_key}")
                while casual_key == id:
                    casual_key = random.choice(list_keys)
                names = possible_persons[casual_key]
                name = names[random.randint(0,len(names)-1)]



            # first random frame
            random_frame = random.choice(list(verbs_to_past.items()))
            while random_frame[0] in info_elem['frane_name_pb']:
                random_frame = random.choice(list(verbs_to_past.items()))



            if location_born is not None:
                locations = location_born.split(',')
                if len(locations) > 1:
                    location_chose = random.choice(locations)
                else:
                    location_chose = locations[0]

                contrs.append(add_hp(subject,random_frame[1],name,time = time_before.replace(',', ' '),location=location_chose))

                random_frame = random.choice(list(verbs_to_past.items()))
                while random_frame[0] in info_elem['frane_name_pb']:
                    random_frame = random.choice(list(verbs_to_past.items()))

                neutrals.append(add_hp(subject,random_frame[1],name,time = time_after.replace(',', ' '),location=location_chose))
            else:
                contrs.append(add_hp(subject,random_frame[1],name,time = time_before.replace(',', ' ')))

                random_frame = random.choice(list(verbs_to_past.items()))
                while random_frame[0] in info_elem['frane_name_pb']:
                    random_frame = random.choice(list(verbs_to_past.items()))
                
                neutrals.append(add_hp(subject,random_frame[1],name,time = time_after.replace(',', ' ')))

                    

            for elem in contrs:
                new_sample = {}
                new_sample['premise'] = text_pre
                new_sample['hypothesis'] = elem
                new_sample['label'] = "CONTRADICTION"
                new_samples.append(new_sample)
            
            for elem in neutrals:
                new_sample = {}
                new_sample['premise'] = text_pre
 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [0, 3]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [5, 9]}]}}, {'tokenIndex': 10, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [0, 10]}, {'role': 'Attribute', 'score': 1.0, 'span': [11, 20]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [0, 10]}, {'role': 'ARG2', 'score': 1.0, 'span': [11, 20]}]}}, {'tokenIndex': 22, 'verbatlas': {'frameName': 'BEGIN', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [21, 22]}, {'role': 'Theme', 'score': 1.0, 'span': [23, 35]}, {'role': 'Time', 'score': 1.0, 'span': [35, 39]}]}, 'englishPropbank': {'frameName': 'begin.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [21, 22]}, {'role': 'ARG1', 'score': 1.0, 'span': [23, 35]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [35, 39]}]}}, {'tokenIndex': 25, 'verbatlas': {'frameName': 'HOST_MEAL_INVITE', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [21, 22]}, {'role': 'Attribute', 'score': 1.0, 'span': [23, 24]}, {'role': 'Beneficiary', 'score': 1.0, 'span': [26, 27]}, {'role': 'Attribute', 'score': 1.0, 'span': [31, 35]}, {'role': 'Time', 'score': 1.0, 'span': [35, 37]}]}, 'englishPropbank': {'frameName': 'host.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [21, 22]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [23, 24]}, {'role': 'ARG1', 'score': 1.0, 'span': [26, 27]}, {'role': 'ARGM-COM', 'score': 1.0, 'span': [27, 31]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [31, 35]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [35, 37]}]}}, {'tokenIndex': 41, 'verbatlas': {'frameName': 'RECEIVE', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [40, 41]}, {'role': 'Theme', 'score': 1.0, 'span': [42, 48]}]}, 'englishPropbank': {'frameName': 'receive.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [40, 41]}, {'role': 'ARG1', 'score': 1.0, 'span': [42, 48]}]}}, {'tokenIndex': 50, 'verbatlas': {'frameName': 'WIN', 'roles': [{'role': 'Agent', 'score': 1.0, 'span': [40, 41]}, {'role': 'Patient', 'score': 1.0, 'span': [51, 53]}, {'role': 'Cause', 'score': 1.0, 'span': [53, 61]}]}, 'englishPropbank': {'frameName': 'win.01', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [40, 41]}, {'role': 'ARG1', 'score': 1.0, 'span': [51, 53]}, {'role': 'ARGM-CAU', 'score': 1.0, 'span': [53, 61]}]}}, {'tokenIndex': 54, 'verbatlas': {'frameName': 'MOUNT_ASSEMBLE_PRODUCE', 'roles': [{'role': 'Product', 'score': 1.0, 'span': [55, 61]}]}, 'englishPropbank': {'frameName': 'produce.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [55, 61]}]}}]

# %% [markdown]
# # Modify hypothesis

# %%
# extract info from hypothesis and leverage them!
def extract_hp_info(filtered_dataset):
    verbs= set()
    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')
    most_frequent_verbs = {}
    most_frequent_pbframe = {}
    
    for index,elem in tqdm(enumerate(filtered_dataset)):

        new_sample = {}
        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']


        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']


        # find the born event in srl annotations
        # info_elem['subjects'] = extract_full_names(text_pre)
        # info_elements.append(info_elem)





        for annotation_hp in annotations_hp:

            #reference verb of annotation
            token_index = annotation_hp['tokenIndex']
            verb = tokens_hp[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_hp['verbatlas']
            propbankAnn = annotation_hp['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            rolespb = propbankAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']
            


            if (frame_name_pb in most_frequent_pbframe):
                most_frequent_pbframe[frame_name_pb] +=1
            else:
                most_frequent_pbframe[frame_name_pb] = 0


            if (verb in most_frequent_verbs):
                most_frequent_verbs[verb] +=1
            else:
                most_frequent_verbs[verb] = 1

           

    # return info_elements
    return most_frequent_verbs,most_frequent_pbframe
    return verbs
    return most_frequent_verbs,most_frequent_pbframe,verbs

most_frequent_verbs,most_frequent_pbframe = extract_hp_info(nli_dataset['train'])
# info_elements = extract_info(nli_dataset['train'])
# most_frequent_verbs,most_frequent_pbframe,verbs = extract_info(nli_dataset['train'])

# %%
# print(most_frequent_verbs)
for elem in most_frequent_pbframe:
    print(f" {elem} :: {most_frequent_pbframe[elem]}")

# %% [markdown]
# # To check

# %%
# IDEA: leverage information about bithday
from tqdm import tqdm
from datetime import datetime
import sys






months_list = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]

def clean_name(name):
    # Remove trailing characters like '(' and strip any leading/trailing whitespace
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    # Split the name into components and check if all components start with a capital letter
    name_components = cleaned_name.split()
    if all(component[0].isupper() for component in name_components):
        return cleaned_name
    return False

def strip_name(name):
    pronoms = {'he','she'}
    final_name = ''
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    name_components = cleaned_name.split()
    for index,component in enumerate(name_components):
        if component.lower() in pronoms: return False
        if component[0].isupper(): final_name+=component.strip()
        if index != len(name_components)-1: final_name+=' '
    return final_name

def clean_time(date_str):
        # Remove parentheses and "born"
        date_str = date_str.strip('() ').replace('born ', '')
        try:
            # Parse the date
            date_obj = datetime.strptime(date_str, '%B, %d , %Y')
            # Format the date in the desired format
            return date_obj.strftime('%B, %d, %Y')
        except ValueError as e:
            print(f"Error parsing date: {date_str}")
            return False  # Return original date string if parsing fails
        
def extract_date_components(date_str,pattern,months_list):
    matches = pattern.findall(date_str)
    day, month, year = None, None, None
    for match in matches:
        if match[0]:
            day = match[0]
      
        if match[1]:
            month = match[1]
        if match[2]:
            year = match[2]
        
        # more check to avoid error!
        if day and not (1 <= int(day) <= 31):
            day = None
        if month and month not in months_list:
            month = None
    return day, month, year

def check_location(text):
    doc = nlp(text)
    locations = []
    
    # iterate over the entities 
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE (Geopolitical Entity) is the label used for locations
            locations.append(ent.text)    

    return locations




#AUXILIAR METHOD FOR EACH CASE
def be():
    pass




## TODO: manca solo da creare nuovi sample
def extract_relations(filtered_dataset,months_list):

    most_frequent_verbs = {}
    is_data = set()
    nb_data = set()
    new_samples = []
    info_elements = []
    possible_locations = []
    marriage_role = set()
    marriages_info = []
    verbs= set()


    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')

    for index,elem in tqdm(enumerate(filtered_dataset)):

        born_event = False
        new_sample = {}

        info_elem = {} # a dictionary in which I store the information of who is born
        marriage_info = {}

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']
        subject_added = False
        
        marriage_added = False

        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']


        # find the born event in srl annotations

        subjects_premise = {}

        for annotation_pre in annotations_pre:
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]  #reference verb of annotation
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            roles = verbatlasAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']

            #Check born event
            if frame_name == 'GIVE-BIRTH':
                born_event = True # in this sample there is a relation born
                for role in roles:
                    span = role['span']
                    if role['role'] == 'Patient':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            subject_added = True
                            subjects_premise['born'] = name
                            info_elem['subject'] = name
                    elif role['role'] == 'Time':
                        text = get_text_from_span(tokens_pre,span)
                        day,month,year = extract_date_components(text,pattern_time,months_list)
                        if (day or month or year):
                            format_time = ''
                            if (day!=None): 
                                format_time+=day+','
                            else: 
                                format_time+='None,'
                            if (month!=None): 
                                format_time+=month+','
                            else: 
                                format_time+='None,'
                            if (year!=None): 
                                format_time+=year+''
                            else: 
                                format_time+='None'
                            info_elem['whenBorn'] = format_time
                    elif role['role'] == 'Location':
                        text = get_text_from_span(tokens_pre,span)
                        locations = check_location(text)
                        if(len(locations)>0):
                            list_loc = ''
                            for i in range(len(locations)):
                                list_loc += locations[i]
                                if (i!= len(locations)-1): list_loc+=','
                            info_elem['whereBorn'] = list_loc
                    elif role['role'] == 'Agent':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            info_elem['parent'] = name
            else:
                for role in roles:
                    span = role['span']
                    if role['role'] == 'Patient':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            subjects_premise['OtherPatients'].append(name)
                    elif role['role'] == 'Agent':
                        text = get_text_from_span(tokens_pre,span)
                        name = clean_name(text)
                        if (name):
                            subjects_premise['OtherAgents'].append(name)


                
            
        

        # if there is born event I exploit it to create contradiction samples!
        if born_event:
            print("subject premise", subjects_premise)
            sys.exit()
















            # marry.01
            if (frame_name_pb == "sostituisci con marry.01"):
                # verbs.add(verb)
                


                arg1 = None
                arg2 = None
   

                for role in roles_pb:
                    role_info = role['role']
                    span = role['span']
                    text = get_text_from_span(tokens_pre, span)
                    marriage_role.add(role_info)
                    if role_info == 'ARG1':
                        name = strip_name(text)
                        if (name):
                            marriage_info['Arg1'] = name
                            arg1 = name

                    elif role_info == 'ARG2':
                        name = strip_name(text)
                        if (name):
                            marriage_info['Arg2'] = name
                            arg2 = name
                if arg1 and arg2: 
                    marriage_added = True
                    if verb in {'marry', 'remarries', 'wed', 'marrying', 'marries', 'married'}:
                        new_sample['hypothesis'] = arg1 + ' ' + verb + ' ' + arg2 
                        new_sample['premise'] = text_pre
                        new_samples.append(new_sample)



        # add what needed
        if(subject_added):info_elements.append(info_elem)
        if(marriage_added):marriages_info.append(marriage_info)

    
    for elem in is_data:
        print("is data:: ",elem)

    return new_samples,info_elements


new_samples,info_elements = extract_relations(nli_dataset['train'],months_list)
# print(len(nli_dataset['train']))

# %% [markdown]
# # Idea generate sentences is a

# %%
filtered_dataset_isa = nli_dataset['train'].filter(lambda example: ' is a ' in example['hypothesis'].lower())
# Out:
# Filter:   0%|          | 0/51086 [00:00<?, ? examples/s]

# %%
for elem in filtered_dataset_isa:
    print(elem['hypothesis'])
# Out:
# Roman Atwood is a content creator.
# There is a movie called The Hunger Games.
# Ryan Seacrest is a person.
# Stranger than Fiction is a film.
# Grace Jones is a dancer.
# Uzbekistan is a part of the Commonwealth of Independent States (CIS).
# Paul Wesley is a professional alias.
# Led Zeppelin is a band.
# Led Zeppelin is a band.
# The Fosters is a television series.
# Overwatch is a video game in which players gain cosmetic awards and it assigns players into two teams of six, each player with a style of play known as Offense, Defense, Tank, and Support.
# Star vs. the Forces of Evil is a series.
# Star vs. the Forces of Evil is a series.
# Star vs. the Forces of Evil is a series.
# Gilmore Girls is a Canadian show.
# Thor: The Dark World is a movie.
# Thor: The Dark World is a movie.
# Thor: The Dark World is a movie.
# Chester Bennington is a person.
# Tender Mercies is a drama from America.
# David Dhawan is a film director.
# Keanu Reeves is a film actor.
# Heartland is a canadian TV series.
# Ronin is a film.
# There is a producer named Fred Savage.
# Interstellar is a narrative in a visual medium.
# Interstellar is a narrative in a visual medium.
# Interstellar is a narrative in a visual medium.
# Brave is a 2010s film.
# There is a geologic period that spans 43 million years called Paleogene.
# Donkey is a fast-talking donkey.
# The Minnesota Vikings is a National Football League team.
# There is a video game called Overwatch (video game).
# Farrah Fawcett acted in the romantic comedy Love is a Funny Thing.
# Juana la virgen is a telenovela written by Perla Farias.
# Robert Redford is a film director.
# Bob Riley is a lawyer.
# The Citadelle Laferrière is a large red fortress.
# Journey is a band.
# Journey is a band.
# Journey is a band.
# Russia is a recognized biologic weapon state.
# There is a group of Americans in the motion picture industry called the Directos Guild of America.
# Gorgeous Ladies of Wrestling is a wrestling promotion for women.
# The Sopranos is a televised show.
# Leonardo DiCaprio is a fish.
# Super Metroid is a movie sequel.
# Super Metroid is a movie sequel.
# Richard Eyre is a television director.
# Saratoga is a Canadian film.
# There is a film called Absolute Beginners.
# The Catalyst is a rock song.
# Umbrella is a single.
# Born This Way is a piece of music.
# There is a mosque in the Taj Mahal.
# Ellyse Perry is a man.
# Ellyse Perry is a man.
# Unapologetic is a work.
# Unapologetic is a work.
# Andre Agassi is a golfer.
# Nicki Minaj is a person.
# Nicki Minaj is a person.
# Nicki Minaj is a person.
# Jack Reacher is a 1600s period piece.
# Romelu Lukaku is a golfer.
# Toy Story is a movie of the buddy comedy adventure genres.
# Randy Orton is a squid.
# Randy Orton is a squid.
# Randy Orton is a squid.
# Randy Orton is a squid.
# Randy Orton is a squid.
# Randy Orton is a squid.
# Randy Orton is a squid.
# The Ten Commandments (1956 film) is a 1956 American movie.
# Lewis Hamilton is a race car driver.
# Lewis Hamilton is a race car driver.
# Lewis Hamilton is a racecar driver in F1.
# There is a screenwriter named Jim Rash.
# Toy Story is a television show.
# Chris Terrio is a film director from the United States.
# Superior Donuts is a noir film.
# Song Sung Blue is a work of music.
# Eva Longoria is a performer.
# Eva Longoria is a performer.
# Diana is a solo album by Diana Ross.
# Three Men and a Baby is a baby food store.
# Jordan Knight is a vegan.
# Moana is a work in the medium of animation.
# The Twilight series's is a young adult vampire romance series, the first book of which is called Twilight.
# The Invention of Lying is a restaurant.
# Constantine is a 2005 novel.
# Las Vegas is a city.
# Las Vegas is a city.
# Las Vegas is a city.
# Purple Haze is a Jimi Hendrix song.
# Purple Haze is a Jimi Hendrix song.
# Purple Haze is a Jimi Hendrix song.
# Ajay Devgn is a banker.
# Abigail Breslin is a person who acts.
# Abigail Breslin is a person who acts.
# Juana la virgen is a telenovela from Venezuela.
# Kaakha Kaakha is a film.
# Lymphoma is a kitten.
# Lithuania is a country that is part of the European Union.
# Iain Glen is a television actor.
# There is a science fiction film called Star Trek.
# There is a science fiction film called Star Trek.
# Estella Warren is a person.
# Ji Chang-wook is a model.
# We Found Love is a song.
# Miranda Cosgrove is a person.
# Miranda Cosgrove is a person.
# Miranda Cosgrove is a person.
# Miranda Cosgrove is a person.
# A Song of Ice and Fire is a work.
# Emilio Estevez is a director.
# Alice is a reworking of an English film.
# Snowpiercer is a film that is on many critic's top ten cinematic film list.
# Jeff Hardy is a 50-year-old wrestler.
# Outlander is a British-American drama television series.
# Raphael Bob-Waksberg is a person.
# Pamela Anderson is a communist.
# Jamie Foxx is a record producer and he acts.
# Thor: The Dark World is a movie from 2013.
# Thor: The Dark World is a movie from 2013.
# Slovakia is a warship.
# Slovakia is a warship.
# Slovakia is a warship.
# Slovakia is a warship.
# Slovakia is a warship.
# Julia Louis-Dreyfus is a student.
# Alice is a reworking of a Federico Fellini film.
# Anderson Cooper is a person.
# Phantoms is a science fiction horror film.
# The Matrix Revolutions is a film released in the early 2000s.
# George Clooney is a fundraiser.
# George Clooney is a fundraiser.
# George Clooney is a fundraiser.
# George Clooney is a fundraiser.
# Junun is a book.
# Junun is a book.
# Following is a film.
# Following is a film.
# Joey Graceffa is a YouTuber and he is American.
# Ellen DeGeneres is a host of a television show.
# Jon Huntsman Jr. is a diplomat.
# Andorra is a television show.
# A Clash of Kings is a novel that Gendry appeared in.
# Stephen Hawking is a politician.
# Teen Wolf is a political movement.
# Teen Wolf is a political movement.
# Teen Wolf is a political movement.
# Los Angeles is a clothing brand in Southern California.
# Paul Simon is a singer-songwriter.
# Transformers: Dark of the Moon is a movie.
# Maggie Gyllenhaal is a singer.
# Shawn Mendes is a musician who records music.
# There is a sitcom from America starring Tim Allen.
# There is a sitcom from America starring Tim Allen.
# Portugal is a state.
# Until Dawn is a survival game.
# Final Fantasy XII is a religion.
# Final Fantasy XII is a religion.
# Final Fantasy XII is a religion.
# Final Fantasy XII is a religion.
# Tequila is a food.
# Lay (entertainer) is a Chinese author in China.
# Patton Oswalt is a stand-up comedian focusing on his own personal quirks.
# Alien: Covenant is a critically panned 2017 American science fiction horror film that was co-written by John Logan and Dante Harper.
# Shaggy is a nickname shared by 4 Scooby-Doo characters.
# Venice is a city.
# Venice is a city.
# Catherine Zeta-Jones is a Pisces.
# Usain Bolt is a whale.
# Usain Bolt is a whale.
# Role Models is a motion picture.
# Kathy Bates is a person.
# Oh Yeon-seo is a former member of a band and she is musical.
# D. B. Weiss is a driver.
# Beijing is a city.
# Beijing is a city.
# Beijing is a city.
# Beijing is a city.
# Missing is a French film.
# Tyler, The Creator is a recording artist.
# Splatoon 2 is a team-based third-person RPG.
# Colombia is a place.
# Colombia is a place.
# Colombia is a place.
# Serena Williams is a tennis player.
# Serena Williams is a tennis player.
# Serena Williams is a tennis player.
# Serena Williams is a tennis player.
# American Idiot is a Green Day album.
# Little Mix is a girl group.
# Little Mix is a girl group.
# Little Mix is a girl group.
# Lily James is a person.
# Harry Potter is a navy captain.
# Harry Potter is a navy captain.
# Harry Potter is a navy captain.
# Dirty Diana is a song by Michael Joseph Jackson.
# The Strain is a name.
# Frank is a studio album.
# Ajay Devgan is a person.
# Leukemia is a group of cancers beginning in bone marrow and producing abnormal white blood cells.
# The Sopranos is a show.
# The Sopranos is a show.
# Vito Corleone is a fictional mountain.
# Philadelphia is a center of illegal activity.
# Nick Jonas is a recording artist.
# Nick Jonas is a recording artist.
# Nick Jonas is a recording artist.
# Nick Jonas is a recording artist.
# Iceland is a country.
# There is a American film called Maleficent with Ella Purnell in it.
# James Wilson is a real person yet to be made into a fictional character.
# Diego Costa is a soccer player
# Diego Costa is a soccer player
# The Hobbit is a movie.
# Randy Orton is a professional wrestler.
# Google Home is a smart speaker by Google.
# The Santos FC is a club.
# The Santos FC is a club.
# Jeff Ament is a member of a band.
# Mark Burg is a theater actor.
# Werner Herzog is a German producer.
# Ratatouille is a Golden Globe wining 2007 film.
# Basketball is a musical.
# Tiger Woods is a professional athlete.
# Tiger Woods is a professional athlete.
# Prometheus is a motion picture.
# Prometheus is a motion picture.
# Prometheus is a motion picture.
# Prometheus is a motion picture.
# The World Senior Chess Championship is a chess competition.
# Aneurin Barnard's birth date is a date other than May 8th.
# Crystal Palace F.C. is a science club.
# Gunday is a film.
# Telangana is a southern Indian state.
# Anderson Silva is a martial artist.
# Anderson Silva is a martial artist.
# Egypt is a city.
# Christina Aguilera is a performer of music.
# Christina Aguilera is a performer of music.
# Christina Aguilera is a performer of music.
# Christina Aguilera is a performer of music.
# Christina Aguilera is a performer of music.
# Josh Homme is a singer.
# Kris Wu is a Canadian thespian.
# There is a popular culture category for politics.
# Mukesh Ambani is a person.
# Mukesh Ambani is a person.
# Mukesh Ambani is a person.
# Directing is a profession of Alfred Hitchcock's.
# Silicon Valley is a county.
# Silicon Valley is a county.
# Seth Rogen is a car.
# Seth Rogen is a car.
# Iran is a sovereign state that still has a large influence.
# Billy Wilder is a director.
# Billy Wilder is a director.
# Stephon Marbury is a sports player.
# Ruth Negga is a film actress.
# Thomas Haden Church is a director.
# Thomas Haden Church is a director.
# 24 is a film.
# Eddie Vedder is a musician.
# Patrick Bateman is a character in fiction.
# Saw VI is a 2009 film from America.
# Google is a multinational organization.
# Law of value is a central concept in Karl Marx corpse.
# The Celtic F.C. is a professional football club.
# Star Wars: The Force Awakens is a film.
# Star Wars: The Force Awakens is a film.
# Star Wars: The Force Awakens is a film.
# Gorgeous Ladies of Wrestling is a professional wrestling promotion.
# Lewis Hamilton is a driver.
# Lewis Hamilton is a driver.
# Lewis Hamilton is a driver.
# Lewis Hamilton is a driver.
# Lipstick Under My Burkha is a movie.
# Kirk Douglas is a person who acts as a producer.
# Joey Graceffa is a person.
# Thandie Newton is a person.
# Vera Farmiga is a French actress.
# Ted Kennedy is a senator.
# Kumkum Bhagya is a television show from India.
# Portugal is a city.
# Gemini is a 2002 action movie.
# Detroit is a place.
# Detroit is a place.
# Jamie Foxx is a piano player.
# Zombieland is a film that Jesse Eisenberg starred in.
# Roald Dahl is a British writer.
# Peter Davison is a professional television actor.
# Star Wars: The Force Awakens is a western.
# Andy Warhol is a banker.
# Selena Gomez is a person.
# Selena Gomez is a person.
# Alia Bhatt is a film actress.
# Twitter is a consumer of breaking news.
# The Nintendo Switch is a console.
# The Nintendo Switch is a console.
# The Nintendo Switch is a console.
# The Nintendo Switch is a console.
# The Nintendo Switch is a console.
# Alice is a reworking of a horror film.
# Donnie Wahlberg is a person.
# Berlin is a place.
# Berlin is a place.
# There is a country called the United Kingdom.
# There is a country called the United Kingdom.
# There is a country called the United Kingdom.
# The National Library of India is a library of a certain size.
# Shania Twain is a musical artist that writes songs.
# Telangana is a place.
# Home Alone is a Christmas movie.
# Joan Allen is a star of The Contender.
# Davis Guggenheim is a television show-runner.
# The Conjuring is a horror film.
# Steve Buscemi is a person
# Steve Buscemi is a person
# Steve Buscemi is a person
# Wiz Khalifa is a person.
# Wiz Khalifa is a person.
# Basketball is a sport that involves working together.
# Deadpool (film) is a superhero television show only.
# There is a series called Grey's Anatomy.
# There is a series called Grey's Anatomy.
# There is a series called Grey's Anatomy.
# There is a series called Grey's Anatomy.
# There is a series called Grey's Anatomy.
# Singapore is a location.
# Singapore is a location.
# Singapore is a location.
# Singapore is a location.
# The Vampire Diaries is a television series.
# The Vampire Diaries is a television series.
# The Vampire Diaries is a television series.
# The Vampire Diaries is a television series.
# The Vampire Diaries is a television series.
# Mother Teresa is a saint.
# Wayne Rooney is a professional footballer.
# Wayne Rooney is a professional footballer.
# One character on Homeland is a U.S. Marine.
# Naturi Naughton is a skater.
# The Legend of Tarzan (film) is a film that had zero reviews from critics only.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Baahubali: The Beginning is a movie.
# Stockard Channing is a singer.
# Friday the 13th is a film series.
# Marble Hill, Manhattan is a New York City neighborhood.
# Michael C. Hall is a Golden Globe Award winner.
# Kangana Ranaut is a singer.
# Rescue Me is a thriller TV series.
# Usher is a music artist.
# Usher is a music artist.
# Thor: The Dark World is a TV show.
# Thor: The Dark World is a TV show.
# Gunday is a film.
# Gunday is a film.
# There Will Be Blood is a published work.
# Chandni is a film from India.
# 50 First Dates is a film.
# Diamonds is a work of music.
# Bring It On (film) is a film.
# Roman Atwood is a vlogger.
# In & Out is a film.
# Eddie Redmayne is a vegetarian.
# Legion is a villainous character.
# Austria is a location.
# Hugo Weaving is a voice actor.
# Miyu Irino is a citizen of Japan.
# Brooks Wackerman is a member of a band.
# Unleashed is a song.
# Demi Lovato is a person.
# Demi Lovato is a person.
# Demi Lovato is a person.
# Demi Lovato is a person.
# Demi Lovato is a person.
# Demi Lovato is a person.
# Jamie Foxx is a singer.
# Death in Paradise (TV series) is a crime comedy-drama television series that is British and French.
# Wi-Fi is a trademark of the Wi-Fi Alliance, which certifies the technology.
# Radiohead is a river.
# Imperial is a county outside of Southern California.
# Harry Potter and the Deathly Hallows is a novel which received acclaim.
# Guy-Manuel de Homem-Christo is a choreographic director.
# Vedanta is a term that refers to a specific Hindu tradition.
# Vedanta is a term that refers to a specific Hindu tradition.
# Hulk is a TV show.
# Hulk is a TV show.
# Hulk is a TV show.
# Bob Riley is a Brazilian.
# Olivia Wilde is a dancer.
# Denis Leary is a performer.
# Las Vegas is a city.
# Las Vegas is a city.
# Hilary Swank is a woman.
# Allure is a beauty magazine.
# Wishful Drinking is a novel.
# D. B. Weiss is a reader.
# Australia is a boat in the Pacific Ocean.
# Salman Khan is a performer.
# Salman Khan is a performer.
# Craig Middlebrooks is a character on an NBC sitcom.
# Sherlock is a TV series on the BBC.
# Bam Margera is a movie performer.
# Tom Felton is a person.
# Tom Felton is a person.
# Carice van Houten is a doctor.
# Evolution is a debut studio album.
# Planet of the Apes is a film.
# Werner Herzog is a German screenwriter.
# The Odyssey is a non-linear epic poem.
# Romelu Lukaku is a soccer player.
# Bangladesh is a nation.
# Kid Rock is a rapper.
# Svitavy is a place.
# Christine Daaé is a character by Gaston Leroux.
# The Prestige is a museum.
# The Wolf of Wall Street is a movie.
# The Wolf of Wall Street is a movie.
# Snooki is a television host.
# Thor: The Dark World is a movie.
# Natalie Portman is a person.
# Dwayne Johnson is a film producer.
# Ted Kaczynski is a domestic anarchist.
# Big Boi is a film producer.
# Fight Club is a television show.
# Grey's Anatomy is a TV drama.
# Grey's Anatomy is a TV drama.
# Vincent Cassel is a singer.
# Paleogene is a geologic system that spans 43 million years.
# The Netherlands is a nation.
# The Netherlands is a nation.
# The Netherlands is a nation.
# The Netherlands is a nation.
# The Vampire Diaries is a popular American drama television series.
# The Vampire Diaries is a popular American drama television series.
# Gunday is a romantic film.
# Jared Kushner is a business owner.
# Mr. Freeze is a supervillain.
# Kiefer Sutherland is a person.
# Raphael Bob-Waksberg is a person who produces.
# New Girl is a book.
# New Girl is a book.
# New Girl is a book.
# New Girl is a book.
# New Girl is a book.
# Gunday is a bad film.
# The People vs. Larry Flynt is a biopic.
# Tennis is a sport.
# Tennis is a sport.
# Tennis is a sport.
# Norway is a country.
# Charles Mackay is a poet and an author.
# Kong: Skull Island is a 2015 film.
# Live Your Life is a book.
# Live Your Life is a book.
# Antarctica is a continent.
# Antarctica is a continent.
# Planet of the Apes is a TV show.
# Tyrion Lannister is a character in fiction.
# Tyrion Lannister is a character in fiction.
# Tyrion Lannister is a character in fiction.
# Tyrion Lannister is a character in fiction.
# Tyrion Lannister is a character in fiction.
# Tyrion Lannister is a character in fiction.
# Taraji P. Henson is a television actor.
# Bangladesh is a place.
# A Wrinkle in Time is a profitable business.
# John Cena is a winner for a event held in 2008.
# Travis Barker is a drummer.
# Travis Barker is a drummer.
# Ryan O'Neal is a former fighter.
# Terminator Genisys is a soft reboot to the film series.
# Emmy Rossum is a person.
# Emmy Rossum is a person.
# Emmy Rossum is a person.
# The Voice is a university class.
# The Voice is a university class.
# The Voice is a university class.
# Love & Friendship is a film.
# Future is a video game series.
# Future is a video game series.
# The Taj Mahal's centerpiece is a tomb.
# Adventure Time is a series on Cartoon Network.
# Harley Quinn is a comic book character.
# The Girl on the Train is a statue in Manhattan.
# The Girl on the Train is a statue in Manhattan.
# Gregor Clegane is a fictional dog.
# Gregor Clegane is a fictional dog.
# Gregor Clegane is a fictional dog.
# Gregor Clegane is a fictional dog.
# Jennifer Aniston is a Canadian actress.
# Mark Hamill is a performer.
# Mark Hamill is a performer.
# Mark Hamill is a performer.
# Mark Hamill is a performer.
# Passengers is a film.
# Jamie Foxx is a performer.
# Jamie Foxx is a performer.
# Jamie Foxx is a performer.
# Sunrise is a studio.
# Warren Buffett is a saint.
# Eat Pray Love is a romantic best-selling album.
# The Hunger Games is a convention.
# The Hunger Games is a convention.
# The Hunger Games is a convention.
# Believe is a work.
# Believe is a work.
# Macbeth is a comedy.
# Macbeth is a comedy.
# Spotlight is a goat.
# Spotlight is a goat.
# Spotlight is a goat.
# Sons of Anarchy is a work.
# Sons of Anarchy is a work.
# Dhool is a work.
# The X Factor is a TV show.
# The X Factor is a TV show.
# The X Factor is a TV show.
# The X Factor is a TV show.
# The X Factor is a TV show.
# Nocturnal Animals is a band.
# Nocturnal Animals is a band.
# Ink Master is a film.
# John Williams is a gymnast.
# Harry Potter is a fictional story.
# There is a producer named Jim Rash.
# Rajesh Khanna is a novelist.
# There is a comedian named Woody Allen.
# Charles Haley is a former football linebacker and defensive end.
# Warren Casey is a playwright.
# Jamaicans for Justice is a group that is non-profit.
# Cher is a film actor.
# Diary of the Dead is a film that tries to get a physiological reaction through the use of fear and shocking one's audiences.
# Jenna Dewan is a person from America.
# Star Wars: The Last Jedi is a space opera.
# The Who is a British band.
# Girls' Generation is a boy band.
# The Great Outdoors (film) is a comedy creative work.
# Seminary is a type of educational institution.
# Jared Kushner is a real estate investor.
# Rabat is a capital city.
# Dwyane Wade is a basketball player.
# Gil Sharone began working on an album in 2013 and he is a musician.
# Matt Damon is a producer.
# Mr. Nobody is a comedic film.
# The Smurfs is a TV series.
# Vegemite is a type of stress.
# Daft Punk is a duo.
# Daft Punk is a duo.
# The Prestige is a movie that David Bowie acted in.
# Steven Knight is a director.
# The United States Naval Academy is a four year academy.
# Moscow is a city.
# Moscow is a city.
# Moscow is a city.
# Gendry is a character created by J.K. Rowling.
# Rope is a film.
# Adrienne Bailon is a Canadian.
# G-Dragon is a person who creates art.
# G-Dragon is a person who creates art.
# Liev Schreiber is a stage director.
# Lipstick Under My Burkha is a film.
# Delta Air Lines is a major carrier.
# Sunflower (1970 film) is a film made in Italy.
# There is a company called The New York Times.
# There is a company called The New York Times.
# Wyoming is a place.
# D. B. Weiss is a writer.
# Gillian Anderson is a German-Italian actress.
# Home Alone is a Thanksgiving comedy film.
# Slovenia is a country.
# Slovakia is a place.
# James McAvoy is a person who acts.
# James McAvoy is a person who acts.
# James McAvoy is a person who acts.
# Triple H is a business executive from New Mexico.
# The Strangers is a romantic film.
# Nineteen Eighty-Four is a novel.
# Ramadan is a month of feasting.
# Sarah Palin is a politician.
# Good Will Hunting is a film.
# Jeff Hardy is a team wrestler.
# Iraq is a car.
# Legion is a real human being.
# Jamie Foxx is a songwriter.
# Paleogene is a geologic period that spans 46 million years.
# Baahubali: The Beginning is a 2015 Indian event.
# Kalpana Raghavendar is a songwriter.
# Chess is a sport.
# Mark Cuban is a person who invests.
# Boston Legal is a spin-off.
# Dangerous Liaisons is a film.
# Dangerous Liaisons is a film.
# Emma Thompson is a person.
# Sister Act is a TV show.
# Hotel Hell is a TV series.
# Goliyon Ki Raasleela Ram-Leela is a crime drama film.
# Slash is a guitarist in Guns N' Roses.
# Slash is a guitarist in Guns N' Roses.
# Oakland, California is a tiny city.
# Birth of the Dragon is a film.
# 10 Cloverfield Lane is a book in the Cloverfield franchise.
# Katharine Hepburn is a Classic Hollywood actress.
# Ellen DeGeneres is a Gemini.
# Heartland is a show.
# Heartland is a show.
# Eddie Vedder is a member of a band from anywhere except Seattle, Washington.
# Ajab Prem Ki Ghazab Kahani is a film.
# Cersei Lannister is a character copyrighted by J. J. Abrams.
# Umbrella is a lead singer.
# Young MC is a singer.
# Rabat is a city.
# Mad Men is a series.
# Mad Men is a series.
# The Black Dahlia is a French-American restaurant.
# The Black Dahlia is a French-American restaurant.
# The Black Dahlia is a French-American restaurant.
# Jack Reacher is a movie.
# Just Dance is a song.
# Just Dance is a song.
# Just Dance is a song.
# Just Dance is a song.
# Just Dance is a song.
# Kiiara is a person.
# Kiiara is a person.
# Dungeons & Dragons is a role-playing game.
# Baylor University is a private Texan university.
# Kristofer Hivju is a poet.
# Miley Cyrus is a person.
# Gucci is a luxury brand.
# To Kill a Mockingbird is a book.
# School 2013 is a American television series.
# Horseshoe Falls is a part of Niagara Falls.
# Yamaha Corporation is a corporation.
# Gregor Clegane is a character from a novel by Brandon Sanderson.
# Beautiful is a comedy-drama film.
# Grand Theft Auto V is a game set in an open world.
# Grand Theft Auto V is a game set in an open world.
# Grand Theft Auto V is a game set in an open world.
# Athena is a conductor.
# Egypt is a member of an organization.
# There is a book Wishful Drinking.
# The Illusionist (2006 film) is a film written and directed by Michael Bay only.
# Christopher Marlowe is a translator of French poetry.
# Slovenia is a member of the European Union.
# Richard Curtis is a British scriptwriter.
# Greyson Chance is a Democrat.
# Back to the Future Part II is a movie.
# Shallow Hal is a comedy Canadian film.
# Look at My Dab is a law.
# Tonga is a Christian country.
# John Cena is a person.
# The Boot Monument is a memorial for a conflict with Great Britain.
# Laura Prepon is a Buddhist.
# There is a plain in the center of Ireland.
# The Prestige is a book.
# Mariah Carey is a Canadian songwriter.
# Mariah Carey is a Canadian songwriter.
# Shakira is a dancer.
# Kerala is a State of India.
# Coca is a plant.
# Coca is a plant.
# Brentwood is a place lacking in money and resources.
# The USS Constitution is a fully commissioned Canadian Navy ship.
# The Martian is a 2015 Spanish science fiction film.
# A Perfect Circle is a country supergroup.
# Glenn Frey is a singer.
# Glen Campbell is a musician.
# Dylan O'Brien is a film critic.
# Hugo Weaving is a voice actor.
# Santorini is a place.
# Didier Drogba is a goalscorer.
# Alkaline Trio is a musical group that plays punk rock.
# The New Adventures of Old Christine is a television show.
# Saamy is a 2003 film.
# Kanye West is a critically acclaimed musician.
# David Beckham is a UNICEF UK spokesman.
# Daft Punk is a French music duo.
# Daft Punk is a French music duo.
# Daft Punk is a French music duo.
# Daft Punk is a French music duo.
# Daft Punk is a French music duo.
# Daft Punk is a French music duo.
# J. Cole is a recording artist.
# Nicole Kidman is a person.
# Nicole Kidman is a person.
# Antarctica is a desert.
# Broadchurch is a place.
# Broadchurch is a place.
# Broadchurch is a place.
# XXx: Return of Xander Cage is a film.
# Glenn Close is a person that has been honored on the Hollywood walk of fame with a star.
# Elementary is a television series.
# Toy Story 3 is a 2010 film.
# Pi is a number.
# Pi is a number.
# Pi is a number.
# There is a catastrophic nuclear accident that was called Chernobyl disaster.
# Gennady Golovkin is a squid.
# Gennady Golovkin is a squid.
# Woody Allen is a computer program.
# Woody Allen is a computer program.
# Woody Allen is a computer program.
# Gone with the Wind is a work.
# Gone with the Wind is a work.
# Gone with the Wind is a work.
# Gone with the Wind is a work.
# The Dark Half is a 1983 film.
# Eminem is a rap artist.
# Eminem is a rap artist.
# Eminem is a rap artist.
# Melanie Griffith is a person who acts.
# Gerard Lee is a German novelist.
# Shallow Hal is a creative work.
# Cindy McCain is a businesswoman.
# Cindy McCain is a businesswoman.
# Liberia is a country.
# Solange Knowles is a citizen.
# Princess Agents is a book yet to be adapted to TV.
# Room is a film.
# Ed Sheeran is a guitarist.
# The Wolf of Wall Street is a movie.
# Adventure Time is a series.
# Adrienne Bailon is a European.
# Nepal is a nation.
# Nepal is a nation.
# RuPaul is a dancer.
# The Prestige is a thriller film.
# United Kingdom is a car.
# Rogue is a character who is fictional.
# Catherine Zeta-Jones is a singer.
# Ben Stiller is a member of the Frat Pack.
# In & Out is a comedic film.
# Vera Farmiga is a director.
# Vera Farmiga is a director.
# Ron Cobb is a director.
# Chris Hemsworth is a singer.
# The People vs. Larry Flynt is a biographical drama album.
# There is a county in Southern California.
# There is a county in Southern California.
# There is a county in Southern California.
# Dangerous Beauty is a 1998 funk band.
# Rafael Nadal is a person who plays tennis.
# Rafael Nadal is a person who plays tennis.
# Miranda Kerr is a model.
# Miranda Kerr is a model.
# Miranda Kerr is a model.
# Sleeping Beauty is a show.
# Rogue is a Marvel Comics fictional character.
# Didier Drogba is a soccer player.
# The Juice is a nickname of O. J. Simpson.
# Bob Riley is a pacifist.
# There Will Be Blood is a religious movement.
# Hungary is a member of the AIIB.
# Snooki is a professional wrestler for the WWE.
# The Shadow Line is a creative work.
# Jim Rash is a producer.
# Budapest is a city.
# James Bond is a spy for MI6.
# Chester Bennington is a person.
# Chester Bennington is a person.
# Chester Bennington is a person.
# Chester Bennington is a person.
# Eddie Vedder is a member of a band from Twin Peaks, Washington.
# Snoop Dogg is a person.
# Andorra is a place.
# Andorra is a place.
# Andorra is a place.
# Star Wars: The Force Awakens is a store.
# Legion is a TV series.
# Wentworth is a television series.
# There is a comic book named Captain America.
# Only Lovers Left Alive is a 2013 film.
# Thomas Haden Church is a producer.
# The Great British Sewing Bee is a 45 minute show.
# Jacinda Barrett is a former photographer.
# There is a movie called Toy Story.
# There is a movie called Toy Story.
# There is a movie called Toy Story.
# Craig Middlebrooks is a fictional place.
# Craig Middlebrooks is a fictional place.
# Saamy is a 2003 action film.
# Three Days of the Condor is a political thriller film.
# Selene is a character in a written film.
# Sofía Vergara is a Republican.
# Ben Affleck is a painter.
# Ben Affleck is a painter.
# Ben Affleck is a painter.
# The United Kingdom is a country.
# A Nightmare on Elm Street is a TV episode.
# A Nightmare on Elm Street is a TV episode.
# A Nightmare on Elm Street is a TV episode.
# A Nightmare on Elm Street is a TV episode.
# A Nightmare on Elm Street is a TV episode.
# Wallander is a horror television series.
# Wild is a single frame.
# Wild is a single frame.
# Rich Girl is a remake of a 1773 song.
# Birth of the Dragon is a book.
# Helen Keller is a famous deaf woman.
# The Right Stuff is a historical documentary.
# Régine Chassagne is a woman.
# Thor: The Dark World is a movie featuring a superhero.
# Boston Latin School is a language.
# Lee Child is a Zoroastrian.
# Roman Atwood is a car tire.
# Adele is a person.
# Adi Shankar is a Youtube personality who acts in skits.
# Xbox One is a gaming system.
# Xbox One is a gaming system.
# Born This Way is a work.
# Cape Fear is a remake of the 1962 film of the same name.
# Arnold Vinick is a male character on The West Wing.
# Keisuke Honda is a futbol player.
# Suicide Kings is a mystery crime TV series.
# There is a desert in California.
# There is a desert in California.
# The Silence of the Lambs is a drama film without any elements of horror.
# Feature advertisement is a division of Davis Entertainment.
# Rogue is a Gemini.
# Google is a multinational entity.
# Linda Schuyler is a Canadian.
# Andorra is a place.
# The Ten Commandments is a biblical film.
# Andy Roddick is a professional tennis player.
# Andy Roddick is a professional tennis player.
# One America News Network is a television channel.
# Dirt is a series.
# Red Headed Stranger is a movie.
# K-pop Star 2 is a show from a country.
# Eragon is a film directed by Robert Carlyle.
# Snoop Dogg is a Catholic.
# The Crazies is a film.
# Taylor Swift is a commercial work.
# Overwatch is a game.
# Love Actually is a 2003 art exhibition.
# Jim Rash is a performer.
# Punisher is a war veteran.
# Mao Zedong is a theorist.
# Hawaii Five-0 is a reboot of the original series of the same name.
# The Backstreet Boys is a TV show.
# The Backstreet Boys is a TV show.
# The Backstreet Boys is a TV show.
# Enemy is a film.
# Enemy is a film.
# Enemy is a film.
# Stephen Hawking is a lifetime member of the NRA.
# A Game of Thrones is a television show.
# There is a singer named Miranda Cosgrove.
# Paris is a major center of popular culture.
# Fernando Alonso is a driver.
# Fernando Alonso is a driver.
# Fernando Alonso is a driver.
# Fernando Alonso is a driver.
# United Kingdom is a member of the United Nations.
# Haitian Creole is a novel.
# Houston is a large human settlement called a city.
# Houston is a large human settlement called a city.
# Berlin is a German city.
# La La Anthony is a producer and actress from Hollywood.
# Robert Wagner is a playwright.
# John Stewart is a character.
# Beijing is a car.
# The Murder of Roger Ackroyd is a work of tree.
# Tender Mercies is a 1983 film.
# 50 First Dates is a 2004 American film.
# Joey Graceffa is a YouTube personality.
# Whoopi Goldberg is a stand-up comedian.
# Baloo is a fictional character.
# Paul Wesley is a Canadian.
# Iran is a sovereign state that still has a moderate influence.
# Iraq is a country in Western Asia
# Gregor Clegane is a character from a the kingdom of Westeros.
# Daft Punk is a two people.
# Daft Punk is a two people.
# Daft Punk is a two people.
# Isis is a puppy.
# Thanos is a character that appeared in creative work.
# Thanos is a character that appeared in creative work.
# Tidewater region is a geographic area in the US.
# Tidewater region is a geographic area in the US.
# Tidewater region is a geographic area in the US.
# Tidewater region is a geographic area in the US.
# Shah Rukh Khan is a star in horror comedy cinema.
# Laura Prepon is a singer.
# Gwen Stefani is a fashion designer.
# The Bostonians (film) is a 1984 creative work.
# Gwen Stefani is a celebrity.
# Kurt Angle is a dancer.
# Missing is a 1982 film.
# Three Days of the Condor is a film.
# Three Days of the Condor is a film.
# Eminem is a person.
# Eminem is a person.
# Eminem is a person.
# Jamaicans for Justice is a non-violent group formed in 1995.
# Daz Dillinger is a lawyer.
# Matt Sorum is a member of Blackstreet.
# There is a Christian state called England.
# Novak Djokovic is a vegan.
# Lee Child is a person.
# Lee Child is a person.
# Michelle Williams is a film actress.
# Lust for Life is a film.
# Novak Djokovic is a professional video game player.
# Albus Dumbledore is a headmaster for a school of magic.
# Albus Dumbledore is a headmaster for a school of magic.
# Ocean's Eight is a spin-off of the Ocean's cruise line.
# Mr. Nobody is a film.
# Norway is a town.
# Norway is a town.
# Jet Li is a Chinese martial artist who practices aikido.
# Beyoncé Knowles is a singer.
# Beyoncé Knowles is a singer.
# Beyoncé Knowles is a singer.
# Radiohead is a punk group.
# Shia LaBeouf is a performer.
# Shia LaBeouf is a performer.
# Shia LaBeouf is a performer.
# Shia LaBeouf is a performer.
# Shia LaBeouf is a performer.
# Jamie Foxx is a person who sings.
# There is a film called Back to the Future Part II.
# Roger Federer is a soccer coach.
# Bob Dylan is a painter.
# Popeye is a live-action film adaptation of the Popeye comic strip.
# The United Kingdom is a monarchy with a constitution.
# Take a Bow is a single.
# Demi Lovato is a singer and songwriter.
# Chester Bennington is a Buddhist.
# Futurama is a live action series.
# Dangerous Liaisons is a 1998 American protest.
# Meghan McCain is a host and contributor on a news program.
# Meghan McCain is a host and contributor on a news program.
# Conan O'Brien is a television host.
# Spider-Man 3 is a superhero film.
# There is a precious metal called Gold.
# Chelsea F.C. is a team which has won all 3 UEFA club competitions.
# The Strangers is a film.
# The Strangers is a film.
# Phantoms is a nonfiction romance film.
# Thenmerku Paruvakaatru is a Tamil movie.
# Ji Chang-wook is a person.
# Ji Chang-wook is a person.
# Iron Man 3 is a sequel.
# Maria Sharapova is a tennis player.
# The Danish Girl is a motion picture.
# The Danish Girl is a motion picture.
# Abby Sciuto is a recurring character.
# Lexmark is a thing.
# Jaden Smith is a person.
# Jaden Smith is a person.
# U2 is a Polish band.
# The Bravo Award is a weekly award.
# Chris Brown is a rapper.
# Ron Perlman is a horror movie.
# Solange Knowles is a brief time actress.
# Keith Urban is a country singer who has produced several albums.
# Kaminey is a work.
# T-Pain is a gospel singer.
# Stand-up comedy is a style in which a comedian performs in front of a live audience.
# Carol Leifer is a fiction writer.
# Beyoncé is a singer.
# Beyoncé is a singer.
# Beyoncé is a singer.
# José Aldo is a mixed martial artist from Brazil.
# Katharine Hepburn is a professional actress.
# Katharine Hepburn is a professional actress.
# Christopher Nolan is a person.
# Christopher Nolan is a person.
# The Who is a British band from Leeds.
# Constantine is a film.
# David LeRoy Anderson is a makeup artist.
# Black Sabbath is a rock band from England.
# Glamorous is a song by Fergie.
# Istanbul is a city.
# Istanbul is a city.
# Christopher Marlowe is a person.
# Christopher Marlowe is a person.
# Christopher Marlowe is a person.
# In Her Shoes is a drama.
# The Murder of Roger Ackroyd is a work of detective fiction.
# Prometheus is a 2012 film that serves as a sequel.
# The Amanda Show is a live action television show that aired on Disney.
# London is a region of the world.
# Russia is a country.
# Connie Britton is a person.
# Black Sails is a cancelled television series.
# Selena Gomez is a person who acts.
# Maria Sharapova is a United States resident.
# The 2017 film The Mummy is a sequel to an earlier film.
# Game of Thrones (season 3) is a movie.
# Game of Thrones (season 3) is a movie.
# Grey's Anatomy is a series with dramatic elements.
# When In Rome is a movie that cast Kristen Bell.
# Denmark is a constitutional monarchy.
# Stephen Hawking is a scientist.
# Trolls is a 2016 TV series.
# In Her Shoes is a dating website.
# Gwen Stefani is a fashion model.
# Mark Cuban is a person.
# Marcus Allen's younger brother is a monk.
# Albania is a supporter of the Union for the Mediterranean
# The Blacklist is a recorded work.
# The Blacklist is a recorded work.
# Gerard Butler is a performer.
# Gerard Butler is a performer.
# Gerard Butler is a performer.
# Gerard Butler is a performer.
# The Gadsden flag is a historical controversial flag.
# John Stewart is a fiction writer.
# Sherlock (TV series) is a drama centered around crime.
# Massachusetts is a place.
# Massachusetts is a place.
# Massachusetts is a place.
# Heikegani is a species of lobster.
# 21 Jump Street is a comic book.
# 21 Jump Street is a comic book.
# Ron Perlman is a Leo.
# Film is a field that Sahid Kapoor works in.
# Film is a field that Sahid Kapoor works in.
# Film is a field that Sahid Kapoor works in.
# Film is a field that Sahid Kapoor works in.
# Adrienne Bailon is a magician.
# Akshay Kumar is a person.
# Akshay Kumar is a person.
# Louis Tomlinson is a person.
# Louis Tomlinson is a person.
# Louis Tomlinson is a person.
# The Night Of is a miniseries.
# A Perfect Circle is a supergroup from America.
# Assassination is a film that Jun Ji-hyun is in.
# The Messenger is a film released in 2009.
# Pawn Sacrifice is a film about a director.
# Pamela Anderson is a model.
# Following is a film.
# Following is a film.
# Formula One is a league.
# The Prestige is a 2006 British-American mystery thriller film.
# Adrien Broner is a professional American boxer.
# Richmond, Virginia is a neighbor to the United States Court of Appeals for the Fourth Circuit.
# Gregor Clegane is a character in the A Song of Ice and Fire collection.
# Lauren Graham is a person.
# Roald Dahl is a governor.
# Delta Air Lines is a transport provider.
# True Blood is a horror television series.
# Jake Gyllenhaal is a person.
# Jake Gyllenhaal is a person.
# Jake Gyllenhaal is a person.
# Adam West is a film actor.
# Christine Daaé is a character.
# Radiohead is a single person.
# Heidi Klum is a businesswoman.
# Heidi Klum is a businesswoman.
# The Chronicles of Narnia is a series from Walden Media based in CA.
# Observer Media is a print company.
# Wi-Fi is a technology.
# Scarlett Johansson is a performer.
# Black Sails is a prequel to Treasure Island set in 1692.
# Lady Gaga is a lizard, songwriter, and actress.
# Champion is a film that has nothing to do with sports.
# Alfred Hitchcock is a choreographer.
# Kate Beckinsale is a person.
# Cambodia is a place.
# Queen Latifah is a musician.
# Queen Latifah is a musician.
# Princess Margaret, Countess of Snowdon is a member of the British comedy troupe.
# Bill Clinton is a politician.
# Big Boi is a member of American hip hop duo Outkast.
# Warren Casey is a writer.
# Suicide Kings is a film that was created in 1997.
# Willow Smith is a person.
# The Fall (Gorillaz album) is a photo album.
# The Fall (Gorillaz album) is a photo album.
# Jared Leto is a director.
# Mark Ruffalo is a producer.
# Roy Whiting is a convicted child killer.
# Paper Moon (film) is a 1973 American comedy-drama film.
# There is a writer for Doctor Who.
# Facebook is a social networking service and is successful.
# Goddamnit is a debut studio album recorded by Alkaline Trio.
# The Twilight Saga is a work.
# The Fujitsu iPAD is a desktop computer.
# Hotel Transylvania is a computer-animated film by Sony Pictures.
# The Marvel Cinematic Universe is a television series.
# Southport is a town.
# Shia LaBeouf is a male actor.
# Lake Powell is a dog.
# Green Day is a band.
# Green Day is a band.
# Green Day is a band.
# La La Anthony is a radio personality.
# Fiji is a monarchy.
# Ready Player One is a literary work.
# Ready Player One is a literary work.
# Ready Player One is a literary work.
# Elsa Pataky is a Spanish model.
# Kill Bill: Volume 2 is a TV show.
# There is a sport called Cricket.
# There is a sport called Cricket.
# There is a sport called Cricket.
# There is a sport called Cricket.
# There is a sport called Cricket.
# There is a sport called Cricket.
# Broadchurch is a book series.
# Veronica Mars is a character.
# Negan is a fictional character in The Walking Dead.
# Steven Tyler is the only member of his band who is a multi-instrumentalist.
# Italy is a parliamentary monarchy.
# The Girl on the Train is a film.
# The Girl on the Train is a film.
# Daddy Yankee is a website.
# David Jones (video game developer) is a son.
# Vito Corleone is a fictional character created by Mario Puzo.
# Steven Spielberg is a citizen of a country.
# Wishful Drinking is a book.
# There is a book called Catching Fire.
# There is a book called Catching Fire.
# Jet Li is a Russian martial artist.
# Jake Gyllenhaal is a person.
# Nicolas Cage is a person.
# Jim Rash is a performer.
# Vuelta a Espana is a competition where Chris Froome was a three-time runner up.
# Alien: Covenant is a type of art.
# Houston is a city in Texas.
# The Adjustment Bureau is a thriller film.
# Foxcatcher is a film.
# Kurt Angle is a dog walker.
# Star vs. the Forces of Evil is a comic book.
# Star vs. the Forces of Evil is a comic book.
# John Cena is a wrestler.
# Batman v Superman: Dawn is a film about superheroes.
# Cristiano Ronaldo is a professional footballer for Spanish club Real Madrid.
# Hilary Swank is a woman.
# Kristofer Hivju is a Norwegian producer.
# Jim Rash is a performer.
# Canada is a country.
# The Sopranos is a show on television.
# The Sopranos is a show on television.
# The Sopranos is a show on television.
# Mike Pence is a Republican.
# Mike Pence is a Republican.
# Mike Pence is a Republican.
# Aruba is a sea.
# FC Barcelona is a North American football club.
# FC Barcelona is a North American football club.
# FC Barcelona is a North American football club.
# FC Barcelona is a North American football club.
# Foundations is a song by Kate Nash.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Luxembourg is a steak with a salad.
# Pope John Paul II is a movie.
# Joy is a biographical film.
# Big Boi is a member of a group.
# Minnesota is a regional division.
# Quinoa is a plant.
# There is a YouTube video series about the life of Jazz Jennings hosted by Jazz Jennings.
# Meek Mill is a hip hop artist.
# Before Night Falls is a film.
# Before Night Falls is a film.
# Pineapple Express is a horror film.
# Tyrese Gibson is a performer.
# 42 is a strictly fictional film.
# Kamala Harris is a person.
# Kamala Harris is a person.
# Kamala Harris is a person.
# Sam Smith is a person.
# Before Night Falls is a 2017 film.
# Sansa Stark is a wizard.
# Captain America: The Winter Soldier is a TV show.
# Arnold Vinick is a nonfiction character.
# Adam Sandler is a playwright.
# Broadcast News is a television show.
# Nikita is a reboot of a film series.
# 50 First Dates is a 2004 Danish film.
# Black Mirror is a British science-fiction television show.
# Maggie Smith is a singer.
# The Amanda Show is a dramatic television show.
# Matt Sorum is a member of Slipknot.
# Pirates of the Caribbean (film series) is a series.
# Pirates of the Caribbean (film series) is a series.
# Darth Vader is a character in Star Wars.
# Darth Vader is a character in Star Wars.
# Punk rock is a genre.
# Girls' Generation is a South Korean girl group.
# Anderson Cooper is a Gemini.
# Scars to Your Beautiful is a movie.
# The Xbox One is a console for video games.
# Avatar is a film.
# Avatar is a film.
# Superman is a Marvel Comics character.
# Superman is a Marvel Comics character.
# Transformers: The Last Knight is a movie.
# Transformers: The Last Knight is a movie.
# Transformers: The Last Knight is a movie.
# Love Actually is a movie.
# Love Actually is a movie.
# Punk rock is a genre of rock.
# The Voice is a reality television show.
# Junun is a film directed by Paul Thomas Anderson.
# There is a video game called Splatoon 2.
# Prometheus is a 2012 film that serves as a prequel.
# The Great Gatsby is a game.
# Maynard James Keenan is a singer.
# Emmy Rossum is a director.
# India is a republic in South Asia.
# There is a country called Colombia.
# Jim Carrey is a performer who portrays a character.
# Jim Carrey is a performer who portrays a character.
# Her is a film.
# University of Oxford is a book.
# Willie Nelson is a country songwriter.
# Gold is a metal.
# Extracorporeal shockwave therapy (ESWT) is a diagnosis.
# Look at My Dab is by an American hip hop group and it is a turning point in music.
# There is a county in Southern California.
# There is a county in Southern California.
# Saturn is a Christian state.
# Underworld is a 2003 supernatural film.
# Velaiilla Pattadhari 2 is a film.
# Saint Peter is a saint in the Christian tradition.
# Faith Evans is a writer as well as actor.
# Adele is a person.
# Adele is a person.
# Adele is a person.
# Adele is a person.
# Adele is a person.
# Adele is a person.
# Adele is a person.
# Miss Peregrine's Home for Peculiar Children is a story about a boy.
# Miss Peregrine's Home for Peculiar Children is a story about a boy.
# Ketogenic diet is a classic diet of more fat than carbohydrates and protein combined.
# Mel Brooks is a squid.
# The gray wolf is a species of Canis.
# James Wilson is a real medical practitioner.
# Performance (film) is a motion picture.
# Baby Driver is a Nigerian film.
# Following is a film.
# Tanzania is a country.
# Tanzania is a country.
# The Wild Thornberrys is a film.
# Mauritius is a landlocked nation.
# Mauritius is a landlocked nation.
# Look at My Dab is a work.
# Scott Eastwood is a lawnmower.
# Scott Eastwood is a lawnmower.
# Miley Cyrus is a singer.
# Hannah Simone is a race-car driver.
# Olivia Wilde is a Texan.
# Macbeth is a film.
# The Simpsons is a recorded work.
# The Simpsons is a recorded work.
# Beautiful People is a film.
# The Vampire Diaries is a supernatural television series created in the United States.
# The Fujitsu iPAD is a handheld device.
# Haim Saban is a philanthropist.
# Patch Adams (film) is a film starring American actor Robin Williams.
# There is a drama called Heartland.
# Paul Pogba is a soccer player.
# Paul Pogba is a soccer player.
# Paul Pogba is a soccer player.
# Paul Pogba is a soccer player.
# Terminator Salvation is a post-apocalyptic science fiction war film.
# Zendaya is a performer.
# Zendaya is a performer.
# Miss Selfridge is a store.
# Poppy is a pop singer.
# Charles Haley is a former soccer forward and goalkeeper.
# The Voice is a show on NBC.
# The Voice is a show on NBC.
# Page Hamilton is a musician.
# Iran is a sovereign state.
# From the Earth to the Moon is a television miniseries.
# Ruth Negga is a television actress.
# Ruth Negga is a television actress.
# 24 is a science fiction film.
# 24 is a science fiction film.
# L.A. Law is a legal drama television series.
# The Weeknd is a Canadian lawyer.
# Paul Newman is a Canadian boxer that never lost a fight.
# Benin is a desert nation.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Shakira is a performer.
# Albania is a member.
# Mel Brooks is a comedian.
# Zinedine Zidane is a father.
# Suicide Kings is a film that was created in the year 1200.
# Chitty Chitty Bang Bang is a British film released in 1968.
# Instagram is a service.
# Angela Lansbury is a woman who acts.
# Dragon is a word in English.
# Glen Campbell is a Gemini.
# SpaceX is a company that focuses on technology.
# SpaceX is a company that focuses on technology.
# SpaceX is a company that focuses on technology.
# SpaceX is a company that focuses on technology.
# Lee Majors is a man who acts on television.
# The Breakfast Club is a movie.
# Sienna Miller is a Victoria's Secret model.
# Elementary is a Sherlock Holmes inspired show created by Robert Doherty.
# Adienne Bailon is a movie actress.
# Nas is a Spanish politician.
# Tropic Thunder is a movie.
# Mike Love is a dancer, playwright, and actor.
# There is a reboot called Kong: Skull Island.
# The Hobbit is a three film series.
# Only Lovers Left Alive is a film.
# Only Lovers Left Alive is a film.
# Wynonna Judd is a singer in country music.
# Julia Louis-Dreyfus is a female actor.
# Julia Louis-Dreyfus is a female actor.
# Overwatch is a board game.
# Jing Tian is a Gemini.
# The X Factor is a singing competition in the UK.
# Another One Bites the Dust is a song.
# Faith Evans is a person.
# Faith Evans is a person.
# Vincent van Gogh is a well-known artist from Amsterdam.
# Broadcast News is a 2017 film.
# Carole King is a singer-songwriter.
# Telangana is a part of Asia.
# Vienna is a township.
# The Divergent Series: Insurgent is a science fiction action amusement park.
# The Strain is a single episode.
# ...
# The gray wolf is a species unrelated to the Canis genus.
# Allen Ginsberg is a poet.
# Allen Ginsberg is a poet.
# German is a Western Romance Language.
# Rich Girl is a remake of Louchie Lou & Michie One's song of the same name.
# South Korea is a country.
# The Punisher is a character.
# Gary Ridgway is a killer.
# Andy Warhol is a person.
# Miss Peregrine's Home for Peculiar Children is a restaurant.
# Miss Peregrine's Home for Peculiar Children is a restaurant.
# Henry V is a television set.
# Kris Jenner is a musical influence of Kylie Jenner.
# The UK is a member of the Commonwealth of Nations, the Council of Europe, the G7 finance ministers, the G7 forum, the G20, NATO, the Organisation for Economic Co-operation and Development (OECD), and the World Trade Organization (WTO).
# Dracula is a book published in 1897.
# California is a U. S. state.
# California is a U. S. state.
# California is a U. S. state.
# California is a U. S. state.
# Chris Froome is a cyclist for team U.S.A.
# Zootopia is a title.
# Diego Luna is a gymnast.
# Hugh Hefer is a publisher of magazines and American.
# The Champ is a 1979 film.
# Instagram is a software program you can use to share photos.
# A Song of Ice and Fire is by someone who works in the science fiction genre and it is a novel series.
# Ketogenic diet is a difficult diet.
# Taylor Kitsch is a performer.
# Taylor Kitsch is a performer.
# Taylor Kitsch is a performer.
# Angelina Jolie is a person.
# Angelina Jolie is a person.
# Angelina Jolie is a person.
# Alexander Lukashenko is a writer.
# Shallow Hal is a comedy television show.
# Thor: The Dark World is a horror movie.
# Gucci is a brand of cars.
# Steve Buscemi is a singer.
# Kalpana Raghavendar is a musician.
# Junun is a 2015 documentary film.
# Gillian Anderson is a film, TV, and theatre actress.
# Ratatouille is a 2007 film which won at least one Oscar.
# Oliver Reed is a thespian.
# Oliver Reed is a thespian.
# Hotel Hell is a movie.
# Triple H is a pancakes executive.
# Page Hamilton is a guitarist.
# Wi-Fi is a term.
# Baahubali: The Beginning is a 2005 Indian film.
# Foxcatcher is a television show.
# There is a rock band called Coldplay.
# There is a rock band called Coldplay.
# There is a rock band called Coldplay.
# There is a rock band called Coldplay.
# Kristen Bell is a person.
# Kristen Bell is a person.
# Judd Apatow is a singer.
# Butter is a type of dairy spread.
# Ethan Hawke is a person.
# Ethan Hawke is a person.
# Ethan Hawke is a person.
# The Sopranos is a show not about illegal activity.
# Star Wars is a film.
# The only character in the movie Steel (1997) film is a dog named Joe.
# Alexander Lukashenko is a person.
# Marc Maron is a resident of Los Angeles.
# There is a television series that cast Naomi Watts.
# Ben Still is a comedic actor.
# Jamie Foxx is a record producer.
# Unapologetic is a Rihanna album.
# David Carradine is a film actor.
# David Carradine is a film actor.
# Star Trek is a television series.
# Unapologetic is a song.
# Beijing is a center.
# Haitian Creole is a language spoken by 9.6 to 12 million droids.
# Ron Perlman is a person.
# Ron Perlman is a person.
# Ron Perlman is a person.
# Keith Urban is a communist.
# It's Always Sunny in Philadelphia is a restaurant.
# It's Always Sunny in Philadelphia is a restaurant.
# Anaheim, California is a city in California.
# The Twilight Zone is a famous restaurant.
# Chris Mckenna is a person.
# Randy Orton is a professional acrobat.
# Avatar is a TV show.
# Big Show is a circus act.
# Tall Story is a film from the 1960's.
# Ricky Martin is a star in a North American country.
# Bangladesh is a country.
# Bangladesh is a country.
# Leicester City F.C. is a softball club.
# Leicester City F.C. is a softball club.
# Leicester City F.C. is a softball club.
# Leicester City F.C. is a softball club.
# Leicester City F.C. is a softball club.
# Indian is a crime thriller book.
# Zendaya is a person.
# Zendaya is a person.
# Zendaya is a person.
# IO Theater is a restaurant.
# Egypt is a member of the Aligned Movement.
# The Catalyst is a music composition.
# Francis Ford Coppola is a Scientologist.
# Donnie Wahlberg is a creative work producer.
# David Simon is a person.
# David Simon is a person.
# Galaxy Quest is a film.
# Gopalkrishna Gandhi is a retired officer.
# Mark Hamill is a worker.
# Mark Hamill is a worker.
# Mark Hamill is a worker.
# Serbia is a European country.
# Serbia is a European country.
# Elsa Pataky is a film producer and actress.
# Andrew Garfield is a waiter.
# Rosamund Pike is a performer.
# Adam Driver is a person who acts.
# Adam Driver is a person who acts.
# Adam Driver is a person who acts.
# Adam Driver is a person who acts.
# The Economic Times is a serial American publication containing news, articles, and advertising.
# Metallica is a band based in America.
# Jeff Hardy is a world champion.
# Ireland is a land mass.
# Laureline is a character in Valerian and the City of a Thousand Planets.
# London is a region of France.
# London is a region of France.
# The Beach Boys is a band.
# The Beach Boys is a band.
# The Beach Boys is a band.
# Usain Bolt is a swimmer.
# Jaden Smith is a singer.
# Hawaii is a state in the United States.
# Hawaii is a state in the United States.
# The Great Buck Howard is a death eater.
# Hamlet (1990 film) is a film.
# Nikita is a reboot of a TV series based on the film Nikita.
# In Too Deep is a 1999 American crime thriller top grossing film.
# Jessica Chastain is a performer.
# Russell Brand is a dancer.
# Lisa Marie Presley is a musician.
# Ajay Devgn is a Japanese director.
# Poland is a place.
# Whoopi Goldberg is a person.
# Romelu Lukaku is a member of the Premier League.
# George Clooney is a Martian.
# George Clooney is a Martian.
# George Clooney is a Martian.
# George Clooney is a Martian.
# George Clooney is a Martian.
# Gang Signs & Prayer is a debut single.
# Gang Signs & Prayer is a debut single.
# Pornhub is a pornographic website.
# Outlander is a German-American television series.
# There is a band called Imagine Dragons.
# Baloo is a main fictional character.
# Gia is a biographical film.
# Jim Rash is a brand name.
# Jim Rash is a brand name.
# Jim Rash is a brand name.
# The Illusionist (2006 film) is a 2006 film.
# Garry Kasparov is a person.
# Garry Kasparov is a person.
# Garry Kasparov is a person.
# Paul Wesley is a Texan.
# Catherine Zeta-Jones is a person who acts.
# Catherine Zeta-Jones is a person who acts.
# Catherine Zeta-Jones is a person who acts.
# Catherine Zeta-Jones is a person who acts.
# Haitian Creole is a language spoken by less than 9.6 to 12 million people.
# Rio de Janeiro is a city.
# Rio de Janeiro is a city.
# Johan Heldenbergh is a singer.
# Twenty One Pilots is a movie.
# Usher (musician) is a singer.
# Usher (musician) is a singer.
# Usher (musician) is a singer.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Berlin is a place.
# Stand-up comedy is a style.
# Splatoon 2 is a video game on the Nintendo Switch.
# Conor McGregor is a professional mixed martial artist.
# See You Again is a song from 1983.
# See You Again is a song from 1983.
# Roald Dahl is a person.
# Stagira is a Greek city.
# Olivia Munn is a person.
# Olivia Munn is a person.
# The United Kingdom is a member of no organizations.
# The blue-ringed octopus is a terrestrial animal.
# Denzel Washington is a vegetarian.
# Lily Collins is a woman who acts.
# The Wild Thornberrys is a only a book.
# Patricia Lea ``Patty'' Jenkins  is a screenwriter.
# Conan O'Brien is a TV host.
# Diary of the Dead is a film by George A. Romero.
# Ellyse Perry is a mother.
# Break on Me is a part of a studio album.
# Wayne Rooney is a soccer player.
# Wayne Rooney is a soccer player.
# Wayne Rooney is a soccer player.
# Wayne Rooney is a soccer player.
# Wayne Rooney is a soccer player.
# The Divergent Series: Allegiant is a film.
# Massachusetts is a global leader in poverty.
# Nicole Kidman is a citizen of Australia and the United States.
# There is a TV series called Prisoner.
# Ray Milland is a film actor.
# Constantine is a film about an occult detective.
# Rupert Wyatt is a director.
# Rupert Wyatt is a director.
# Bernie Sanders is a self-described monkey.
# Michael Schumacher is a Formula One driver.
# Neil Young is a guitar player.
# Colm Feore is a film actor.
# Adrien Broner is a professional musician.
# The United Kingdom is a developed European country.
# Grace VanderWaal is a performer.
# A Few Good Men is a film.
# Little Miss Sunshine is a TV series.
# Little Miss Sunshine is a TV series.
# Emily Ratajkowski is a person.
# Emily Ratajkowski is a person.
# Beijing is a place.
# "My Wife" is a single recorded by Nick Cannon.
# Cher is a performer.
# Cher is a performer.
# Cher is a performer.
# Istanbul is a primate city.
# The Wizard of Oz is a film.
# Good Will Hunting is a recorded work.
# Ava DuVernay is a Christian.
# Music artist is a profession of Christina Aguilera's
# Chris Froome is a successful rider in racing competitions.
# Chris Froome is a successful rider in racing competitions.
# Justin Timberlake is a singer-songwriter from the United States.
# There is a county in Southern California.
# Outfit (retailer) is a European company.
# Constantine is a 2005 film.
# Halle Berry is a person.
# Saint Peter is a Christian saint.
# Eddie Vedder is a lion.
# Varun Dhawan is a person.
# Varun Dhawan is a person.
# Varun Dhawan is a person.
# Escape from Planet Earth is a film.
# Anaconda is a song.
# The internet is a global system.
# Peggy Sue Got Married is a comedy-drama play.
# Shawn Michaels is a professional wrestler that has been inducted into the WWE Hall of Fame.
# Mao Zedong is a Chinese poet and visionary.
# Tanzania is a place.
# There is a movie called Good Will Hunting.
# Hawaii is a state.
# Unforgettable is a 2017 book.
# Frank Ocean is a singer and has a 6 octave range.
# Directing is a profession of Kenneth Branagh.
# Vincente Minnelli is a film and stage director.
# Game of Thrones is a television series.
# Game of Thrones is a television series.
# Michael Schumacher is a race car driver in Formula One.
# Her is a film.
# Anne Bancroft is a star.
# Tezaab is a Tamil language film.
# Jeff Hardy is a tag team wrestler.
# The Night Of is a miniseries.
# Khal Drogo is a Dothraki.
# The Girl on the Train is a mystery thriller drama film.
# Eragon is a film incapable of starring Garrett Hedlund.
# Alkaline Trio is a river.
# Alkaline Trio is a river.
# Alkaline Trio is a river.
# Apple Inc. is a U.S company.
# The 12-hour clock is a time convention that splits the 24 hours of the day.
# Berlin is a place.
# Berlin is a place.
# Rupert Wyatt is a horse.
# Neal Schon is a guitarist.
# Zootopia is a painting.
# Apple Inc. is a U.S technology company.
# Glee is a movie.
# The Weeknd is a person who sings.
# Ron Cobb is a comic book artist.
# Jared Kushner is a publication owner.
# Slash is a hard rock musician.
# Benin is a tropical fruit.
# Benin is a tropical fruit.
# Benin is a tropical fruit.
# The Belko Experiment is a Canadian romantic novel.
# Juana la virgen is a telenovela penned by a television screenwriter from Venezuela.
# Goliyon Ki Raasleela Ram-Leela is a film released after 2010.
# The Outcasts is a film.
# Ghost in the Shell is a cyberpunk-themed video game.
# John Constantine is a Marvel comics character.
# Kim Basinger is a person who acts.
# Kim Basinger is a person who acts.
# Adam West is a performer.
# Arnold Schwarzenegger is a film actor.
# Arnold Schwarzenegger is a film actor.
# Arnold Schwarzenegger is a film actor.
# Arnold Schwarzenegger is a film actor.
# Tokyo Ghoul (film) is a dark fantasy action horror work.
# The Offspring is a band.
# Tom Cruise is a Taurus.
# Honey to the B is a pop album released in 1998.
# Catching Fire is a painting.
# Greenwich is a mountain range.
# The Punisher is a fictional comic book character.
# G-Dragon is a musical artist.
# G-Dragon is a musical artist.
# G-Dragon is a musical artist.
# G-Dragon is a musical artist.
# G-Dragon is a musical artist.
# Lucas is a film.
# Snooki is a television host.
# Ranbir Kapoor is a person who works in the film industry.
# Ranbir Kapoor is a person who works in the film industry.
# Ranbir Kapoor is a person who works in the film industry.
# Iran has large reserves of fossil fuels and it is a large country.
# Mukesh Ambani is a shareholder of Apple.
# Farrah Fawcett acted in Money is a Funny Thing.
# California Gurls is a movie.
# Raphael Bob-Waksberg is a singer.
# Loni Love is a performer.
# The Great Outdoors (film) is a comedy film.
# Drake is a rapper.
# Jerry Seinfeld is a director.
# Google is a North American company.
# Heikegani is a painting of decapod crustacean.
# Hawaii is a place.
# Hawaii is a place.
# There is a large hill in Montreal known as Mount Royal.
# Ava DuVernay is a person with a vocation of any kind.
# Love & Friendship is a commercial.
# Carice van Houten is a person.
# Carice van Houten is a person.
# Little Mix is a car.
# Tony Goldwyn is a German producer.
# Moscow is a place.
# Moscow is a place.
# Moscow is a place.
# Moscow is a place.
# Terminator Salvation is a Russian film.
# Melbourne is a city in Australia.
# Melbourne is a city in Australia.
# Melbourne is a city in Australia.
# Nicole Kidman is a Companion in the Order of Australia.
# Alkaline Trio is a punk rock gospel band.
# Ricky Martin is a singer.
# Jennifer Garner is a board member of Doctors Without Borders.
# Selena Gomez is a person.
# Nikita is a TV series.
# Mr. Freeze is a fictional supervillain.
# Marta Kauffman is a writer on a TV show.
# Tony Blair is a member of the Labour Party.
# Home Alone is a Christmas movie from 1990.
# Missing is a future horror film.
# Hotel Transylvania is a horror film.
# Room 93 is a creative work.
# Weightlifting Fairy Kim Bok-joo is a comic book.
# Poppy (singer) is a Canadian YouTube personality.
# Gay is a word contained in the acronym LGBT.
# Seville is a place that is larger than a town.
# The Craft is a 1996 film.
# Josh Duhamel is a person.
# A phylogenetic tress is a diagram that branches.
# Rembrandt is a composer from Amsterdam.
# Pineapple Express is a French film.
# Loki is a deity in Norse mythology.
# Paris is a major center of the humanitarian studies.
# Star Trek is a thing.
# Star Trek is a thing.
# Weightlifting Fairy Kim Bok-joo is a K-drama.
# Calvin Harris is a musician.
# Calvin Harris is a musician.
# Calvin Harris is a musician.
# Bronson (film) is a 2008 British film.
# D. B. Weiss is a director.
# D. B. Weiss is a director.
# Jack Nicholson is a person.
# Olivia Wilde is a Buddhist.
# Athena is a goddess.
# Tuvalu is a Christian country.
# Glee is a TV show.
# Wolverine is a character in comics.
# The United Kingdom is a developing country.
# Dhool is a film directed by an Indian.
# The Matrix Revolutions is a 2003 film.
# The Conjuring 2 is a 1993 film.
# Dhool is a film.
# Yusuke Murata is a writer.
# Fernando Alonso is a winner of something.
# Just the Way You Are is a piece of music.
# Keanu Reeves is a bassist.
# Green Arrow is a comic book character who first appeared in the Golden Age of Comics.
# Andrew Garfield is a film actor.
# Just the Way You Are is a song.
# Just the Way You Are is a song.
# Just the Way You Are is a song.
# Maggie Smith is a person.
# Constantine is a television show.
# Constantine is a television show.
# Arrow is a place.
# Arrow is a place.
# Furia is from 1999 and it is a film.
# Hungary is a member of a group.
# Radioactive is a song.
# Colm Feore is a television actor.
# Gareth Neame is a producer.
# Kurt Angle is a wrestler.
# Kurt Angle is a wrestler.
# Kurt Angle is a wrestler.
# Kurt Angle is a wrestler.
# Kurt Angle is a wrestler.
# Heartland is a show.
# Splash is a German fantasy romantic comedy film.
# Pacific Rim is a comic book.
# Steffi Graf is a tennis player.
# Steffi Graf is a tennis player.
# Vito Corleone is a father.
# Azerbaijan is a city.
# Azerbaijan is a city.
# Thailand is a country in Asia.
# Quinoa is a herbaceous annual plant.
# Yardie is a work.
# Yardie is a work.
# Lilith is a Hebrew-language text.
# George Orwell is a writer.
# John Williams is a pharmacist.
# David Simon is a Mormon.
# Catching Fire is a sequel.
# Ben Affleck is a director.
# We Found Love is a romance novel.
# We Found Love is a romance novel.
# We Found Love is a romance novel.
# We Found Love is a romance novel.
# We Found Love is a romance novel.
# We Found Love is a romance novel.
# The Invention of Lying is a recorded production.
# The Invention of Lying is a recorded production.
# Artemis is a Hellenic goddess, praised monthly on every third Sunday.
# Dwayne Johnson is a dual National.

# %%
# IDEA: leverage information about bithday
from tqdm import tqdm
from datetime import datetime
import sys




months_list = [
    "January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"
]





def clean_name(name):
    # Remove trailing characters like '(' and strip any leading/trailing whitespace
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    # Split the name into components and check if all components start with a capital letter
    name_components = cleaned_name.split()
    if all(component[0].isupper() for component in name_components):
        return cleaned_name
    return False

def strip_name(name):
    pronoms = {'he','she'}
    final_name = ''
    cleaned_name = re.sub(r'[^A-Za-z\s]', '', name).strip()
    name_components = cleaned_name.split()
    for index,component in enumerate(name_components):
        if component.lower() in pronoms: return False
        if component[0].isupper(): final_name+=component.strip()
        if index != len(name_components)-1: final_name+=' '
    return final_name

def clean_time(date_str):
        # Remove parentheses and "born"
        date_str = date_str.strip('() ').replace('born ', '')
        try:
            # Parse the date
            date_obj = datetime.strptime(date_str, '%B, %d , %Y')
            # Format the date in the desired format
            return date_obj.strftime('%B, %d, %Y')
        except ValueError as e:
            print(f"Error parsing date: {date_str}")
            return False  # Return original date string if parsing fails
        
def extract_date_components(date_str,pattern,months_list):
    matches = pattern.findall(date_str)
    day, month, year = None, None, None
    for match in matches:
        if match[0]:
            day = match[0]
      
        if match[1]:
            month = match[1]
        if match[2]:
            year = match[2]
        
        # more check to avoid error!
        if day and not (1 <= int(day) <= 31):
            day = None
        if month and month not in months_list:
            month = None
        
    return day, month, year

def check_location(text):
    doc = nlp(text)
    locations = []
    
    # iterate over the entities 
    for ent in doc.ents:
        if ent.label_ == "GPE":  # GPE (Geopolitical Entity) is the label used for locations
            locations.append(ent.text)    

    return locations




#AUXILIAR METHOD FOR EACH CASE
def be():
    pass




## TODO: manca solo da creare nuovi sample
def create_birthday_samples(filtered_dataset,months_list):

    most_frequent_verbs = {}




    info_premises = []
    info_hps = []


    pattern_time = re.compile(r'(?:(?P<day>\d{1,2})(?:st|nd|rd|th)?[ ,]*)?(?:(?P<month>[A-Za-z]+)[ ,]*)?(?:(?P<year>\d{4}))?')
    for index,elem in tqdm(enumerate(filtered_dataset)):


        info_premise = {}
        info_hp = {}

        info_premise['Arg0'] = []
        info_premise['Arg1'] = []
        info_premise['Arg2'] = []
        info_hp['Arg0'] = []
        info_hp['Arg1'] = []
        info_hp['Arg2'] = []

        


        info_hp_added = False
        info_pre_added = False

        new_sample = {}

        info_elem = {} # a dictionary in which I store the information of who is born
        

        premise = elem['premise']

        id = elem['id']
        info_elem['id'] = id

        text_pre = elem['premise']
        text_hp = elem['hypothesis']

        wsd_pre = elem['wsd']['premise']
        wsd_hp = elem['wsd']['hypothesis']
        srl_pre = elem['srl']['premise']
        srl_hp = elem['srl']['hypothesis']

        tokens_pre = srl_pre['tokens']
        tokens_hp= srl_hp['tokens']
        annotations_pre = srl_pre['annotations']
        annotations_hp = srl_hp['annotations']


        

        for annotation_pre in annotations_pre:

            #reference verb of annotation
            token_index = annotation_pre['tokenIndex']
            verb = tokens_pre[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_pre['verbatlas']
            propbankAnn = annotation_pre['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']

            roles_pb = propbankAnn['roles']


            for role in roles_pb:
                role_info = role['role']
                span = role['span']
                text = get_text_from_span(tokens_pre, span)

                if role_info == 'ARG0':
                    info_premise['Arg0'].append(text)
                elif role_info == 'ARG1':
                    info_premise['Arg1'].append(text)
                elif role_info == 'ARG2':
                    info_premise['Arg2'].append(text)
            
            
        info_premises.append(info_premise)
        print(f"roles_pb -> {srl_pre}")



        # HYPOTHESIS
        for annotation_hp in annotations_hp:

            #reference verb of annotation
            token_index = annotation_hp['tokenIndex']
            verb = tokens_hp[token_index]["rawText"]
            # print(f"verb = {verb}")
            verbatlasAnn =  annotation_hp['verbatlas']
            propbankAnn = annotation_hp['englishPropbank']
            # print(verbatlasAnn)
            # take the roles 
            roles = verbatlasAnn['roles']
            frame_name = verbatlasAnn['frameName']
            frame_name_pb = propbankAnn['frameName']
            roles_pb = propbankAnn['roles']

            for role in roles_pb:
                role_info = role['role']
                span = role['span']
                text = get_text_from_span(tokens_pre, span)

                if role_info == 'ARG0':
                    info_hp['Arg0'].append(text)
                elif role_info == 'ARG1':
                    info_hp['Arg1'].append(text)
                elif role_info == 'ARG2':
                    info_hp['Arg2'].append(text)


        info_hps.append(info_hp)

        print(f"info_premises -> {info_premises}")
        print(f"info_hps -> {info_hps}")

        break



        

            

            

            


            
                    
                    

    

    # # print("info extracted -> ",info_elem)
    # print(f"info pre -> {info_premise}")
    # print(f"info hp -> {info_hp}")
    # break
        


    
  

    return info_premises,info_hps


info_premises,info_hps = create_birthday_samples(nli_dataset['train'],months_list)
# print(len(nli_dataset['train']))
# Out:
# 0it [00:00, ?it/s]
# roles_pb -> {'tokens': [{'index': 0, 'rawText': 'Roman'}, {'index': 1, 'rawText': 'Atwood'}, {'index': 2, 'rawText': '.'}, {'index': 3, 'rawText': 'He'}, {'index': 4, 'rawText': 'is'}, {'index': 5, 'rawText': 'best'}, {'index': 6, 'rawText': 'known'}, {'index': 7, 'rawText': 'for'}, {'index': 8, 'rawText': 'his'}, {'index': 9, 'rawText': 'vlogs'}, {'index': 10, 'rawText': ','}, {'index': 11, 'rawText': 'where'}, {'index': 12, 'rawText': 'he'}, {'index': 13, 'rawText': 'posts'}, {'index': 14, 'rawText': 'updates'}, {'index': 15, 'rawText': 'about'}, {'index': 16, 'rawText': 'his'}, {'index': 17, 'rawText': 'life'}, {'index': 18, 'rawText': 'on'}, {'index': 19, 'rawText': 'a'}, {'index': 20, 'rawText': 'daily'}, {'index': 21, 'rawText': 'basis'}, {'index': 22, 'rawText': '.'}, {'index': 23, 'rawText': 'His'}, {'index': 24, 'rawText': 'vlogging'}, {'index': 25, 'rawText': 'channel'}, {'index': 26, 'rawText': ','}, {'index': 27, 'rawText': '`'}, {'index': 28, 'rawText': '`'}, {'index': 29, 'rawText': 'RomanAtwoodVlogs'}, {'index': 30, 'rawText': "''"}, {'index': 31, 'rawText': ','}, {'index': 32, 'rawText': 'has'}, {'index': 33, 'rawText': 'a'}, {'index': 34, 'rawText': 'total'}, {'index': 35, 'rawText': 'of'}, {'index': 36, 'rawText': '3.3'}, {'index': 37, 'rawText': 'billion'}, {'index': 38, 'rawText': 'views'}, {'index': 39, 'rawText': 'and'}, {'index': 40, 'rawText': '11.9'}, {'index': 41, 'rawText': 'million'}, {'index': 42, 'rawText': 'subscribers'}, {'index': 43, 'rawText': '.'}, {'index': 44, 'rawText': 'He'}, {'index': 45, 'rawText': 'also'}, {'index': 46, 'rawText': 'has'}, {'index': 47, 'rawText': 'another'}, {'index': 48, 'rawText': 'YouTube'}, {'index': 49, 'rawText': 'channel'}, {'index': 50, 'rawText': 'called'}, {'index': 51, 'rawText': '`'}, {'index': 52, 'rawText': '`'}, {'index': 53, 'rawText': 'RomanAtwood'}, {'index': 54, 'rawText': "''"}, {'index': 55, 'rawText': ','}, {'index': 56, 'rawText': 'where'}, {'index': 57, 'rawText': 'he'}, {'index': 58, 'rawText': 'posts'}, {'index': 59, 'rawText': 'pranks'}, {'index': 60, 'rawText': '.'}], 'annotations': [{'tokenIndex': 4, 'verbatlas': {'frameName': 'COPULA', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [3, 4]}, {'role': 'Attribute', 'score': 1.0, 'span': [5, 22]}]}, 'englishPropbank': {'frameName': 'be.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [3, 4]}, {'role': 'ARG2', 'score': 1.0, 'span': [5, 22]}]}}, {'tokenIndex': 6, 'verbatlas': {'frameName': 'KNOW', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [3, 4]}, {'role': 'Attribute', 'score': 1.0, 'span': [5, 6]}, {'role': 'Topic', 'score': 1.0, 'span': [7, 22]}]}, 'englishPropbank': {'frameName': 'know.01', 'roles': [{'role': 'ARG1', 'score': 1.0, 'span': [3, 4]}, {'role': 'ARGM-MNR', 'score': 1.0, 'span': [5, 6]}, {'role': 'ARG2', 'score': 1.0, 'span': [7, 22]}]}}, {'tokenIndex': 13, 'verbatlas': {'frameName': 'RECORD', 'roles': [{'role': 'Location', 'score': 1.0, 'span': [8, 10]}, {'role': 'Agent', 'score': 1.0, 'span': [12, 13]}, {'role': 'Theme', 'score': 1.0, 'span': [14, 18]}, {'role': 'Time', 'score': 1.0, 'span': [18, 22]}]}, 'englishPropbank': {'frameName': 'post.01', 'roles': [{'role': 'ARGM-LOC', 'score': 1.0, 'span': [8, 10]}, {'role': 'R-ARGM-LOC', 'score': 1.0, 'span': [11, 12]}, {'role': 'ARG0', 'score': 1.0, 'span': [12, 13]}, {'role': 'ARG1', 'score': 1.0, 'span': [14, 18]}, {'role': 'ARGM-TMP', 'score': 1.0, 'span': [18, 22]}]}}, {'tokenIndex': 32, 'verbatlas': {'frameName': 'EXIST-WITH-FEATURE', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [23, 32]}, {'role': 'Attribute', 'score': 1.0, 'span': [33, 43]}]}, 'englishPropbank': {'frameName': 'have.03', 'roles': [{'role': 'ARG0', 'score': 1.0, 'span': [23, 32]}, {'role': 'ARG1', 'score': 1.0, 'span': [33, 43]}]}}, {'tokenIndex': 46, 'verbatlas': {'frameName': 'EXIST-WITH-FEATURE', 'roles': [{'role': 'Theme', 'score': 1.0, 'span': [44, 45]}, {'role': 'Attribute', 'score': 1.0, 'span': [47, 60]}]}, 'englishPropbank': {'frameN ...
# info_premises -> [{'Arg0': ['he posts', "His vlogging channel , ` ` RomanAtwoodVlogs '' , has", 'He also', 'he posts'], 'Arg1': ['He is', 'He is', 'updates about his life on', 'a total of 3.3 billion views and 11.9 million subscribers .', "another YouTube channel called ` ` RomanAtwood '' , where he posts pranks .", 'another YouTube channel called', 'pranks .'], 'Arg2': ['best known for his vlogs , where he posts updates about his life on a daily basis .', 'for his vlogs , where he posts updates about his life on a daily basis .', "` ` RomanAtwood '' ,"]}]
# info_hps -> [{'Arg0': [], 'Arg1': ['Roman Atwood .'], 'Arg2': ['He is best known']}]

# %%
for elem1,elem2 in zip(info_premises,info_hps):
    print("premise::  ", elem1)
    print("hp::  ", elem2)


# for elem in info_hps:
#     print(elem)
# Out:
# premise::   {'Arg0': [], 'Arg1': ['He is'], 'Arg2': []}
# hp::   {'Arg0': [], 'Arg1': ['Roman Atwood is'], 'Arg2': ['a content creator .']}

# %% [markdown]
# # Model

# %%
# MODEL
# Initialize the model

model = AutoModelForSequenceClassification.from_pretrained(language_model_name,
                                                                   ignore_mismatched_sizes=True,
                                                                   output_attentions=False, output_hidden_states=False,
                                                                   num_labels=3) # number of the classes to change to 3

tokenizer = AutoTokenizer.from_pretrained(language_model_name)

# padding with the most long sentence!
data_collator = DataCollatorWithPadding(tokenizer=tokenizer) # avoid to use can reduce the memory on GPU

#examples are batch!
def tokenize_function(examples):
    examples["label"] = [labels_mapping[label] for label in examples["label"]]
    return tokenizer(examples["premise"], examples["hypothesis"],padding = True, truncation=True)




# Tokenize the dataset ...
print("Tokenize the dataset ...")
labels_mapping = {"ENTAILMENT":0, "CONTRADICTION":1, "NEUTRAL":2 }
tokenized_nli_dataset= nli_dataset.map(tokenize_function, batched=True)

print(tokenized_nli_dataset["train"][0])

# %%
# DATASET EXPLORATION
print(f"nli_dataset -> {nli_dataset}")

#MODEL TRAINING

training_args = TrainingArguments(
    output_dir="training_dir",                    # output directory [Mandatory]
    num_train_epochs=epochs,                      # total number of training epochs
    per_device_train_batch_size=batch_size,       # batch size per device during training
    warmup_steps=500,                             # number of warmup steps for learning rate scheduler
    weight_decay=weight_decay,                    # strength of weight decay
    save_strategy="no",                           # save the model
    learning_rate=learning_rate,                  # learning rate
    gradient_checkpointing = True                 # to reduce memory usage
    # fp16 = True                                 # to reduce more memory usage
)


trainer = Trainer(
   model=model,
   args=training_args,
   train_dataset=tokenized_nli_dataset["train"],
   eval_dataset=tokenized_nli_dataset["validation"],
   tokenizer=tokenizer,
   data_collator=data_collator,
   compute_metrics=compute_metrics,
)


trainer.train()

# %%
trainer.evaluate()
